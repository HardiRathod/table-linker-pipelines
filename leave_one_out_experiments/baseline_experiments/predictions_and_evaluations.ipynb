# %% [markdown]
# ## Purpose: A quick notebook to get the predictions and metric results
# Parameters to Set:
# - Input data path
# - Features to include
# - Model to use for prediction
# - Scaler to use for prediction
# - Experiment Name so as to store the results
# - The new column name for the files
# Outputs
# - Top 5 Ranked files
# - Metrics Result witt & without combining
# - Colorized files

# %%
import pandas as pd
import os
import glob
import numpy as np

# %%
##Here we will get location of all complete datasets.
main_dataset_location = '/nas/ckgfs/kgtk/hrathod/scratch/datasets/'
dataset_folder_location = '/complete_data/features/'
# to get to semtab data, we need to go -> main_dataset_location/{semtab_data}/datat2dv2set_folder_location
datasets = "semtab_data,t2dv2_data,limaye_data,bio_div_data,2t_data"

# %%
features = ["monge_elkan","monge_elkan_aliases","jaro_winkler",
            "levenshtein","singleton","context_score_3","pgt_centroid_score","pgt_class_count_tf_idf_score",
            "pgt_property_count_tf_idf_score", "num_occurences", "incorrectness_scores"]

# %%
final_score_column = "siamese_prediction"

# %%
#Mention the test dataset
test_dataset = "semtab_data"
experiment_number = "Experiment_test_semtab"
titled = "_reduced"
result_main_location = f"Experiment/results/{experiment_number+titled}/"
result_predictions_location = f"Experiment/results/{experiment_number+titled}/test/test_predictions_top_k"
result_metrics_location = f"Experiment/results/{experiment_number+titled}/test/test_predictions_metrics/"
result_colorized_location= f"Experiment/results/{experiment_number+titled}/test/test_predictions_colored/"
result_train_predictions_location = f"Experiment/results/{experiment_number+titled}/test/test_predictions_metrics/"
result_train_metrics_location = f"Experiment/results/{experiment_number+titled}/test/test_predictions_metrics/"
# !mkdir -p $result_main_location
# !mkdir -p $result_predictions_location
# !mkdir -p $result_metrics_location
# !mkdir -p $result_colorized_location
# !mkdir -p $result_train_predictions_location
# !mkdir -p $result_train_metrics_location

# %%
import boto3
s3 = boto3.client('s3')

# %%
model_path = f'Experiments/{experiment_number}/final_models/cell/top1_0.7520739963764661_epoch_1_loss_0.19324207305908203_batch_size_32_learning_rate_1e-05.pth'
min_max_scaler_path = f"Experiments/{experiment_number}/model_training_data/tl_pipeline_normalization_factor.pkl"
s3.download_file('table-linker-datasets', model_path,
                 'model_2.pth')
s3.download_file('table-linker-datasets',
                 min_max_scaler_path,
                 'normalization_factor_2.pkl')
model_path = 'model_2.pth'
min_max_scaler_path = 'Experiment/Exp_test_semtab/training_data/tl_pipeline_normalization_factor.pkl'

# %%
# !mkdir -p complete_dataset

# %%
def dev_prediction(dev_feature_path, dev_predictions_top_k, saved_model, output_column, min_max_scaler_path, k, dev_predictions_metrics):
    print(dev_feature_path)
    df_list = []
    for file in glob.glob(dev_feature_path + '/*.csv'):
        print(file)
        filename = file.split("/")[-1]

        dev_output = f"{dev_predictions_top_k}/{filename}"
        if os.path.exists(dev_output):
            continue
        df = pd.read_csv(file)
        df = df[df['evaluation_label'] != '[]']
        df.to_csv(file, index=False)
        feature_str =  ",".join(features)
        if os.path.getsize(file) == 0:
            continue

        
        # location where the output generated by the predictions wil be stored.

        k = '5'
        print(output_column, k, dev_output, file)
        # !tl predict-using-model $file -o $output_column \
            --features $feature_str \
            --ranking-model $saved_model \
            --normalization-factor $min_max_scaler_path \
            / get-kg-links -c $output_column -k $k --k-rows \
            > $dev_output
        filename = file.split("/")[-1]
        print(filename)
        if os.path.getsize(file) == 0:
                    continue
        k_2 = '1'
        score_column = output_column
        dev_metrics_file = f"{dev_predictions_metrics}/{filename}"
        # !tl metrics $dev_output -k $k_2 -c $score_column --tag $filename> $dev_metrics_file
        df_list.append(pd.read_csv(dev_metrics_file))
    return pd.concat(df_list)
        
def add_color(dev_predictions_top_k, dev_colorized_path, score_column, k=5):
    for file in glob.glob(dev_predictions_top_k + '/*.csv'):
        filename = file.split("/")[-1]
        print(filename)
        if os.path.getsize(file) == 0:
                    continue
                
        dev_color_file = f"{dev_colorized_path}/{filename[:-4]}.xlsx"
        # !tl add-color $file -c "$score_column,evaluation_label" -k $k --output $dev_color_file
'''
def metrics(column, file_path=None, df=None, k: int = 1, tag=""):
    """
    computes the precision, recall and f1 score for the tl pipeline.
    Args:
        column: column with ranking score
        file_path: input file path
        df: or input dataframe
        k: calculate recall at top k candidates
        tag: a tag to use in the output file to identify the results of running the given pipeline
    Returns:
    """
    if file_path is None and df is None:
        raise RequiredInputParameterMissingException(
            'One of the input parameters is required: {} or {}'.format('file_path', 'df'))

    if file_path:
        df = read_csv(file_path, dtype=object)

    # remove duplicate candidates if exist
    df = normalize_scores.drop_duplicate("kg_id", [column], df=df)

    # replace na to 0.0
    df[column] = df[column].astype(float).fillna(0.0)
    df['max_score'] = df.groupby(by=['column', 'row'])[column].transform(max)

    # relevant df
    rdf = df[df['evaluation_label'].astype(float) != 0.0]

    col_grouped = rdf.groupby(by=['column'])
    results = []
    for col, cgdf in col_grouped:
        # true positive for precision at 1
        tp_ps = []

        # true positive for recall at k
        tp_rs = defaultdict(list)
        grouped = cgdf.groupby(by=['row'])
        n = len(grouped)
        for key, gdf in grouped:
            gdf = gdf.sort_values(by=[column, 'kg_id'], ascending=[False, True]).reset_index()

            for i, row in gdf.iterrows():
                if float(row['evaluation_label']) == 1 and row[column] == row['max_score']:
                    tp_ps.append(key)

                # this df is sorted by score, so highest ranked candidate is rank 1 and so on...
                rank = i + 1
                if rank <= k and (row['evaluation_label'] == '1' or row['evaluation_label'] == 1.0):
                    tp_rs[k].append(key)

        precision = float(len(tp_ps)) / float(n)
        recall = {k: float(len(each_tp_rs)) / float(n) for k, each_tp_rs in tp_rs.items()}
        # sort as k value increasing
        recall = {k: v for k, v in sorted(recall.items(), key=lambda x: x[0])}

        for _k, each_recall in recall.items():
            if precision == 0 and each_recall == 0:
                f1_score = 0.0
            else:
                f1_score = (2 * precision * each_recall) / (precision + each_recall)
            results.append({"k": _k,
                            'f1': f1_score,
                            'precision': precision,
                            'recall': each_recall,
                            'column': col,
                            'tag': tag})

    output_df = pd.DataFrame(results)
    return output_df
'''
def compute_metrics(dev_predictions_top_k, dev_predictions_metrics, score_column, k=1):
    df_list = []
    for file in glob.glob(dev_predictions_top_k + '/*.csv'):
        #print(file)
        #print(df)

        filename = file.split("/")[-1]
        print(filename)
        if os.path.getsize(file) == 0:
                    continue
                
        dev_metrics_file = f"{dev_predictions_metrics}/{filename}"
        # !tl metrics $file -k $k -c $score_column --tag $filename> $dev_metrics_file
        df_list.append(pd.read_csv(dev_metrics_file))
    return pd.concat(df_list)

# %%
# Getting the testing metrics
metrics_df = dev_prediction('../datasets/semtab_data/complete_data/features/', result_predictions_location, model_path, 'siamese_prediction', min_max_scaler_path, 5, result_metrics_location)
#dev_prediction(main_dataset_location+test_dataset+dataset_folder_location, result_predictions_location, model_path, "siamese_prediction", min_max_scaler_path, k=5)
# Out:
# ../datasets/semtab_data/complete_data/features/
# ../datasets/semtab_data/complete_data/features/00UQHNO3.csv
# ../datasets/semtab_data/complete_data/features/03XJOJ15.csv
# ../datasets/semtab_data/complete_data/features/06BZ6E4W.csv
# ../datasets/semtab_data/complete_data/features/06UFHM3B.csv
# ../datasets/semtab_data/complete_data/features/06ZS1QBE.csv
# ../datasets/semtab_data/complete_data/features/085QNFGZ.csv
# ../datasets/semtab_data/complete_data/features/090EELY2.csv
# ../datasets/semtab_data/complete_data/features/09Z268Z7.csv
# ../datasets/semtab_data/complete_data/features/0BY9CFLK.csv
# ../datasets/semtab_data/complete_data/features/0CHQAATH.csv
# ../datasets/semtab_data/complete_data/features/0D1JRXQD.csv
# ../datasets/semtab_data/complete_data/features/0DVQGVUW.csv
# ../datasets/semtab_data/complete_data/features/0HFY1TOW.csv
# ../datasets/semtab_data/complete_data/features/0HZG8QGJ.csv
# ../datasets/semtab_data/complete_data/features/0KL64BZL.csv
# ../datasets/semtab_data/complete_data/features/0LGYY0Y7.csv
# ../datasets/semtab_data/complete_data/features/0MYK9SQC.csv
# ../datasets/semtab_data/complete_data/features/0U3WMR09.csv
# ../datasets/semtab_data/complete_data/features/0UJRG5XA.csv
# ../datasets/semtab_data/complete_data/features/0VC79Y6X.csv
# ../datasets/semtab_data/complete_data/features/0VDX10IJ.csv
# ../datasets/semtab_data/complete_data/features/0VTG406B.csv
# ../datasets/semtab_data/complete_data/features/0XWQ7DA6.csv
# ../datasets/semtab_data/complete_data/features/0Z7HR2PY.csv
# ../datasets/semtab_data/complete_data/features/12MLK2A7.csv
# ../datasets/semtab_data/complete_data/features/14DACNEL.csv
# ../datasets/semtab_data/complete_data/features/15S9J1SE.csv
# ../datasets/semtab_data/complete_data/features/15ULGJXA.csv
# ../datasets/semtab_data/complete_data/features/15Z7HD0M.csv
# ../datasets/semtab_data/complete_data/features/18PQGWE2.csv
# ../datasets/semtab_data/complete_data/features/19NE0FCU.csv
# ../datasets/semtab_data/complete_data/features/19VR20Q8.csv
# ../datasets/semtab_data/complete_data/features/1A51CWBN.csv
# ../datasets/semtab_data/complete_data/features/1DT331RM.csv
# ../datasets/semtab_data/complete_data/features/1FIFDPBT.csv
# ../datasets/semtab_data/complete_data/features/1FPJTMCX.csv
# ../datasets/semtab_data/complete_data/features/1FXQQ1RM.csv
# ../datasets/semtab_data/complete_data/features/1H6S7TGO.csv
# ../datasets/semtab_data/complete_data/features/1I3AJ8QT.csv
# ../datasets/semtab_data/complete_data/features/1J4YRLOY.csv
# ../datasets/semtab_data/complete_data/features/1JCXMKCK.csv
# ../datasets/semtab_data/complete_data/features/1JGP7FA0.csv
# ../datasets/semtab_data/complete_data/features/1JMXOUP0.csv
# ../datasets/semtab_data/complete_data/features/1JV6896P.csv
# ../datasets/semtab_data/complete_data/features/1K47VLGF.csv
# ../datasets/semtab_data/complete_data/features/1O72GQD8.csv
# ../datasets/semtab_data/complete_data/features/1SEMN3SZ.csv
# ../datasets/semtab_data/complete_data/features/1T2D8C5C.csv
# ../datasets/semtab_data/complete_data/features/1T9NKN9B.csv
# ../datasets/semtab_data/complete_data/features/1TRSZPVI.csv
# ../datasets/semtab_data/complete_data/features/1XK9O8CF.csv
# ../datasets/semtab_data/complete_data/features/1XPHI0P2.csv
# ../datasets/semtab_data/complete_data/features/1ZX2DCW7.csv
# ../datasets/semtab_data/complete_data/features/21P58N2X.csv
# ../datasets/semtab_data/complete_data/features/239AZL33.csv
# ../datasets/semtab_data/complete_data/features/23NFMDP0.csv
# ../datasets/semtab_data/complete_data/features/243JI1XC.csv
# ../datasets/semtab_data/complete_data/features/24OGNVVP.csv
# ../datasets/semtab_data/complete_data/features/253OSZNL.csv
# ../datasets/semtab_data/complete_data/features/25EPRHUJ.csv
# ../datasets/semtab_data/complete_data/features/25KTY2D9.csv
# ../datasets/semtab_data/complete_data/features/27V1TQHW.csv
# ../datasets/semtab_data/complete_data/features/29AXQS5A.csv
# ../datasets/semtab_data/complete_data/features/2BATTV6X.csv
# ../datasets/semtab_data/complete_data/features/2CPISXSF.csv
# ../datasets/semtab_data/complete_data/features/2FHCJAMA.csv
# ../datasets/semtab_data/complete_data/features/2I24Y64Q.csv
# ../datasets/semtab_data/complete_data/features/2J3MZCRD.csv
# ../datasets/semtab_data/complete_data/features/2LC2LBG1.csv
# ../datasets/semtab_data/complete_data/features/2OJXQ9F3.csv
# ../datasets/semtab_data/complete_data/features/2QM0QJW9.csv
# ../datasets/semtab_data/complete_data/features/2RTA5JIB.csv
# ../datasets/semtab_data/complete_data/features/2S72D3R9.csv
# ../datasets/semtab_data/complete_data/features/2TG5KMPI.csv
# ../datasets/semtab_data/complete_data/features/2WRDGDBJ.csv
# ../datasets/semtab_data/complete_data/features/2XEP26CX.csv
# ../datasets/semtab_data/complete_data/features/2Z7W9245.csv
# ../datasets/semtab_data/complete_data/features/2ZCUZYY9.csv
# ../datasets/semtab_data/complete_data/features/2ZLDMP9R.csv
# ../datasets/semtab_data/complete_data/features/2ZYEX9U9.csv
# ../datasets/semtab_data/complete_data/features/30KYZ3HO.csv
# ../datasets/semtab_data/complete_data/features/328N1USF.csv
# ../datasets/semtab_data/complete_data/features/3290T9NG.csv
# ../datasets/semtab_data/complete_data/features/340JKVHO.csv
# ../datasets/semtab_data/complete_data/features/3540Y3D5.csv
# ../datasets/semtab_data/complete_data/features/36KH7GH7.csv
# ../datasets/semtab_data/complete_data/features/39DC3Z7N.csv
# ../datasets/semtab_data/complete_data/features/3AK02Q9B.csv
# ../datasets/semtab_data/complete_data/features/3DRSAGO5.csv
# ../datasets/semtab_data/complete_data/features/3FQ85RUH.csv
# ../datasets/semtab_data/complete_data/features/3FRIAFQG.csv
# ../datasets/semtab_data/complete_data/features/3HLRFWSX.csv
# ../datasets/semtab_data/complete_data/features/3IBPLURT.csv
# ../datasets/semtab_data/complete_data/features/3K0JGMP1.csv
# ../datasets/semtab_data/complete_data/features/3KX6UPPG.csv
# ../datasets/semtab_data/complete_data/features/3L4TR8X5.csv
# ../datasets/semtab_data/complete_data/features/3NCTWO03.csv
# ../datasets/semtab_data/complete_data/features/3O0C4D3O.csv
# ../datasets/semtab_data/complete_data/features/3QZT9O12.csv
# ../datasets/semtab_data/complete_data/features/3R0OGDXK.csv
# ../datasets/semtab_data/complete_data/features/3S4OOVHT.csv
# ../datasets/semtab_data/complete_data/features/3S6WON79.csv
# ../datasets/semtab_data/complete_data/features/3T93HF0D.csv
# ../datasets/semtab_data/complete_data/features/3TKOQZJ7.csv
# ../datasets/semtab_data/complete_data/features/3UP2SR30.csv
# ../datasets/semtab_data/complete_data/features/42BKS5LP.csv
# ../datasets/semtab_data/complete_data/features/42CSV98Q.csv
# ../datasets/semtab_data/complete_data/features/42WEUQ95.csv
# ../datasets/semtab_data/complete_data/features/45D6VIRT.csv
# ../datasets/semtab_data/complete_data/features/471N0AUD.csv
# ../datasets/semtab_data/complete_data/features/471ODBDH.csv
# ../datasets/semtab_data/complete_data/features/4722C9EQ.csv
# ../datasets/semtab_data/complete_data/features/48PAQE6M.csv
# ../datasets/semtab_data/complete_data/features/49XGWHEN.csv
# ../datasets/semtab_data/complete_data/features/4ANNOIVH.csv
# ../datasets/semtab_data/complete_data/features/4C37XZHJ.csv
# ../datasets/semtab_data/complete_data/features/4E99I3P7.csv
# ../datasets/semtab_data/complete_data/features/4ENVC6F0.csv
# ../datasets/semtab_data/complete_data/features/4FXN1RZ3.csv
# ../datasets/semtab_data/complete_data/features/4I7A5GID.csv
# ../datasets/semtab_data/complete_data/features/4I995NNQ.csv
# ../datasets/semtab_data/complete_data/features/4IJHCIR9.csv
# ../datasets/semtab_data/complete_data/features/4L16JP9T.csv
# ../datasets/semtab_data/complete_data/features/4LFJR3YN.csv
# ../datasets/semtab_data/complete_data/features/4MGX23BZ.csv
# ../datasets/semtab_data/complete_data/features/4N6X42PJ.csv
# ../datasets/semtab_data/complete_data/features/4O1BS5W9.csv
# ../datasets/semtab_data/complete_data/features/4Q6FAT24.csv
# ../datasets/semtab_data/complete_data/features/4QTU5MYM.csv
# ../datasets/semtab_data/complete_data/features/4UUFDEP4.csv
# ../datasets/semtab_data/complete_data/features/4VAYQOG0.csv
# ../datasets/semtab_data/complete_data/features/4WN91IQN.csv
# ../datasets/semtab_data/complete_data/features/4XIXYJZJ.csv
# ../datasets/semtab_data/complete_data/features/4YBOUF9V.csv
# ../datasets/semtab_data/complete_data/features/50ULP1KH.csv
# ../datasets/semtab_data/complete_data/features/519M624G.csv
# ../datasets/semtab_data/complete_data/features/51BN46AU.csv
# ../datasets/semtab_data/complete_data/features/568P9F4E.csv
# ../datasets/semtab_data/complete_data/features/5739HKRB.csv
# ../datasets/semtab_data/complete_data/features/5894JWA5.csv
# ../datasets/semtab_data/complete_data/features/59CFTDPL.csv
# ../datasets/semtab_data/complete_data/features/59JNC864.csv
# ../datasets/semtab_data/complete_data/features/5BD6VKB3.csv
# ../datasets/semtab_data/complete_data/features/5BEY9DAJ.csv
# ../datasets/semtab_data/complete_data/features/5BVL4YJS.csv
# ../datasets/semtab_data/complete_data/features/5CG871YQ.csv
# ../datasets/semtab_data/complete_data/features/5D3I2S1N.csv
# ../datasets/semtab_data/complete_data/features/5GS30C2C.csv
# ../datasets/semtab_data/complete_data/features/5KZVO2UP.csv
# ../datasets/semtab_data/complete_data/features/5MMHOLUI.csv
# ../datasets/semtab_data/complete_data/features/5N8AUSXE.csv
# ../datasets/semtab_data/complete_data/features/5NTTT408.csv
# ../datasets/semtab_data/complete_data/features/5PJ0EF0X.csv
# ../datasets/semtab_data/complete_data/features/5QDDFGBJ.csv
# ../datasets/semtab_data/complete_data/features/5S8PITYQ.csv
# ../datasets/semtab_data/complete_data/features/5TWQ98LE.csv
# ../datasets/semtab_data/complete_data/features/5TXLGRXA.csv
# ../datasets/semtab_data/complete_data/features/5VD9H3AD.csv
# ../datasets/semtab_data/complete_data/features/5W6MRY0W.csv
# ../datasets/semtab_data/complete_data/features/080HU8A5.csv
# ../datasets/semtab_data/complete_data/features/0G9YPQC0.csv
# ../datasets/semtab_data/complete_data/features/0LZ0M8W4.csv
# ../datasets/semtab_data/complete_data/features/0P8H49LQ.csv
# ../datasets/semtab_data/complete_data/features/0QWF60VG.csv
# ../datasets/semtab_data/complete_data/features/0WBTX8LY.csv
# ../datasets/semtab_data/complete_data/features/13BLTPJD.csv
# ../datasets/semtab_data/complete_data/features/1GOKLC0K.csv
# ../datasets/semtab_data/complete_data/features/1GUVMENF.csv
# ../datasets/semtab_data/complete_data/features/1NS33P8C.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1NS33P8C.csv ../datasets/semtab_data/complete_data/features/1NS33P8C.csv
# predict-using-model Time: 2.8116910457611084s
# get-kg-links-siamese_prediction Time: 0.3055236339569092s
# 1NS33P8C.csv
# metrics Time: 0.13805079460144043s
# ../datasets/semtab_data/complete_data/features/1XIWQBSF.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1XIWQBSF.csv ../datasets/semtab_data/complete_data/features/1XIWQBSF.csv
# predict-using-model Time: 2.184793710708618s
# get-kg-links-siamese_prediction Time: 0.6770660877227783s
# 1XIWQBSF.csv
# metrics Time: 0.3367912769317627s
# ../datasets/semtab_data/complete_data/features/1YPLVLS9.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1YPLVLS9.csv ../datasets/semtab_data/complete_data/features/1YPLVLS9.csv
# predict-using-model Time: 3.7349910736083984s
# get-kg-links-siamese_prediction Time: 0.7382915019989014s
# 1YPLVLS9.csv
# metrics Time: 0.3435187339782715s
# ../datasets/semtab_data/complete_data/features/1ZFRQBQS.csv
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1ZFRQBQS.csv ../datasets/semtab_data/complete_data/features/1ZFRQBQS.csv
# predict-using-model Time: 3.1823534965515137s
# get-kg-links-siamese_prediction Time: 1.7203984260559082s
# 1ZFRQBQS.csv
# metrics Time: 0.7841682434082031s
# ../datasets/semtab_data/complete_data/features/28D7RBJT.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/28D7RBJT.csv ../datasets/semtab_data/complete_data/features/28D7RBJT.csv
# predict-using-model Time: 3.1929478645324707s
# get-kg-links-siamese_prediction Time: 0.7407734394073486s
# 28D7RBJT.csv
# metrics Time: 0.3693575859069824s
# ../datasets/semtab_data/complete_data/features/2FXR6BX7.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/2FXR6BX7.csv ../datasets/semtab_data/complete_data/features/2FXR6BX7.csv
# predict-using-model Time: 3.152341365814209s
# get-kg-links-siamese_prediction Time: 1.3156907558441162s
# 2FXR6BX7.csv
# metrics Time: 0.6695265769958496s
# ../datasets/semtab_data/complete_data/features/2PKG4E2V.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/2PKG4E2V.csv ../datasets/semtab_data/complete_data/features/2PKG4E2V.csv
# predict-using-model Time: 3.9149012565612793s
# get-kg-links-siamese_prediction Time: 1.4499537944793701s
# 2PKG4E2V.csv
# metrics Time: 0.668440580368042s
# ../datasets/semtab_data/complete_data/features/2YCSL7OH.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/2YCSL7OH.csv ../datasets/semtab_data/complete_data/features/2YCSL7OH.csv
# predict-using-model Time: 1.8150174617767334s
# get-kg-links-siamese_prediction Time: 0.8330905437469482s
# 2YCSL7OH.csv
# metrics Time: 0.3755919933319092s
# ../datasets/semtab_data/complete_data/features/3M5QXPWN.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3M5QXPWN.csv ../datasets/semtab_data/complete_data/features/3M5QXPWN.csv
# predict-using-model Time: 1.769355058670044s
# get-kg-links-siamese_prediction Time: 0.7275581359863281s
# 3M5QXPWN.csv
# metrics Time: 0.39847588539123535s
# ../datasets/semtab_data/complete_data/features/3OAZEVOY.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3OAZEVOY.csv ../datasets/semtab_data/complete_data/features/3OAZEVOY.csv
# predict-using-model Time: 2.010240077972412s
# get-kg-links-siamese_prediction Time: 0.9160163402557373s
# 3OAZEVOY.csv
# metrics Time: 0.48764967918395996s
# ../datasets/semtab_data/complete_data/features/3WXFYEAX.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3WXFYEAX.csv ../datasets/semtab_data/complete_data/features/3WXFYEAX.csv
# predict-using-model Time: 1.4675638675689697s
# get-kg-links-siamese_prediction Time: 0.3687610626220703s
# 3WXFYEAX.csv
# metrics Time: 0.15252017974853516s
# ../datasets/semtab_data/complete_data/features/44NDHWR1.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/44NDHWR1.csv ../datasets/semtab_data/complete_data/features/44NDHWR1.csv
# predict-using-model Time: 2.882122278213501s
# get-kg-links-siamese_prediction Time: 0.6728997230529785s
# 44NDHWR1.csv
# metrics Time: 0.45615172386169434s
# ../datasets/semtab_data/complete_data/features/4DC5O5I4.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/4DC5O5I4.csv ../datasets/semtab_data/complete_data/features/4DC5O5I4.csv
# predict-using-model Time: 2.761324882507324s
# get-kg-links-siamese_prediction Time: 0.3712794780731201s
# 4DC5O5I4.csv
# metrics Time: 0.184401273727417s
# ../datasets/semtab_data/complete_data/features/4DPRZWVL.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/4DPRZWVL.csv ../datasets/semtab_data/complete_data/features/4DPRZWVL.csv
# predict-using-model Time: 2.546160936355591s
# get-kg-links-siamese_prediction Time: 0.3868978023529053s
# 4DPRZWVL.csv
# metrics Time: 0.18947839736938477s
# ../datasets/semtab_data/complete_data/features/4FG1UN8O.csv
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/4FG1UN8O.csv ../datasets/semtab_data/complete_data/features/4FG1UN8O.csv
# predict-using-model Time: 2.7607169151306152s
# get-kg-links-siamese_prediction Time: 1.4005649089813232s
# 4FG1UN8O.csv
# metrics Time: 0.7269737720489502s
# ../datasets/semtab_data/complete_data/features/4SOL8H0M.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/4SOL8H0M.csv ../datasets/semtab_data/complete_data/features/4SOL8H0M.csv
# predict-using-model Time: 3.749408721923828s
# get-kg-links-siamese_prediction Time: 1.3504109382629395s
# 4SOL8H0M.csv
# metrics Time: 0.6755545139312744s
# ../datasets/semtab_data/complete_data/features/50NWQJ1T.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/50NWQJ1T.csv ../datasets/semtab_data/complete_data/features/50NWQJ1T.csv
# predict-using-model Time: 2.2468953132629395s
# get-kg-links-siamese_prediction Time: 0.8081223964691162s
# 50NWQJ1T.csv
# metrics Time: 0.36235499382019043s
# ../datasets/semtab_data/complete_data/features/53OUTCE4.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/53OUTCE4.csv ../datasets/semtab_data/complete_data/features/53OUTCE4.csv
# predict-using-model Time: 2.499393939971924s
# get-kg-links-siamese_prediction Time: 0.701718807220459s
# 53OUTCE4.csv
# metrics Time: 0.34168028831481934s
# ../datasets/semtab_data/complete_data/features/58E7A5WL.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/58E7A5WL.csv ../datasets/semtab_data/complete_data/features/58E7A5WL.csv
# predict-using-model Time: 2.508728265762329s
# get-kg-links-siamese_prediction Time: 0.7105710506439209s
# 58E7A5WL.csv
# metrics Time: 0.3799893856048584s
# ../datasets/semtab_data/complete_data/features/59W76Q0Y.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/59W76Q0Y.csv ../datasets/semtab_data/complete_data/features/59W76Q0Y.csv
# predict-using-model Time: 2.09446382522583s
# get-kg-links-siamese_prediction Time: 0.3280985355377197s
# 59W76Q0Y.csv
# metrics Time: 0.1991100311279297s
# ../datasets/semtab_data/complete_data/features/5PKTGQ6Q.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/5PKTGQ6Q.csv ../datasets/semtab_data/complete_data/features/5PKTGQ6Q.csv
# predict-using-model Time: 2.063889980316162s
# get-kg-links-siamese_prediction Time: 0.27045226097106934s
# 5PKTGQ6Q.csv
# metrics Time: 0.1863725185394287s
# ../datasets/semtab_data/complete_data/features/5TJI4XTK.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/5TJI4XTK.csv ../datasets/semtab_data/complete_data/features/5TJI4XTK.csv
# predict-using-model Time: 2.674323081970215s
# get-kg-links-siamese_prediction Time: 0.3794374465942383s
# 5TJI4XTK.csv
# metrics Time: 0.14674735069274902s
# ../datasets/semtab_data/complete_data/features/2P4BZPW1.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/2P4BZPW1.csv ../datasets/semtab_data/complete_data/features/2P4BZPW1.csv
# predict-using-model Time: 2.1436543464660645s
# get-kg-links-siamese_prediction Time: 0.36850905418395996s
# 2P4BZPW1.csv
# metrics Time: 0.16992950439453125s
# ../datasets/semtab_data/complete_data/features/1375IHBW.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1375IHBW.csv ../datasets/semtab_data/complete_data/features/1375IHBW.csv
# predict-using-model Time: 3.0658106803894043s
# get-kg-links-siamese_prediction Time: 1.2610011100769043s
# 1375IHBW.csv
# metrics Time: 0.4636549949645996s
# ../datasets/semtab_data/complete_data/features/3HZEPYNC.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3HZEPYNC.csv ../datasets/semtab_data/complete_data/features/3HZEPYNC.csv
# predict-using-model Time: 3.406085968017578s
# get-kg-links-siamese_prediction Time: 0.3907959461212158s
# 3HZEPYNC.csv
# metrics Time: 0.1802198886871338s
# ../datasets/semtab_data/complete_data/features/2OYAB7YM.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/2OYAB7YM.csv ../datasets/semtab_data/complete_data/features/2OYAB7YM.csv
# predict-using-model Time: 2.8785693645477295s
# get-kg-links-siamese_prediction Time: 0.7066309452056885s
# 2OYAB7YM.csv
# metrics Time: 0.35843873023986816s
# ../datasets/semtab_data/complete_data/features/3CJEDV9F.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3CJEDV9F.csv ../datasets/semtab_data/complete_data/features/3CJEDV9F.csv
# predict-using-model Time: 2.5205047130584717s
# get-kg-links-siamese_prediction Time: 0.38126540184020996s
# 3CJEDV9F.csv
# metrics Time: 0.1793065071105957s
# ../datasets/semtab_data/complete_data/features/00YF468U.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/00YF468U.csv ../datasets/semtab_data/complete_data/features/00YF468U.csv
# predict-using-model Time: 3.3999171257019043s
# get-kg-links-siamese_prediction Time: 0.6013922691345215s
# 00YF468U.csv
# metrics Time: 0.34142398834228516s
# ../datasets/semtab_data/complete_data/features/2BLFNACC.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/2BLFNACC.csv ../datasets/semtab_data/complete_data/features/2BLFNACC.csv
# predict-using-model Time: 1.9791855812072754s
# get-kg-links-siamese_prediction Time: 0.7077465057373047s
# 2BLFNACC.csv
# metrics Time: 0.3990209102630615s
# ../datasets/semtab_data/complete_data/features/3C74M7HU.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3C74M7HU.csv ../datasets/semtab_data/complete_data/features/3C74M7HU.csv
# predict-using-model Time: 2.66450572013855s
# get-kg-links-siamese_prediction Time: 0.6832151412963867s
# 3C74M7HU.csv
# metrics Time: 0.37389707565307617s
# ../datasets/semtab_data/complete_data/features/11VNNTDS.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/11VNNTDS.csv ../datasets/semtab_data/complete_data/features/11VNNTDS.csv
# predict-using-model Time: 2.335581064224243s
# get-kg-links-siamese_prediction Time: 0.6997096538543701s
# 11VNNTDS.csv
# metrics Time: 0.3448793888092041s
# ../datasets/semtab_data/complete_data/features/0ADP8WGU.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0ADP8WGU.csv ../datasets/semtab_data/complete_data/features/0ADP8WGU.csv
# predict-using-model Time: 1.7656197547912598s
# get-kg-links-siamese_prediction Time: 0.38088393211364746s
# 0ADP8WGU.csv
# metrics Time: 0.1923213005065918s
# ../datasets/semtab_data/complete_data/features/0P4Y07PN.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0P4Y07PN.csv ../datasets/semtab_data/complete_data/features/0P4Y07PN.csv
# predict-using-model Time: 3.0774037837982178s
# get-kg-links-siamese_prediction Time: 1.020888328552246s
# 0P4Y07PN.csv
# metrics Time: 0.4967312812805176s
# ../datasets/semtab_data/complete_data/features/302H92MV.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/302H92MV.csv ../datasets/semtab_data/complete_data/features/302H92MV.csv
# predict-using-model Time: 3.612266778945923s
# get-kg-links-siamese_prediction Time: 0.7896091938018799s
# 302H92MV.csv
# metrics Time: 0.35997462272644043s
# ../datasets/semtab_data/complete_data/features/174Q7GKD.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/174Q7GKD.csv ../datasets/semtab_data/complete_data/features/174Q7GKD.csv
# predict-using-model Time: 2.297032356262207s
# get-kg-links-siamese_prediction Time: 0.3736402988433838s
# 174Q7GKD.csv
# metrics Time: 0.19420242309570312s
# ../datasets/semtab_data/complete_data/features/2P3KJ1P0.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/2P3KJ1P0.csv ../datasets/semtab_data/complete_data/features/2P3KJ1P0.csv
# predict-using-model Time: 2.3715667724609375s
# get-kg-links-siamese_prediction Time: 1.1344876289367676s
# 2P3KJ1P0.csv
# metrics Time: 0.5150556564331055s
# ../datasets/semtab_data/complete_data/features/26CIDK81.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/26CIDK81.csv ../datasets/semtab_data/complete_data/features/26CIDK81.csv
# predict-using-model Time: 3.427969217300415s
# get-kg-links-siamese_prediction Time: 0.7119882106781006s
# 26CIDK81.csv
# metrics Time: 0.25280046463012695s
# ../datasets/semtab_data/complete_data/features/08XTIUJQ.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/08XTIUJQ.csv ../datasets/semtab_data/complete_data/features/08XTIUJQ.csv
# predict-using-model Time: 1.4764137268066406s
# get-kg-links-siamese_prediction Time: 0.3421297073364258s
# 08XTIUJQ.csv
# metrics Time: 0.16334891319274902s
# ../datasets/semtab_data/complete_data/features/17DA0MJ4.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/17DA0MJ4.csv ../datasets/semtab_data/complete_data/features/17DA0MJ4.csv
# predict-using-model Time: 2.9267916679382324s
# get-kg-links-siamese_prediction Time: 0.49416637420654297s
# 17DA0MJ4.csv
# metrics Time: 0.2574653625488281s
# ../datasets/semtab_data/complete_data/features/3RC46CRC.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3RC46CRC.csv ../datasets/semtab_data/complete_data/features/3RC46CRC.csv
# predict-using-model Time: 2.9403440952301025s
# get-kg-links-siamese_prediction Time: 0.8914844989776611s
# 3RC46CRC.csv
# metrics Time: 0.49955224990844727s
# ../datasets/semtab_data/complete_data/features/03Q5JG9I.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/03Q5JG9I.csv ../datasets/semtab_data/complete_data/features/03Q5JG9I.csv
# predict-using-model Time: 2.6074178218841553s
# get-kg-links-siamese_prediction Time: 0.47217750549316406s
# 03Q5JG9I.csv
# metrics Time: 0.26892542839050293s
# ../datasets/semtab_data/complete_data/features/1STAURLW.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1STAURLW.csv ../datasets/semtab_data/complete_data/features/1STAURLW.csv
# predict-using-model Time: 1.5178046226501465s
# get-kg-links-siamese_prediction Time: 0.33187341690063477s
# 1STAURLW.csv
# metrics Time: 0.18409228324890137s
# ../datasets/semtab_data/complete_data/features/0ZXPJXH4.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0ZXPJXH4.csv ../datasets/semtab_data/complete_data/features/0ZXPJXH4.csv
# predict-using-model Time: 2.969151258468628s
# get-kg-links-siamese_prediction Time: 0.2590460777282715s
# 0ZXPJXH4.csv
# metrics Time: 0.15129303932189941s
# ../datasets/semtab_data/complete_data/features/0M7R2JUU.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0M7R2JUU.csv ../datasets/semtab_data/complete_data/features/0M7R2JUU.csv
# predict-using-model Time: 2.2189619541168213s
# get-kg-links-siamese_prediction Time: 1.2877576351165771s
# 0M7R2JUU.csv
# metrics Time: 0.5617539882659912s
# ../datasets/semtab_data/complete_data/features/20PYU63R.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/20PYU63R.csv ../datasets/semtab_data/complete_data/features/20PYU63R.csv
# predict-using-model Time: 2.4383671283721924s
# get-kg-links-siamese_prediction Time: 0.26482129096984863s
# 20PYU63R.csv
# metrics Time: 0.18490290641784668s
# ../datasets/semtab_data/complete_data/features/3IB64ASX.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3IB64ASX.csv ../datasets/semtab_data/complete_data/features/3IB64ASX.csv
# predict-using-model Time: 2.425654649734497s
# get-kg-links-siamese_prediction Time: 0.9613442420959473s
# 3IB64ASX.csv
# metrics Time: 0.38333702087402344s
# ../datasets/semtab_data/complete_data/features/15CM535P.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/15CM535P.csv ../datasets/semtab_data/complete_data/features/15CM535P.csv
# predict-using-model Time: 2.109189033508301s
# get-kg-links-siamese_prediction Time: 0.27477502822875977s
# 15CM535P.csv
# metrics Time: 0.21138978004455566s
# ../datasets/semtab_data/complete_data/features/1D0TLL3P.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1D0TLL3P.csv ../datasets/semtab_data/complete_data/features/1D0TLL3P.csv
# predict-using-model Time: 1.467841386795044s
# get-kg-links-siamese_prediction Time: 0.25667691230773926s
# 1D0TLL3P.csv
# metrics Time: 0.18048667907714844s
# ../datasets/semtab_data/complete_data/features/0B8EGHVB.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0B8EGHVB.csv ../datasets/semtab_data/complete_data/features/0B8EGHVB.csv
# predict-using-model Time: 2.5911502838134766s
# get-kg-links-siamese_prediction Time: 0.38483738899230957s
# 0B8EGHVB.csv
# metrics Time: 0.1805591583251953s
# ../datasets/semtab_data/complete_data/features/15HDRE87.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/15HDRE87.csv ../datasets/semtab_data/complete_data/features/15HDRE87.csv
# predict-using-model Time: 2.0083160400390625s
# get-kg-links-siamese_prediction Time: 0.3721785545349121s
# 15HDRE87.csv
# metrics Time: 0.194838285446167s
# ../datasets/semtab_data/complete_data/features/0KWK2FSC.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0KWK2FSC.csv ../datasets/semtab_data/complete_data/features/0KWK2FSC.csv
# predict-using-model Time: 2.3691253662109375s
# get-kg-links-siamese_prediction Time: 0.7796840667724609s
# 0KWK2FSC.csv
# metrics Time: 0.3564624786376953s
# ../datasets/semtab_data/complete_data/features/3IALBWVT.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3IALBWVT.csv ../datasets/semtab_data/complete_data/features/3IALBWVT.csv
# predict-using-model Time: 3.399580717086792s
# get-kg-links-siamese_prediction Time: 1.1124844551086426s
# 3IALBWVT.csv
# metrics Time: 0.50337815284729s
# ../datasets/semtab_data/complete_data/features/0RWHW0S0.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0RWHW0S0.csv ../datasets/semtab_data/complete_data/features/0RWHW0S0.csv
# predict-using-model Time: 2.8989219665527344s
# get-kg-links-siamese_prediction Time: 0.7849428653717041s
# 0RWHW0S0.csv
# metrics Time: 0.48230957984924316s
# ../datasets/semtab_data/complete_data/features/0L4YDT86.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0L4YDT86.csv ../datasets/semtab_data/complete_data/features/0L4YDT86.csv
# predict-using-model Time: 2.469957113265991s
# get-kg-links-siamese_prediction Time: 0.2997009754180908s
# 0L4YDT86.csv
# metrics Time: 0.1423959732055664s
# ../datasets/semtab_data/complete_data/features/2BRG4KEL.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/2BRG4KEL.csv ../datasets/semtab_data/complete_data/features/2BRG4KEL.csv
# predict-using-model Time: 3.646064281463623s
# get-kg-links-siamese_prediction Time: 0.37209439277648926s
# 2BRG4KEL.csv
# metrics Time: 0.13393497467041016s
# ../datasets/semtab_data/complete_data/features/0ZZFENJS.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0ZZFENJS.csv ../datasets/semtab_data/complete_data/features/0ZZFENJS.csv
# predict-using-model Time: 2.0911388397216797s
# get-kg-links-siamese_prediction Time: 0.8997292518615723s
# 0ZZFENJS.csv
# metrics Time: 0.32974934577941895s
# ../datasets/semtab_data/complete_data/features/3J5ABW9E.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3J5ABW9E.csv ../datasets/semtab_data/complete_data/features/3J5ABW9E.csv
# predict-using-model Time: 3.0771305561065674s
# get-kg-links-siamese_prediction Time: 1.0205259323120117s
# 3J5ABW9E.csv
# metrics Time: 0.3903050422668457s
# ../datasets/semtab_data/complete_data/features/24VU5BR7.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/24VU5BR7.csv ../datasets/semtab_data/complete_data/features/24VU5BR7.csv
# predict-using-model Time: 2.8036599159240723s
# get-kg-links-siamese_prediction Time: 0.702258825302124s
# 24VU5BR7.csv
# metrics Time: 0.31863903999328613s
# ../datasets/semtab_data/complete_data/features/24VD82I7.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/24VD82I7.csv ../datasets/semtab_data/complete_data/features/24VD82I7.csv
# predict-using-model Time: 2.2961270809173584s
# get-kg-links-siamese_prediction Time: 0.5522663593292236s
# 24VD82I7.csv
# metrics Time: 0.3305068016052246s
# ../datasets/semtab_data/complete_data/features/24HLK9BD.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/24HLK9BD.csv ../datasets/semtab_data/complete_data/features/24HLK9BD.csv
# predict-using-model Time: 2.4542384147644043s
# get-kg-links-siamese_prediction Time: 0.9637312889099121s
# 24HLK9BD.csv
# metrics Time: 0.46094799041748047s
# ../datasets/semtab_data/complete_data/features/1XV2X3XE.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1XV2X3XE.csv ../datasets/semtab_data/complete_data/features/1XV2X3XE.csv
# predict-using-model Time: 3.511995553970337s
# get-kg-links-siamese_prediction Time: 0.5173356533050537s
# 1XV2X3XE.csv
# metrics Time: 0.3422410488128662s
# ../datasets/semtab_data/complete_data/features/32DWSB26.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/32DWSB26.csv ../datasets/semtab_data/complete_data/features/32DWSB26.csv
# predict-using-model Time: 2.1223270893096924s
# get-kg-links-siamese_prediction Time: 0.28705549240112305s
# 32DWSB26.csv
# metrics Time: 0.18621134757995605s
# ../datasets/semtab_data/complete_data/features/1LI468T0.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1LI468T0.csv ../datasets/semtab_data/complete_data/features/1LI468T0.csv
# predict-using-model Time: 2.849749803543091s
# get-kg-links-siamese_prediction Time: 0.721717357635498s
# 1LI468T0.csv
# metrics Time: 0.4526088237762451s
# ../datasets/semtab_data/complete_data/features/289YGN9G.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/289YGN9G.csv ../datasets/semtab_data/complete_data/features/289YGN9G.csv
# predict-using-model Time: 3.329913854598999s
# get-kg-links-siamese_prediction Time: 1.0922009944915771s
# 289YGN9G.csv
# metrics Time: 0.6166567802429199s
# ../datasets/semtab_data/complete_data/features/10WA15QW.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/10WA15QW.csv ../datasets/semtab_data/complete_data/features/10WA15QW.csv
# predict-using-model Time: 2.362316370010376s
# get-kg-links-siamese_prediction Time: 0.26543092727661133s
# 10WA15QW.csv
# metrics Time: 0.1576709747314453s
# ../datasets/semtab_data/complete_data/features/3EL4J49W.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3EL4J49W.csv ../datasets/semtab_data/complete_data/features/3EL4J49W.csv
# predict-using-model Time: 1.8870534896850586s
# get-kg-links-siamese_prediction Time: 0.30243587493896484s
# 3EL4J49W.csv
# metrics Time: 0.1917126178741455s
# ../datasets/semtab_data/complete_data/features/16F08KC4.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/16F08KC4.csv ../datasets/semtab_data/complete_data/features/16F08KC4.csv
# predict-using-model Time: 1.4186224937438965s
# get-kg-links-siamese_prediction Time: 0.7256448268890381s
# 16F08KC4.csv
# metrics Time: 0.48182201385498047s
# ../datasets/semtab_data/complete_data/features/1AXBOBYJ.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1AXBOBYJ.csv ../datasets/semtab_data/complete_data/features/1AXBOBYJ.csv
# predict-using-model Time: 2.5422966480255127s
# get-kg-links-siamese_prediction Time: 1.0436949729919434s
# 1AXBOBYJ.csv
# metrics Time: 0.41329360008239746s
# ../datasets/semtab_data/complete_data/features/3CSAH6ZY.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3CSAH6ZY.csv ../datasets/semtab_data/complete_data/features/3CSAH6ZY.csv
# predict-using-model Time: 2.1206746101379395s
# get-kg-links-siamese_prediction Time: 0.40177106857299805s
# 3CSAH6ZY.csv
# metrics Time: 0.13410139083862305s
# ../datasets/semtab_data/complete_data/features/32GFE6D8.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/32GFE6D8.csv ../datasets/semtab_data/complete_data/features/32GFE6D8.csv
# predict-using-model Time: 2.7860398292541504s
# get-kg-links-siamese_prediction Time: 0.8548398017883301s
# 32GFE6D8.csv
# metrics Time: 0.374910831451416s
# ../datasets/semtab_data/complete_data/features/0A4KYJH5.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0A4KYJH5.csv ../datasets/semtab_data/complete_data/features/0A4KYJH5.csv
# predict-using-model Time: 2.3329789638519287s
# get-kg-links-siamese_prediction Time: 0.4706599712371826s
# 0A4KYJH5.csv
# metrics Time: 0.34258079528808594s
# ../datasets/semtab_data/complete_data/features/1QGWWYAF.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1QGWWYAF.csv ../datasets/semtab_data/complete_data/features/1QGWWYAF.csv
# predict-using-model Time: 2.2880189418792725s
# get-kg-links-siamese_prediction Time: 0.8390538692474365s
# 1QGWWYAF.csv
# metrics Time: 0.3839120864868164s
# ../datasets/semtab_data/complete_data/features/3PSDVWZR.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3PSDVWZR.csv ../datasets/semtab_data/complete_data/features/3PSDVWZR.csv
# predict-using-model Time: 3.0010008811950684s
# get-kg-links-siamese_prediction Time: 0.7449071407318115s
# 3PSDVWZR.csv
# metrics Time: 0.385251522064209s
# ../datasets/semtab_data/complete_data/features/18T4PJWW.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/18T4PJWW.csv ../datasets/semtab_data/complete_data/features/18T4PJWW.csv
# predict-using-model Time: 1.958228349685669s
# get-kg-links-siamese_prediction Time: 0.382448673248291s
# 18T4PJWW.csv
# metrics Time: 0.1916217803955078s
# ../datasets/semtab_data/complete_data/features/0JSE9VIO.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0JSE9VIO.csv ../datasets/semtab_data/complete_data/features/0JSE9VIO.csv
# predict-using-model Time: 3.1167757511138916s
# get-kg-links-siamese_prediction Time: 1.1705131530761719s
# 0JSE9VIO.csv
# metrics Time: 0.5269544124603271s
# ../datasets/semtab_data/complete_data/features/0DHFD9QY.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0DHFD9QY.csv ../datasets/semtab_data/complete_data/features/0DHFD9QY.csv
# predict-using-model Time: 2.6509742736816406s
# get-kg-links-siamese_prediction Time: 0.3642573356628418s
# 0DHFD9QY.csv
# metrics Time: 0.13959455490112305s
# ../datasets/semtab_data/complete_data/features/0EH4XC4H.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0EH4XC4H.csv ../datasets/semtab_data/complete_data/features/0EH4XC4H.csv
# predict-using-model Time: 2.3741743564605713s
# get-kg-links-siamese_prediction Time: 0.8425452709197998s
# 0EH4XC4H.csv
# metrics Time: 0.3841390609741211s
# ../datasets/semtab_data/complete_data/features/2IQQE9DB.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/2IQQE9DB.csv ../datasets/semtab_data/complete_data/features/2IQQE9DB.csv
# predict-using-model Time: 2.1038460731506348s
# get-kg-links-siamese_prediction Time: 0.8640172481536865s
# 2IQQE9DB.csv
# metrics Time: 0.37672972679138184s
# ../datasets/semtab_data/complete_data/features/27BGOKZ7.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/27BGOKZ7.csv ../datasets/semtab_data/complete_data/features/27BGOKZ7.csv
# predict-using-model Time: 3.9359827041625977s
# get-kg-links-siamese_prediction Time: 0.7456150054931641s
# 27BGOKZ7.csv
# metrics Time: 0.49370646476745605s
# ../datasets/semtab_data/complete_data/features/1SWM4IDV.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1SWM4IDV.csv ../datasets/semtab_data/complete_data/features/1SWM4IDV.csv
# predict-using-model Time: 1.4049859046936035s
# get-kg-links-siamese_prediction Time: 0.757544755935669s
# 1SWM4IDV.csv
# metrics Time: 0.3910202980041504s
# ../datasets/semtab_data/complete_data/features/0DS28PUJ.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0DS28PUJ.csv ../datasets/semtab_data/complete_data/features/0DS28PUJ.csv
# predict-using-model Time: 1.9275481700897217s
# get-kg-links-siamese_prediction Time: 0.26046228408813477s
# 0DS28PUJ.csv
# metrics Time: 0.1515653133392334s
# ../datasets/semtab_data/complete_data/features/1UBAHGEU.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1UBAHGEU.csv ../datasets/semtab_data/complete_data/features/1UBAHGEU.csv
# predict-using-model Time: 3.297738790512085s
# get-kg-links-siamese_prediction Time: 0.3336527347564697s
# 1UBAHGEU.csv
# metrics Time: 0.15460872650146484s
# ../datasets/semtab_data/complete_data/features/19WCLMKZ.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/19WCLMKZ.csv ../datasets/semtab_data/complete_data/features/19WCLMKZ.csv
# predict-using-model Time: 2.03102445602417s
# get-kg-links-siamese_prediction Time: 0.3228936195373535s
# 19WCLMKZ.csv
# metrics Time: 0.20449495315551758s
# ../datasets/semtab_data/complete_data/features/3CUK6D56.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3CUK6D56.csv ../datasets/semtab_data/complete_data/features/3CUK6D56.csv
# predict-using-model Time: 1.9966540336608887s
# get-kg-links-siamese_prediction Time: 0.5666906833648682s
# 3CUK6D56.csv
# metrics Time: 0.33878207206726074s
# ../datasets/semtab_data/complete_data/features/0Z8LKW3C.csv
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0Z8LKW3C.csv ../datasets/semtab_data/complete_data/features/0Z8LKW3C.csv
# predict-using-model Time: 3.5264992713928223s
# get-kg-links-siamese_prediction Time: 1.3884506225585938s
# 0Z8LKW3C.csv
# metrics Time: 0.8001251220703125s
# ../datasets/semtab_data/complete_data/features/042AKDN1.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/042AKDN1.csv ../datasets/semtab_data/complete_data/features/042AKDN1.csv
# predict-using-model Time: 2.1656181812286377s
# get-kg-links-siamese_prediction Time: 0.30202555656433105s
# 042AKDN1.csv
# metrics Time: 0.15872502326965332s
# ../datasets/semtab_data/complete_data/features/09DZVIPV.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/09DZVIPV.csv ../datasets/semtab_data/complete_data/features/09DZVIPV.csv
# predict-using-model Time: 2.320932149887085s
# get-kg-links-siamese_prediction Time: 0.3966195583343506s
# 09DZVIPV.csv
# metrics Time: 0.19335198402404785s
# ../datasets/semtab_data/complete_data/features/0UX45YZS.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0UX45YZS.csv ../datasets/semtab_data/complete_data/features/0UX45YZS.csv
# predict-using-model Time: 2.8468093872070312s
# get-kg-links-siamese_prediction Time: 0.7442336082458496s
# 0UX45YZS.csv
# metrics Time: 0.4123232364654541s
# ../datasets/semtab_data/complete_data/features/1E1WKZOC.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1E1WKZOC.csv ../datasets/semtab_data/complete_data/features/1E1WKZOC.csv
# predict-using-model Time: 1.9277675151824951s
# get-kg-links-siamese_prediction Time: 0.37245655059814453s
# 1E1WKZOC.csv
# metrics Time: 0.2157268524169922s
# ../datasets/semtab_data/complete_data/features/0VGKU21T.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/0VGKU21T.csv ../datasets/semtab_data/complete_data/features/0VGKU21T.csv
# predict-using-model Time: 2.2835283279418945s
# get-kg-links-siamese_prediction Time: 0.5437736511230469s
# 0VGKU21T.csv
# metrics Time: 0.23464608192443848s
# ../datasets/semtab_data/complete_data/features/01E31BCQ.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/01E31BCQ.csv ../datasets/semtab_data/complete_data/features/01E31BCQ.csv
# predict-using-model Time: 2.901921510696411s
# get-kg-links-siamese_prediction Time: 0.6945838928222656s
# 01E31BCQ.csv
# metrics Time: 0.3553733825683594s
# ../datasets/semtab_data/complete_data/features/3PZX8I05.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3PZX8I05.csv ../datasets/semtab_data/complete_data/features/3PZX8I05.csv
# predict-using-model Time: 4.399273633956909s
# get-kg-links-siamese_prediction Time: 1.5777125358581543s
# 3PZX8I05.csv
# metrics Time: 0.7527880668640137s
# ../datasets/semtab_data/complete_data/features/18TCX9AJ.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/18TCX9AJ.csv ../datasets/semtab_data/complete_data/features/18TCX9AJ.csv
# predict-using-model Time: 2.3316919803619385s
# get-kg-links-siamese_prediction Time: 0.3895246982574463s
# 18TCX9AJ.csv
# metrics Time: 0.18969941139221191s
# ../datasets/semtab_data/complete_data/features/3MFTI3Y1.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/3MFTI3Y1.csv ../datasets/semtab_data/complete_data/features/3MFTI3Y1.csv
# predict-using-model Time: 3.592925786972046s
# get-kg-links-siamese_prediction Time: 0.7252206802368164s
# 3MFTI3Y1.csv
# metrics Time: 0.36070990562438965s
# ../datasets/semtab_data/complete_data/features/1FF0TRWQ.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/1FF0TRWQ.csv ../datasets/semtab_data/complete_data/features/1FF0TRWQ.csv
# predict-using-model Time: 1.9654591083526611s
# get-kg-links-siamese_prediction Time: 0.37252211570739746s
# 1FF0TRWQ.csv
# metrics Time: 0.19959545135498047s
# ../datasets/semtab_data/complete_data/features/28Y667AR.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/28Y667AR.csv ../datasets/semtab_data/complete_data/features/28Y667AR.csv
# predict-using-model Time: 2.6548924446105957s
# get-kg-links-siamese_prediction Time: 0.7132952213287354s
# 28Y667AR.csv
# metrics Time: 0.36365556716918945s
# ../datasets/semtab_data/complete_data/features/263P426L.csv
# siamese_prediction 5 Experiment/results/Experiment_test_semtab_reduced/test/test_predictions_top_k/263P426L.csv ../datasets/semtab_data/complete_data/features/263P426L.csv
# predict-using-model Time: 3.223055839538574s
# ...
#  2  1  0.90       0.90    0.90       2         20  263P426L.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  0.7        0.7     0.7       0         20  258AFYQJ.csv
#  1  1  1.0        1.0     1.0       1         20  258AFYQJ.csv
#  2  1  1.0        1.0     1.0       2         20  258AFYQJ.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  0.35       0.35    0.35       0         20  1JY71MSY.csv
#  1  1  1.00       1.00    1.00       1         20  1JY71MSY.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  1.00       1.00    1.00       0         20  2AQ0VUOP.csv
#  1  1  0.75       0.75    0.75       2         20  2AQ0VUOP.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  1FP8LYOS.csv
#  1  1  1.0        1.0     1.0       1         20  1FP8LYOS.csv
#  2  1  1.0        1.0     1.0       2         20  1FP8LYOS.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  2JN1R1VW.csv
#  1  1  1.0        1.0     1.0       1         20  2JN1R1VW.csv
#  2  1  1.0        1.0     1.0       2         20  2JN1R1VW.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         28  2QS5IM8T.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  1DQVRVUL.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  0BM19RVO.csv
#  1  1  1.0        1.0     1.0       1         20  0BM19RVO.csv
#  2  1  1.0        1.0     1.0       2         20  0BM19RVO.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  0.5        0.5     0.5       0         20  3CLS11K2.csv
#  1  1  1.0        1.0     1.0       2         20  3CLS11K2.csv
#  2  1  1.0        1.0     1.0       3         20  3CLS11K2.csv
#  3  1  1.0        1.0     1.0       4         20  3CLS11K2.csv
#  4  1  1.0        1.0     1.0       5         20  3CLS11K2.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  2OQR5KK1.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  39HQAJDE.csv
#  1  1  1.0        1.0     1.0       3         20  39HQAJDE.csv
#  2  1  1.0        1.0     1.0       4         20  39HQAJDE.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  0.9        0.9     0.9       0         20  04A3K0PO.csv
#  1  1  1.0        1.0     1.0       1         20  04A3K0PO.csv
#  2  1  1.0        1.0     1.0       3         20  04A3K0PO.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  2VWPPCQM.csv
#  1  1  1.0        1.0     1.0       1         20  2VWPPCQM.csv
#  2  1  1.0        1.0     1.0       2         20  2VWPPCQM.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  1CS2NQUR.csv
#  1  1  1.0        1.0     1.0       1         20  1CS2NQUR.csv
#  2  1  1.0        1.0     1.0       2         20  1CS2NQUR.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  0.90       0.90    0.90       0         20  36LCWPLR.csv
#  1  1  1.00       1.00    1.00       1         20  36LCWPLR.csv
#  2  1  0.95       0.95    0.95       2         20  36LCWPLR.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  0.85       0.85    0.85       0         20  0IUSS6UH.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  1TQSKB2E.csv
#  1  1  1.0        1.0     1.0       1         20  1TQSKB2E.csv
#  2  1  1.0        1.0     1.0       2         20  1TQSKB2E.csv,
#     k        f1  precision    recall  column  num_cells           tag
#  0  1  0.862069   0.862069  0.862069       0         58  20ISN4OJ.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  2TUG0XHN.csv
#  1  1  1.0        1.0     1.0       1         20  2TUG0XHN.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  1.00       1.00    1.00       0         20  3SQ9UAK1.csv
#  1  1  0.75       0.75    0.75       1         20  3SQ9UAK1.csv
#  2  1  1.00       1.00    1.00       2         20  3SQ9UAK1.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  1U6PF4FY.csv
#  1  1  1.0        1.0     1.0       2         20  1U6PF4FY.csv
#  2  1  1.0        1.0     1.0       3         20  1U6PF4FY.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  2ZLGXNTV.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  3T54D76A.csv
#  1  1  1.0        1.0     1.0       2         20  3T54D76A.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  3MKMD5TW.csv
#  1  1  1.0        1.0     1.0       2         20  3MKMD5TW.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  2XDZM14F.csv
#  1  1  1.0        1.0     1.0       1         20  2XDZM14F.csv
#  2  1  1.0        1.0     1.0       2         20  2XDZM14F.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  19FQNTBF.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  0.8        0.8     0.8       0         20  3TZ2D9V5.csv
#  1  1  1.0        1.0     1.0       2         20  3TZ2D9V5.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  0.8        0.8     0.8       0         20  3WIJWVTF.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  40DGQ0R6.csv,
#     k        f1  precision    recall  column  num_cells           tag
#  0  1  0.694444   0.694444  0.694444       0         36  41UF0D20.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  43NKPCQ8.csv
#  1  1  1.0        1.0     1.0       1         20  43NKPCQ8.csv
#  2  1  1.0        1.0     1.0       2         20  43NKPCQ8.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  46HT6F8E.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  479O847V.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  48BAS22X.csv
#  1  1  1.0        1.0     1.0       1         20  48BAS22X.csv
#  2  1  1.0        1.0     1.0       2         20  48BAS22X.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  49K301SA.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  4DM4KN9O.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  4G8G7N8W.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  0.95       0.95    0.95       0         20  4IB27COT.csv
#  1  1  0.95       0.95    0.95       1         20  4IB27COT.csv
#  2  1  1.00       1.00    1.00       3         20  4IB27COT.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  4KDMZHXJ.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  4NVYEVEQ.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  4P9QJEV9.csv
#  1  1  1.0        1.0     1.0       4         20  4P9QJEV9.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  0.95       0.95    0.95       0         20  4RB6CKKQ.csv
#  1  1  1.00       1.00    1.00       1         20  4RB6CKKQ.csv
#  2  1  1.00       1.00    1.00       2         20  4RB6CKKQ.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  4UZA5UWB.csv
#  1  1  1.0        1.0     1.0       2         20  4UZA5UWB.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  0.95       0.95    0.95       0         20  4VL4BFPM.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  4ZZG4HMD.csv
#  1  1  1.0        1.0     1.0       1         20  4ZZG4HMD.csv
#  2  1  1.0        1.0     1.0       2         20  4ZZG4HMD.csv
#  3  1  1.0        1.0     1.0       3         20  4ZZG4HMD.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  54SEC9F3.csv
#  1  1  1.0        1.0     1.0       2         20  54SEC9F3.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  56CDHMVN.csv
#  1  1  1.0        1.0     1.0       1         20  56CDHMVN.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  5BGVRHI5.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  5E9CSACP.csv
#  1  1  1.0        1.0     1.0       1         20  5E9CSACP.csv
#  2  1  1.0        1.0     1.0       2         20  5E9CSACP.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  0.9        0.9     0.9       0         20  5ECFP78V.csv
#  1  1  1.0        1.0     1.0       1         20  5ECFP78V.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  5FMSUKCH.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  1.00       1.00    1.00       0         20  5G4M4L5W.csv
#  1  1  0.95       0.95    0.95       2         20  5G4M4L5W.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  5IKCI9Z4.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  0.9        0.9     0.9       0         20  5J25NATF.csv
#  1  1  1.0        1.0     1.0       1         20  5J25NATF.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  5NMYKF77.csv
#  1  1  1.0        1.0     1.0       1         20  5NMYKF77.csv
#  2  1  1.0        1.0     1.0       2         20  5NMYKF77.csv
#  3  1  1.0        1.0     1.0       3         20  5NMYKF77.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  5P2SOXGW.csv
#  1  1  1.0        1.0     1.0       1         20  5P2SOXGW.csv
#  2  1  1.0        1.0     1.0       2         20  5P2SOXGW.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  5Q5RASS8.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         19  5SB78VPX.csv
#  1  1  1.0        1.0     1.0       1         20  5SB78VPX.csv
#  2  1  1.0        1.0     1.0       2         20  5SB78VPX.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  1.00       1.00    1.00       0         20  5T891IJ9.csv
#  1  1  1.00       1.00    1.00       1         20  5T891IJ9.csv
#  2  1  0.95       0.95    0.95       2         20  5T891IJ9.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  5WA7NENC.csv
#  1  1  0.8        0.8     0.8       2         20  5WA7NENC.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  0.95       0.95    0.95       0         20  5WFYRRY7.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  00ECUL14.csv
#  1  1  1.0        1.0     1.0       2         20  00ECUL14.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  0CETTKTA.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  0FQOOJPU.csv
#  1  1  1.0        1.0     1.0       2         20  0FQOOJPU.csv
#  2  1  1.0        1.0     1.0       3         20  0FQOOJPU.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  0JSF530F.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  0LF7RI6N.csv
#  1  1  1.0        1.0     1.0       1         20  0LF7RI6N.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  0TQXSY28.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  1.00       1.00    1.00       0         20  1PTL0CX1.csv
#  1  1  0.95       0.95    0.95       2         20  1PTL0CX1.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  0.95       0.95    0.95       0         20  1T91CHXV.csv
#  1  1  1.00       1.00    1.00       1         20  1T91CHXV.csv
#  2  1  0.80       0.80    0.80       2         20  1T91CHXV.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  29D1VZHF.csv
#  1  1  1.0        1.0     1.0       1         20  29D1VZHF.csv
#  2  1  1.0        1.0     1.0       2         20  29D1VZHF.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  0.95       0.95    0.95       0         20  2E6QBLCA.csv
#  1  1  0.85       0.85    0.85       2         20  2E6QBLCA.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  2FSRG0OI.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  0.9        0.9     0.9       0         20  2QFYH2N9.csv
#  1  1  1.0        1.0     1.0       1         20  2QFYH2N9.csv
#  2  1  1.0        1.0     1.0       2         20  2QFYH2N9.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  0.90       0.90    0.90       0         20  2TGNKH1P.csv
#  1  1  0.95       0.95    0.95       2         20  2TGNKH1P.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  39W7XXTI.csv
#  1  1  1.0        1.0     1.0       1         20  39W7XXTI.csv
#  2  1  1.0        1.0     1.0       2         20  39W7XXTI.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  0.95       0.95    0.95       0         20  3B54GZSX.csv
#  1  1  1.00       1.00    1.00       1         20  3B54GZSX.csv
#  2  1  1.00       1.00    1.00       2         20  3B54GZSX.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  3JNFST2K.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  0.80       0.80    0.80       0         20  3OCW1LDZ.csv
#  1  1  1.00       1.00    1.00       2         20  3OCW1LDZ.csv
#  2  1  0.95       0.95    0.95       3         20  3OCW1LDZ.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         20  4PKEEJU4.csv
#  1  1  1.0        1.0     1.0       1         20  4PKEEJU4.csv
#  2  1  1.0        1.0     1.0       2         20  4PKEEJU4.csv,
#     k    f1  precision  recall  column  num_cells           tag
#  0  1  0.95       0.95    0.95       0         20  4V4O0CTS.csv
#  1  1  1.00       1.00    1.00       1         20  4V4O0CTS.csv,
#     k   f1  precision  recall  column  num_cells           tag
#  0  1  1.0        1.0     1.0       0         23  5IXA0RAI.csv]

# %%
add_color(result_predictions_location, result_colorized_location, 'siamese_prediction', k=5)
# Out:
# 03XJOJ15.csv
# add-color Time: 0.7236204147338867s
# 06UFHM3B.csv
# add-color Time: 0.27489733695983887s
# 06ZS1QBE.csv
# add-color Time: 0.17109084129333496s
# 090EELY2.csv
# add-color Time: 0.2694880962371826s
# 0CHQAATH.csv
# add-color Time: 0.30591297149658203s
# 0DVQGVUW.csv
# add-color Time: 0.3859376907348633s
# 0HFY1TOW.csv
# add-color Time: 0.1995680332183838s
# 0KL64BZL.csv
# add-color Time: 0.1757965087890625s
# 0LGYY0Y7.csv
# add-color Time: 0.18250274658203125s
# 0U3WMR09.csv
# add-color Time: 0.15735101699829102s
# 0UJRG5XA.csv
# add-color Time: 0.20933890342712402s
# 0VTG406B.csv
# add-color Time: 0.17556428909301758s
# 15S9J1SE.csv
# add-color Time: 0.140855073928833s
# 15ULGJXA.csv
# add-color Time: 0.13775277137756348s
# 15Z7HD0M.csv
# add-color Time: 0.2646012306213379s
# 18PQGWE2.csv
# add-color Time: 3.024301767349243s
# 1A51CWBN.csv
# add-color Time: 0.2887074947357178s
# 1DT331RM.csv
# add-color Time: 0.3035416603088379s
# 1FIFDPBT.csv
# add-color Time: 0.18437695503234863s
# 1FPJTMCX.csv
# add-color Time: 0.16524839401245117s
# 1H6S7TGO.csv
# add-color Time: 0.23368048667907715s
# 1I3AJ8QT.csv
# add-color Time: 0.14678144454956055s
# 1JGP7FA0.csv
# add-color Time: 0.25672173500061035s
# 1JMXOUP0.csv
# add-color Time: 0.19187164306640625s
# 1JV6896P.csv
# add-color Time: 0.1624140739440918s
# 1T2D8C5C.csv
# add-color Time: 1.1256723403930664s
# 1XPHI0P2.csv
# add-color Time: 0.27225327491760254s
# 23NFMDP0.csv
# add-color Time: 0.31716012954711914s
# 243JI1XC.csv
# add-color Time: 0.16294264793395996s
# 253OSZNL.csv
# add-color Time: 0.15873217582702637s
# 25EPRHUJ.csv
# add-color Time: 3.172452449798584s
# 25KTY2D9.csv
# add-color Time: 0.27467799186706543s
# 27V1TQHW.csv
# add-color Time: 0.200120210647583s
# 29AXQS5A.csv
# add-color Time: 0.24433374404907227s
# 2BATTV6X.csv
# add-color Time: 0.13052105903625488s
# 2CPISXSF.csv
# add-color Time: 3.183743476867676s
# 2I24Y64Q.csv
# add-color Time: 0.25119686126708984s
# 2J3MZCRD.csv
# add-color Time: 0.10558223724365234s
# 2LC2LBG1.csv
# add-color Time: 0.24460315704345703s
# 2QM0QJW9.csv
# add-color Time: 0.24214911460876465s
# 2RTA5JIB.csv
# add-color Time: 0.25283026695251465s
# 2S72D3R9.csv
# add-color Time: 0.32234954833984375s
# 2TG5KMPI.csv
# add-color Time: 0.17423701286315918s
# 2Z7W9245.csv
# add-color Time: 0.24181580543518066s
# 2ZCUZYY9.csv
# add-color Time: 0.2639791965484619s
# 2ZYEX9U9.csv
# add-color Time: 4.884344577789307s
# 30KYZ3HO.csv
# add-color Time: 0.15579009056091309s
# 328N1USF.csv
# add-color Time: 0.2825591564178467s
# 340JKVHO.csv
# add-color Time: 0.2799689769744873s
# 39DC3Z7N.csv
# add-color Time: 0.20264697074890137s
# 3K0JGMP1.csv
# add-color Time: 3.537524938583374s
# 3KX6UPPG.csv
# add-color Time: 0.1670224666595459s
# 3L4TR8X5.csv
# add-color Time: 0.15206527709960938s
# 3NCTWO03.csv
# add-color Time: 0.13541960716247559s
# 3O0C4D3O.csv
# add-color Time: 0.1525716781616211s
# 3QZT9O12.csv
# add-color Time: 2.0068094730377197s
# 3R0OGDXK.csv
# add-color Time: 0.16956043243408203s
# 3S4OOVHT.csv
# add-color Time: 0.2784440517425537s
# 3TKOQZJ7.csv
# add-color Time: 0.16408705711364746s
# 42CSV98Q.csv
# add-color Time: 4.52954626083374s
# 471N0AUD.csv
# add-color Time: 0.159010648727417s
# 471ODBDH.csv
# add-color Time: 0.2688639163970947s
# 4722C9EQ.csv
# add-color Time: 0.1910848617553711s
# 49XGWHEN.csv
# add-color Time: 2.2648398876190186s
# 4ANNOIVH.csv
# add-color Time: 0.22499442100524902s
# 4E99I3P7.csv
# add-color Time: 0.14194202423095703s
# 4ENVC6F0.csv
# add-color Time: 0.18423056602478027s
# 4FXN1RZ3.csv
# add-color Time: 0.1048121452331543s
# 4I7A5GID.csv
# add-color Time: 0.1651148796081543s
# 4L16JP9T.csv
# add-color Time: 0.34448981285095215s
# 4LFJR3YN.csv
# add-color Time: 0.1573483943939209s
# 4N6X42PJ.csv
# add-color Time: 0.09952735900878906s
# 4O1BS5W9.csv
# add-color Time: 0.14145994186401367s
# 4Q6FAT24.csv
# add-color Time: 2.604018211364746s
# 4UUFDEP4.csv
# add-color Time: 0.22066569328308105s
# 4WN91IQN.csv
# add-color Time: 0.20524120330810547s
# 4YBOUF9V.csv
# add-color Time: 0.21691203117370605s
# 50ULP1KH.csv
# add-color Time: 0.13825178146362305s
# 519M624G.csv
# add-color Time: 0.1725776195526123s
# 51BN46AU.csv
# add-color Time: 0.23679089546203613s
# 568P9F4E.csv
# add-color Time: 0.1786336898803711s
# 59CFTDPL.csv
# add-color Time: 0.24318218231201172s
# 5BD6VKB3.csv
# add-color Time: 1.9918780326843262s
# 5BEY9DAJ.csv
# add-color Time: 0.22220683097839355s
# 5BVL4YJS.csv
# add-color Time: 0.45223450660705566s
# 5GS30C2C.csv
# add-color Time: 0.16310453414916992s
# 5MMHOLUI.csv
# add-color Time: 0.2474663257598877s
# 5NTTT408.csv
# add-color Time: 0.2806510925292969s
# 5S8PITYQ.csv
# add-color Time: 0.9293813705444336s
# 5VD9H3AD.csv
# add-color Time: 0.3146493434906006s
# 080HU8A5.csv
# add-color Time: 0.160797119140625s
# 0QWF60VG.csv
# add-color Time: 0.22454047203063965s
# 0WBTX8LY.csv
# add-color Time: 0.23007798194885254s
# 1ZFRQBQS.csv
# add-color Time: 0.31186914443969727s
# 2FXR6BX7.csv
# add-color Time: 0.3062736988067627s
# 2YCSL7OH.csv
# add-color Time: 0.22817564010620117s
# 3OAZEVOY.csv
# add-color Time: 0.2569420337677002s
# 3WXFYEAX.csv
# add-color Time: 0.14379382133483887s
# 4FG1UN8O.csv
# add-color Time: 0.3016939163208008s
# 50NWQJ1T.csv
# add-color Time: 5.6391096115112305s
# 53OUTCE4.csv
# add-color Time: 0.21655750274658203s
# 5TJI4XTK.csv
# add-color Time: 0.14493799209594727s
# 06BZ6E4W.csv
# add-color Time: 0.1377265453338623s
# 4XIXYJZJ.csv
# add-color Time: 0.15117645263671875s
# 3FRIAFQG.csv
# add-color Time: 1.21710205078125s
# 44NDHWR1.csv
# add-color Time: 0.23720955848693848s
# 0Z7HR2PY.csv
# add-color Time: 0.21133828163146973s
# 19VR20Q8.csv
# add-color Time: 0.25152134895324707s
# 0XWQ7DA6.csv
# add-color Time: 0.13624334335327148s
# 0G9YPQC0.csv
# add-color Time: 4.028022527694702s
# 2OJXQ9F3.csv
# add-color Time: 0.1737983226776123s
# 4I995NNQ.csv
# add-color Time: 0.24985909461975098s
# 1TRSZPVI.csv
# add-color Time: 0.215836763381958s
# 3AK02Q9B.csv
# add-color Time: 2.5474724769592285s
# 1GOKLC0K.csv
# 1K47VLGF.csv
# add-color Time: 0.27791810035705566s
# 09Z268Z7.csv
# add-color Time: 0.15204429626464844s
# 21P58N2X.csv
# add-color Time: 0.11214184761047363s
# 5N8AUSXE.csv
# add-color Time: 0.22657084465026855s
# 1O72GQD8.csv
# add-color Time: 0.2342841625213623s
# 3540Y3D5.csv
# add-color Time: 0.2471144199371338s
# 1XK9O8CF.csv
# add-color Time: 0.1918628215789795s
# 3DRSAGO5.csv
# add-color Time: 0.20279288291931152s
# 36KH7GH7.csv
# add-color Time: 0.2188103199005127s
# 2FHCJAMA.csv
# add-color Time: 3.6595020294189453s
# 3UP2SR30.csv
# add-color Time: 0.17296671867370605s
# 59JNC864.csv
# add-color Time: 0.19939136505126953s
# 4QTU5MYM.csv
# add-color Time: 0.46808695793151855s
# 5KZVO2UP.csv
# add-color Time: 0.24553585052490234s
# 0D1JRXQD.csv
# add-color Time: 0.18790507316589355s
# 239AZL33.csv
# add-color Time: 0.14706897735595703s
# 5739HKRB.csv
# add-color Time: 0.2029097080230713s
# 28D7RBJT.csv
# add-color Time: 0.17134594917297363s
# 0HZG8QGJ.csv
# add-color Time: 2.893127918243408s
# 1SEMN3SZ.csv
# add-color Time: 0.2521986961364746s
# 42WEUQ95.csv
# add-color Time: 0.2090303897857666s
# 0P8H49LQ.csv
# add-color Time: 0.2459414005279541s
# 1NS33P8C.csv
# add-color Time: 6.364975452423096s
# 5PJ0EF0X.csv
# add-color Time: 0.19989490509033203s
# 12MLK2A7.csv
# add-color Time: 0.15946245193481445s
# 19NE0FCU.csv
# add-color Time: 0.1847376823425293s
# 3S6WON79.csv
# add-color Time: 0.6486051082611084s
# 085QNFGZ.csv
# add-color Time: 0.1542506217956543s
# 0VC79Y6X.csv
# add-color Time: 0.43942999839782715s
# 5D3I2S1N.csv
# add-color Time: 0.1859273910522461s
# 1JCXMKCK.csv
# add-color Time: 0.42584967613220215s
# 00UQHNO3.csv
# add-color Time: 0.2700989246368408s
# 4C37XZHJ.csv
# add-color Time: 0.2990076541900635s
# 1J4YRLOY.csv
# add-color Time: 0.19101762771606445s
# 3IBPLURT.csv
# add-color Time: 0.17912030220031738s
# 5CG871YQ.csv
# add-color Time: 3.0250613689422607s
# 3T93HF0D.csv
# add-color Time: 0.2223355770111084s
# 0VDX10IJ.csv
# add-color Time: 0.20540332794189453s
# 4SOL8H0M.csv
# add-color Time: 0.27010655403137207s
# 0BY9CFLK.csv
# add-color Time: 0.15948748588562012s
# 3HLRFWSX.csv
# add-color Time: 0.15862011909484863s
# 48PAQE6M.csv
# add-color Time: 1.1541039943695068s
# 2XEP26CX.csv
# add-color Time: 0.2080678939819336s
# 5PKTGQ6Q.csv
# add-color Time: 0.17204618453979492s
# 59W76Q0Y.csv
# add-color Time: 0.15070581436157227s
# 1GUVMENF.csv
# 24OGNVVP.csv
# add-color Time: 3.6160266399383545s
# 5TWQ98LE.csv
# add-color Time: 0.13790154457092285s
# 1T9NKN9B.csv
# add-color Time: 0.1869983673095703s
# 2ZLDMP9R.csv
# add-color Time: 0.17214632034301758s
# 0LZ0M8W4.csv
# add-color Time: 0.2419440746307373s
# 4DC5O5I4.csv
# add-color Time: 0.0991365909576416s
# 3290T9NG.csv
# add-color Time: 0.1551213264465332s
# 5894JWA5.csv
# add-color Time: 2.552192211151123s
# 0MYK9SQC.csv
# add-color Time: 0.20637154579162598s
# 4MGX23BZ.csv
# add-color Time: 0.24025464057922363s
# 5TXLGRXA.csv
# add-color Time: 0.22765684127807617s
# 1YPLVLS9.csv
# add-color Time: 0.3025968074798584s
# 5W6MRY0W.csv
# add-color Time: 4.151595115661621s
# 2PKG4E2V.csv
# add-color Time: 0.2926669120788574s
# 3M5QXPWN.csv
# add-color Time: 0.2332324981689453s
# 14DACNEL.csv
# add-color Time: 0.17621541023254395s
# 58E7A5WL.csv
# add-color Time: 0.18754839897155762s
# 1ZX2DCW7.csv
# add-color Time: 3.0423271656036377s
# 4VAYQOG0.csv
# add-color Time: 0.14176464080810547s
# 45D6VIRT.csv
# add-color Time: 0.16573739051818848s
# 2WRDGDBJ.csv
# add-color Time: 0.2912585735321045s
# 4DPRZWVL.csv
# add-color Time: 0.15091562271118164s
# 3FQ85RUH.csv
# add-color Time: 0.20991039276123047s
# 5QDDFGBJ.csv
# add-color Time: 0.30399656295776367s
# 4IJHCIR9.csv
# add-color Time: 0.17051076889038086s
# 42BKS5LP.csv
# add-color Time: 0.1374063491821289s
# 1FXQQ1RM.csv
# add-color Time: 0.15145230293273926s
# 1XIWQBSF.csv
# add-color Time: 7.449718475341797s
# 2P4BZPW1.csv
# add-color Time: 0.15538239479064941s
# 1375IHBW.csv
# add-color Time: 0.295212984085083s
# 3HZEPYNC.csv
# add-color Time: 0.13561511039733887s
# 2OYAB7YM.csv
# add-color Time: 0.2973496913909912s
# 3CJEDV9F.csv
# add-color Time: 0.14412546157836914s
# 00YF468U.csv
# add-color Time: 1.5936245918273926s
# 2BLFNACC.csv
# add-color Time: 0.2268972396850586s
# 3C74M7HU.csv
# add-color Time: 0.18691277503967285s
# 11VNNTDS.csv
# add-color Time: 0.1897444725036621s
# 0ADP8WGU.csv
# add-color Time: 0.11777591705322266s
# 0P4Y07PN.csv
# add-color Time: 2.798091173171997s
# 302H92MV.csv
# add-color Time: 0.18961882591247559s
# 174Q7GKD.csv
# add-color Time: 0.16679787635803223s
# 2P3KJ1P0.csv
# add-color Time: 0.22620868682861328s
# 26CIDK81.csv
# add-color Time: 0.17973613739013672s
# 5P2SOXGW.csv
# add-color Time: 0.21074914932250977s
# 5Q5RASS8.csv
# add-color Time: 0.1531059741973877s
# 0JSF530F.csv
# add-color Time: 2.738010883331299s
# 08XTIUJQ.csv
# add-color Time: 0.14355039596557617s
# 17DA0MJ4.csv
# add-color Time: 0.20656371116638184s
# 3RC46CRC.csv
# add-color Time: 0.24342036247253418s
# 03Q5JG9I.csv
# add-color Time: 0.18138861656188965s
# 1STAURLW.csv
# add-color Time: 0.1489112377166748s
# 0ZXPJXH4.csv
# add-color Time: 0.13935375213623047s
# 0M7R2JUU.csv
# add-color Time: 3.335263967514038s
# 4DM4KN9O.csv
# add-color Time: 0.14749813079833984s
# 20PYU63R.csv
# add-color Time: 0.15044736862182617s
# 3IB64ASX.csv
# add-color Time: 0.403796911239624s
# 15CM535P.csv
# add-color Time: 0.17151260375976562s
# 1D0TLL3P.csv
# add-color Time: 0.1352977752685547s
# 0B8EGHVB.csv
# add-color Time: 0.14507055282592773s
# 15HDRE87.csv
# add-color Time: 0.14605307579040527s
# 4KDMZHXJ.csv
# add-color Time: 0.14177560806274414s
# 0KWK2FSC.csv
# add-color Time: 0.23498988151550293s
# 3IALBWVT.csv
# add-color Time: 0.24930763244628906s
# 0RWHW0S0.csv
# add-color Time: 0.24784231185913086s
# 0L4YDT86.csv
# add-color Time: 2.8894076347351074s
# 2BRG4KEL.csv
# add-color Time: 0.14990949630737305s
# 0ZZFENJS.csv
# add-color Time: 0.22459077835083008s
# 3J5ABW9E.csv
# add-color Time: 0.2279191017150879s
# 24VU5BR7.csv
# add-color Time: 0.1957111358642578s
# 24VD82I7.csv
# add-color Time: 6.813486099243164s
# 24HLK9BD.csv
# add-color Time: 0.2341158390045166s
# 1XV2X3XE.csv
# add-color Time: 0.20449256896972656s
# 48BAS22X.csv
# add-color Time: 0.2314896583557129s
# 32DWSB26.csv
# add-color Time: 0.13998198509216309s
# 1LI468T0.csv
# add-color Time: 0.22060871124267578s
# 289YGN9G.csv
# add-color Time: 0.28613924980163574s
# 10WA15QW.csv
# add-color Time: 0.14822101593017578s
# 3EL4J49W.csv
# add-color Time: 0.11012482643127441s
# 16F08KC4.csv
# add-color Time: 0.22641515731811523s
# 1AXBOBYJ.csv
# add-color Time: 0.25325465202331543s
# 49K301SA.csv
# add-color Time: 0.1556851863861084s
# 3CSAH6ZY.csv
# add-color Time: 4.29862380027771s
# 32GFE6D8.csv
# add-color Time: 0.3655245304107666s
# 0A4KYJH5.csv
# add-color Time: 0.13575267791748047s
# 3WIJWVTF.csv
# add-color Time: 0.16574859619140625s
# 1QGWWYAF.csv
# add-color Time: 0.2136368751525879s
# 4RB6CKKQ.csv
# add-color Time: 0.23769617080688477s
# 3PSDVWZR.csv
# add-color Time: 0.2277076244354248s
# 18T4PJWW.csv
# add-color Time: 0.15625762939453125s
# 0JSE9VIO.csv
# add-color Time: 0.21470952033996582s
# 4G8G7N8W.csv
# add-color Time: 4.047138929367065s
# 4NVYEVEQ.csv
# add-color Time: 0.10235810279846191s
# 4IB27COT.csv
# add-color Time: 0.23316121101379395s
# 0DHFD9QY.csv
# add-color Time: 0.20911860466003418s
# 0EH4XC4H.csv
# add-color Time: 0.2302556037902832s
# 2IQQE9DB.csv
# add-color Time: 0.22848892211914062s
# 27BGOKZ7.csv
# add-color Time: 0.25946974754333496s
# 1SWM4IDV.csv
# add-color Time: 0.2518641948699951s
# 0DS28PUJ.csv
# add-color Time: 0.14021658897399902s
# 1UBAHGEU.csv
# add-color Time: 0.15143704414367676s
# 19WCLMKZ.csv
# add-color Time: 0.14521527290344238s
# 3CUK6D56.csv
# add-color Time: 0.20141077041625977s
# 0Z8LKW3C.csv
# add-color Time: 7.003995656967163s
# 042AKDN1.csv
# add-color Time: 0.15671634674072266s
# 09DZVIPV.csv
# add-color Time: 0.17288804054260254s
# 46HT6F8E.csv
# add-color Time: 0.10315322875976562s
# 0UX45YZS.csv
# add-color Time: 0.22859501838684082s
# 1E1WKZOC.csv
# add-color Time: 7.912233829498291s
# 0VGKU21T.csv
# add-color Time: 0.21182990074157715s
# 01E31BCQ.csv
# add-color Time: 0.21585369110107422s
# 3PZX8I05.csv
# add-color Time: 0.29672861099243164s
# 18TCX9AJ.csv
# add-color Time: 0.10159802436828613s
# 3MFTI3Y1.csv
# add-color Time: 7.976480722427368s
# 41UF0D20.csv
# add-color Time: 0.34087109565734863s
# 1FF0TRWQ.csv
# add-color Time: 0.1755356788635254s
# 28Y667AR.csv
# add-color Time: 0.18938422203063965s
# 263P426L.csv
# add-color Time: 0.22473835945129395s
# 258AFYQJ.csv
# add-color Time: 0.2606627941131592s
# 1JY71MSY.csv
# add-color Time: 3.011171579360962s
# 2AQ0VUOP.csv
# add-color Time: 0.1901407241821289s
# 1FP8LYOS.csv
# add-color Time: 0.21296048164367676s
# 2JN1R1VW.csv
# add-color Time: 0.25141119956970215s
# 4P9QJEV9.csv
# add-color Time: 0.1890113353729248s
# 2QS5IM8T.csv
# add-color Time: 0.17731642723083496s
# 1DQVRVUL.csv
# add-color Time: 0.1508934497833252s
# 0BM19RVO.csv
# add-color Time: 0.24037408828735352s
# 3CLS11K2.csv
# add-color Time: 0.3174777030944824s
# 2OQR5KK1.csv
# add-color Time: 0.13705778121948242s
# 40DGQ0R6.csv
# add-color Time: 0.15188860893249512s
# 39HQAJDE.csv
# add-color Time: 9.592272281646729s
# 04A3K0PO.csv
# add-color Time: 0.22922253608703613s
# 43NKPCQ8.csv
# add-color Time: 0.2582368850708008s
# 3TZ2D9V5.csv
# add-color Time: 0.21297931671142578s
# 2VWPPCQM.csv
# add-color Time: 0.21349143981933594s
# 1CS2NQUR.csv
# add-color Time: 8.658316135406494s
# 36LCWPLR.csv
# add-color Time: 0.2299487590789795s
# 0IUSS6UH.csv
# add-color Time: 0.1412506103515625s
# 1TQSKB2E.csv
# add-color Time: 0.26602911949157715s
# 20ISN4OJ.csv
# add-color Time: 0.22798871994018555s
# 2TUG0XHN.csv
# add-color Time: 0.17795419692993164s
# 479O847V.csv
# add-color Time: 0.1404879093170166s
# 3SQ9UAK1.csv
# add-color Time: 0.22420191764831543s
# 1U6PF4FY.csv
# add-color Time: 0.2305433750152588s
# 2ZLGXNTV.csv
# add-color Time: 0.14012527465820312s
# 3T54D76A.csv
# add-color Time: 0.18471884727478027s
# 3MKMD5TW.csv
# add-color Time: 0.20108509063720703s
# 2XDZM14F.csv
# add-color Time: 0.22072410583496094s
# 19FQNTBF.csv
# add-color Time: 5.351886034011841s
# 4UZA5UWB.csv
# add-color Time: 0.18628573417663574s
# 4VL4BFPM.csv
# add-color Time: 0.1407923698425293s
# 4ZZG4HMD.csv
# add-color Time: 0.25656723976135254s
# 54SEC9F3.csv
# add-color Time: 0.19792747497558594s
# 56CDHMVN.csv
# add-color Time: 6.552964687347412s
# 5BGVRHI5.csv
# add-color Time: 0.13021206855773926s
# 5E9CSACP.csv
# add-color Time: 0.22284483909606934s
# 5ECFP78V.csv
# add-color Time: 0.1871504783630371s
# 5FMSUKCH.csv
# add-color Time: 0.1370837688446045s
# 5G4M4L5W.csv
# add-color Time: 0.19816350936889648s
# 5IKCI9Z4.csv
# add-color Time: 8.193011999130249s
# 5J25NATF.csv
# add-color Time: 0.2012343406677246s
# 5NMYKF77.csv
# add-color Time: 4.185208797454834s
# 5SB78VPX.csv
# add-color Time: 0.2458646297454834s
# 5T891IJ9.csv
# add-color Time: 0.23520278930664062s
# 5WA7NENC.csv
# add-color Time: 1.5439269542694092s
# 5WFYRRY7.csv
# add-color Time: 0.1574108600616455s
# 00ECUL14.csv
# add-color Time: 0.18030333518981934s
# 0CETTKTA.csv
# add-color Time: 0.1489114761352539s
# 0FQOOJPU.csv
# add-color Time: 0.22394776344299316s
# 0LF7RI6N.csv
# add-color Time: 0.1940476894378662s
# 0TQXSY28.csv
# add-color Time: 0.1451554298400879s
# 1PTL0CX1.csv
# add-color Time: 0.185791015625s
# 1T91CHXV.csv
# add-color Time: 0.22912955284118652s
# 29D1VZHF.csv
# add-color Time: 0.22249126434326172s
# 2E6QBLCA.csv
# add-color Time: 7.838221073150635s
# 2FSRG0OI.csv
# add-color Time: 0.1784060001373291s
# 2QFYH2N9.csv
# add-color Time: 0.2167043685913086s
# 2TGNKH1P.csv
# add-color Time: 0.1980915069580078s
# 39W7XXTI.csv
# add-color Time: 0.22446823120117188s
# 3B54GZSX.csv
# add-color Time: 8.575754404067993s
# 3JNFST2K.csv
# add-color Time: 0.1777663230895996s
# 3OCW1LDZ.csv
# add-color Time: 0.23815274238586426s
# 4PKEEJU4.csv
# add-color Time: 0.22515654563903809s
# 4V4O0CTS.csv
# add-color Time: 0.18516945838928223s
# 5IXA0RAI.csv
# add-color Time: 8.506836175918579s

# %%
metrics_k_200 = compute_metrics(result_predictions_location, result_metrics_location, final_score_column, k = 200)
# Out:
# T7RPWH6N.csv
# NDSTZH1I.csv
# metrics Time: 0.66619873046875s
# QIW5EC2H.csv
# metrics Time: 7.522080421447754s
# P8B3IAOY.csv
# metrics Time: 0.2715945243835449s
# ZZNW93IV.csv
# PWNRGOJ5.csv
# metrics Time: 0.47112107276916504s
# UURPYBGQ.csv
# 4FW66XNV.csv
# metrics Time: 0.06413602828979492s

# %%
metrics_k_200
# Out:
#      k        f1  precision    recall  column  num_cells           tag
# 0  200  0.980000   0.960784  1.000000       1         51  T7RPWH6N.csv
# 1  200  0.675325   0.509804  1.000000       2         51  T7RPWH6N.csv
# 2  200  0.980392   0.980392  0.980392       6         51  T7RPWH6N.csv
# 0  200  0.808163   0.733333  0.900000       0         60  NDSTZH1I.csv
# 1  200  0.806061   0.700000  0.950000       1         60  NDSTZH1I.csv
# 0  200  0.872972   0.826944  0.924425       0        913  QIW5EC2H.csv
# 1  200  1.000000   1.000000  1.000000       1        913  QIW5EC2H.csv
# 0  200  1.000000   1.000000  1.000000       0         15  P8B3IAOY.csv
# 1  200  0.928571   0.866667  1.000000       1         15  P8B3IAOY.csv
# 2  200  1.000000   1.000000  1.000000       2         15  P8B3IAOY.csv
# 0  200  1.000000   1.000000  1.000000       0         28  PWNRGOJ5.csv
# 1  200  1.000000   1.000000  1.000000       1         28  PWNRGOJ5.csv
# 2  200  0.857143   0.750000  1.000000       4         28  PWNRGOJ5.csv
# 0  200  0.000000   0.000000  0.500000       0          6  4FW66XNV.csv

# %%
metrics_k_1 = compute_metrics(result_predictions_location, result_metrics_location, final_score_column, k=1)
# Out:
# PWNRGOJ5.csv
# 4FW66XNV.csv
# metrics Time: 0.06575465202331543s
