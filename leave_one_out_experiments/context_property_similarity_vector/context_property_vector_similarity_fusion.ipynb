# %% [markdown]
# ## Purpose: Use both context similarity vector and context score
# To complete this experiment, following changes have been done,
# - Calculate context similarity vector by first calculating normal context property vector from context property string
# - Use PCA as dimensional reduction technique on the context similarity vector
# - Recalculate the context property vector during training (not flexible to store) and apply autoencoder for dimensional reduction. <br>
#
# Set parameters in the cells tagged "set_parameters" <br>
# Download data from table-linker-datasets/context_vector_{train/dev}_data in to Experiments/context_vector_train/dev_data
# <br>
# It stores result while creating the similarity vector temporarily in temp_c_{N_PCA_Components} which can be erased once the pos and neg pickle files are generated.

# %%
###Importing all the libraries
import glob
import boto3
import time
import os
import pandas as pd
import sklearn.metrics
from sklearn.preprocessing import MinMaxScaler
import pickle
from argparse import ArgumentParser, Namespace
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam
from itertools import chain
import copy
import shutil
import pickle
from tqdm import tqdm
import scipy.sparse as sp
import os
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense
## Importing context_similarity function
import context_property_similarity_code

# %%
# Setup the variables
N_PCA_COMPONENTS = 10
features = ["monge_elkan","monge_elkan_aliases","jaro_winkler",
            "levenshtein","singleton","context_score_3","pgt_centroid_score","pgt_class_count_tf_idf_score",
            "pgt_property_count_tf_idf_score", "num_occurences"]
features = ["monge_elkan","monge_elkan_aliases","jaro_winkler",
            "levenshtein","singleton","context_score_3", "num_occurences"]
BATCH_SIZE = 32
LEARNING_RATE = 0.00001
autoencoder_path = 'saved_2000_100/saved_2000_1000'
ENCODER_COMPONENTS = 100

# %%
experiment_name = f"Experiment_test_semtab_plain_version_n_{N_PCA_COMPONENTS}"
experiment_data = '2t_data,limaye_data,biotab_data,t2dv2_data,biodiv_data'
### Creating the directories for the results.
experiment_train_data = experiment_data
experiment_dev_data =  experiment_data
experiment_test_data = 'semtab_data'
experiment_store_path = f"../Experiments/{experiment_name}"
processed_dev_data = f"{experiment_store_path}/dev/features/"
processed_test_data = f"{experiment_store_path}/test/features/"
dev_predictions = f"{experiment_store_path}/dev/dev_predictions/"
test_predictions = f"{experiment_store_path}/test/test_predictions/"
dev_output_pred = f"{experiment_store_path}/dev/dev_output/"
dev_predictions_top_k = f"{experiment_store_path}/dev/dev_predictions_top_k/"
dev_metrics = f"{experiment_store_path}/dev/dev_metrics/"
dev_predictions_colorized = f"{experiment_store_path}/dev/dev_predictions_colorized/"
model_save_path = f'{experiment_store_path}/model_save_path/'
best_model_path = ''

training_data_path = f'{experiment_store_path}/model_training_data'

pos_output = f'{training_data_path}/tl_pipeline_pos_features_{BATCH_SIZE}.pkl'
neg_output = f'{training_data_path}/tl_pipeline_neg_features_{BATCH_SIZE}.pkl'
min_max_scaler_path = f'{training_data_path}/tl_pipeline_normalization_factor.pkl'

final_score_column = 'siamese_prediction'

extra_feat = ['column-id', 'column', 'row', 'evaluation_label', 'dataset_id', 'table_id', 'context_property_vector']
for f in features:
    extra_feat.append(f)


# !mkdir -p $experiment_store_path 
# !mkdir -p $dev_predictions 
# !mkdir -p $dev_output_pred
# !mkdir -p $dev_predictions_top_k 
# !mkdir -p $dev_metrics 
# !mkdir -p $dev_predictions_colorized 
# !mkdir -p $model_save_path 
# !mkdir -p $training_data_path
# !mkdir -p $processed_dev_data
# !mkdir -p $processed_test_data
# !mkdir -p $test_predictions
temp_csv_cfolder = f'temp_contextscore_c{N_PCA_COMPONENTS}'
# !mkdir -p $temp_csv_cfolder

# %%
train_files_path = [f'../Experiments/context_vector_train_data/' + i for i in experiment_train_data.split(',')]
train_files = []
for train_path in train_files_path:
    set_of_files = glob.glob(train_path + '/*.csv')
    train_files.extend(set_of_files)
print(len(train_files))
dev_files_path = ['../Experiments/context_vector_dev_data/' + i for i in experiment_train_data.split(',')]
dev_files = []
for dev_path in dev_files_path:
    set_of_files = glob.glob(dev_path + '/*.csv')
    dev_files.extend(set_of_files)
print(len(dev_files))
test_files = []
test_files_location = ['../Experiments/context_vector_dev_data/semtab_data', '../Experiments/context_vector_train_data/semtab_data']
for k in test_files_location:
    test_files.extend(glob.glob(k + '/*.csv'))
print(len(test_files))
all_prop = pickle.load(open('all_properties.pkl', 'rb'))
# Out:
# 453
# 161
# 345

# %%
class AutoEncoders(Model):

    def __init__(self, layer_1_unit = 2000, layer_2_unit=100, layer_3_unit = None, output_units = None):
        super().__init__()
        self.encoder = Sequential(
            [
                Dense(layer_1_unit, activation="relu"),
                Dense(layer_2_unit, activation="relu"),
                #Dense(layer_3_unit, activation="relu")
            ]
        )

        self.decoder = Sequential(
            [
                #Dense(layer_2_unit, activation="relu"),
                Dense(layer_1_unit, activation="relu"),
                Dense(output_units, activation="sigmoid")
            ]
        )


    def call(self, inputs):
        encoded = self.encoder(inputs)
        decoded = self.decoder(encoded)
        return decoded

# %%
a_model = AutoEncoders(output_units = len(all_prop))
print(a_model.layers)
a_model.load_weights(autoencoder_path)
encoder_layer = a_model.get_layer('sequential')
# Out:
# [<tensorflow.python.keras.engine.sequential.Sequential object at 0x7f65b4f572e0>, <tensorflow.python.keras.engine.sequential.Sequential object at 0x7f65b4f57c10>]

# %%
# Helpher functions for data preprocessing
def merge_files(args):
    # datapath = args.train_path
    df_list = []
    for fn in args.train_files:
        fid = fn.split('/')[-1][:-4]
        dataset_id = fn.split('/')[-2]
        df = read_file(fn)
        if not isinstance(df, pd.DataFrame) :
            continue

        df['table_id'] = fid
        print(dataset_id, fid)
        df['dataset_id'] = dataset_id
        df['context_score'].fillna(0.0, inplace=True)
        if 'column-id' not in df.columns:
            df['column-id'] = fn.split('/')[-1] + df['column'].astype('str')

        df = df[extra_feat]
        df_list.append(df)
    return pd.concat(df_list)


def compute_normalization_factor(args, all_data):
    min_max_scaler_path = args.min_max_scaler_path
    all_data_features = all_data[features]
    scaler = MinMaxScaler()
    scaler.fit(all_data_features)
    return scaler


def read_file(key):
    #resp = s3.get_object(Bucket = bucket, Key = key)
    try:
        df = pd.read_csv(key, sep = ',')
    except pd.errors.EmptyDataError:
        df = ''
        print('Empty csv file!')
    return df

# %%
def generate_train_data(args, all_data, scaler, shuffle_by = None):
    num_cells_1 = 0
    scaler_path = args.min_max_scaler_path
    #scaler = pickle.load(open('./tmp/min_max_scaler_path.pkl', 'rb'))
    final_list = []
    sfeatures = copy.deepcopy(features) + ['context_property_vector'] #+ [f'csp_{i}' for i in range(N_PCA_COMPONENTS)] 
    normalize_features = features
    evaluation_label = ['evaluation_label']
    positive_features_final = []
    negative_features_final = []
    super_groups = all_data.groupby(['column-id'])
    if shuffle_by == 'dataset':
        super_groups = all_data.groupby(['dataset_id'])
        for i, s_group in super_groups:
            pos_features_dataset = []
            neg_features_dataset = []
            grouped_obj = s_group.groupby(['column', 'row', 'column-id'])

            for cell in grouped_obj:
                num_cells_1 += 1
                cell[1][normalize_features] = scaler.transform(cell[1][normalize_features])
                pos_features = []
                neg_features = []
                a = cell[1][cell[1]['evaluation_label'] == 1]
                if a.empty:
                    continue
                pos_rows = cell[1][cell[1]['evaluation_label'].astype(int) == 1][sfeatures].to_numpy()
                if len(pos_rows) < 1:
                    continue
                if len(pos_rows) > 1:
                    print("here")
                for i in range(len(pos_rows)):
                    pos_features.append(pos_rows[i])
                neg_rows = cell[1][cell[1]['evaluation_label'].astype(int) == -1][sfeatures].to_numpy()
                for i in range(min(BATCH_SIZE, len(neg_rows))):
                    neg_features.append(neg_rows[i])

                for k in range(len(neg_features) - len(pos_features)):
                    pos_features.append(random.choice(pos_rows))
                if len(pos_features) != len(neg_features):
                    continue
                pos_features_dataset.append(pos_features)
                neg_features_dataset.append(neg_features)
            if len(pos_features_dataset) > 0:
                c = list(zip(pos_features_dataset, neg_features_dataset))
                random.shuffle(c)
                pos_features_dataset, neg_features_dataset = zip(*c)
                positive_features_final.extend(pos_features_dataset)
                negative_features_final.extend(neg_features_dataset)
    elif shuffle_by == 'table':
        super_groups = all_data.groupby(['table_id'])
        for i, s_group in super_groups:
            pos_features_table = []
            neg_features_table = []
            file_name = i.split('-')[0]
            # Setting the return context property to false for now. After generating dataset, we will run again to get the 
            # context property vector. Reduces memory used for saving files.
            # s_group_n = context_property_similarity_code.return_a_table(s_group, pca_components = N_PCA_COMPONENTS, return_context_property = False)
            #print("entering ", file_name)
            ds_id = s_group['dataset_id'].values[0]
            print("File: ", file_name, ds_id)
            '''
            if os.path.exists(f'temp_csv_c{N_PCA_COMPONENTS}/neg_{ds_id}_{file_name}.pkl'):
                print("Already Exists!")
                pos_features_table = pickle.load(open(f'temp_csv_c{N_PCA_COMPONENTS}/pos_{ds_id}_{file_name}.pkl', 'rb'))
                neg_features_table = pickle.load(open(f'temp_csv_c{N_PCA_COMPONENTS}/neg_{ds_id}_{file_name}.pkl', 'rb'))
                positive_features_final.extend(pos_features_table)
                negative_features_final.extend(neg_features_table) 
                continue
            '''
            grouped_obj = s_group.groupby(['column', 'row'])
    
            for cell in grouped_obj:
                num_cells_1 += 1
                cell[1][normalize_features] = scaler.transform(cell[1][normalize_features])
                pos_features = []
                neg_features = []
                a = cell[1][cell[1]['evaluation_label'] == 1]
                if a.empty:
                    continue
                pos_rows = cell[1][cell[1]['evaluation_label'].astype(int) == 1][sfeatures].to_numpy()
                if len(pos_rows) < 1:
                    continue
                if len(pos_rows) > 1:
                    print("here")
                for i in range(len(pos_rows)):
                    pos_features.append(pos_rows[i])
                neg_rows = cell[1][cell[1]['evaluation_label'].astype(int) == -1][sfeatures].to_numpy()
                for i in range(min(BATCH_SIZE, len(neg_rows))):
                    neg_features.append(neg_rows[i])

                for k in range(len(neg_features) - len(pos_features)):
                    pos_features.append(random.choice(pos_rows))
                if len(pos_features) != len(neg_features):
                    continue
                random.shuffle(pos_features)

                random.shuffle(neg_features)
                pos_features_table.append(pos_features)
                neg_features_table.append(neg_features)
            if len(pos_features_table) > 0:
                c = list(zip(pos_features_table, neg_features_table))
                random.shuffle(c)
                pos_features_table, neg_features_table = zip(*c)
                positive_features_final.extend(pos_features_table)
                negative_features_final.extend(neg_features_table)
                
                pickle.dump(pos_features_table, open(f'temp_csv_c{N_PCA_COMPONENTS}/pos_{ds_id}_{file_name}.pkl', 'wb'))
                pickle.dump(neg_features_table, open(f'temp_csv_c{N_PCA_COMPONENTS}/neg_{ds_id}_{file_name}.pkl', 'wb'))
    else:
        for i, s_group in super_groups:
            file_name = i.split('-')[0]
            #print("entering ", file_name)
            grouped_obj = s_group.groupby(['column', 'row'])
            for cell in grouped_obj:
                num_cells_1 += 1
                cell[1][normalize_features] = scaler.transform(cell[1][normalize_features])
                pos_features = []
                neg_features = []
                a = cell[1][cell[1]['evaluation_label'] == 1]
                if a.empty:
                    continue
                pos_rows = cell[1][cell[1]['evaluation_label'].astype(int) == 1][sfeatures].to_numpy()
                if len(pos_rows) < 1:
                    continue
                if len(pos_rows) > 1:
                    print("here")
                for i in range(len(pos_rows)):
                    pos_features.append(pos_rows[i])
                neg_rows = cell[1][cell[1]['evaluation_label'].astype(int) == -1][sfeatures].to_numpy()
                for i in range(min(BATCH_SIZE, len(neg_rows))):
                    neg_features.append(neg_rows[i])

                for k in range(len(neg_features) - len(pos_features)):
                    pos_features.append(random.choice(pos_rows))
                random.shuffle(pos_features)
                random.shuffle(neg_features)
                if len(pos_features) != len(neg_features):
                    print("HHHERRRERR")
                else:
                    positive_features_final.append(pos_features)
                    negative_features_final.append(neg_features)
                #print(len(positive_features_final), len(positive_features_final[3]))
                #print(len(negative_features_final), len(negative_features_final[3]))
    if shuffle_by == 'complete_shuffle':
        c = list(zip(positive_features_final, negative_features_final))
        random.shuffle(c)
        positive_features_final, positive_features_final = zip(*c)
    print(len(positive_features_final), len(positive_features_final[3]))
    print(len(negative_features_final), len(negative_features_final[3]))

    print(len(positive_features_final), len(positive_features_final[3]))
    print(len(negative_features_final), len(negative_features_final[3]))
    return positive_features_final, negative_features_final

def generate_dataloader(positive_feat_path, negative_feat_path):
    pos_features = pickle.load(open(positive_feat_path, 'rb'))
    neg_features = pickle.load(open(negative_feat_path, 'rb'))
    print(pos_features[10])
    pos_features_flatten = list(chain.from_iterable(pos_features))
    neg_features_flatten = list(chain.from_iterable(neg_features))
    return pos_features_flatten, neg_features_flatten

# %%
# Setting the scaler and merging files
gen_training_data_args = Namespace(train_files=train_files, pos_output=pos_output, neg_output=neg_output,min_max_scaler_path=min_max_scaler_path)
all_data = merge_files(gen_training_data_args)
scaler = compute_normalization_factor(gen_training_data_args, all_data)
pickle.dump(scaler, open(min_max_scaler_path, 'wb'))
# Out:
# 2t_data 3DOM5NIW
# 2t_data 3JXMPC7N
# 2t_data 3LG8J4MX
# 2t_data 3N6S2FCX
# 2t_data 4J75OL3W
# 2t_data 6I7ET24J
# 2t_data 71SY0Z5S
# 2t_data AUU9A6KL
# 2t_data B20WIQKU
# 2t_data B38A9Q5R
# 2t_data BID0NRU0
# 2t_data CHZGO92A
# 2t_data CNQ5Z0BG
# 2t_data DXTA1MV8
# 2t_data E22XXKVQ
# 2t_data E3ZK744Q
# 2t_data E45F8QW2
# 2t_data EQZ21058
# 2t_data ET9REW9Y
# 2t_data EV6LDIB8
# 2t_data F98SUVJH
# 2t_data FF00TEZG
# 2t_data FVKKTA8O
# 2t_data FWSGRDQ3
# 2t_data GINQPZQC
# 2t_data GNDO9OXJ
# 2t_data GY7KNULP
# 2t_data HB00DX4L
# 2t_data HCLZSPEJ
# 2t_data HGIUTSCG
# 2t_data HGYG2DVU
# 2t_data HLJ9HHEE
# 2t_data HQCEC5NO
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 2t_data HQRATPBV
# 2t_data HTF6MVY9
# 2t_data I0ENR9U5
# 2t_data I6BBMPNU
# 2t_data IP6ZRIGH
# 2t_data IPTLCCCU
# 2t_data IYZYF533
# 2t_data IZF82AX9
# 2t_data J9EJV2S3
# 2t_data JA4L7KWX
# 2t_data JN0T2O5I
# 2t_data JZ22O0DD
# 2t_data JZLRN9PL
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 2t_data K2VEUQT0
# 2t_data K3X3L22Y
# 2t_data K71YYDXO
# 2t_data KOQM4YU9
# 2t_data LV5N8XDB
# 2t_data MANO2PKR
# 2t_data MSCT8MJD
# 2t_data MZ0BI8NN
# 2t_data N6QAC84T
# 2t_data NDSTZH1I
# 2t_data NV4GY44T
# 2t_data NYFX4M8T
# 2t_data O0BECB72
# 2t_data O0UJJVBR
# 2t_data OD9USH5H
# 2t_data OHGI1JNY
# 2t_data OIDIXPNZ
# 2t_data OKW6UUW5
# 2t_data ORPKCFRL
# 2t_data OZYCQ769
# 2t_data P86ZJFXK
# 2t_data P8B3IAOY
# 2t_data PWNRGOJ5
# 2t_data PZXDACJ9
# 2t_data QIW5EC2H
# 2t_data QNP7O8L5
# 2t_data QOAVEFGY
# 2t_data QOL4ZIHL
# 2t_data QPFX5Z8J
# 2t_data QW492LGU
# 2t_data RYTFLT5K
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 2t_data S7DQFOD4
# 2t_data S8UOQYBG
# 2t_data SFGT3EDA
# 2t_data SNUO09BH
# 2t_data SPPNJXB2
# 2t_data SRVLBA90
# 2t_data T7RPWH6N
# 2t_data TNI3UKH2
# 2t_data TW1HGRFI
# 2t_data U1FDHL7N
# 2t_data U5L6L4Q4
# 2t_data UURPYBGQ
# 2t_data VGUZX5R3
# 2t_data VKWTT7F7
# 2t_data WH6JINCM
# 2t_data WI5LYQ0H
# 2t_data WRGS0WCX
# 2t_data WRPAQPNC
# 2t_data WWBIR8H6
# 2t_data WZL61XYS
# 2t_data X1LRVWSR
# 2t_data X23TMJ3R
# 2t_data X3RACWMT
# 2t_data XBHX2VRT
# 2t_data Y85GTOSS
# 2t_data YCOUS57M
# 2t_data Z4M8AT89
# 2t_data ZZNW93IV
# limaye_data file110008_0_cols1_rows66
# limaye_data file110816_0_cols1_rows40
# limaye_data file137293_0_cols1_rows6
# limaye_data file13997_0_cols1_rows20
# limaye_data file171157_0_cols1_rows21
# limaye_data file183712_0_cols1_rows19
# limaye_data file198804_0_cols1_rows39
# limaye_data file205708_0_cols1_rows20
# limaye_data file222751_0_cols1_rows13
# limaye_data file229323_0_cols1_rows7
# limaye_data file234482_0_cols1_rows68
# limaye_data file236160_0_cols1_rows28
# limaye_data file240410_0_cols1_rows60
# limaye_data file256909_0_cols1_rows39
# limaye_data file268478_10_cols1_rows25
# limaye_data file27532_1_cols1_rows53
# limaye_data file288293_0_cols1_rows14
# limaye_data file290427_0_cols1_rows14
# limaye_data file30066_0_cols1_rows14
# limaye_data file304250_0_cols1_rows14
# limaye_data file306553_0_cols1_rows14
# limaye_data file315351_0_cols1_rows14
# limaye_data file331278_0_cols1_rows23
# limaye_data file337276_0_cols1_rows31
# limaye_data file338151_0_cols1_rows6
# limaye_data file365726_0_cols1_rows13
# limaye_data file366288_0_cols1_rows29
# limaye_data file383362_0_cols1_rows21
# limaye_data file394725_0_cols1_rows24
# limaye_data file398415_0_cols1_rows58
# limaye_data file405886_0_cols1_rows14
# limaye_data file422017_0_cols1_rows12
# limaye_data file426195_0_cols1_rows21
# limaye_data file434605_0_cols1_rows15
# limaye_data file456872_2_cols1_rows15
# limaye_data file489984_0_cols1_rows86
# limaye_data file495772_0_cols1_rows24
# limaye_data file496605_1_cols1_rows39
# limaye_data file499596_0_cols1_rows39
# limaye_data file505202_0_cols1_rows6
# limaye_data file51833_0_cols1_rows68
# limaye_data file533779_0_cols1_rows7
# limaye_data file535849_0_cols1_rows20
# limaye_data file558362_0_cols1_rows20
# limaye_data file60228_9_cols1_rows37
# limaye_data file63591_4_cols1_rows58
# limaye_data file65862_24_cols1_rows58
# limaye_data file69673_0_cols1_rows58
# limaye_data file77529_0_cols1_rows20
# limaye_data file85468_0_cols1_rows80
# limaye_data file98470_1_cols1_rows55
# limaye_data file98594_6_cols1_rows25
# limaye_data file99290_1_cols1_rows63
# limaye_data file107572_0_cols1_rows62
# limaye_data file123945_0_cols1_rows17
# limaye_data file139009_9_cols1_rows21
# limaye_data file139009_10_cols1_rows25
# limaye_data file152457_0_cols1_rows7
# limaye_data file167874_0_cols1_rows11
# limaye_data file181303_0_cols1_rows31
# limaye_data file180098_0_cols1_rows23
# limaye_data file191712_11_cols1_rows25
# limaye_data file191712_8_cols1_rows20
# limaye_data file191825_0_cols1_rows15
# limaye_data file202151_0_cols1_rows31
# limaye_data file219474_11_cols1_rows22
# limaye_data file221797_1_cols1_rows39
# limaye_data file224977_0_cols1_rows66
# limaye_data file226691_0_cols1_rows20
# limaye_data file251103_0_cols1_rows19
# limaye_data file257923_0_cols1_rows84
# limaye_data file265665_0_cols1_rows15
# limaye_data file267184_0_cols1_rows22
# limaye_data file267997_0_cols1_rows69
# limaye_data file269877_0_cols1_rows39
# limaye_data file270041_0_cols1_rows23
# limaye_data file270540_4_cols1_rows17
# limaye_data file279754_0_cols1_rows19
# limaye_data file282772_0_cols1_rows45
# limaye_data file285010_0_cols1_rows31
# limaye_data file286121_14_cols1_rows65
# limaye_data file289661_0_cols1_rows6
# limaye_data file288111_0_cols1_rows34
# limaye_data file313602_0_cols1_rows78
# limaye_data file322685_0_cols1_rows29
# limaye_data file339783_0_cols1_rows11
# limaye_data file34615_2_cols1_rows24
# limaye_data file363812_1_cols1_rows21
# limaye_data file365069_0_cols1_rows66
# limaye_data file358104_14_cols1_rows65
# limaye_data file37584_0_cols1_rows56
# limaye_data file385293_0_cols1_rows14
# limaye_data file386878_0_cols1_rows23
# limaye_data file388743_6_cols1_rows28
# limaye_data file409049_0_cols1_rows46
# limaye_data file431384_13_cols1_rows65
# limaye_data file431641_0_cols1_rows78
# limaye_data file439313_0_cols1_rows68
# limaye_data file451761_0_cols1_rows19
# limaye_data file461483_0_cols1_rows39
# limaye_data file492921_0_cols1_rows39
# limaye_data file479464_0_cols1_rows14
# limaye_data file493682_0_cols1_rows31
# limaye_data file494624_0_cols1_rows35
# limaye_data file51375_4_cols1_rows88
# limaye_data file568285_0_cols1_rows15
# limaye_data file593609_0_cols1_rows14
# limaye_data file68383_1_cols1_rows60
# limaye_data file812_0_cols1_rows20
# limaye_data file88377_0_cols1_rows13
# limaye_data file82769_0_cols1_rows83
# limaye_data file8429_0_cols1_rows83
# limaye_data file101640_0_cols1_rows31
# limaye_data file114403_0_cols1_rows82
# limaye_data file117573_0_cols1_rows23
# limaye_data file119797_0_cols1_rows39
# limaye_data file132514_0_cols1_rows17
# limaye_data file135940_0_cols1_rows35
# limaye_data file138978_0_cols1_rows83
# limaye_data file139009_11_cols1_rows25
# limaye_data file139009_8_cols1_rows21
# limaye_data file143181_0_cols1_rows56
# limaye_data file144332_0_cols1_rows14
# limaye_data file145174_1_cols1_rows37
# limaye_data file169346_0_cols1_rows7
# limaye_data file172679_0_cols1_rows14
# limaye_data file177766_0_cols1_rows83
# limaye_data file178948_0_cols1_rows14
# limaye_data file180087_0_cols1_rows12
# limaye_data file183833_0_cols1_rows21
# limaye_data file184323_0_cols1_rows67
# limaye_data file187184_0_cols1_rows84
# limaye_data file191426_0_cols1_rows31
# limaye_data file191712_10_cols1_rows25
# limaye_data file191712_9_cols1_rows20
# limaye_data file192085_0_cols1_rows31
# limaye_data file195533_0_cols1_rows18
# limaye_data file196742_0_cols1_rows14
# limaye_data file199463_1_cols1_rows14
# limaye_data file202088_0_cols1_rows32
# limaye_data file208153_0_cols1_rows17
# limaye_data file21126_1_cols1_rows86
# limaye_data file211429_0_cols1_rows92
# limaye_data file214477_0_cols1_rows45
# limaye_data file217042_0_cols1_rows14
# limaye_data file219474_12_cols1_rows17
# limaye_data file220036_5_cols1_rows15
# limaye_data file215105_0_cols1_rows23
# limaye_data file228670_0_cols1_rows20
# limaye_data file231281_1_cols1_rows39
# limaye_data file233008_0_cols1_rows39
# limaye_data file234296_0_cols1_rows14
# limaye_data file234558_0_cols1_rows39
# limaye_data file239528_0_cols1_rows39
# limaye_data file244317_0_cols1_rows39
# limaye_data file258799_0_cols1_rows40
# limaye_data file263556_0_cols1_rows45
# limaye_data file268478_11_cols1_rows25
# limaye_data file268478_8_cols1_rows20
# limaye_data file268478_9_cols1_rows20
# limaye_data file27532_0_cols1_rows82
# limaye_data file277057_2_cols1_rows31
# limaye_data file277954_0_cols1_rows21
# limaye_data file284898_0_cols1_rows31
# limaye_data file288989_0_cols1_rows68
# limaye_data file294473_0_cols1_rows17
# limaye_data file334380_0_cols1_rows21
# limaye_data file344029_0_cols1_rows34
# limaye_data file359655_0_cols1_rows14
# limaye_data file37584_2_cols1_rows28
# limaye_data file376591_0_cols1_rows19
# limaye_data file377321_1_cols1_rows24
# limaye_data file381801_0_cols1_rows6
# limaye_data file389632_0_cols1_rows31
# limaye_data file391510_0_cols1_rows19
# limaye_data file397636_0_cols1_rows14
# limaye_data file404549_0_cols1_rows20
# limaye_data file405599_0_cols1_rows23
# limaye_data file409309_0_cols1_rows60
# limaye_data file409727_0_cols1_rows20
# limaye_data file411836_0_cols1_rows83
# limaye_data file416640_0_cols1_rows6
# limaye_data file421553_0_cols1_rows14
# limaye_data file431641_1_cols1_rows62
# limaye_data file437154_0_cols1_rows31
# limaye_data file440470_0_cols1_rows26
# limaye_data file450629_12_cols1_rows24
# limaye_data file455767_0_cols1_rows44
# limaye_data file489155_0_cols1_rows17
# limaye_data file467640_0_cols1_rows20
# limaye_data file493618_0_cols1_rows39
# limaye_data file501300_8_cols1_rows35
# limaye_data file503004_0_cols1_rows20
# limaye_data file505656_0_cols1_rows20
# limaye_data file506769_0_cols1_rows24
# limaye_data file521391_0_cols1_rows6
# limaye_data file525125_0_cols1_rows39
# limaye_data file531575_0_cols1_rows31
# limaye_data file550665_0_cols1_rows20
# limaye_data file569522_0_cols1_rows21
# limaye_data file57149_0_cols1_rows12
# limaye_data file6170_0_cols1_rows24
# limaye_data file63247_13_cols1_rows65
# limaye_data file64479_0_cols1_rows12
# limaye_data file73526_0_cols1_rows46
# limaye_data file75651_0_cols1_rows14
# limaye_data file65785_1_cols1_rows57
# limaye_data file95757_0_cols1_rows19
# limaye_data file98594_5_cols1_rows22
# limaye_data file99290_0_cols1_rows79
# biotab_data EC8956
# biotab_data 72B32A
# biotab_data 7F39F8
# biotab_data F89913
# biotab_data AAB323
# biotab_data D3D944
# biotab_data D64592
# biotab_data C0C7C7
# biotab_data D9D4F4
# biotab_data 8F14E4
# biotab_data 7CBBC4
# biotab_data 14BFA6
# biotab_data 43EC51
# biotab_data F457C5
# biotab_data 9BF31C
# biotab_data D2DDEA
# biotab_data 6C8349
# biotab_data C9F0F8
# biotab_data C74D97
# biotab_data 35F4A8
# biotab_data 33E75F
# biotab_data 8E296A
# biotab_data 6F4922
# biotab_data 68D30A
# biotab_data D09BF4
# biotab_data 45C48C
# biotab_data C20AD4
# biotab_data 4E732C
# biotab_data 65B9EE
# biotab_data A3C65C
# biotab_data 2723D0
# biotab_data 6974CE
# biotab_data E2EF52
# biotab_data 1FF1DE
# biotab_data 9778D5
# biotab_data 283802
# biotab_data C9E107
# biotab_data F4B9EC
# biotab_data ED3D2C
# biotab_data B6D767
# biotab_data F033AB
# biotab_data 764796
# biotab_data 3295C7
# biotab_data C51CE4
# biotab_data AC627A
# biotab_data A87FF6
# biotab_data C81E72
# biotab_data 861398
# biotab_data FE9FC2
# biotab_data 37693C
# biotab_data 38B3EF
# biotab_data FC490C
# biotab_data E2C420
# biotab_data 28DD2C
# biotab_data 3416A7
# biotab_data 32BB90
# biotab_data 54229A
# biotab_data 67C6A1
# biotab_data 26657D
# biotab_data C7E124
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# biotab_data 167909
# biotab_data C16A53
# biotab_data 1C383C
# biotab_data AD61AB
# biotab_data 735B90
# biotab_data A5771B
# biotab_data A5BFC9
# biotab_data 66F041
# biotab_data D82C8D
# biotab_data 98F137
# biotab_data 34173C
# biotab_data EA5D2F
# biotab_data 9A1158
# biotab_data A1D0C6
# biotab_data 642E92
# biotab_data 19CA14
# biotab_data 6364D3
# biotab_data 6512BD
# biotab_data FBD793
# biotab_data F0935E
# biotab_data A97DA6
# biotab_data 093F65
# biotab_data 92CC22
# biotab_data 44F683
# biotab_data 1F0E3D
# biotab_data ECCBC8
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# biotab_data 9F6140
# biotab_data 93DB85
# t2dv2_data 39173938_0_7916056990138658530
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# t2dv2_data 46671561_0_6122315295162029872
# t2dv2_data 58891288_0_1117541047012405958
# t2dv2_data 29414811_13_8724394428539174350
# t2dv2_data 77694908_0_6083291340991074532
# t2dv2_data 50270082_0_444360818941411589
# t2dv2_data 14380604_4_3329235705746762392
# t2dv2_data 39759273_0_1427898308030295194
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# t2dv2_data 69537082_0_7789694313271016902
# t2dv2_data 29414811_12_251152470253168163
# t2dv2_data 14067031_0_559833072073397908
# t2dv2_data 84548468_0_5955155464119382182
# t2dv2_data 1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2
# t2dv2_data 35188621_0_6058553107571275232
# t2dv2_data 39650055_5_7135804139753401681
# t2dv2_data 21362676_0_6854186738074119688
# t2dv2_data 10579449_0_1681126353774891032
# t2dv2_data 39107734_2_2329160387535788734
# t2dv2_data 1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2
# t2dv2_data 41480166_0_6681239260286218499
# t2dv2_data 9834884_0_3871985887467090123
# t2dv2_data 16767252_0_2409448375013995751
# t2dv2_data 45073662_0_3179937335063201739
# t2dv2_data 28086084_0_3127660530989916727
# t2dv2_data 43237185_1_3636357855502246981
# t2dv2_data 8468806_0_4382447409703007384
# t2dv2_data 54719588_0_8417197176086756912
# t2dv2_data 38428277_0_1311643810102462607
# t2dv2_data 53989675_0_8697482470743954630
# t2dv2_data 37856682_0_6818907050314633217
# t2dv2_data 90196673_0_5458330029110291950
# t2dv2_data 60319454_0_3938426910282115527
# t2dv2_data 71840765_0_6664391841933033844
# t2dv2_data 80588006_0_6965325215443683359
# t2dv2_data 40534006_0_4617468856744635526
# t2dv2_data 24036779_0_5608105867560183058
# t2dv2_data 25404227_0_2240631045609013057
# t2dv2_data 53822652_0_5767892317858575530
# t2dv2_data 52299421_0_4473286348258170200
# t2dv2_data 20135078_0_7570343137119682530
# t2dv2_data 29414811_2_4773219892816395776
# t2dv2_data 33401079_0_9127583903019856402
# t2dv2_data 9567241_0_5666388268510912770
# t2dv2_data 1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (2,6,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# biodiv_data cb1601379dca4472b6df915185124990
# biodiv_data b785d9ed72b347ae9cb0997df17258d8
# biodiv_data 0bc67e05a4d14011a2cf3fca2f869495
# biodiv_data 0dc3add04e344228bb140d5392399521
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# biodiv_data 1d09a099d3964602aca9425adcde89cd
# biodiv_data dffeec8c3593402bafa69b50f5920fa5

# %%
# Creating final data
positive_features_final, negative_features_final = generate_train_data(gen_training_data_args, all_data, scaler, shuffle_by = 'table')
pickle.dump(positive_features_final, open(pos_output, 'wb'))
pickle.dump(negative_features_final, open(neg_output, 'wb'))
# Out:
# File:  093F65 biotab_data
# File:  0bc67e05a4d14011a2cf3fca2f869495 biodiv_data
# File:  0dc3add04e344228bb140d5392399521 biodiv_data
# File:  10579449_0_1681126353774891032 t2dv2_data
# File:  14067031_0_559833072073397908 t2dv2_data
# File:  1438042986423_95_20150728002306 t2dv2_data
# File:  1438042989018_40_20150728002309 t2dv2_data
# File:  1438042989043_35_20150728002309 t2dv2_data
# File:  14380604_4_3329235705746762392 t2dv2_data
# File:  14BFA6 biotab_data
# File:  16767252_0_2409448375013995751 t2dv2_data
# File:  167909 biotab_data
# File:  19CA14 biotab_data
# File:  1C383C biotab_data
# File:  1F0E3D biotab_data
# File:  1FF1DE biotab_data
# File:  1d09a099d3964602aca9425adcde89cd biodiv_data
# File:  20135078_0_7570343137119682530 t2dv2_data
# File:  21362676_0_6854186738074119688 t2dv2_data
# File:  24036779_0_5608105867560183058 t2dv2_data
# File:  25404227_0_2240631045609013057 t2dv2_data
# File:  26657D biotab_data
# File:  2723D0 biotab_data
# File:  28086084_0_3127660530989916727 t2dv2_data
# File:  283802 biotab_data
# File:  28DD2C biotab_data
# File:  29414811_12_251152470253168163 t2dv2_data
# File:  29414811_13_8724394428539174350 t2dv2_data
# File:  29414811_2_4773219892816395776 t2dv2_data
# File:  3295C7 biotab_data
# File:  32BB90 biotab_data
# File:  33401079_0_9127583903019856402 t2dv2_data
# File:  33E75F biotab_data
# File:  3416A7 biotab_data
# File:  34173C biotab_data
# File:  35188621_0_6058553107571275232 t2dv2_data
# File:  35F4A8 biotab_data
# File:  37693C biotab_data
# File:  37856682_0_6818907050314633217 t2dv2_data
# File:  38428277_0_1311643810102462607 t2dv2_data
# File:  38B3EF biotab_data
# File:  39107734_2_2329160387535788734 t2dv2_data
# File:  39173938_0_7916056990138658530 t2dv2_data
# File:  39650055_5_7135804139753401681 t2dv2_data
# File:  39759273_0_1427898308030295194 t2dv2_data
# File:  3DOM5NIW 2t_data
# File:  3JXMPC7N 2t_data
# File:  3LG8J4MX 2t_data
# File:  3N6S2FCX 2t_data
# File:  40534006_0_4617468856744635526 t2dv2_data
# File:  41480166_0_6681239260286218499 t2dv2_data
# File:  43237185_1_3636357855502246981 t2dv2_data
# File:  43EC51 biotab_data
# File:  44F683 biotab_data
# File:  45073662_0_3179937335063201739 t2dv2_data
# File:  45C48C biotab_data
# File:  46671561_0_6122315295162029872 t2dv2_data
# File:  4E732C biotab_data
# File:  4J75OL3W 2t_data
# File:  50270082_0_444360818941411589 t2dv2_data
# File:  52299421_0_4473286348258170200 t2dv2_data
# File:  53822652_0_5767892317858575530 t2dv2_data
# File:  53989675_0_8697482470743954630 t2dv2_data
# File:  54229A biotab_data
# File:  54719588_0_8417197176086756912 t2dv2_data
# File:  58891288_0_1117541047012405958 t2dv2_data
# File:  60319454_0_3938426910282115527 t2dv2_data
# File:  6364D3 biotab_data
# File:  642E92 biotab_data
# File:  6512BD biotab_data
# File:  65B9EE biotab_data
# File:  66F041 biotab_data
# File:  67C6A1 biotab_data
# File:  68D30A biotab_data
# File:  69537082_0_7789694313271016902 t2dv2_data
# File:  6974CE biotab_data
# File:  6C8349 biotab_data
# File:  6F4922 biotab_data
# File:  6I7ET24J 2t_data
# File:  71840765_0_6664391841933033844 t2dv2_data
# File:  71SY0Z5S 2t_data
# File:  72B32A biotab_data
# File:  735B90 biotab_data
# File:  764796 biotab_data
# File:  77694908_0_6083291340991074532 t2dv2_data
# File:  7CBBC4 biotab_data
# File:  7F39F8 biotab_data
# File:  80588006_0_6965325215443683359 t2dv2_data
# File:  84548468_0_5955155464119382182 t2dv2_data
# File:  8468806_0_4382447409703007384 t2dv2_data
# File:  861398 biotab_data
# File:  8E296A biotab_data
# File:  8F14E4 biotab_data
# File:  90196673_0_5458330029110291950 t2dv2_data
# File:  92CC22 biotab_data
# File:  93DB85 biotab_data
# File:  9567241_0_5666388268510912770 t2dv2_data
# File:  9778D5 biotab_data
# File:  9834884_0_3871985887467090123 t2dv2_data
# File:  98F137 biotab_data
# File:  9A1158 biotab_data
# File:  9BF31C biotab_data
# File:  9F6140 biotab_data
# File:  A1D0C6 biotab_data
# File:  A3C65C biotab_data
# File:  A5771B biotab_data
# File:  A5BFC9 biotab_data
# File:  A87FF6 biotab_data
# File:  A97DA6 biotab_data
# File:  AAB323 biotab_data
# File:  AC627A biotab_data
# File:  AD61AB biotab_data
# File:  AUU9A6KL 2t_data
# File:  B20WIQKU 2t_data
# File:  B38A9Q5R 2t_data
# File:  B6D767 biotab_data
# File:  BID0NRU0 2t_data
# File:  C0C7C7 biotab_data
# File:  C16A53 biotab_data
# File:  C20AD4 biotab_data
# File:  C51CE4 biotab_data
# File:  C74D97 biotab_data
# File:  C7E124 biotab_data
# File:  C81E72 biotab_data
# File:  C9E107 biotab_data
# File:  C9F0F8 biotab_data
# File:  CHZGO92A 2t_data
# File:  CNQ5Z0BG 2t_data
# File:  D09BF4 biotab_data
# File:  D2DDEA biotab_data
# File:  D3D944 biotab_data
# File:  D64592 biotab_data
# File:  D82C8D biotab_data
# File:  D9D4F4 biotab_data
# File:  DXTA1MV8 2t_data
# File:  E22XXKVQ 2t_data
# File:  E2C420 biotab_data
# File:  E2EF52 biotab_data
# File:  E3ZK744Q 2t_data
# File:  E45F8QW2 2t_data
# File:  EA5D2F biotab_data
# File:  EC8956 biotab_data
# File:  ECCBC8 biotab_data
# File:  ED3D2C biotab_data
# File:  EQZ21058 2t_data
# File:  ET9REW9Y 2t_data
# File:  EV6LDIB8 2t_data
# File:  F033AB biotab_data
# File:  F0935E biotab_data
# File:  F457C5 biotab_data
# File:  F4B9EC biotab_data
# File:  F89913 biotab_data
# File:  F98SUVJH 2t_data
# File:  FBD793 biotab_data
# File:  FC490C biotab_data
# File:  FE9FC2 biotab_data
# File:  FF00TEZG 2t_data
# File:  FVKKTA8O 2t_data
# File:  FWSGRDQ3 2t_data
# File:  GINQPZQC 2t_data
# File:  GNDO9OXJ 2t_data
# File:  GY7KNULP 2t_data
# File:  HB00DX4L 2t_data
# File:  HCLZSPEJ 2t_data
# File:  HGIUTSCG 2t_data
# File:  HGYG2DVU 2t_data
# File:  HLJ9HHEE 2t_data
# File:  HQCEC5NO 2t_data
# File:  HQRATPBV 2t_data
# File:  HTF6MVY9 2t_data
# File:  I0ENR9U5 2t_data
# File:  I6BBMPNU 2t_data
# File:  IP6ZRIGH 2t_data
# File:  IPTLCCCU 2t_data
# File:  IYZYF533 2t_data
# File:  IZF82AX9 2t_data
# File:  J9EJV2S3 2t_data
# File:  JA4L7KWX 2t_data
# File:  JN0T2O5I 2t_data
# File:  JZ22O0DD 2t_data
# File:  JZLRN9PL 2t_data
# File:  K2VEUQT0 2t_data
# File:  K3X3L22Y 2t_data
# File:  K71YYDXO 2t_data
# File:  KOQM4YU9 2t_data
# File:  LV5N8XDB 2t_data
# File:  MANO2PKR 2t_data
# File:  MSCT8MJD 2t_data
# File:  MZ0BI8NN 2t_data
# File:  N6QAC84T 2t_data
# File:  NDSTZH1I 2t_data
# File:  NV4GY44T 2t_data
# File:  NYFX4M8T 2t_data
# File:  O0BECB72 2t_data
# File:  O0UJJVBR 2t_data
# File:  OD9USH5H 2t_data
# File:  OHGI1JNY 2t_data
# File:  OIDIXPNZ 2t_data
# File:  OKW6UUW5 2t_data
# File:  ORPKCFRL 2t_data
# File:  OZYCQ769 2t_data
# File:  P86ZJFXK 2t_data
# File:  P8B3IAOY 2t_data
# File:  PWNRGOJ5 2t_data
# File:  PZXDACJ9 2t_data
# File:  QIW5EC2H 2t_data
# File:  QNP7O8L5 2t_data
# File:  QOAVEFGY 2t_data
# File:  QOL4ZIHL 2t_data
# File:  QPFX5Z8J 2t_data
# File:  QW492LGU 2t_data
# File:  RYTFLT5K 2t_data
# File:  S7DQFOD4 2t_data
# File:  S8UOQYBG 2t_data
# File:  SFGT3EDA 2t_data
# File:  SNUO09BH 2t_data
# File:  SPPNJXB2 2t_data
# File:  SRVLBA90 2t_data
# File:  T7RPWH6N 2t_data
# File:  TNI3UKH2 2t_data
# File:  TW1HGRFI 2t_data
# File:  U1FDHL7N 2t_data
# File:  U5L6L4Q4 2t_data
# File:  UURPYBGQ 2t_data
# File:  VGUZX5R3 2t_data
# File:  VKWTT7F7 2t_data
# File:  WH6JINCM 2t_data
# File:  WI5LYQ0H 2t_data
# File:  WRGS0WCX 2t_data
# File:  WRPAQPNC 2t_data
# File:  WWBIR8H6 2t_data
# File:  WZL61XYS 2t_data
# File:  X1LRVWSR 2t_data
# File:  X23TMJ3R 2t_data
# File:  X3RACWMT 2t_data
# File:  XBHX2VRT 2t_data
# File:  Y85GTOSS 2t_data
# File:  YCOUS57M 2t_data
# File:  Z4M8AT89 2t_data
# File:  ZZNW93IV 2t_data
# File:  b785d9ed72b347ae9cb0997df17258d8 biodiv_data
# File:  cb1601379dca4472b6df915185124990 biodiv_data
# File:  dffeec8c3593402bafa69b50f5920fa5 biodiv_data
# File:  file101640_0_cols1_rows31 limaye_data
# File:  file107572_0_cols1_rows62 limaye_data
# File:  file110008_0_cols1_rows66 limaye_data
# File:  file110816_0_cols1_rows40 limaye_data
# File:  file114403_0_cols1_rows82 limaye_data
# File:  file117573_0_cols1_rows23 limaye_data
# File:  file119797_0_cols1_rows39 limaye_data
# File:  file123945_0_cols1_rows17 limaye_data
# File:  file132514_0_cols1_rows17 limaye_data
# File:  file135940_0_cols1_rows35 limaye_data
# File:  file137293_0_cols1_rows6 limaye_data
# File:  file138978_0_cols1_rows83 limaye_data
# File:  file139009_10_cols1_rows25 limaye_data
# File:  file139009_11_cols1_rows25 limaye_data
# File:  file139009_8_cols1_rows21 limaye_data
# File:  file139009_9_cols1_rows21 limaye_data
# File:  file13997_0_cols1_rows20 limaye_data
# File:  file143181_0_cols1_rows56 limaye_data
# File:  file144332_0_cols1_rows14 limaye_data
# File:  file145174_1_cols1_rows37 limaye_data
# File:  file152457_0_cols1_rows7 limaye_data
# File:  file167874_0_cols1_rows11 limaye_data
# File:  file169346_0_cols1_rows7 limaye_data
# File:  file171157_0_cols1_rows21 limaye_data
# File:  file172679_0_cols1_rows14 limaye_data
# File:  file177766_0_cols1_rows83 limaye_data
# File:  file178948_0_cols1_rows14 limaye_data
# File:  file180087_0_cols1_rows12 limaye_data
# File:  file180098_0_cols1_rows23 limaye_data
# File:  file181303_0_cols1_rows31 limaye_data
# File:  file183712_0_cols1_rows19 limaye_data
# File:  file183833_0_cols1_rows21 limaye_data
# File:  file184323_0_cols1_rows67 limaye_data
# File:  file187184_0_cols1_rows84 limaye_data
# File:  file191426_0_cols1_rows31 limaye_data
# File:  file191712_10_cols1_rows25 limaye_data
# File:  file191712_11_cols1_rows25 limaye_data
# File:  file191712_8_cols1_rows20 limaye_data
# File:  file191712_9_cols1_rows20 limaye_data
# File:  file191825_0_cols1_rows15 limaye_data
# File:  file192085_0_cols1_rows31 limaye_data
# File:  file195533_0_cols1_rows18 limaye_data
# File:  file196742_0_cols1_rows14 limaye_data
# File:  file198804_0_cols1_rows39 limaye_data
# File:  file199463_1_cols1_rows14 limaye_data
# File:  file202088_0_cols1_rows32 limaye_data
# File:  file202151_0_cols1_rows31 limaye_data
# File:  file205708_0_cols1_rows20 limaye_data
# File:  file208153_0_cols1_rows17 limaye_data
# File:  file21126_1_cols1_rows86 limaye_data
# File:  file211429_0_cols1_rows92 limaye_data
# File:  file214477_0_cols1_rows45 limaye_data
# File:  file215105_0_cols1_rows23 limaye_data
# File:  file217042_0_cols1_rows14 limaye_data
# File:  file219474_11_cols1_rows22 limaye_data
# File:  file219474_12_cols1_rows17 limaye_data
# File:  file220036_5_cols1_rows15 limaye_data
# File:  file221797_1_cols1_rows39 limaye_data
# File:  file222751_0_cols1_rows13 limaye_data
# File:  file224977_0_cols1_rows66 limaye_data
# File:  file226691_0_cols1_rows20 limaye_data
# File:  file228670_0_cols1_rows20 limaye_data
# File:  file229323_0_cols1_rows7 limaye_data
# File:  file231281_1_cols1_rows39 limaye_data
# File:  file233008_0_cols1_rows39 limaye_data
# File:  file234296_0_cols1_rows14 limaye_data
# File:  file234482_0_cols1_rows68 limaye_data
# File:  file234558_0_cols1_rows39 limaye_data
# File:  file236160_0_cols1_rows28 limaye_data
# File:  file239528_0_cols1_rows39 limaye_data
# File:  file240410_0_cols1_rows60 limaye_data
# File:  file244317_0_cols1_rows39 limaye_data
# File:  file251103_0_cols1_rows19 limaye_data
# File:  file256909_0_cols1_rows39 limaye_data
# File:  file257923_0_cols1_rows84 limaye_data
# File:  file258799_0_cols1_rows40 limaye_data
# File:  file263556_0_cols1_rows45 limaye_data
# File:  file265665_0_cols1_rows15 limaye_data
# File:  file267184_0_cols1_rows22 limaye_data
# File:  file267997_0_cols1_rows69 limaye_data
# File:  file268478_10_cols1_rows25 limaye_data
# File:  file268478_11_cols1_rows25 limaye_data
# File:  file268478_8_cols1_rows20 limaye_data
# File:  file268478_9_cols1_rows20 limaye_data
# File:  file269877_0_cols1_rows39 limaye_data
# File:  file270041_0_cols1_rows23 limaye_data
# File:  file270540_4_cols1_rows17 limaye_data
# File:  file27532_0_cols1_rows82 limaye_data
# File:  file27532_1_cols1_rows53 limaye_data
# File:  file277057_2_cols1_rows31 limaye_data
# File:  file277954_0_cols1_rows21 limaye_data
# File:  file279754_0_cols1_rows19 limaye_data
# File:  file282772_0_cols1_rows45 limaye_data
# File:  file284898_0_cols1_rows31 limaye_data
# File:  file285010_0_cols1_rows31 limaye_data
# File:  file286121_14_cols1_rows65 limaye_data
# File:  file288111_0_cols1_rows34 limaye_data
# File:  file288293_0_cols1_rows14 limaye_data
# File:  file288989_0_cols1_rows68 limaye_data
# File:  file289661_0_cols1_rows6 limaye_data
# File:  file290427_0_cols1_rows14 limaye_data
# File:  file294473_0_cols1_rows17 limaye_data
# File:  file30066_0_cols1_rows14 limaye_data
# File:  file304250_0_cols1_rows14 limaye_data
# File:  file306553_0_cols1_rows14 limaye_data
# File:  file313602_0_cols1_rows78 limaye_data
# File:  file315351_0_cols1_rows14 limaye_data
# File:  file322685_0_cols1_rows29 limaye_data
# File:  file331278_0_cols1_rows23 limaye_data
# File:  file334380_0_cols1_rows21 limaye_data
# File:  file337276_0_cols1_rows31 limaye_data
# File:  file338151_0_cols1_rows6 limaye_data
# File:  file339783_0_cols1_rows11 limaye_data
# File:  file344029_0_cols1_rows34 limaye_data
# File:  file34615_2_cols1_rows24 limaye_data
# File:  file358104_14_cols1_rows65 limaye_data
# File:  file359655_0_cols1_rows14 limaye_data
# File:  file363812_1_cols1_rows21 limaye_data
# File:  file365069_0_cols1_rows66 limaye_data
# File:  file365726_0_cols1_rows13 limaye_data
# File:  file366288_0_cols1_rows29 limaye_data
# File:  file37584_0_cols1_rows56 limaye_data
# File:  file37584_2_cols1_rows28 limaye_data
# File:  file376591_0_cols1_rows19 limaye_data
# File:  file377321_1_cols1_rows24 limaye_data
# File:  file381801_0_cols1_rows6 limaye_data
# File:  file383362_0_cols1_rows21 limaye_data
# File:  file385293_0_cols1_rows14 limaye_data
# File:  file386878_0_cols1_rows23 limaye_data
# File:  file388743_6_cols1_rows28 limaye_data
# File:  file389632_0_cols1_rows31 limaye_data
# File:  file391510_0_cols1_rows19 limaye_data
# File:  file394725_0_cols1_rows24 limaye_data
# File:  file397636_0_cols1_rows14 limaye_data
# File:  file398415_0_cols1_rows58 limaye_data
# File:  file404549_0_cols1_rows20 limaye_data
# File:  file405599_0_cols1_rows23 limaye_data
# File:  file405886_0_cols1_rows14 limaye_data
# File:  file409049_0_cols1_rows46 limaye_data
# File:  file409309_0_cols1_rows60 limaye_data
# File:  file409727_0_cols1_rows20 limaye_data
# File:  file411836_0_cols1_rows83 limaye_data
# File:  file416640_0_cols1_rows6 limaye_data
# File:  file421553_0_cols1_rows14 limaye_data
# File:  file422017_0_cols1_rows12 limaye_data
# File:  file426195_0_cols1_rows21 limaye_data
# File:  file431384_13_cols1_rows65 limaye_data
# File:  file431641_0_cols1_rows78 limaye_data
# File:  file431641_1_cols1_rows62 limaye_data
# File:  file434605_0_cols1_rows15 limaye_data
# File:  file437154_0_cols1_rows31 limaye_data
# File:  file439313_0_cols1_rows68 limaye_data
# File:  file440470_0_cols1_rows26 limaye_data
# File:  file450629_12_cols1_rows24 limaye_data
# File:  file451761_0_cols1_rows19 limaye_data
# File:  file455767_0_cols1_rows44 limaye_data
# File:  file456872_2_cols1_rows15 limaye_data
# File:  file461483_0_cols1_rows39 limaye_data
# File:  file467640_0_cols1_rows20 limaye_data
# File:  file479464_0_cols1_rows14 limaye_data
# File:  file489155_0_cols1_rows17 limaye_data
# File:  file489984_0_cols1_rows86 limaye_data
# File:  file492921_0_cols1_rows39 limaye_data
# File:  file493618_0_cols1_rows39 limaye_data
# File:  file493682_0_cols1_rows31 limaye_data
# File:  file494624_0_cols1_rows35 limaye_data
# File:  file495772_0_cols1_rows24 limaye_data
# File:  file496605_1_cols1_rows39 limaye_data
# File:  file499596_0_cols1_rows39 limaye_data
# File:  file501300_8_cols1_rows35 limaye_data
# File:  file503004_0_cols1_rows20 limaye_data
# File:  file505202_0_cols1_rows6 limaye_data
# File:  file505656_0_cols1_rows20 limaye_data
# File:  file506769_0_cols1_rows24 limaye_data
# File:  file51375_4_cols1_rows88 limaye_data
# File:  file51833_0_cols1_rows68 limaye_data
# File:  file521391_0_cols1_rows6 limaye_data
# File:  file525125_0_cols1_rows39 limaye_data
# File:  file531575_0_cols1_rows31 limaye_data
# File:  file533779_0_cols1_rows7 limaye_data
# File:  file535849_0_cols1_rows20 limaye_data
# File:  file550665_0_cols1_rows20 limaye_data
# File:  file558362_0_cols1_rows20 limaye_data
# File:  file568285_0_cols1_rows15 limaye_data
# File:  file569522_0_cols1_rows21 limaye_data
# File:  file57149_0_cols1_rows12 limaye_data
# File:  file593609_0_cols1_rows14 limaye_data
# File:  file60228_9_cols1_rows37 limaye_data
# File:  file6170_0_cols1_rows24 limaye_data
# File:  file63247_13_cols1_rows65 limaye_data
# File:  file63591_4_cols1_rows58 limaye_data
# File:  file64479_0_cols1_rows12 limaye_data
# File:  file65785_1_cols1_rows57 limaye_data
# File:  file65862_24_cols1_rows58 limaye_data
# File:  file68383_1_cols1_rows60 limaye_data
# File:  file69673_0_cols1_rows58 limaye_data
# File:  file73526_0_cols1_rows46 limaye_data
# File:  file75651_0_cols1_rows14 limaye_data
# File:  file77529_0_cols1_rows20 limaye_data
# File:  file812_0_cols1_rows20 limaye_data
# File:  file82769_0_cols1_rows83 limaye_data
# File:  file8429_0_cols1_rows83 limaye_data
# File:  file85468_0_cols1_rows80 limaye_data
# File:  file88377_0_cols1_rows13 limaye_data
# File:  file95757_0_cols1_rows19 limaye_data
# File:  file98470_1_cols1_rows55 limaye_data
# File:  file98594_5_cols1_rows22 limaye_data
# File:  file98594_6_cols1_rows25 limaye_data
# File:  file99290_0_cols1_rows79 limaye_data
# File:  file99290_1_cols1_rows63 limaye_data
# 34655 32
# 34655 32
# 34655 32
# 34655 32

# %%
# To get the features faster - if all the preprocessing has been done for all the files.
'''
positive_features_final= [] 
negative_features_final = []
for i in train_files:
    file_name = i.split('/')[-1][:-4]
    ds_id = i.split('/')[-2]
    print(file_name, ds_id)
    pos_location = f'temp_csv_c{N_PCA_COMPONENTS}/pos_{ds_id}_{file_name}.pkl'
    neg_location = f'temp_csv_c{N_PCA_COMPONENTS}/neg_{ds_id}_{file_name}.pkl'
    if os.path.exists(pos_location):
        pos_features_table = pickle.load(open(f'temp_csv_c{N_PCA_COMPONENTS}/pos_{ds_id}_{file_name}.pkl', 'rb'))
        neg_features_table = pickle.load(open(f'temp_csv_c{N_PCA_COMPONENTS}/neg_{ds_id}_{file_name}.pkl', 'rb'))
        positive_features_final.extend(pos_features_table)
        negative_features_final.extend(neg_features_table) 
pickle.dump(positive_features_final, open(pos_output, 'wb'))
pickle.dump(negative_features_final, open(neg_output, 'wb'))
'''
# Out:
# 3DOM5NIW 2t_data
# 3JXMPC7N 2t_data
# 3LG8J4MX 2t_data
# 3N6S2FCX 2t_data
# 4J75OL3W 2t_data
# 6I7ET24J 2t_data
# 71SY0Z5S 2t_data
# AUU9A6KL 2t_data
# B20WIQKU 2t_data
# B38A9Q5R 2t_data
# BID0NRU0 2t_data
# CHZGO92A 2t_data
# CNQ5Z0BG 2t_data
# DXTA1MV8 2t_data
# E22XXKVQ 2t_data
# E3ZK744Q 2t_data
# E45F8QW2 2t_data
# EQZ21058 2t_data
# ET9REW9Y 2t_data
# EV6LDIB8 2t_data
# F98SUVJH 2t_data
# FF00TEZG 2t_data
# FVKKTA8O 2t_data
# FWSGRDQ3 2t_data
# GINQPZQC 2t_data
# GNDO9OXJ 2t_data
# GY7KNULP 2t_data
# HB00DX4L 2t_data
# HCLZSPEJ 2t_data
# HGIUTSCG 2t_data
# HGYG2DVU 2t_data
# HLJ9HHEE 2t_data
# HQCEC5NO 2t_data
# HQRATPBV 2t_data
# HTF6MVY9 2t_data
# I0ENR9U5 2t_data
# I6BBMPNU 2t_data
# IP6ZRIGH 2t_data
# IPTLCCCU 2t_data
# IYZYF533 2t_data
# IZF82AX9 2t_data
# J9EJV2S3 2t_data
# JA4L7KWX 2t_data
# JN0T2O5I 2t_data
# JZ22O0DD 2t_data
# JZLRN9PL 2t_data
# K2VEUQT0 2t_data
# K3X3L22Y 2t_data
# K71YYDXO 2t_data
# KOQM4YU9 2t_data
# LV5N8XDB 2t_data
# MANO2PKR 2t_data
# MSCT8MJD 2t_data
# MZ0BI8NN 2t_data
# N6QAC84T 2t_data
# NDSTZH1I 2t_data
# NV4GY44T 2t_data
# NYFX4M8T 2t_data
# O0BECB72 2t_data
# O0UJJVBR 2t_data
# OD9USH5H 2t_data
# OHGI1JNY 2t_data
# OIDIXPNZ 2t_data
# OKW6UUW5 2t_data
# ORPKCFRL 2t_data
# OZYCQ769 2t_data
# P86ZJFXK 2t_data
# P8B3IAOY 2t_data
# PWNRGOJ5 2t_data
# PZXDACJ9 2t_data
# QIW5EC2H 2t_data
# QNP7O8L5 2t_data
# QOAVEFGY 2t_data
# QOL4ZIHL 2t_data
# QPFX5Z8J 2t_data
# QW492LGU 2t_data
# RYTFLT5K 2t_data
# S7DQFOD4 2t_data
# S8UOQYBG 2t_data
# SFGT3EDA 2t_data
# SNUO09BH 2t_data
# SPPNJXB2 2t_data
# SRVLBA90 2t_data
# T7RPWH6N 2t_data
# TNI3UKH2 2t_data
# TW1HGRFI 2t_data
# U1FDHL7N 2t_data
# U5L6L4Q4 2t_data
# UURPYBGQ 2t_data
# VGUZX5R3 2t_data
# VKWTT7F7 2t_data
# WH6JINCM 2t_data
# WI5LYQ0H 2t_data
# WRGS0WCX 2t_data
# WRPAQPNC 2t_data
# WWBIR8H6 2t_data
# WZL61XYS 2t_data
# X1LRVWSR 2t_data
# X23TMJ3R 2t_data
# X3RACWMT 2t_data
# XBHX2VRT 2t_data
# Y85GTOSS 2t_data
# YCOUS57M 2t_data
# Z4M8AT89 2t_data
# ZZNW93IV 2t_data
# file110008_0_cols1_rows66 limaye_data
# file110816_0_cols1_rows40 limaye_data
# file137293_0_cols1_rows6 limaye_data
# file13997_0_cols1_rows20 limaye_data
# file171157_0_cols1_rows21 limaye_data
# file183712_0_cols1_rows19 limaye_data
# file198804_0_cols1_rows39 limaye_data
# file205708_0_cols1_rows20 limaye_data
# file222751_0_cols1_rows13 limaye_data
# file229323_0_cols1_rows7 limaye_data
# file234482_0_cols1_rows68 limaye_data
# file236160_0_cols1_rows28 limaye_data
# file240410_0_cols1_rows60 limaye_data
# file256909_0_cols1_rows39 limaye_data
# file268478_10_cols1_rows25 limaye_data
# file27532_1_cols1_rows53 limaye_data
# file288293_0_cols1_rows14 limaye_data
# file290427_0_cols1_rows14 limaye_data
# file30066_0_cols1_rows14 limaye_data
# file304250_0_cols1_rows14 limaye_data
# file306553_0_cols1_rows14 limaye_data
# file315351_0_cols1_rows14 limaye_data
# file331278_0_cols1_rows23 limaye_data
# file337276_0_cols1_rows31 limaye_data
# file338151_0_cols1_rows6 limaye_data
# file365726_0_cols1_rows13 limaye_data
# file366288_0_cols1_rows29 limaye_data
# file383362_0_cols1_rows21 limaye_data
# file394725_0_cols1_rows24 limaye_data
# file398415_0_cols1_rows58 limaye_data
# file405886_0_cols1_rows14 limaye_data
# file422017_0_cols1_rows12 limaye_data
# file426195_0_cols1_rows21 limaye_data
# file434605_0_cols1_rows15 limaye_data
# file456872_2_cols1_rows15 limaye_data
# file489984_0_cols1_rows86 limaye_data
# file495772_0_cols1_rows24 limaye_data
# file496605_1_cols1_rows39 limaye_data
# file499596_0_cols1_rows39 limaye_data
# file505202_0_cols1_rows6 limaye_data
# file51833_0_cols1_rows68 limaye_data
# file533779_0_cols1_rows7 limaye_data
# file535849_0_cols1_rows20 limaye_data
# file558362_0_cols1_rows20 limaye_data
# file60228_9_cols1_rows37 limaye_data
# file63591_4_cols1_rows58 limaye_data
# file65862_24_cols1_rows58 limaye_data
# file69673_0_cols1_rows58 limaye_data
# file77529_0_cols1_rows20 limaye_data
# file85468_0_cols1_rows80 limaye_data
# file98470_1_cols1_rows55 limaye_data
# file98594_6_cols1_rows25 limaye_data
# file99290_1_cols1_rows63 limaye_data
# file107572_0_cols1_rows62 limaye_data
# file123945_0_cols1_rows17 limaye_data
# file139009_9_cols1_rows21 limaye_data
# file139009_10_cols1_rows25 limaye_data
# file152457_0_cols1_rows7 limaye_data
# file167874_0_cols1_rows11 limaye_data
# file181303_0_cols1_rows31 limaye_data
# file180098_0_cols1_rows23 limaye_data
# file191712_11_cols1_rows25 limaye_data
# file191712_8_cols1_rows20 limaye_data
# file191825_0_cols1_rows15 limaye_data
# file202151_0_cols1_rows31 limaye_data
# file219474_11_cols1_rows22 limaye_data
# file221797_1_cols1_rows39 limaye_data
# file224977_0_cols1_rows66 limaye_data
# file226691_0_cols1_rows20 limaye_data
# file251103_0_cols1_rows19 limaye_data
# file257923_0_cols1_rows84 limaye_data
# file265665_0_cols1_rows15 limaye_data
# file267184_0_cols1_rows22 limaye_data
# file267997_0_cols1_rows69 limaye_data
# file269877_0_cols1_rows39 limaye_data
# file270041_0_cols1_rows23 limaye_data
# file270540_4_cols1_rows17 limaye_data
# file279754_0_cols1_rows19 limaye_data
# file282772_0_cols1_rows45 limaye_data
# file285010_0_cols1_rows31 limaye_data
# file286121_14_cols1_rows65 limaye_data
# file289661_0_cols1_rows6 limaye_data
# file288111_0_cols1_rows34 limaye_data
# file313602_0_cols1_rows78 limaye_data
# file322685_0_cols1_rows29 limaye_data
# file339783_0_cols1_rows11 limaye_data
# file34615_2_cols1_rows24 limaye_data
# file363812_1_cols1_rows21 limaye_data
# file365069_0_cols1_rows66 limaye_data
# file358104_14_cols1_rows65 limaye_data
# file37584_0_cols1_rows56 limaye_data
# file385293_0_cols1_rows14 limaye_data
# file386878_0_cols1_rows23 limaye_data
# file388743_6_cols1_rows28 limaye_data
# file409049_0_cols1_rows46 limaye_data
# file431384_13_cols1_rows65 limaye_data
# file431641_0_cols1_rows78 limaye_data
# file439313_0_cols1_rows68 limaye_data
# file451761_0_cols1_rows19 limaye_data
# file461483_0_cols1_rows39 limaye_data
# file492921_0_cols1_rows39 limaye_data
# file479464_0_cols1_rows14 limaye_data
# file493682_0_cols1_rows31 limaye_data
# file494624_0_cols1_rows35 limaye_data
# file51375_4_cols1_rows88 limaye_data
# file568285_0_cols1_rows15 limaye_data
# file593609_0_cols1_rows14 limaye_data
# file68383_1_cols1_rows60 limaye_data
# file812_0_cols1_rows20 limaye_data
# file88377_0_cols1_rows13 limaye_data
# file82769_0_cols1_rows83 limaye_data
# file8429_0_cols1_rows83 limaye_data
# file101640_0_cols1_rows31 limaye_data
# file114403_0_cols1_rows82 limaye_data
# file117573_0_cols1_rows23 limaye_data
# file119797_0_cols1_rows39 limaye_data
# file132514_0_cols1_rows17 limaye_data
# file135940_0_cols1_rows35 limaye_data
# file138978_0_cols1_rows83 limaye_data
# file139009_11_cols1_rows25 limaye_data
# file139009_8_cols1_rows21 limaye_data
# file143181_0_cols1_rows56 limaye_data
# file144332_0_cols1_rows14 limaye_data
# file145174_1_cols1_rows37 limaye_data
# file169346_0_cols1_rows7 limaye_data
# file172679_0_cols1_rows14 limaye_data
# file177766_0_cols1_rows83 limaye_data
# file178948_0_cols1_rows14 limaye_data
# file180087_0_cols1_rows12 limaye_data
# file183833_0_cols1_rows21 limaye_data
# file184323_0_cols1_rows67 limaye_data
# file187184_0_cols1_rows84 limaye_data
# file191426_0_cols1_rows31 limaye_data
# file191712_10_cols1_rows25 limaye_data
# file191712_9_cols1_rows20 limaye_data
# file192085_0_cols1_rows31 limaye_data
# file195533_0_cols1_rows18 limaye_data
# file196742_0_cols1_rows14 limaye_data
# file199463_1_cols1_rows14 limaye_data
# file202088_0_cols1_rows32 limaye_data
# file208153_0_cols1_rows17 limaye_data
# file21126_1_cols1_rows86 limaye_data
# file211429_0_cols1_rows92 limaye_data
# file214477_0_cols1_rows45 limaye_data
# file217042_0_cols1_rows14 limaye_data
# file219474_12_cols1_rows17 limaye_data
# file220036_5_cols1_rows15 limaye_data
# file215105_0_cols1_rows23 limaye_data
# file228670_0_cols1_rows20 limaye_data
# file231281_1_cols1_rows39 limaye_data
# file233008_0_cols1_rows39 limaye_data
# file234296_0_cols1_rows14 limaye_data
# file234558_0_cols1_rows39 limaye_data
# file239528_0_cols1_rows39 limaye_data
# file244317_0_cols1_rows39 limaye_data
# file258799_0_cols1_rows40 limaye_data
# file263556_0_cols1_rows45 limaye_data
# file268478_11_cols1_rows25 limaye_data
# file268478_8_cols1_rows20 limaye_data
# file268478_9_cols1_rows20 limaye_data
# file27532_0_cols1_rows82 limaye_data
# file277057_2_cols1_rows31 limaye_data
# file277954_0_cols1_rows21 limaye_data
# file284898_0_cols1_rows31 limaye_data
# file288989_0_cols1_rows68 limaye_data
# file294473_0_cols1_rows17 limaye_data
# file334380_0_cols1_rows21 limaye_data
# file344029_0_cols1_rows34 limaye_data
# file359655_0_cols1_rows14 limaye_data
# file37584_2_cols1_rows28 limaye_data
# file376591_0_cols1_rows19 limaye_data
# file377321_1_cols1_rows24 limaye_data
# file381801_0_cols1_rows6 limaye_data
# file389632_0_cols1_rows31 limaye_data
# file391510_0_cols1_rows19 limaye_data
# file397636_0_cols1_rows14 limaye_data
# file404549_0_cols1_rows20 limaye_data
# file405599_0_cols1_rows23 limaye_data
# file409309_0_cols1_rows60 limaye_data
# file409727_0_cols1_rows20 limaye_data
# file411836_0_cols1_rows83 limaye_data
# file416640_0_cols1_rows6 limaye_data
# file421553_0_cols1_rows14 limaye_data
# file431641_1_cols1_rows62 limaye_data
# file437154_0_cols1_rows31 limaye_data
# file440470_0_cols1_rows26 limaye_data
# file450629_12_cols1_rows24 limaye_data
# file455767_0_cols1_rows44 limaye_data
# file489155_0_cols1_rows17 limaye_data
# file467640_0_cols1_rows20 limaye_data
# file493618_0_cols1_rows39 limaye_data
# file501300_8_cols1_rows35 limaye_data
# file503004_0_cols1_rows20 limaye_data
# file505656_0_cols1_rows20 limaye_data
# file506769_0_cols1_rows24 limaye_data
# file521391_0_cols1_rows6 limaye_data
# file525125_0_cols1_rows39 limaye_data
# file531575_0_cols1_rows31 limaye_data
# file550665_0_cols1_rows20 limaye_data
# file569522_0_cols1_rows21 limaye_data
# file57149_0_cols1_rows12 limaye_data
# file6170_0_cols1_rows24 limaye_data
# file63247_13_cols1_rows65 limaye_data
# file64479_0_cols1_rows12 limaye_data
# file73526_0_cols1_rows46 limaye_data
# file75651_0_cols1_rows14 limaye_data
# file65785_1_cols1_rows57 limaye_data
# file95757_0_cols1_rows19 limaye_data
# file98594_5_cols1_rows22 limaye_data

# %%
#load scaler and saved pos and neg pairs
scaler = pickle.load(open(min_max_scaler_path, 'rb'))
pos, neg = generate_dataloader(pos_output, neg_output)
# Out:
# [array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object), array([1.0, 0.941798941798942, 1.0, 1.0, 1.0, 0.7619047619047619, 1.0,
#        "{'_P680': 1.0}"], dtype=object)]

# %%
N_PCA_COMPONENTS
# Out:
# 10

# %%
features
# Out:
# ['monge_elkan',
#  'monge_elkan_aliases',
#  'jaro_winkler',
#  'levenshtein',
#  'singleton',
#  'context_score_3',
#  'num_occurences']

# %%
len(pos[0])
# Out:
# 8

# %%
# Saving files for dev and test to reduce training time
processed_dev_files = []
processed_test_files = []
for dev_file in dev_files:
    file_name = dev_file.split('/')[-1]
    dev_result_file = f'{processed_dev_data}/{file_name}'
    processed_dev_files.append(dev_result_file)
    if not os.path.exists(dev_result_file):
        print(dev_file, dev_result_file)
        dev_df = pd.read_csv(dev_file)
        try:
            d_result_df = context_property_similarity_code.return_a_table(dev_df, pca_components = N_PCA_COMPONENTS, 
                                                                        autoencoder = encoder_layer, return_context_property = False)
        except MemoryError:
            processed_dev_files.remove(dev_result_file)
            continue
            #print("entering ", file_name)
        d_result_df.to_csv(dev_result_file, index = False)
for dev_file in test_files:

    file_name = dev_file.split('/')[-1]
    dev_result_file = f'{processed_test_data}/{file_name}'
    processed_test_files.append(dev_result_file)

    if not os.path.exists(dev_result_file):
        print(dev_file, dev_result_file)
        dev_df = pd.read_csv(dev_file)
        d_result_df = context_property_similarity_code.return_a_table(dev_df, pca_components = N_PCA_COMPONENTS, 
                                                                        autoencoder = encoder_layer, return_context_property = False)
        d_result_df.to_csv(dev_result_file, index = False)
# Out:
# ../Experiments/context_vector_dev_data/2t_data/0D70DN48.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//0D70DN48.csv
# ../Experiments/context_vector_dev_data/2t_data/0IR0XIUW.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//0IR0XIUW.csv
# ../Experiments/context_vector_dev_data/2t_data/1C9LFOKN.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//1C9LFOKN.csv
# ../Experiments/context_vector_dev_data/2t_data/1MQL5T7F.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//1MQL5T7F.csv
# ../Experiments/context_vector_dev_data/2t_data/24W5SSRB.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//24W5SSRB.csv
# ../Experiments/context_vector_dev_data/2t_data/29BNEL1Q.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//29BNEL1Q.csv
# ../Experiments/context_vector_dev_data/2t_data/2BEBH437.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//2BEBH437.csv
# ../Experiments/context_vector_dev_data/2t_data/2EZKB5RU.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//2EZKB5RU.csv
# ../Experiments/context_vector_dev_data/2t_data/2VRS31OV.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//2VRS31OV.csv
# ../Experiments/context_vector_dev_data/2t_data/2XHMV76G.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//2XHMV76G.csv
# ../Experiments/context_vector_dev_data/2t_data/3C3INQLM.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//3C3INQLM.csv
# ../Experiments/context_vector_dev_data/2t_data/4FFI99VQ.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//4FFI99VQ.csv
# ../Experiments/context_vector_dev_data/2t_data/4HP08FY9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//4HP08FY9.csv
# ../Experiments/context_vector_dev_data/2t_data/4WMC1B70.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//4WMC1B70.csv
# ../Experiments/context_vector_dev_data/2t_data/51MYHYDF.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//51MYHYDF.csv
# ../Experiments/context_vector_dev_data/2t_data/54S3KOBO.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//54S3KOBO.csv
# ../Experiments/context_vector_dev_data/2t_data/5DKX42VB.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//5DKX42VB.csv
# ../Experiments/context_vector_dev_data/2t_data/5HD27KI3.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//5HD27KI3.csv
# ../Experiments/context_vector_dev_data/2t_data/5OLOTSKC.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//5OLOTSKC.csv
# ../Experiments/context_vector_dev_data/2t_data/60G94POT.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//60G94POT.csv
# ../Experiments/context_vector_dev_data/2t_data/64OJP4G3.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//64OJP4G3.csv
# ../Experiments/context_vector_dev_data/2t_data/7GOG4IKF.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//7GOG4IKF.csv
# ../Experiments/context_vector_dev_data/2t_data/7QNYGYI7.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//7QNYGYI7.csv
# ../Experiments/context_vector_dev_data/2t_data/7VVP9YIF.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//7VVP9YIF.csv
# ../Experiments/context_vector_dev_data/2t_data/8D8CVBT0.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//8D8CVBT0.csv
# ../Experiments/context_vector_dev_data/2t_data/8MKQXO18.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//8MKQXO18.csv
# ../Experiments/context_vector_dev_data/2t_data/8QA9EYPI.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//8QA9EYPI.csv
# ../Experiments/context_vector_dev_data/2t_data/8R6ZM8HE.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//8R6ZM8HE.csv
# ../Experiments/context_vector_dev_data/2t_data/8YINKYDR.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//8YINKYDR.csv
# ../Experiments/context_vector_dev_data/2t_data/9BGE5Y4L.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//9BGE5Y4L.csv
# ../Experiments/context_vector_dev_data/2t_data/9HIRS45A.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//9HIRS45A.csv
# ../Experiments/context_vector_dev_data/2t_data/9JA43FJL.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//9JA43FJL.csv
# ../Experiments/context_vector_dev_data/2t_data/9Y8MPU2Q.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//9Y8MPU2Q.csv
# ../Experiments/context_vector_dev_data/2t_data/AN306FAH.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//AN306FAH.csv
# ../Experiments/context_vector_dev_data/2t_data/BDH3WFGJ.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//BDH3WFGJ.csv
# ../Experiments/context_vector_dev_data/2t_data/BLBITS6S.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//BLBITS6S.csv
# ../Experiments/context_vector_dev_data/2t_data/CAF0E2JH.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//CAF0E2JH.csv
# ../Experiments/context_vector_dev_data/2t_data/CXBCCWXI.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//CXBCCWXI.csv
# ../Experiments/context_vector_dev_data/2t_data/DRSJ0SOG.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//DRSJ0SOG.csv
# ../Experiments/context_vector_dev_data/2t_data/1C7N45JA.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//1C7N45JA.csv
# ../Experiments/context_vector_dev_data/limaye_data/file235911_0_cols1_rows40.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file235911_0_cols1_rows40.csv
# ../Experiments/context_vector_dev_data/limaye_data/file138986_23_cols1_rows17.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file138986_23_cols1_rows17.csv
# ../Experiments/context_vector_dev_data/limaye_data/file40567_0_cols1_rows6.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file40567_0_cols1_rows6.csv
# ../Experiments/context_vector_dev_data/limaye_data/file42049_0_cols1_rows6.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file42049_0_cols1_rows6.csv
# ../Experiments/context_vector_dev_data/limaye_data/file449225_0_cols1_rows50.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file449225_0_cols1_rows50.csv
# ../Experiments/context_vector_dev_data/limaye_data/file417489_17_cols1_rows28.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file417489_17_cols1_rows28.csv
# ../Experiments/context_vector_dev_data/limaye_data/file136273_3_cols1_rows11.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file136273_3_cols1_rows11.csv
# ../Experiments/context_vector_dev_data/limaye_data/file525008_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file525008_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file124647_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file124647_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file430636_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file430636_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file362299_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file362299_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file184372_0_cols1_rows13.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file184372_0_cols1_rows13.csv
# ../Experiments/context_vector_dev_data/limaye_data/file338795_1_cols1_rows83.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file338795_1_cols1_rows83.csv
# ../Experiments/context_vector_dev_data/limaye_data/file568853_0_cols1_rows18.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file568853_0_cols1_rows18.csv
# ../Experiments/context_vector_dev_data/limaye_data/file487374_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file487374_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file32078_0_cols1_rows12.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file32078_0_cols1_rows12.csv
# ../Experiments/context_vector_dev_data/limaye_data/file466379_0_cols1_rows11.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file466379_0_cols1_rows11.csv
# ../Experiments/context_vector_dev_data/limaye_data/file420753_0_cols1_rows11.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file420753_0_cols1_rows11.csv
# ../Experiments/context_vector_dev_data/limaye_data/file40637_0_cols1_rows12.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file40637_0_cols1_rows12.csv
# ../Experiments/context_vector_dev_data/limaye_data/file516163_0_cols1_rows24.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file516163_0_cols1_rows24.csv
# ../Experiments/context_vector_dev_data/limaye_data/file532025_0_cols1_rows11.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file532025_0_cols1_rows11.csv
# ../Experiments/context_vector_dev_data/limaye_data/file413245_3_cols1_rows12.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file413245_3_cols1_rows12.csv
# ../Experiments/context_vector_dev_data/limaye_data/file2503_2_cols1_rows12.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file2503_2_cols1_rows12.csv
# ../Experiments/context_vector_dev_data/limaye_data/file333289_2_cols1_rows12.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file333289_2_cols1_rows12.csv
# ../Experiments/context_vector_dev_data/limaye_data/file420324_0_cols1_rows12.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file420324_0_cols1_rows12.csv
# ../Experiments/context_vector_dev_data/limaye_data/file322407_2_cols1_rows18.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file322407_2_cols1_rows18.csv
# ../Experiments/context_vector_dev_data/limaye_data/file30597_5_cols1_rows11.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file30597_5_cols1_rows11.csv
# ../Experiments/context_vector_dev_data/limaye_data/file39042_0_cols1_rows6.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file39042_0_cols1_rows6.csv
# ../Experiments/context_vector_dev_data/limaye_data/file39810_0_cols1_rows6.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file39810_0_cols1_rows6.csv
# ../Experiments/context_vector_dev_data/limaye_data/file236612_0_cols1_rows14.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file236612_0_cols1_rows14.csv
# ../Experiments/context_vector_dev_data/limaye_data/file380717_0_cols1_rows8.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file380717_0_cols1_rows8.csv
# ../Experiments/context_vector_dev_data/limaye_data/file331899_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file331899_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file212038_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file212038_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file444427_0_cols1_rows22.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file444427_0_cols1_rows22.csv
# ../Experiments/context_vector_dev_data/limaye_data/file539385_17_cols1_rows87.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file539385_17_cols1_rows87.csv
# ../Experiments/context_vector_dev_data/limaye_data/file114818_0_cols1_rows22.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file114818_0_cols1_rows22.csv
# ../Experiments/context_vector_dev_data/limaye_data/file160562_0_cols1_rows11.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file160562_0_cols1_rows11.csv
# ../Experiments/context_vector_dev_data/limaye_data/file429503_0_cols1_rows12.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file429503_0_cols1_rows12.csv
# ../Experiments/context_vector_dev_data/limaye_data/file134372_0_cols1_rows11.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file134372_0_cols1_rows11.csv
# ../Experiments/context_vector_dev_data/limaye_data/file526591_0_cols1_rows20.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file526591_0_cols1_rows20.csv
# ../Experiments/context_vector_dev_data/limaye_data/file137959_0_cols1_rows19.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file137959_0_cols1_rows19.csv
# ../Experiments/context_vector_dev_data/limaye_data/file162595_3_cols1_rows19.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file162595_3_cols1_rows19.csv
# ../Experiments/context_vector_dev_data/limaye_data/file16426_0_cols1_rows11.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file16426_0_cols1_rows11.csv
# ../Experiments/context_vector_dev_data/limaye_data/file325689_0_cols1_rows11.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file325689_0_cols1_rows11.csv
# ../Experiments/context_vector_dev_data/limaye_data/file155305_0_cols1_rows17.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file155305_0_cols1_rows17.csv
# ../Experiments/context_vector_dev_data/limaye_data/file413846_0_cols1_rows17.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file413846_0_cols1_rows17.csv
# ../Experiments/context_vector_dev_data/limaye_data/file339527_0_cols1_rows19.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file339527_0_cols1_rows19.csv
# ../Experiments/context_vector_dev_data/limaye_data/file273143_0_cols1_rows6.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file273143_0_cols1_rows6.csv
# ../Experiments/context_vector_dev_data/limaye_data/file64428_2_cols1_rows18.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file64428_2_cols1_rows18.csv
# ../Experiments/context_vector_dev_data/limaye_data/file331221_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file331221_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file242908_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file242908_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file304130_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file304130_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file173767_1_cols1_rows33.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file173767_1_cols1_rows33.csv
# ../Experiments/context_vector_dev_data/limaye_data/file338795_0_cols1_rows83.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file338795_0_cols1_rows83.csv
# ../Experiments/context_vector_dev_data/limaye_data/file499936_5_cols1_rows86.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file499936_5_cols1_rows86.csv
# ../Experiments/context_vector_dev_data/limaye_data/file399053_0_cols1_rows14.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file399053_0_cols1_rows14.csv
# ../Experiments/context_vector_dev_data/limaye_data/file405469_0_cols1_rows16.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file405469_0_cols1_rows16.csv
# ../Experiments/context_vector_dev_data/limaye_data/file41945_0_cols1_rows87.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file41945_0_cols1_rows87.csv
# ../Experiments/context_vector_dev_data/limaye_data/file435083_10_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file435083_10_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file71478_0_cols1_rows17.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file71478_0_cols1_rows17.csv
# ../Experiments/context_vector_dev_data/limaye_data/file329942_5_cols1_rows18.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file329942_5_cols1_rows18.csv
# ../Experiments/context_vector_dev_data/limaye_data/file266838_5_cols1_rows22.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file266838_5_cols1_rows22.csv
# ../Experiments/context_vector_dev_data/limaye_data/file241396_9_cols1_rows69.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file241396_9_cols1_rows69.csv
# ../Experiments/context_vector_dev_data/limaye_data/file136273_4_cols1_rows7.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file136273_4_cols1_rows7.csv
# ../Experiments/context_vector_dev_data/limaye_data/file592476_0_cols1_rows8.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file592476_0_cols1_rows8.csv
# ../Experiments/context_vector_dev_data/limaye_data/file391005_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file391005_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file118301_28_cols1_rows28.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file118301_28_cols1_rows28.csv
# ../Experiments/context_vector_dev_data/limaye_data/file51190_1_cols1_rows6.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file51190_1_cols1_rows6.csv
# ../Experiments/context_vector_dev_data/limaye_data/file345145_0_cols1_rows8.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file345145_0_cols1_rows8.csv
# ../Experiments/context_vector_dev_data/limaye_data/file100415_0_cols1_rows14.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file100415_0_cols1_rows14.csv
# ../Experiments/context_vector_dev_data/limaye_data/file281613_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file281613_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file455094_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file455094_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file396413_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file396413_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file270598_0_cols1_rows13.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file270598_0_cols1_rows13.csv
# ../Experiments/context_vector_dev_data/limaye_data/file91274_1_cols1_rows17.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file91274_1_cols1_rows17.csv
# ../Experiments/context_vector_dev_data/limaye_data/file469366_1_cols1_rows19.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file469366_1_cols1_rows19.csv
# ../Experiments/context_vector_dev_data/limaye_data/file384878_0_cols1_rows17.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file384878_0_cols1_rows17.csv
# ../Experiments/context_vector_dev_data/limaye_data/file539385_18_cols1_rows87.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file539385_18_cols1_rows87.csv
# ../Experiments/context_vector_dev_data/limaye_data/file291850_0_cols1_rows9.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file291850_0_cols1_rows9.csv
# ../Experiments/context_vector_dev_data/limaye_data/file199969_2_cols1_rows19.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file199969_2_cols1_rows19.csv
# ../Experiments/context_vector_dev_data/limaye_data/file38336_0_cols1_rows12.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file38336_0_cols1_rows12.csv
# ../Experiments/context_vector_dev_data/limaye_data/file464588_0_cols1_rows12.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file464588_0_cols1_rows12.csv
# ../Experiments/context_vector_dev_data/limaye_data/file420793_0_cols1_rows12.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file420793_0_cols1_rows12.csv
# ../Experiments/context_vector_dev_data/limaye_data/file522774_0_cols1_rows20.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file522774_0_cols1_rows20.csv
# ../Experiments/context_vector_dev_data/limaye_data/file404761_0_cols1_rows11.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file404761_0_cols1_rows11.csv
# ../Experiments/context_vector_dev_data/limaye_data/file429559_0_cols1_rows31.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//file429559_0_cols1_rows31.csv
# ../Experiments/context_vector_dev_data/biotab_data/D67D8A.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//D67D8A.csv
# ../Experiments/context_vector_dev_data/biotab_data/2A38A4.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//2A38A4.csv
# ../Experiments/context_vector_dev_data/biotab_data/17E621.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//17E621.csv
# ../Experiments/context_vector_dev_data/biotab_data/F71771.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//F71771.csv
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ../Experiments/context_vector_dev_data/biotab_data/3C59DC.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//3C59DC.csv
# ../Experiments/context_vector_dev_data/biotab_data/70EFDF.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//70EFDF.csv
# ../Experiments/context_vector_dev_data/biotab_data/A684EC.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//A684EC.csv
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ../Experiments/context_vector_dev_data/biotab_data/812B4B.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//812B4B.csv
# ../Experiments/context_vector_dev_data/biotab_data/E4DA3B.csv ../Experiments/Experiment_test_semtab_plain_version_n_10/dev/features//E4DA3B.csv
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-18-3d950978d01e>", line 12, in <module>
#     d_result_df = context_property_similarity_code.return_a_table(dev_df, pca_components = N_PCA_COMPONENTS,
#   File "/nas/ckgfs/kgtk/hrathod/scratch/context_property_vector/context_property_similarity_code.py", line 112, in return_a_table
#     context_similarity_result_array = create_context_similarity(df, apply_pca_components = pca_components, concatenate=True, return_context_property= return_context_property, autoencoder = autoencoder)
#   File "/nas/ckgfs/kgtk/hrathod/scratch/context_property_vector/context_property_similarity_code.py", line 75, in create_context_similarity
#     context_property_similarity = pca_kernel.fit_transform(context_property_similarity)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 376, in fit_transform
#     U, S, V = self._fit(X)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 425, in _fit
#     return self._fit_truncated(X, n_components, self._fit_svd_solver)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 542, in _fit_truncated
#     U, S, V = randomized_svd(X, n_components=n_components,
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/extmath.py", line 349, in randomized_svd
#     Q = randomized_range_finder(
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/extmath.py", line 234, in randomized_range_finder
#     Q, _ = linalg.lu(safe_sparse_dot(A, Q), permute_l=True)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/posixpath.py", line 391, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/posixpath.py", line 425, in _joinrealpath
#     if not islink(newpath):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/posixpath.py", line 167, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-18-3d950978d01e>", line 12, in <module>
#     d_result_df = context_property_similarity_code.return_a_table(dev_df, pca_components = N_PCA_COMPONENTS,
#   File "/nas/ckgfs/kgtk/hrathod/scratch/context_property_vector/context_property_similarity_code.py", line 112, in return_a_table
#     context_similarity_result_array = create_context_similarity(df, apply_pca_components = pca_components, concatenate=True, return_context_property= return_context_property, autoencoder = autoencoder)
#   File "/nas/ckgfs/kgtk/hrathod/scratch/context_property_vector/context_property_similarity_code.py", line 75, in create_context_similarity
#     context_property_similarity = pca_kernel.fit_transform(context_property_similarity)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 376, in fit_transform
#     U, S, V = self._fit(X)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 425, in _fit
#     return self._fit_truncated(X, n_components, self._fit_svd_solver)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 542, in _fit_truncated
#     U, S, V = randomized_svd(X, n_components=n_components,
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/extmath.py", line 349, in randomized_svd
#     Q = randomized_range_finder(
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/extmath.py", line 234, in randomized_range_finder
#     Q, _ = linalg.lu(safe_sparse_dot(A, Q), permute_l=True)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3338, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3435, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1151, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 751, in getmodule
#     f = getabsfile(module)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 720, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 705, in getsourcefile
#     if os.path.exists(filename):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-18-3d950978d01e>", line 12, in <module>
#     d_result_df = context_property_similarity_code.return_a_table(dev_df, pca_components = N_PCA_COMPONENTS,
#   File "/nas/ckgfs/kgtk/hrathod/scratch/context_property_vector/context_property_similarity_code.py", line 112, in return_a_table
#     context_similarity_result_array = create_context_similarity(df, apply_pca_components = pca_components, concatenate=True, return_context_property= return_context_property, autoencoder = autoencoder)
#   File "/nas/ckgfs/kgtk/hrathod/scratch/context_property_vector/context_property_similarity_code.py", line 75, in create_context_similarity
#     context_property_similarity = pca_kernel.fit_transform(context_property_similarity)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 376, in fit_transform
#     U, S, V = self._fit(X)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 425, in _fit
#     return self._fit_truncated(X, n_components, self._fit_svd_solver)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 542, in _fit_truncated
#     U, S, V = randomized_svd(X, n_components=n_components,
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/extmath.py", line 349, in randomized_svd
#     Q = randomized_range_finder(
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/extmath.py", line 234, in randomized_range_finder
#     Q, _ = linalg.lu(safe_sparse_dot(A, Q), permute_l=True)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/sklearn/utils/extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3338, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3435, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1151, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2923, in _run_cell
#     return runner(coro)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3146, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     self.showtraceback()
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1211, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1151, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 751, in getmodule
#     f = getabsfile(module)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/inspect.py", line 721, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/posixpath.py", line 381, in abspath
#     return normpath(path)
#   File "/nas/home/hrathod/anaconda3/lib/python3.8/posixpath.py", line 362, in normpath
#     new_comps.append(comp)
# KeyboardInterrupt

# %%
processed_dev_files = glob.glob(processed_dev_data + '/*.csv')
processed_test_files = glob.glob(processed_test_data + '/*.csv')

# %%
len(pos[0])
# Out:
# 11

# %%
len(test_files)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 2120
# 345

# %%
X_data = context_property_similarity_code.convert_to_matrix_vector(pos, list(all_prop), encoder_layer)
print(X_data[0])
Y_data = context_property_similarity_code.convert_to_matrix_vector(neg, list(all_prop), encoder_layer)
print(Y_data[0])

# %%
len(X_data[0])

# %%
## Deleting the context property vector string before feeding data

# %%
## Functions to train model
class T2DV2Dataset(Dataset):
    def __init__(self, pos_features, neg_features):
        self.pos_features = pos_features
        self.neg_features = neg_features

    def __len__(self):
        return len(self.pos_features)

    def __getitem__(self, idx):
        return self.pos_features[idx], self.neg_features[idx]
    
class PairwiseNetwork(nn.Module):
    def __init__(self, hidden_size):
        super().__init__()
        # original 12x24, 24x12, 12x12, 12x1
        self.fc1 = nn.Linear(hidden_size, 2*hidden_size)
        
        self.fc2 = nn.Linear(2*hidden_size, 2*hidden_size)
        #self.fc_x = nn.Linear(2*hidden_size, hidden_size)
        self.fc3 = nn.Linear(2*hidden_size, hidden_size)
        self.fc4 = nn.Linear(hidden_size, 1)

    def forward(self, pos_features, neg_features):
        # Positive pass
        x = F.relu(self.fc1(pos_features))
        x = F.relu(self.fc2(x))
        #x = F.relu(self.fc_x(x))
        x = F.relu(self.fc3(x))
        pos_out = torch.sigmoid(self.fc4(x))

        # Negative Pass
        x = F.relu(self.fc1(neg_features))
        x = F.relu(self.fc2(x))
        #x = F.relu(self.fc_x(x))
        x = F.relu(self.fc3(x))
        neg_out = torch.sigmoid(self.fc4(x))

        return pos_out, neg_out

    def predict(self, test_feat):
        x = F.relu(self.fc1(test_feat))
        x = F.relu(self.fc2(x))
        #x = F.relu(self.fc_x(x))
        x = F.relu(self.fc3(x))
        test_out = torch.sigmoid(self.fc4(x))
        return test_out


# Pairwise Loss
class PairwiseLoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.m = 0

    def forward(self, pos_out, neg_out):
        distance = (1 - pos_out) + neg_out
        loss = torch.mean(torch.max(torch.tensor(0), distance))
        return loss
    
def infer_scores(min_max_scaler_path, input_table_path, output_table_path, model, test = 0):
    #scaler = pickle.loads(s3_1.Bucket("table-linker-datasets").Object(min_max_scaler_path).get()['Body'].read())
    #pca = pickle.load(open('pca_var_500.pkl', 'rb'))
    normalize_features = features
    sfeatures = copy.deepcopy(features) # + [f'csp_{i}' for i in range(N_PCA_COMPONENTS)]
    print(features)
    number_of_cells_top_1 = 0
    number_of_cells_total = 0
    for file in input_table_path:
        file_name = file.split('/')[-1]
        try:
            d_sample = pd.read_csv(file)
        except pd.errors.EmptyDataError:
            continue
        if not isinstance(d_sample, pd.DataFrame):
            continue
        #print(d_sample.columns)
        #d_sample[normalize_features] = scaler.transform(d_sample[normalize_features])
        sorted_df = d_sample
        new_features = sfeatures
        sorted_df_features = sorted_df[sfeatures]
        arr = sorted_df_features.to_numpy()
        #test_inp = context_property_similarity_code.convert_to_matrix_vector(arr, list(all_prop), encoder_layer)
        #print(arr)
        test_inp = arr
        test_tensor = torch.tensor(test_inp).float()
        scores = model.predict(test_tensor)
        scores_list = torch.squeeze(scores).tolist()
        test_df = d_sample
        test_df[final_score_column] = scores_list
        test_df['table_id'] = file_name
        test_df['dataset_id'] = " "
        #df_input_table.append(test_df)
        num_of_cells_with_correct_top_1, num_of_cells = parse_eval_files_stats(test_df, 'siamese_prediction')
        number_of_cells_top_1 += num_of_cells_with_correct_top_1
        number_of_cells_total += num_of_cells
        if test:
            test_df.to_csv(test_predictions + file_name, index=False)
    # print(number_of_cells_top_1, number_of_cells_total, input_table_path)
    return number_of_cells_top_1 / number_of_cells_total

def train(args):
    if torch.cuda.is_available():
        device = torch.device('cuda')

    else:
        device = torch.device('cpu')
    device = torch.device('cpu')
    train_dataset = T2DV2Dataset(X_data, Y_data)
    train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE)
    criterion = PairwiseLoss()
    EPOCHS = args.num_epochs
    model = PairwiseNetwork(len(X_data[0])).to(device=device)
    optimizer = Adam(model.parameters(), lr=args.lr)
    # scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.01)
    top1_max_prec = 0
    for epoch in range(EPOCHS):
        train_epoch_loss = 0
        avg_loss = 0
        model.train()
        for bid_1, batch_1 in tqdm(enumerate(train_dataloader), position=0, leave=True):
            # print("--------------")
            positive_feat = torch.tensor(batch_1[0].float())
            negative_feat = torch.tensor(batch_1[1].float())
            optimizer.zero_grad()
            # print(positive_feat.is_cuda, negative_feat.is_cuda)
            pos_out, neg_out = model(positive_feat, negative_feat)
            ##print(pos_out.is_cuda, neg_out.is_cuda, model.is_cuda)
            loss = criterion(pos_out, neg_out)
            # print(loss.is_cuda)
            loss.backward()
            optimizer.step()
            train_epoch_loss += loss
        avg_loss = train_epoch_loss / bid_1
        # scheduler.step()
        # Evaluation
        model.eval()
        print("Running on dev files")
        top1_precision = infer_scores(args.min_max_scaler_path, dev_files, args.dev_output, model)
        # eval_data = merge_eval_files(args.dev_output)
        # res, candidate_eval_data = parse_eval_files_stats(eval_data, final_score_column)
        # top1_precision = res['num_tasks_with_model_score_top_one_accurate'] / res['num_tasks_with_gt']
        if top1_precision > top1_max_prec:
            #copy_files(args.dev_output, dev_predictions)
            top1_max_prec = top1_precision
            model_save_name = 'top1_{}_epoch_{}_loss_{}_batch_size_{}_learning_rate_{}.pth'.format(top1_max_prec, epoch,
                                                                                                   avg_loss, BATCH_SIZE,
                                                                                                   LEARNING_RATE)
            best_model_path = args.model_save_path + model_save_name
            torch.save(model.state_dict(), best_model_path)
            print("Running on test files")
        print("Test Dataset", infer_scores(args.min_max_scaler_path, test_files, args.dev_output, model, test = 1))
        #s3_1.Bucket('table-linker-datasets').upload_file('/tmp/'+model_save_name, best_model_path)

        print("Epoch {}, Avg Loss is {}, epoch top1 {}, max top1 {}".format(epoch, avg_loss, top1_precision,
                                                                            top1_max_prec))
    return best_model_path, model
def parse_eval_files_stats(eval_data, method):
    res = {}
    candidate_eval_data = eval_data.groupby(['table_id', 'column', 'row'])['table_id'].count().reset_index(name="count")
    res['num_tasks_with_gt'] = len(eval_data[pd.notna(eval_data['GT_kg_id'])].groupby(['table_id', 'column', 'row']))
    num_tasks_with_model_score_top_one_accurate = []
    num_tasks_with_model_score_top_five_accurate = []
    num_tasks_with_model_score_top_ten_accurate = []
    has_gt_list = []
    has_gt_in_candidate = []
    for i, row in candidate_eval_data.iterrows():
        table_id, row_idx, col_idx = row['table_id'], row['row'], row['column']
        c_e_data = eval_data[
            (eval_data['table_id'] == table_id) & (eval_data['row'] == row_idx) & (eval_data['column'] == col_idx)]
        assert len(c_e_data) > 0
        if np.nan not in set(c_e_data['GT_kg_id']):
            has_gt_list.append(1)
        else:
            has_gt_list.append(0)
        if 1 in set(c_e_data['evaluation_label']):
            has_gt_in_candidate.append(1)
        else:
            has_gt_in_candidate.append(0)

        # rank on model score
        s_data = c_e_data.sort_values(by=[method], ascending=False)
        if s_data.iloc[0]['evaluation_label'] == 1:
            num_tasks_with_model_score_top_one_accurate.append(1)
        else:
            num_tasks_with_model_score_top_one_accurate.append(0)

    res['num_tasks_with_model_score_top_one_accurate'] = sum(num_tasks_with_model_score_top_one_accurate)
    # print(sum(num_tasks_with_model_score_top_one_accurate))
    return res['num_tasks_with_model_score_top_one_accurate'], res['num_tasks_with_gt']

# %%
X_data = pos
Y_data = neg
train_dataset = T2DV2Dataset(X_data, Y_data)
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE)
LEARNING_RATE = 0.000009
training_args = Namespace(num_epochs=12, lr=LEARNING_RATE, positive_feat_path=pos_output, negative_feat_path=neg_output,
                         dev_path=dev_files, dev_output=dev_predictions,
                         model_save_path=model_save_path, min_max_scaler_path=min_max_scaler_path)
best_model_path, model = train(training_args)
# Out:
# 0it [00:00, ?it/s]<ipython-input-11-0dc8e9d95f31>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-11-0dc8e9d95f31>:124: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 34643it [01:22, 417.89it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'singleton', 'context_score_3', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Running on test files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'singleton', 'context_score_3', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.8477771897327335
# Epoch 0, Avg Loss is 0.8075975775718689, epoch top1 0.5797761194029851, max top1 0.5797761194029851
# 0it [00:00, ?it/s]<ipython-input-11-0dc8e9d95f31>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-11-0dc8e9d95f31>:124: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 34643it [01:26, 399.42it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'singleton', 'context_score_3', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'singleton', 'context_score_3', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.8497618417570786
# Epoch 1, Avg Loss is 0.2851220965385437, epoch top1 0.5795522388059702, max top1 0.5797761194029851
# 0it [00:00, ?it/s]<ipython-input-11-0dc8e9d95f31>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-11-0dc8e9d95f31>:124: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 34643it [01:24, 409.16it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'singleton', 'context_score_3', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Running on test files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'singleton', 'context_score_3', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.8483064302725589
# Epoch 2, Avg Loss is 0.21584253013134003, epoch top1 0.58, max top1 0.58
# 0it [00:00, ?it/s]<ipython-input-11-0dc8e9d95f31>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-11-0dc8e9d95f31>:124: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 34643it [01:24, 411.67it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'singleton', 'context_score_3', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Running on test files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'singleton', 'context_score_3', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.8478433448002117
# Epoch 3, Avg Loss is 0.2031344473361969, epoch top1 0.5815671641791045, max top1 0.5815671641791045
# 0it [00:00, ?it/s]<ipython-input-11-0dc8e9d95f31>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-11-0dc8e9d95f31>:124: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 34643it [01:09, 496.25it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'singleton', 'context_score_3', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'singleton', 'context_score_3', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.8491002910822969
# Epoch 4, Avg Loss is 0.19503015279769897, epoch top1 0.5802238805970149, max top1 0.5815671641791045
# 0it [00:00, ?it/s]<ipython-input-11-0dc8e9d95f31>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-11-0dc8e9d95f31>:124: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 34643it [01:07, 510.10it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'singleton', 'context_score_3', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'singleton', 'context_score_3', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.8558481079650702
# Epoch 5, Avg Loss is 0.1891176849603653, epoch top1 0.5780597014925373, max top1 0.5815671641791045
# 0it [00:00, ?it/s]<ipython-input-11-0dc8e9d95f31>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-11-0dc8e9d95f31>:124: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 34643it [01:32, 373.28it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'singleton', 'context_score_3', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'singleton', 'context_score_3', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.8469833289229955
# Epoch 6, Avg Loss is 0.1846804916858673, epoch top1 0.5682835820895522, max top1 0.5815671641791045
# 0it [00:00, ?it/s]<ipython-input-11-0dc8e9d95f31>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-11-0dc8e9d95f31>:124: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 26333it [01:00, 434.82it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-daf2ec1d7bf8> in <module>
#       7                          dev_path=dev_files, dev_output=dev_predictions,
#       8                          model_save_path=model_save_path, min_max_scaler_path=min_max_scaler_path)
# ----> 9 best_model_path, model = train(training_args)
#
# <ipython-input-11-0dc8e9d95f31> in train(args)
#     127             pos_out, neg_out = model(positive_feat, negative_feat)
#     128             ##print(pos_out.is_cuda, neg_out.is_cuda, model.is_cuda)
# --> 129             loss = criterion(pos_out, neg_out)
#     130             # print(loss.is_cuda)
#     131             loss.backward()
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     864         return result
#     865
# --> 866     def _call_impl(self, *input, **kwargs):
#     867         # Do not call functions when jit is used
#     868         full_backward_hooks, non_full_backward_hooks = [], []
#
# KeyboardInterrupt:
