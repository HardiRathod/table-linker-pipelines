# %% [markdown]
# ## Purpose
# For leave one out experiments,
# - preprocesses data to add the new feature prefix_monge_elkan similarity,
# - runs the model pipeline experiment over the processed data,
# - predicts over the test dataset and
# - provides overview with cell based and column based metrics.
#
# For data: Directly downloaded from AWS S3.
# For running over different test dataset change needed
# - variable setup tagged cell
# - test setup tagged cell
#
# For experimental setup, a new folder is created, changes to the path can be set in test_setup

# %%
###Importing all the libraries
import glob
import boto3
import time
import os
import pandas as pd
import sklearn.metrics
from sklearn.preprocessing import MinMaxScaler
import pickle
from argparse import ArgumentParser, Namespace
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam
from itertools import chain
import copy
import shutil
import pickle
from tqdm import tqdm
import scipy.sparse as sp
import os

# %%
# Setup the variables
features = ["monge_elkan","monge_elkan_aliases","jaro_winkler",
            "levenshtein", "prefix_monge_elkan_similarity","singleton","context_score_3","pgt_centroid_score","pgt_class_count_tf_idf_score",
            "pgt_property_count_tf_idf_score", "num_occurences", "incorrectness_scores"]
BATCH_SIZE = 32
LEARNING_RATE = 0.00001

# %%
experiment_name = f"Experiment_test_semtab_feature_addition"
experiment_data = '2t_data,limaye_data,biotab_data,t2dv2_data,biodiv_data'
### Creating the directories for the results.
experiment_train_data = experiment_data
experiment_dev_data =  experiment_data
experiment_test_data = 'semtab_data'
experiment_store_path = f"Experiment/{experiment_name}"
processed_dev_data = f"{experiment_store_path}/dev/features/"
processed_test_data = f"{experiment_store_path}/test/features/"
dev_predictions = f"{experiment_store_path}/dev/dev_predictions/"
test_predictions = f"{experiment_store_path}/test/test_predictions/"
dev_output_pred = f"{experiment_store_path}/dev/dev_output/"
dev_predictions_top_k = f"{experiment_store_path}/dev/dev_predictions_top_k/"
dev_metrics = f"{experiment_store_path}/dev/dev_metrics/"
dev_predictions_colorized = f"{experiment_store_path}/dev/dev_predictions_colorized/"
model_save_path = f'{experiment_store_path}/model_save_path/'
best_model_path = ''

training_data_path = f'{experiment_store_path}/model_training_data'

pos_output = f'{training_data_path}/tl_pipeline_pos_features_{BATCH_SIZE}.pkl'
neg_output = f'{training_data_path}/tl_pipeline_neg_features_{BATCH_SIZE}.pkl'
min_max_scaler_path = f'{training_data_path}/tl_pipeline_normalization_factor.pkl'

final_score_column = 'siamese_prediction'

extra_feat = ['column-id', 'column', 'row', 'evaluation_label', 'dataset_id', 'table_id']
for f in features:
    extra_feat.append(f)
    

# !mkdir -p $experiment_store_path 
# !mkdir -p $dev_predictions 
# !mkdir -p $dev_output_pred
# !mkdir -p $dev_predictions_top_k 
# !mkdir -p $dev_metrics 
# !mkdir -p $dev_predictions_colorized 
# !mkdir -p $model_save_path 
# !mkdir -p $training_data_path
# !mkdir -p $processed_dev_data
# !mkdir -p $processed_test_data
# !mkdir -p $test_predictions
results_main_location = f"{experiment_store_path}/results/"
result_predictions_location = f"{results_main_location}/test_predictions_top_k"
result_metrics_location = f"{results_main_location}/test_predictions_metrics/"
result_colorized_location= f"{results_main_location}/test_predictions_colored/"

# !mkdir -p $results_main_location
# !mkdir -p $result_predictions_location
# !mkdir -p $result_metrics_location
# !mkdir -p $result_colorized_location

# %%
# Copying the data from aws to a local directory
aws_location = f's3://table-linker-datasets/Experiments/Experiment_test_{experiment_test_data.split("_")[0]}/'
# !aws s3 cp --recursive {aws_location} {experiment_store_path}
# Out:
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/cell/top1_0.7520739963764661_epoch_1_loss_0.19324207305908203_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/cell/top1_0.7520739963764661_epoch_1_loss_0.19324207305908203_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/cell/top1_0.7484504624773529_epoch_0_loss_0.517475962638855_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/cell/top1_0.7484504624773529_epoch_0_loss_0.517475962638855_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/complete_shuffle/top1_0.6955472911850438_epoch_1_loss_0.9994743466377258_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/complete_shuffle/top1_0.6955472911850438_epoch_1_loss_0.9994743466377258_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/complete_shuffle/top1_0.05454372079717746_epoch_0_loss_0.962913990020752_batch_size_32_learning_rate_0.0001.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/complete_shuffle/top1_0.05454372079717746_epoch_0_loss_0.962913990020752_batch_size_32_learning_rate_0.0001.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/complete_shuffle/top1_0.6959493416423761_epoch_3_loss_0.9982632398605347_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/complete_shuffle/top1_0.6959493416423761_epoch_3_loss_0.9982632398605347_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/complete_shuffle/top1_0.706000603075686_epoch_5_loss_0.9991952776908875_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/complete_shuffle/top1_0.706000603075686_epoch_5_loss_0.9991952776908875_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/cell/top1_0.09220940211690665_epoch_0_loss_0.9607508182525635_batch_size_32_learning_rate_0.01.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/cell/top1_0.09220940211690665_epoch_0_loss_0.9607508182525635_batch_size_32_learning_rate_0.01.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/complete_shuffle/top1_0.638858176701176_epoch_0_loss_0.999894380569458_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/complete_shuffle/top1_0.638858176701176_epoch_0_loss_0.999894380569458_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/complete_shuffle/top1_0.5058644035472489_epoch_1_loss_0.9600976705551147_batch_size_32_learning_rate_0.0001.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/complete_shuffle/top1_0.5058644035472489_epoch_1_loss_0.9600976705551147_batch_size_32_learning_rate_0.0001.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/complete_shuffle/top1_0.6993667705297015_epoch_4_loss_0.9988583922386169_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/complete_shuffle/top1_0.6993667705297015_epoch_4_loss_0.9988583922386169_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/complete_shuffle/top1_0.7122323851643382_epoch_6_loss_0.9989516735076904_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/complete_shuffle/top1_0.7122323851643382_epoch_6_loss_0.9989516735076904_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/dataset/top1_0.7474015447697149_epoch_3_loss_0.17449089884757996_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/dataset/top1_0.7474015447697149_epoch_3_loss_0.17449089884757996_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/dataset/top1_0.7362448746066559_epoch_0_loss_0.49970749020576477_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/dataset/top1_0.7362448746066559_epoch_0_loss_0.49970749020576477_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/dataset/top1_0.7446362162677601_epoch_1_loss_0.1992628574371338_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/dataset/top1_0.7446362162677601_epoch_1_loss_0.1992628574371338_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/dataset/top1_0.7482159010955874_epoch_0_loss_0.5332199335098267_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/dataset/top1_0.7482159010955874_epoch_0_loss_0.5332199335098267_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/dataset/top1_0.752738968740577_epoch_1_loss_0.20076528191566467_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/dataset/top1_0.752738968740577_epoch_1_loss_0.20076528191566467_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/dataset/top1_0.7470201201487556_epoch_2_loss_0.18181964755058289_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/dataset/top1_0.7470201201487556_epoch_2_loss_0.18181964755058289_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/dataset/top1_0.7545481957985727_epoch_4_loss_0.1690938025712967_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/dataset/top1_0.7545481957985727_epoch_4_loss_0.1690938025712967_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/dataset/top1_0.7475922570801945_epoch_4_loss_0.17042699456214905_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/dataset/top1_0.7475922570801945_epoch_4_loss_0.17042699456214905_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/dataset/top1_0.7534425570409087_epoch_2_loss_0.18020395934581757_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/dataset/top1_0.7534425570409087_epoch_2_loss_0.18020395934581757_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/table/top1_0.7459041109659262_epoch_1_loss_0.19401933252811432_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/table/top1_0.7459041109659262_epoch_1_loss_0.19401933252811432_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/table/top1_0.7533420444265755_epoch_3_loss_0.1702928990125656_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/table/top1_0.7533420444265755_epoch_3_loss_0.1702928990125656_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/table/top1_0.7426877073072671_epoch_0_loss_0.5148859620094299_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/table/top1_0.7426877073072671_epoch_0_loss_0.5148859620094299_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/table/top1_0.7566589606995678_epoch_6_loss_0.16280554234981537_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/table/top1_0.7566589606995678_epoch_6_loss_0.16280554234981537_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/table/top1_0.754749221027239_epoch_4_loss_0.166655033826828_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/table/top1_0.754749221027239_epoch_4_loss_0.166655033826828_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/table/top1_0.7563574228565685_epoch_5_loss_0.1643238067626953_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/table/top1_0.7563574228565685_epoch_5_loss_0.1643238067626953_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/final_models/table/top1_0.7496230776962509_epoch_2_loss_0.1769380420446396_batch_size_32_learning_rate_1e-05.pth to Experiment/Experiment_test_semtab_feature_addition/final_models/table/top1_0.7496230776962509_epoch_2_loss_0.1769380420446396_batch_size_32_learning_rate_1e-05.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/model_training_data/cell_tl_pipeline_pos_features.pkl to Experiment/Experiment_test_semtab_feature_addition/model_training_data/cell_tl_pipeline_pos_features.pkl
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/model_training_data/dataset_tl_pipeline_neg_features.pkl to Experiment/Experiment_test_semtab_feature_addition/model_training_data/dataset_tl_pipeline_neg_features.pkl
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/model_training_data/dataset_tl_pipeline_pos_features.pkl to Experiment/Experiment_test_semtab_feature_addition/model_training_data/dataset_tl_pipeline_pos_features.pkl
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/model_training_data/complete_shuffle_tl_pipeline_neg_features.pkl to Experiment/Experiment_test_semtab_feature_addition/model_training_data/complete_shuffle_tl_pipeline_neg_features.pkl
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/model_training_data/cell_tl_pipeline_neg_features.pkl to Experiment/Experiment_test_semtab_feature_addition/model_training_data/cell_tl_pipeline_neg_features.pkl
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/model_training_data/tl_pipeline_normalization_factor.pkl to Experiment/Experiment_test_semtab_feature_addition/model_training_data/tl_pipeline_normalization_factor.pkl
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/model_training_data/table_tl_pipeline_pos_features.pkl to Experiment/Experiment_test_semtab_feature_addition/model_training_data/table_tl_pipeline_pos_features.pkl
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/model_training_data/table_tl_pipeline_neg_features.pkl to Experiment/Experiment_test_semtab_feature_addition/model_training_data/table_tl_pipeline_neg_features.pkl
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/pgt_models/top1_0.5994490881458967_epoch_0_loss_0.393095999956131_batch_size_32_learning_rate_0.0001.pth to Experiment/Experiment_test_semtab_feature_addition/pgt_models/top1_0.5994490881458967_epoch_0_loss_0.393095999956131_batch_size_32_learning_rate_0.0001.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/pgt_models/top1_0.5019946808510638_epoch_0_loss_0.3037075996398926_batch_size_32_learning_rate_0.001.pth to Experiment/Experiment_test_semtab_feature_addition/pgt_models/top1_0.5019946808510638_epoch_0_loss_0.3037075996398926_batch_size_32_learning_rate_0.001.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/pgt_models/top1_0.507313829787234_epoch_1_loss_0.30702662467956543_batch_size_32_learning_rate_0.001.pth to Experiment/Experiment_test_semtab_feature_addition/pgt_models/top1_0.507313829787234_epoch_1_loss_0.30702662467956543_batch_size_32_learning_rate_0.001.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/pgt_models/top1_0.601063829787234_epoch_1_loss_0.2996736764907837_batch_size_32_learning_rate_0.0001.pth to Experiment/Experiment_test_semtab_feature_addition/pgt_models/top1_0.601063829787234_epoch_1_loss_0.2996736764907837_batch_size_32_learning_rate_0.0001.pth
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/model_training_data/complete_shuffle_tl_pipeline_pos_features.pkl to Experiment/Experiment_test_semtab_feature_addition/model_training_data/complete_shuffle_tl_pipeline_pos_features.pkl
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/model_training_data/tl_pipeline_neg_features.pkl to Experiment/Experiment_test_semtab_feature_addition/model_training_data/tl_pipeline_neg_features.pkl
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/model_training_data/tl_pipeline_pos_features.pkl to Experiment/Experiment_test_semtab_feature_addition/model_training_data/tl_pipeline_pos_features.pkl
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/0IR0XIUW.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/0IR0XIUW.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/1MQL5T7F.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/1MQL5T7F.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/1C9LFOKN.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/1C9LFOKN.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/0D70DN48.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/0D70DN48.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/24W5SSRB.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/24W5SSRB.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/29BNEL1Q.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/29BNEL1Q.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/2VRS31OV.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/2VRS31OV.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/4FFI99VQ.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/4FFI99VQ.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/2XHMV76G.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/2XHMV76G.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/2BEBH437.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/2BEBH437.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/3C3INQLM.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/3C3INQLM.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/4HP08FY9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/4HP08FY9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/1C7N45JA.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/1C7N45JA.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/2EZKB5RU.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/2EZKB5RU.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/5DKX42VB.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/5DKX42VB.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/5HD27KI3.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/5HD27KI3.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/51MYHYDF.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/51MYHYDF.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/4WMC1B70.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/4WMC1B70.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/7GOG4IKF.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/7GOG4IKF.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/54S3KOBO.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/54S3KOBO.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/7QNYGYI7.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/7QNYGYI7.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/64OJP4G3.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/64OJP4G3.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/5OLOTSKC.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/5OLOTSKC.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/60G94POT.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/60G94POT.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/7VVP9YIF.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/7VVP9YIF.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/8D8CVBT0.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/8D8CVBT0.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/8MKQXO18.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/8MKQXO18.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/8R6ZM8HE.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/8R6ZM8HE.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/8QA9EYPI.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/8QA9EYPI.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/9HIRS45A.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/9HIRS45A.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/8YINKYDR.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/8YINKYDR.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/9BGE5Y4L.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/9BGE5Y4L.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/9JA43FJL.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/9JA43FJL.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/BLBITS6S.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/BLBITS6S.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/9Y8MPU2Q.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/9Y8MPU2Q.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/BDH3WFGJ.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/BDH3WFGJ.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/CAF0E2JH.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/CAF0E2JH.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/CXBCCWXI.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/CXBCCWXI.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/AN306FAH.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/AN306FAH.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/2t_data/DRSJ0SOG.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/2t_data/DRSJ0SOG.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biodiv_data/56adc7a597b74e38905801fd6edc0f5c.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biodiv_data/56adc7a597b74e38905801fd6edc0f5c.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biodiv_data/18389aef970147c4982d160c7a2d42f9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biodiv_data/18389aef970147c4982d160c7a2d42f9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biodiv_data/23ec62734eee41768969b817069b4011.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biodiv_data/23ec62734eee41768969b817069b4011.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biodiv_data/11a0fb6a86ba4fef9dbb904fa851066b.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biodiv_data/11a0fb6a86ba4fef9dbb904fa851066b.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biodiv_data/d5542ea1fddf44c39d2bb70dc436ddf8.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biodiv_data/d5542ea1fddf44c39d2bb70dc436ddf8.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biodiv_data/2504d3d1356b4e0b85f10170bdbaeaf1.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biodiv_data/2504d3d1356b4e0b85f10170bdbaeaf1.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biodiv_data/a0d91ffa40534e3b8fd488e6f4a38d1b.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biodiv_data/a0d91ffa40534e3b8fd488e6f4a38d1b.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biodiv_data/a9d3d5c71a1648d3ae693997b0971e83.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biodiv_data/a9d3d5c71a1648d3ae693997b0971e83.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biodiv_data/e749786aff714981a5a7da3da0789128.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biodiv_data/e749786aff714981a5a7da3da0789128.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biodiv_data/b9b284ef0bd745749d71bb983ba9ace9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biodiv_data/b9b284ef0bd745749d71bb983ba9ace9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/2A38A4.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/2A38A4.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/3EF815.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/3EF815.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/17E621.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/17E621.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/3C59DC.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/3C59DC.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/5F93F9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/5F93F9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/03AFDB.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/03AFDB.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/6EA9AB.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/6EA9AB.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/812B4B.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/812B4B.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/A684EC.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/A684EC.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/A3F390.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/A3F390.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/70EFDF.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/70EFDF.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/D67D8A.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/D67D8A.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file100415_0_cols1_rows14.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file100415_0_cols1_rows14.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file134372_0_cols1_rows11.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file134372_0_cols1_rows11.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/E4DA3B.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/E4DA3B.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file118301_28_cols1_rows28.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file118301_28_cols1_rows28.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file124647_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file124647_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file136273_3_cols1_rows11.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file136273_3_cols1_rows11.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file114818_0_cols1_rows22.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file114818_0_cols1_rows22.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file138986_23_cols1_rows17.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file138986_23_cols1_rows17.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/C4CA42.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/C4CA42.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file137959_0_cols1_rows19.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file137959_0_cols1_rows19.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/E36985.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/E36985.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/biotab_data/F71771.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/biotab_data/F71771.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file155305_0_cols1_rows17.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file155305_0_cols1_rows17.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file136273_4_cols1_rows7.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file136273_4_cols1_rows7.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file162595_3_cols1_rows19.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file162595_3_cols1_rows19.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file184372_0_cols1_rows13.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file184372_0_cols1_rows13.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file160562_0_cols1_rows11.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file160562_0_cols1_rows11.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file16426_0_cols1_rows11.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file16426_0_cols1_rows11.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file199969_2_cols1_rows19.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file199969_2_cols1_rows19.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file212038_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file212038_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file236612_0_cols1_rows14.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file236612_0_cols1_rows14.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file235911_0_cols1_rows40.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file235911_0_cols1_rows40.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file266838_5_cols1_rows22.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file266838_5_cols1_rows22.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file270598_0_cols1_rows13.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file270598_0_cols1_rows13.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file242908_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file242908_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file273143_0_cols1_rows6.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file273143_0_cols1_rows6.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file241396_9_cols1_rows69.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file241396_9_cols1_rows69.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file304130_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file304130_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file291850_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file291850_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file281613_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file281613_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file325689_0_cols1_rows11.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file325689_0_cols1_rows11.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file30597_5_cols1_rows11.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file30597_5_cols1_rows11.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file322407_2_cols1_rows18.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file322407_2_cols1_rows18.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file331221_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file331221_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file331899_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file331899_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file329942_5_cols1_rows18.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file329942_5_cols1_rows18.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file338795_0_cols1_rows83.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file338795_0_cols1_rows83.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file32078_0_cols1_rows12.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file32078_0_cols1_rows12.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file339527_0_cols1_rows19.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file339527_0_cols1_rows19.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file345145_0_cols1_rows8.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file345145_0_cols1_rows8.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file380717_0_cols1_rows8.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file380717_0_cols1_rows8.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file338795_1_cols1_rows83.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file338795_1_cols1_rows83.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file384878_0_cols1_rows17.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file384878_0_cols1_rows17.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file362299_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file362299_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file39042_0_cols1_rows6.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file39042_0_cols1_rows6.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file391005_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file391005_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file399053_0_cols1_rows14.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file399053_0_cols1_rows14.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file38336_0_cols1_rows12.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file38336_0_cols1_rows12.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file404761_0_cols1_rows11.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file404761_0_cols1_rows11.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file396413_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file396413_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file39810_0_cols1_rows6.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file39810_0_cols1_rows6.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file40567_0_cols1_rows6.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file40567_0_cols1_rows6.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file405469_0_cols1_rows16.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file405469_0_cols1_rows16.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file413846_0_cols1_rows17.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file413846_0_cols1_rows17.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file40637_0_cols1_rows12.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file40637_0_cols1_rows12.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file41945_0_cols1_rows87.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file41945_0_cols1_rows87.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file417489_17_cols1_rows28.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file417489_17_cols1_rows28.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file413245_3_cols1_rows12.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file413245_3_cols1_rows12.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file42049_0_cols1_rows6.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file42049_0_cols1_rows6.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file420753_0_cols1_rows11.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file420753_0_cols1_rows11.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file420793_0_cols1_rows12.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file420793_0_cols1_rows12.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file429559_0_cols1_rows31.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file429559_0_cols1_rows31.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file430636_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file430636_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file429503_0_cols1_rows12.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file429503_0_cols1_rows12.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file455094_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file455094_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file444427_0_cols1_rows22.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file444427_0_cols1_rows22.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file466379_0_cols1_rows11.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file466379_0_cols1_rows11.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file499936_5_cols1_rows86.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file499936_5_cols1_rows86.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file435083_10_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file435083_10_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file464588_0_cols1_rows12.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file464588_0_cols1_rows12.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file469366_1_cols1_rows19.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file469366_1_cols1_rows19.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file487374_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file487374_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file51190_1_cols1_rows6.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file51190_1_cols1_rows6.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file449225_0_cols1_rows50.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file449225_0_cols1_rows50.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file516163_0_cols1_rows24.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file516163_0_cols1_rows24.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file522774_0_cols1_rows20.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file522774_0_cols1_rows20.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file526591_0_cols1_rows20.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file526591_0_cols1_rows20.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file539385_17_cols1_rows87.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file539385_17_cols1_rows87.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file525008_0_cols1_rows9.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file525008_0_cols1_rows9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file592476_0_cols1_rows8.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file592476_0_cols1_rows8.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file64428_2_cols1_rows18.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file64428_2_cols1_rows18.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file539385_18_cols1_rows87.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file539385_18_cols1_rows87.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file568853_0_cols1_rows18.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file568853_0_cols1_rows18.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file71478_0_cols1_rows17.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file71478_0_cols1_rows17.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file532025_0_cols1_rows11.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file532025_0_cols1_rows11.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/limaye_data/file91274_1_cols1_rows17.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/limaye_data/file91274_1_cols1_rows17.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/reduced_dev_data/t2dv2_data/63450419_0_8012592961815711786.csv to Experiment/Experiment_test_semtab_feature_addition/reduced_dev_data/t2dv2_data/63450419_0_8012592961815711786.csv
# ...
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/49XGWHEN.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/49XGWHEN.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4DPRZWVL.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4DPRZWVL.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4FXN1RZ3.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4FXN1RZ3.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4I7A5GID.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4I7A5GID.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4G8G7N8W.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4G8G7N8W.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4KDMZHXJ.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4KDMZHXJ.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4LFJR3YN.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4LFJR3YN.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4IJHCIR9.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4IJHCIR9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4I995NNQ.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4I995NNQ.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4NVYEVEQ.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4NVYEVEQ.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4FG1UN8O.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4FG1UN8O.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4IB27COT.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4IB27COT.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4N6X42PJ.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4N6X42PJ.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4L16JP9T.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4L16JP9T.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4O1BS5W9.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4O1BS5W9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4MGX23BZ.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4MGX23BZ.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4P9QJEV9.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4P9QJEV9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4RB6CKKQ.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4RB6CKKQ.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4Q6FAT24.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4Q6FAT24.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4PKEEJU4.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4PKEEJU4.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4VAYQOG0.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4VAYQOG0.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4SOL8H0M.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4SOL8H0M.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4VL4BFPM.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4VL4BFPM.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4V4O0CTS.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4V4O0CTS.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4QTU5MYM.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4QTU5MYM.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4WN91IQN.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4WN91IQN.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4XIXYJZJ.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4XIXYJZJ.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4UUFDEP4.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4UUFDEP4.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/519M624G.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/519M624G.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4UZA5UWB.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4UZA5UWB.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/50ULP1KH.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/50ULP1KH.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4YBOUF9V.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4YBOUF9V.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/50NWQJ1T.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/50NWQJ1T.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/568P9F4E.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/568P9F4E.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/4ZZG4HMD.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/4ZZG4HMD.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/51BN46AU.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/51BN46AU.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5894JWA5.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5894JWA5.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/53OUTCE4.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/53OUTCE4.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/54SEC9F3.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/54SEC9F3.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/59W76Q0Y.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/59W76Q0Y.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/58E7A5WL.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/58E7A5WL.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/56CDHMVN.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/56CDHMVN.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/59CFTDPL.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/59CFTDPL.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5739HKRB.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5739HKRB.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/59JNC864.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/59JNC864.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5BD6VKB3.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5BD6VKB3.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5BGVRHI5.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5BGVRHI5.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5CG871YQ.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5CG871YQ.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5BVL4YJS.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5BVL4YJS.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5D3I2S1N.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5D3I2S1N.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5FMSUKCH.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5FMSUKCH.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5ECFP78V.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5ECFP78V.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5IXA0RAI.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5IXA0RAI.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5GS30C2C.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5GS30C2C.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5J25NATF.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5J25NATF.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5G4M4L5W.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5G4M4L5W.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5E9CSACP.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5E9CSACP.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5IKCI9Z4.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5IKCI9Z4.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5KZVO2UP.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5KZVO2UP.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5MMHOLUI.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5MMHOLUI.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5PJ0EF0X.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5PJ0EF0X.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5N8AUSXE.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5N8AUSXE.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5P2SOXGW.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5P2SOXGW.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5NMYKF77.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5NMYKF77.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5Q5RASS8.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5Q5RASS8.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5PKTGQ6Q.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5PKTGQ6Q.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5TWQ98LE.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5TWQ98LE.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5NTTT408.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5NTTT408.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5S8PITYQ.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5S8PITYQ.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5QDDFGBJ.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5QDDFGBJ.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5T891IJ9.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5T891IJ9.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5TJI4XTK.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5TJI4XTK.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/training_data/pseudo_pipeline_normalization_factor.pkl to Experiment/Experiment_test_semtab_feature_addition/training_data/pseudo_pipeline_normalization_factor.pkl
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5SB78VPX.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5SB78VPX.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5TXLGRXA.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5TXLGRXA.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5WFYRRY7.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5WFYRRY7.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5W6MRY0W.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5W6MRY0W.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5WA7NENC.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5WA7NENC.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5VD9H3AD.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5VD9H3AD.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/training_data/tl_pipeline_pos_features.pkl to Experiment/Experiment_test_semtab_feature_addition/training_data/tl_pipeline_pos_features.pkl
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/semtab/complete_data/5BEY9DAJ.csv to Experiment/Experiment_test_semtab_feature_addition/semtab/complete_data/5BEY9DAJ.csv
# download: s3://table-linker-datasets/Experiments/Experiment_test_semtab/training_data/tl_pipeline_neg_features.pkl to Experiment/Experiment_test_semtab_feature_addition/training_data/tl_pipeline_neg_features.pkl

# %%
train_files_path = [f'{experiment_store_path}/reduced_train_data/' + i for i in experiment_train_data.split(',')]
train_files = []
for train_path in train_files_path:
    set_of_files = glob.glob(train_path + '/*.csv')
    train_files.extend(set_of_files)
print(len(train_files))
dev_files_path = [f'{experiment_store_path}/reduced_dev_data/' + i for i in experiment_train_data.split(',')]
dev_files = []
for dev_path in dev_files_path:
    set_of_files = glob.glob(dev_path + '/*.csv')
    dev_files.extend(set_of_files)
print(len(dev_files))
test_files = []
test_files_location = [f'{experiment_store_path}/{experiment_test_data.split("_")[0]}/complete_data']
for k in test_files_location:
    test_files.extend(glob.glob(k + '/*.csv'))
print(len(test_files))
# Out:
# 450
# 157
# 345

# %%
preprocessed_train_files_path = f'{experiment_store_path}/processed_train_data/'
preprocessed_dev_files_path = f'{experiment_store_path}/processed_dev_data/'
preprocessed_test_files_path = f'{experiment_store_path}/processed_test_data/'

# %%
### EXTRA DATA PREPROCESSING - Adding a new feature prefix column to all the data

# !mkdir -p {preprocessed_train_files_path}
# !mkdir -p {preprocessed_dev_files_path}
# !mkdir -p {preprocessed_test_files_path}
preprocessed_train_files = []
preprocessed_dev_files = []
preprocessed_test_files = []

print("Preprocessing for train data")
for file in train_files:
    file_name = file.split('/')[-1]
    print(file_name)
    result_file = preprocessed_train_files_path + file_name
    # !tl string-similarity --method prefix_monge_elkan:tokenizer=word -c label_clean kg_labels -o prefix_monge_elkan_similarity $file  > $result_file
    preprocessed_train_files.append(result_file)
    
print("Preprocessing for dev data")
for file in dev_files:
    file_name = file.split('/')[-1]
    print(file_name)
    result_file = preprocessed_dev_files_path + file_name
    # !tl string-similarity --method prefix_monge_elkan:tokenizer=word -c label_clean kg_labels -o prefix_monge_elkan_similarity $file  > $result_file
    preprocessed_dev_files.append(result_file)
    
print("Preprocessing for test data")
for file in test_files:
    file_name = file.split('/')[-1]
    print(file_name)
    result_file = preprocessed_test_files_path + file_name
    # !tl string-similarity --method prefix_monge_elkan:tokenizer=word -c label_clean kg_labels -o prefix_monge_elkan_similarity $file  > $result_file
    preprocessed_test_files.append(result_file)
# Out:
# Preprocessing for train data
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7fe3faf20062> in <module>
#       9
#      10 print("Preprocessing for train data")
# ---> 11 for file in train_files:
#      12     file_name = file.split('/')[-1]
#      13     print(file_name)
#
# NameError: name 'train_files' is not defined

# %%
preprocessed_train_files = glob.glob(preprocessed_train_files_path + '/*.csv')
preprocessed_dev_files = glob.glob(preprocessed_dev_files_path + '/*.csv')
preprocessed_test_files = glob.glob(preprocessed_test_files_path + '/*.csv')
len(preprocessed_train_files), len(preprocessed_dev_files), len(preprocessed_test_files)
# Out:
# (450, 157, 345)

# %%
# Helpher functions for data preprocessing
def merge_files(args):
    # datapath = args.train_path
    df_list = []
    for fn in args.train_files:
        fid = fn.split('/')[-1][:-4]
        dataset_id = fn.split('/')[-2]
        df = read_file(fn)
        if not isinstance(df, pd.DataFrame) :
            continue

        df['table_id'] = fid
        print(dataset_id, fid)
        df['dataset_id'] = dataset_id
        df['context_score'].fillna(0.0, inplace=True)
        if 'column-id' not in df.columns:
            df['column-id'] = fn.split('/')[-1] + df['column'].astype('str')

        df = df[extra_feat]
        df_list.append(df)
    return pd.concat(df_list)


def compute_normalization_factor(args, all_data):
    min_max_scaler_path = args.min_max_scaler_path
    all_data_features = all_data[features]
    scaler = MinMaxScaler()
    scaler.fit(all_data_features)
    return scaler


def read_file(key):
    #resp = s3.get_object(Bucket = bucket, Key = key)
    try:
        df = pd.read_csv(key, sep = ',')
    except pd.errors.EmptyDataError:
        df = ''
        print('Empty csv file!')
    return df

# %%
def generate_train_data(args, all_data, scaler, shuffle_by = None):
    num_cells_1 = 0
    scaler_path = args.min_max_scaler_path
    #scaler = pickle.load(open('./tmp/min_max_scaler_path.pkl', 'rb'))
    final_list = []
    sfeatures = copy.deepcopy(features)
    normalize_features = features
    evaluation_label = ['evaluation_label']
    positive_features_final = []
    negative_features_final = []
    super_groups = all_data.groupby(['column-id'])
    if shuffle_by == 'dataset':
        super_groups = all_data.groupby(['dataset_id'])
        for i, s_group in super_groups:
            pos_features_dataset = []
            neg_features_dataset = []
            grouped_obj = s_group.groupby(['column', 'row', 'column-id'])

            for cell in grouped_obj:
                num_cells_1 += 1
                cell[1][normalize_features] = scaler.transform(cell[1][normalize_features])
                pos_features = []
                neg_features = []
                a = cell[1][cell[1]['evaluation_label'] == 1]
                if a.empty:
                    continue
                pos_rows = cell[1][cell[1]['evaluation_label'].astype(int) == 1][sfeatures].to_numpy()
                if len(pos_rows) < 1:
                    continue
                if len(pos_rows) > 1:
                    print("here")
                for i in range(len(pos_rows)):
                    pos_features.append(pos_rows[i])
                neg_rows = cell[1][cell[1]['evaluation_label'].astype(int) == -1][sfeatures].to_numpy()
                for i in range(min(BATCH_SIZE, len(neg_rows))):
                    neg_features.append(neg_rows[i])

                for k in range(len(neg_features) - len(pos_features)):
                    pos_features.append(random.choice(pos_rows))
                if len(pos_features) != len(neg_features):
                    continue
                pos_features_dataset.append(pos_features)
                neg_features_dataset.append(neg_features)
            if len(pos_features_dataset) > 0:
                c = list(zip(pos_features_dataset, neg_features_dataset))
                random.shuffle(c)
                pos_features_dataset, neg_features_dataset = zip(*c)
                positive_features_final.extend(pos_features_dataset)
                negative_features_final.extend(neg_features_dataset)
    elif shuffle_by == 'table':
        super_groups = all_data.groupby(['table_id'])
        for i, s_group in super_groups:
            pos_features_table = []
            neg_features_table = []
            file_name = i.split('-')[0]
            #s_group_n = context_property_similarity_code.return_a_table(s_group, pca_components = N_PCA_COMPONENTS)
            #print("entering ", file_name)
            ds_id = s_group['dataset_id'].values[0]
            print("File: ", file_name, ds_id)
            grouped_obj = s_group.groupby(['column', 'row'])
    
            for cell in grouped_obj:
                num_cells_1 += 1
                cell[1][normalize_features] = scaler.transform(cell[1][normalize_features])
                pos_features = []
                neg_features = []
                a = cell[1][cell[1]['evaluation_label'] == 1]
                if a.empty:
                    continue
                pos_rows = cell[1][cell[1]['evaluation_label'].astype(int) == 1][sfeatures].to_numpy()
                if len(pos_rows) < 1:
                    continue
                if len(pos_rows) > 1:
                    print("here")
                for i in range(len(pos_rows)):
                    pos_features.append(pos_rows[i])
                neg_rows = cell[1][cell[1]['evaluation_label'].astype(int) == -1][sfeatures].to_numpy()
                for i in range(min(BATCH_SIZE, len(neg_rows))):
                    neg_features.append(neg_rows[i])

                for k in range(len(neg_features) - len(pos_features)):
                    pos_features.append(random.choice(pos_rows))
                if len(pos_features) != len(neg_features):
                    continue
                random.shuffle(pos_features)

                random.shuffle(neg_features)
                pos_features_table.append(pos_features)
                neg_features_table.append(neg_features)
            if len(pos_features_table) > 0:
                c = list(zip(pos_features_table, neg_features_table))
                random.shuffle(c)
                pos_features_table, neg_features_table = zip(*c)
                positive_features_final.extend(pos_features_table)
                negative_features_final.extend(neg_features_table)
    else:
        for i, s_group in super_groups:
            file_name = i.split('-')[0]
            #print("entering ", file_name)
            grouped_obj = s_group.groupby(['column', 'row'])
            for cell in grouped_obj:
                num_cells_1 += 1
                cell[1][normalize_features] = scaler.transform(cell[1][normalize_features])
                pos_features = []
                neg_features = []
                a = cell[1][cell[1]['evaluation_label'] == 1]
                if a.empty:
                    continue
                pos_rows = cell[1][cell[1]['evaluation_label'].astype(int) == 1][sfeatures].to_numpy()
                if len(pos_rows) < 1:
                    continue
                if len(pos_rows) > 1:
                    print("here")
                for i in range(len(pos_rows)):
                    pos_features.append(pos_rows[i])
                neg_rows = cell[1][cell[1]['evaluation_label'].astype(int) == -1][sfeatures].to_numpy()
                for i in range(min(BATCH_SIZE, len(neg_rows))):
                    neg_features.append(neg_rows[i])

                for k in range(len(neg_features) - len(pos_features)):
                    pos_features.append(random.choice(pos_rows))
                random.shuffle(pos_features)
                random.shuffle(neg_features)
                if len(pos_features) != len(neg_features):
                    print("Something Wrong")
                else:
                    positive_features_final.append(pos_features)
                    negative_features_final.append(neg_features)

    if shuffle_by == 'complete_shuffle':
        c = list(zip(positive_features_final, negative_features_final))
        random.shuffle(c)
        positive_features_final, positive_features_final = zip(*c)
    print(len(positive_features_final), len(positive_features_final[3]))
    print(len(negative_features_final), len(negative_features_final[3]))

    print(len(positive_features_final), len(positive_features_final[3]))
    print(len(negative_features_final), len(negative_features_final[3]))
    return positive_features_final, negative_features_final
def generate_dataloader(positive_feat_path, negative_feat_path):
    pos_features = pickle.load(open(positive_feat_path, 'rb'))
    neg_features = pickle.load(open(negative_feat_path, 'rb'))
    print(pos_features[10])
    pos_features_flatten = list(chain.from_iterable(pos_features))
    neg_features_flatten = list(chain.from_iterable(neg_features))
    return pos_features_flatten, neg_features_flatten

# %%
# Setting the scaler and merging files
gen_training_data_args = Namespace(train_files=preprocessed_train_files, pos_output=pos_output, neg_output=neg_output,min_max_scaler_path=min_max_scaler_path)
all_data = merge_files(gen_training_data_args)
scaler = compute_normalization_factor(gen_training_data_args, all_data)
pickle.dump(scaler, open(min_max_scaler_path, 'wb'))
# Out:
# processed_train_data 3N6S2FCX
# processed_train_data CNQ5Z0BG
# processed_train_data 4J75OL3W
# processed_train_data HGYG2DVU
# processed_train_data 3LG8J4MX
# processed_train_data CHZGO92A
# processed_train_data EQZ21058
# processed_train_data HB00DX4L
# processed_train_data FVKKTA8O
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# processed_train_data K2VEUQT0
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# processed_train_data HQRATPBV
# processed_train_data IPTLCCCU
# processed_train_data IYZYF533
# processed_train_data KOQM4YU9
# processed_train_data NV4GY44T
# processed_train_data N6QAC84T
# processed_train_data OKW6UUW5
# processed_train_data OIDIXPNZ
# processed_train_data QOL4ZIHL
# processed_train_data SRVLBA90
# processed_train_data PZXDACJ9
# processed_train_data SPPNJXB2
# processed_train_data TW1HGRFI
# processed_train_data VGUZX5R3
# processed_train_data UURPYBGQ
# processed_train_data U1FDHL7N
# processed_train_data WH6JINCM
# processed_train_data file110008_0_cols1_rows66
# processed_train_data file110816_0_cols1_rows40
# processed_train_data file171157_0_cols1_rows21
# processed_train_data file13997_0_cols1_rows20
# processed_train_data file183712_0_cols1_rows19
# processed_train_data file198804_0_cols1_rows39
# processed_train_data file205708_0_cols1_rows20
# processed_train_data file222751_0_cols1_rows13
# processed_train_data file229323_0_cols1_rows7
# processed_train_data file236160_0_cols1_rows28
# processed_train_data file256909_0_cols1_rows39
# processed_train_data file27532_1_cols1_rows53
# processed_train_data file240410_0_cols1_rows60
# processed_train_data file268478_10_cols1_rows25
# processed_train_data file337276_0_cols1_rows31
# processed_train_data file288293_0_cols1_rows14
# processed_train_data file331278_0_cols1_rows23
# processed_train_data file365726_0_cols1_rows13
# processed_train_data file394725_0_cols1_rows24
# processed_train_data file434605_0_cols1_rows15
# processed_train_data file366288_0_cols1_rows29
# processed_train_data file383362_0_cols1_rows21
# processed_train_data file398415_0_cols1_rows58
# processed_train_data file489984_0_cols1_rows86
# processed_train_data file496605_1_cols1_rows39
# processed_train_data file426195_0_cols1_rows21
# processed_train_data file505202_0_cols1_rows6
# processed_train_data file499596_0_cols1_rows39
# processed_train_data file51833_0_cols1_rows68
# processed_train_data file60228_9_cols1_rows37
# processed_train_data file533779_0_cols1_rows7
# processed_train_data file535849_0_cols1_rows20
# processed_train_data file558362_0_cols1_rows20
# processed_train_data file63591_4_cols1_rows58
# processed_train_data file85468_0_cols1_rows80
# processed_train_data file99290_1_cols1_rows63
# processed_train_data file65862_24_cols1_rows58
# processed_train_data file98470_1_cols1_rows55
# processed_train_data file98594_6_cols1_rows25
# processed_train_data 34173C
# processed_train_data 3295C7
# processed_train_data 19CA14
# processed_train_data 33E75F
# processed_train_data 66F041
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# processed_train_data 6C8349
# processed_train_data 68D30A
# processed_train_data 7CBBC4
# processed_train_data AD61AB
# processed_train_data 98F137
# processed_train_data 861398
# processed_train_data C74D97
# processed_train_data D64592
# processed_train_data FC490C
# processed_train_data ED3D2C
# processed_train_data FE9FC2
# processed_train_data F89913
# processed_train_data 14067031_0_559833072073397908
# processed_train_data 33401079_0_9127583903019856402
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# processed_train_data 38428277_0_1311643810102462607
# processed_train_data 77694908_0_6083291340991074532
# processed_train_data 41480166_0_6681239260286218499
# processed_train_data 80588006_0_6965325215443683359
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# processed_train_data 69537082_0_7789694313271016902
# Empty csv file!
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (6,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# processed_train_data 39a2d36769294a0a846cc209c45234e4
# Empty csv file!
# processed_train_data 89e72a749d764c1aacd9284e01c412a4
# processed_train_data file69673_0_cols1_rows58
# processed_train_data file304250_0_cols1_rows14
# processed_train_data file290427_0_cols1_rows14
# processed_train_data file234482_0_cols1_rows68
# processed_train_data file338151_0_cols1_rows6
# processed_train_data file456872_2_cols1_rows15
# processed_train_data E22XXKVQ
# processed_train_data file77529_0_cols1_rows20
# processed_train_data file137293_0_cols1_rows6
# processed_train_data ORPKCFRL
# processed_train_data WRPAQPNC
# processed_train_data GNDO9OXJ
# processed_train_data LV5N8XDB
# processed_train_data B38A9Q5R
# processed_train_data QPFX5Z8J
# processed_train_data MANO2PKR
# processed_train_data Z4M8AT89
# processed_train_data YCOUS57M
# processed_train_data NDSTZH1I
# processed_train_data GY7KNULP
# processed_train_data OZYCQ769
# processed_train_data HQCEC5NO
# processed_train_data GINQPZQC
# processed_train_data AUU9A6KL
# processed_train_data J9EJV2S3
# processed_train_data E3ZK744Q
# processed_train_data K3X3L22Y
# processed_train_data Y85GTOSS
# processed_train_data P86ZJFXK
# processed_train_data SFGT3EDA
# processed_train_data file202151_0_cols1_rows31
# processed_train_data file461483_0_cols1_rows39
# processed_train_data file279754_0_cols1_rows19
# processed_train_data file107572_0_cols1_rows62
# processed_train_data file494624_0_cols1_rows35
# processed_train_data file270041_0_cols1_rows23
# processed_train_data file270540_4_cols1_rows17
# processed_train_data file282772_0_cols1_rows45
# processed_train_data file285010_0_cols1_rows31
# processed_train_data file139009_9_cols1_rows21
# processed_train_data file226691_0_cols1_rows20
# processed_train_data file363812_1_cols1_rows21
# processed_train_data file288111_0_cols1_rows34
# processed_train_data file386878_0_cols1_rows23
# processed_train_data file191825_0_cols1_rows15
# processed_train_data file431641_0_cols1_rows78
# processed_train_data file139009_10_cols1_rows25
# processed_train_data file431384_13_cols1_rows65
# processed_train_data file265665_0_cols1_rows15
# processed_train_data file181303_0_cols1_rows31
# processed_train_data file286121_14_cols1_rows65
# processed_train_data file358104_14_cols1_rows65
# processed_train_data file409049_0_cols1_rows46
# processed_train_data file191712_11_cols1_rows25
# processed_train_data file257923_0_cols1_rows84
# processed_train_data file492921_0_cols1_rows39
# processed_train_data file191712_8_cols1_rows20
# processed_train_data file68383_1_cols1_rows60
# processed_train_data file388743_6_cols1_rows28
# processed_train_data file221797_1_cols1_rows39
# processed_train_data file123945_0_cols1_rows17
# processed_train_data file34615_2_cols1_rows24
# processed_train_data file251103_0_cols1_rows19
# processed_train_data file812_0_cols1_rows20
# processed_train_data file82769_0_cols1_rows83
# processed_train_data file8429_0_cols1_rows83
# processed_train_data 8E296A
# processed_train_data 1C383C
# processed_train_data 26657D
# processed_train_data 38B3EF
# processed_train_data 28DD2C
# processed_train_data 642E92
# processed_train_data 764796
# processed_train_data 6F4922
# processed_train_data 1F0E3D
# processed_train_data 4E732C
# processed_train_data 45C48C
# processed_train_data 6512BD
# processed_train_data 6974CE
# processed_train_data 6364D3
# processed_train_data 7F39F8
# processed_train_data ECCBC8
# processed_train_data C20AD4
# processed_train_data C0C7C7
# processed_train_data C51CE4
# processed_train_data EA5D2F
# processed_train_data D3D944
# processed_train_data D82C8D
# processed_train_data E2C420
# processed_train_data 10579449_0_1681126353774891032
# processed_train_data 1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5
# processed_train_data 43237185_1_3636357855502246981
# processed_train_data 53989675_0_8697482470743954630
# processed_train_data 84548468_0_5955155464119382182
# processed_train_data 58891288_0_1117541047012405958
# processed_train_data 52299421_0_4473286348258170200
# processed_train_data 9567241_0_5666388268510912770
# processed_train_data 0bc67e05a4d14011a2cf3fca2f869495
# processed_train_data 1d09a099d3964602aca9425adcde89cd
# Empty csv file!
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15,29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# processed_train_data 34169c088ee848e4866f42e87b4ccbc2
# Empty csv file!
# processed_train_data a407fa84d55d4072945ac61346150d03
# Empty csv file!
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (2,6,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# processed_train_data b785d9ed72b347ae9cb0997df17258d8
# processed_train_data file215105_0_cols1_rows23
# processed_train_data file192085_0_cols1_rows31
# processed_train_data file132514_0_cols1_rows17
# processed_train_data file114403_0_cols1_rows82
# processed_train_data file183833_0_cols1_rows21
# processed_train_data WWBIR8H6
# processed_train_data file294473_0_cols1_rows17
# processed_train_data S8UOQYBG
# processed_train_data ET9REW9Y
# processed_train_data 71SY0Z5S
# processed_train_data file37584_2_cols1_rows28
# processed_train_data X23TMJ3R
# processed_train_data B20WIQKU
# processed_train_data file244317_0_cols1_rows39
# processed_train_data file268478_9_cols1_rows20
# processed_train_data file234558_0_cols1_rows39
# processed_train_data HLJ9HHEE
# processed_train_data file119797_0_cols1_rows39
# processed_train_data QW492LGU
# processed_train_data file376591_0_cols1_rows19
# processed_train_data DXTA1MV8
# processed_train_data file268478_11_cols1_rows25
# processed_train_data T7RPWH6N
# processed_train_data file178948_0_cols1_rows14
# processed_train_data file405599_0_cols1_rows23
# processed_train_data file191712_9_cols1_rows20
# processed_train_data 6I7ET24J
# processed_train_data file184323_0_cols1_rows67
# processed_train_data file381801_0_cols1_rows6
# processed_train_data file139009_11_cols1_rows25
# processed_train_data TNI3UKH2
# processed_train_data QNP7O8L5
# processed_train_data file231281_1_cols1_rows39
# processed_train_data file377321_1_cols1_rows24
# processed_train_data file391510_0_cols1_rows19
# processed_train_data file416640_0_cols1_rows6
# processed_train_data file455767_0_cols1_rows44
# processed_train_data file467640_0_cols1_rows20
# processed_train_data file505656_0_cols1_rows20
# processed_train_data file501300_8_cols1_rows35
# processed_train_data file57149_0_cols1_rows12
# processed_train_data file95757_0_cols1_rows19
# processed_train_data file64479_0_cols1_rows12
# processed_train_data file6170_0_cols1_rows24
# processed_train_data file98594_5_cols1_rows22
# processed_train_data 14BFA6
# processed_train_data 32BB90
# processed_train_data 283802
# processed_train_data 72B32A
# processed_train_data 93DB85
# processed_train_data 8F14E4
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# processed_train_data 9F6140
# processed_train_data E2EF52
# processed_train_data B6D767
# processed_train_data A5771B
# processed_train_data AC627A
# processed_train_data AAB323
# processed_train_data C16A53
# processed_train_data FBD793
# processed_train_data D2DDEA
# processed_train_data F033AB
# processed_train_data D09BF4
# processed_train_data D9D4F4
# processed_train_data F0935E
# processed_train_data 37856682_0_6818907050314633217
# processed_train_data 1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2
# processed_train_data 39107734_2_2329160387535788734
# processed_train_data 39650055_5_7135804139753401681
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# processed_train_data c36f7f977dd8442681ace9541e0177c8
# processed_train_data 217d8c0c33a74bb28a55efffcb047885
# Empty csv file!
# processed_train_data file152457_0_cols1_rows7
# processed_train_data file493682_0_cols1_rows31
# processed_train_data file568285_0_cols1_rows15
# processed_train_data file51375_4_cols1_rows88
# processed_train_data F98SUVJH
# processed_train_data file224977_0_cols1_rows66
# processed_train_data OHGI1JNY
# processed_train_data JZ22O0DD
# processed_train_data file289661_0_cols1_rows6
# processed_train_data RYTFLT5K
# processed_train_data QOAVEFGY
# processed_train_data file267184_0_cols1_rows22
# processed_train_data 3DOM5NIW
# processed_train_data file313602_0_cols1_rows78
# processed_train_data file269877_0_cols1_rows39
# processed_train_data file322685_0_cols1_rows29
# processed_train_data file167874_0_cols1_rows11
# processed_train_data O0BECB72
# processed_train_data file219474_11_cols1_rows22
# processed_train_data file267997_0_cols1_rows69
# processed_train_data I6BBMPNU
# processed_train_data O0UJJVBR
# processed_train_data file135940_0_cols1_rows35
# processed_train_data file177766_0_cols1_rows83
# processed_train_data BID0NRU0
# processed_train_data file180087_0_cols1_rows12
# processed_train_data file239528_0_cols1_rows39
# processed_train_data XBHX2VRT
# processed_train_data S7DQFOD4
# processed_train_data file404549_0_cols1_rows20
# processed_train_data FF00TEZG
# processed_train_data file139009_8_cols1_rows21
# processed_train_data file143181_0_cols1_rows56
# processed_train_data JN0T2O5I
# processed_train_data WRGS0WCX
# processed_train_data ZZNW93IV
# processed_train_data X3RACWMT
# processed_train_data file440470_0_cols1_rows26
# processed_train_data file277057_2_cols1_rows31
# processed_train_data file191712_10_cols1_rows25
# processed_train_data JZLRN9PL
# processed_train_data file437154_0_cols1_rows31
# processed_train_data EV6LDIB8
# processed_train_data HTF6MVY9
# processed_train_data file138978_0_cols1_rows83
# processed_train_data file525125_0_cols1_rows39
# processed_train_data file169346_0_cols1_rows7
# processed_train_data file195533_0_cols1_rows18
# processed_train_data file191426_0_cols1_rows31
# processed_train_data file569522_0_cols1_rows21
# processed_train_data K71YYDXO
# processed_train_data file228670_0_cols1_rows20
# processed_train_data 3JXMPC7N
# processed_train_data P8B3IAOY
# processed_train_data file117573_0_cols1_rows23
# processed_train_data file489155_0_cols1_rows17
# processed_train_data WI5LYQ0H
# processed_train_data file506769_0_cols1_rows24
# processed_train_data WZL61XYS
# processed_train_data QIW5EC2H
# processed_train_data file145174_1_cols1_rows37
# processed_train_data file258799_0_cols1_rows40
# processed_train_data file263556_0_cols1_rows45
# processed_train_data IP6ZRIGH
# processed_train_data file99290_0_cols1_rows79
# processed_train_data file451761_0_cols1_rows19
# processed_train_data file37584_0_cols1_rows56
# processed_train_data file439313_0_cols1_rows68
# processed_train_data file339783_0_cols1_rows11
# processed_train_data file365069_0_cols1_rows66
# processed_train_data file88377_0_cols1_rows13
# processed_train_data 167909
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# processed_train_data 093F65
# processed_train_data 2723D0
# processed_train_data 43EC51
# processed_train_data 3416A7
# processed_train_data 44F683
# processed_train_data 67C6A1
# processed_train_data A5BFC9
# processed_train_data 9778D5
# processed_train_data 735B90
# processed_train_data 9BF31C
# processed_train_data A97DA6
# processed_train_data A87FF6
# processed_train_data EC8956
# processed_train_data C81E72
# processed_train_data C9E107
# processed_train_data F457C5
# processed_train_data F4B9EC
# processed_train_data 24036779_0_5608105867560183058
# processed_train_data 29414811_12_251152470253168163
# processed_train_data 16767252_0_2409448375013995751
# processed_train_data 40534006_0_4617468856744635526
# processed_train_data 14380604_4_3329235705746762392
# processed_train_data 1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2
# processed_train_data 53822652_0_5767892317858575530
# processed_train_data 21362676_0_6854186738074119688
# processed_train_data 29414811_13_8724394428539174350
# processed_train_data 25404227_0_2240631045609013057
# processed_train_data 45073662_0_3179937335063201739
# processed_train_data 60319454_0_3938426910282115527
# processed_train_data 54719588_0_8417197176086756912
# processed_train_data 50270082_0_444360818941411589
# processed_train_data 90196673_0_5458330029110291950
# processed_train_data 8468806_0_4382447409703007384
# Empty csv file!
# processed_train_data f99ab21885664e20bd25d1cf848f4c5e
# Empty csv file!
# Empty csv file!
# processed_train_data dffeec8c3593402bafa69b50f5920fa5
# processed_train_data SNUO09BH
# processed_train_data 39173938_0_7916056990138658530
# processed_train_data file409727_0_cols1_rows20
# processed_train_data 46671561_0_6122315295162029872
# processed_train_data IZF82AX9
# processed_train_data file73526_0_cols1_rows46
# processed_train_data 1FF1DE
# processed_train_data FWSGRDQ3
# processed_train_data file288989_0_cols1_rows68
# processed_train_data file65785_1_cols1_rows57
# processed_train_data 9A1158
# processed_train_data 35188621_0_6058553107571275232
# processed_train_data file21126_1_cols1_rows86
# processed_train_data file268478_8_cols1_rows20
# processed_train_data file75651_0_cols1_rows14
# processed_train_data file63247_13_cols1_rows65
# processed_train_data C7E124
# processed_train_data 20135078_0_7570343137119682530
# processed_train_data file284898_0_cols1_rows31
# processed_train_data file27532_0_cols1_rows82
# processed_train_data E45F8QW2
# processed_train_data 37693C
# processed_train_data JA4L7KWX
# processed_train_data 92CC22
# processed_train_data file531575_0_cols1_rows31
# processed_train_data file409309_0_cols1_rows60
# processed_train_data file411836_0_cols1_rows83
# processed_train_data 54229A
# processed_train_data file334380_0_cols1_rows21
# processed_train_data X1LRVWSR
# processed_train_data file521391_0_cols1_rows6
# processed_train_data file211429_0_cols1_rows92
# processed_train_data file219474_12_cols1_rows17
# processed_train_data C9F0F8
# processed_train_data 35F4A8
# processed_train_data HCLZSPEJ
# processed_train_data file208153_0_cols1_rows17
# processed_train_data file101640_0_cols1_rows31
# processed_train_data file389632_0_cols1_rows31
# processed_train_data 28086084_0_3127660530989916727
# processed_train_data NYFX4M8T
# processed_train_data file503004_0_cols1_rows20
# processed_train_data A1D0C6
# processed_train_data PWNRGOJ5
# processed_train_data file187184_0_cols1_rows84
# processed_train_data file233008_0_cols1_rows39
# processed_train_data file493618_0_cols1_rows39
# processed_train_data 39759273_0_1427898308030295194
# processed_train_data file220036_5_cols1_rows15
# processed_train_data U5L6L4Q4
# processed_train_data file214477_0_cols1_rows45
# processed_train_data OD9USH5H
# processed_train_data VKWTT7F7
# processed_train_data MSCT8MJD
# processed_train_data file431641_1_cols1_rows62
# processed_train_data I0ENR9U5
# processed_train_data file234296_0_cols1_rows14
# processed_train_data file550665_0_cols1_rows20
# processed_train_data 65B9EE
# processed_train_data 29414811_2_4773219892816395776
# processed_train_data file344029_0_cols1_rows34
# processed_train_data MZ0BI8NN
# processed_train_data A3C65C
# processed_train_data HGIUTSCG
# processed_train_data 9834884_0_3871985887467090123
# processed_train_data 71840765_0_6664391841933033844
# Empty csv file!
# processed_train_data cb1601379dca4472b6df915185124990
# processed_train_data b0edc48006d5454dae3ca3e41f33e280
# processed_train_data bd00b752eba94953882023490ade0978

# %%
# Creating final data
positive_features_final, negative_features_final = generate_train_data(gen_training_data_args, all_data, scaler, shuffle_by = 'table')
pickle.dump(positive_features_final, open(pos_output, 'wb'))
pickle.dump(negative_features_final, open(neg_output, 'wb'))
# Out:
# File:  093F65 processed_train_data
# File:  0bc67e05a4d14011a2cf3fca2f869495 processed_train_data
# File:  10579449_0_1681126353774891032 processed_train_data
# File:  14067031_0_559833072073397908 processed_train_data
# File:  1438042986423_95_20150728002306 processed_train_data
# File:  1438042989018_40_20150728002309 processed_train_data
# File:  1438042989043_35_20150728002309 processed_train_data
# File:  14380604_4_3329235705746762392 processed_train_data
# File:  14BFA6 processed_train_data
# File:  16767252_0_2409448375013995751 processed_train_data
# File:  167909 processed_train_data
# File:  19CA14 processed_train_data
# File:  1C383C processed_train_data
# File:  1F0E3D processed_train_data
# File:  1FF1DE processed_train_data
# File:  1d09a099d3964602aca9425adcde89cd processed_train_data
# File:  20135078_0_7570343137119682530 processed_train_data
# File:  21362676_0_6854186738074119688 processed_train_data
# File:  217d8c0c33a74bb28a55efffcb047885 processed_train_data
# File:  24036779_0_5608105867560183058 processed_train_data
# File:  25404227_0_2240631045609013057 processed_train_data
# File:  26657D processed_train_data
# File:  2723D0 processed_train_data
# File:  28086084_0_3127660530989916727 processed_train_data
# File:  283802 processed_train_data
# File:  28DD2C processed_train_data
# File:  29414811_12_251152470253168163 processed_train_data
# File:  29414811_13_8724394428539174350 processed_train_data
# File:  29414811_2_4773219892816395776 processed_train_data
# File:  3295C7 processed_train_data
# File:  32BB90 processed_train_data
# File:  33401079_0_9127583903019856402 processed_train_data
# File:  33E75F processed_train_data
# File:  34169c088ee848e4866f42e87b4ccbc2 processed_train_data
# File:  3416A7 processed_train_data
# File:  34173C processed_train_data
# File:  35188621_0_6058553107571275232 processed_train_data
# File:  35F4A8 processed_train_data
# File:  37693C processed_train_data
# File:  37856682_0_6818907050314633217 processed_train_data
# File:  38428277_0_1311643810102462607 processed_train_data
# File:  38B3EF processed_train_data
# File:  39107734_2_2329160387535788734 processed_train_data
# File:  39173938_0_7916056990138658530 processed_train_data
# File:  39650055_5_7135804139753401681 processed_train_data
# File:  39759273_0_1427898308030295194 processed_train_data
# File:  39a2d36769294a0a846cc209c45234e4 processed_train_data
# File:  3DOM5NIW processed_train_data
# File:  3JXMPC7N processed_train_data
# File:  3LG8J4MX processed_train_data
# File:  3N6S2FCX processed_train_data
# File:  40534006_0_4617468856744635526 processed_train_data
# File:  41480166_0_6681239260286218499 processed_train_data
# File:  43237185_1_3636357855502246981 processed_train_data
# File:  43EC51 processed_train_data
# File:  44F683 processed_train_data
# File:  45073662_0_3179937335063201739 processed_train_data
# File:  45C48C processed_train_data
# File:  46671561_0_6122315295162029872 processed_train_data
# File:  4E732C processed_train_data
# File:  4J75OL3W processed_train_data
# File:  50270082_0_444360818941411589 processed_train_data
# File:  52299421_0_4473286348258170200 processed_train_data
# File:  53822652_0_5767892317858575530 processed_train_data
# File:  53989675_0_8697482470743954630 processed_train_data
# File:  54229A processed_train_data
# File:  54719588_0_8417197176086756912 processed_train_data
# File:  58891288_0_1117541047012405958 processed_train_data
# File:  60319454_0_3938426910282115527 processed_train_data
# File:  6364D3 processed_train_data
# File:  642E92 processed_train_data
# File:  6512BD processed_train_data
# File:  65B9EE processed_train_data
# File:  66F041 processed_train_data
# File:  67C6A1 processed_train_data
# File:  68D30A processed_train_data
# File:  69537082_0_7789694313271016902 processed_train_data
# File:  6974CE processed_train_data
# File:  6C8349 processed_train_data
# File:  6F4922 processed_train_data
# File:  6I7ET24J processed_train_data
# File:  71840765_0_6664391841933033844 processed_train_data
# File:  71SY0Z5S processed_train_data
# File:  72B32A processed_train_data
# File:  735B90 processed_train_data
# File:  764796 processed_train_data
# File:  77694908_0_6083291340991074532 processed_train_data
# File:  7CBBC4 processed_train_data
# File:  7F39F8 processed_train_data
# File:  80588006_0_6965325215443683359 processed_train_data
# File:  84548468_0_5955155464119382182 processed_train_data
# File:  8468806_0_4382447409703007384 processed_train_data
# File:  861398 processed_train_data
# File:  89e72a749d764c1aacd9284e01c412a4 processed_train_data
# File:  8E296A processed_train_data
# File:  8F14E4 processed_train_data
# File:  90196673_0_5458330029110291950 processed_train_data
# File:  92CC22 processed_train_data
# File:  93DB85 processed_train_data
# File:  9567241_0_5666388268510912770 processed_train_data
# File:  9778D5 processed_train_data
# File:  9834884_0_3871985887467090123 processed_train_data
# File:  98F137 processed_train_data
# File:  9A1158 processed_train_data
# File:  9BF31C processed_train_data
# File:  9F6140 processed_train_data
# File:  A1D0C6 processed_train_data
# File:  A3C65C processed_train_data
# File:  A5771B processed_train_data
# File:  A5BFC9 processed_train_data
# File:  A87FF6 processed_train_data
# File:  A97DA6 processed_train_data
# File:  AAB323 processed_train_data
# File:  AC627A processed_train_data
# File:  AD61AB processed_train_data
# File:  AUU9A6KL processed_train_data
# File:  B20WIQKU processed_train_data
# File:  B38A9Q5R processed_train_data
# File:  B6D767 processed_train_data
# File:  BID0NRU0 processed_train_data
# File:  C0C7C7 processed_train_data
# File:  C16A53 processed_train_data
# File:  C20AD4 processed_train_data
# File:  C51CE4 processed_train_data
# File:  C74D97 processed_train_data
# File:  C7E124 processed_train_data
# File:  C81E72 processed_train_data
# File:  C9E107 processed_train_data
# File:  C9F0F8 processed_train_data
# File:  CHZGO92A processed_train_data
# File:  CNQ5Z0BG processed_train_data
# File:  D09BF4 processed_train_data
# File:  D2DDEA processed_train_data
# File:  D3D944 processed_train_data
# File:  D64592 processed_train_data
# File:  D82C8D processed_train_data
# File:  D9D4F4 processed_train_data
# File:  DXTA1MV8 processed_train_data
# File:  E22XXKVQ processed_train_data
# File:  E2C420 processed_train_data
# File:  E2EF52 processed_train_data
# File:  E3ZK744Q processed_train_data
# File:  E45F8QW2 processed_train_data
# File:  EA5D2F processed_train_data
# File:  EC8956 processed_train_data
# File:  ECCBC8 processed_train_data
# File:  ED3D2C processed_train_data
# File:  EQZ21058 processed_train_data
# File:  ET9REW9Y processed_train_data
# File:  EV6LDIB8 processed_train_data
# File:  F033AB processed_train_data
# File:  F0935E processed_train_data
# File:  F457C5 processed_train_data
# File:  F4B9EC processed_train_data
# File:  F89913 processed_train_data
# File:  F98SUVJH processed_train_data
# File:  FBD793 processed_train_data
# File:  FC490C processed_train_data
# File:  FE9FC2 processed_train_data
# File:  FF00TEZG processed_train_data
# File:  FVKKTA8O processed_train_data
# File:  FWSGRDQ3 processed_train_data
# File:  GINQPZQC processed_train_data
# File:  GNDO9OXJ processed_train_data
# File:  GY7KNULP processed_train_data
# File:  HB00DX4L processed_train_data
# File:  HCLZSPEJ processed_train_data
# File:  HGIUTSCG processed_train_data
# File:  HGYG2DVU processed_train_data
# File:  HLJ9HHEE processed_train_data
# File:  HQCEC5NO processed_train_data
# File:  HQRATPBV processed_train_data
# File:  HTF6MVY9 processed_train_data
# File:  I0ENR9U5 processed_train_data
# File:  I6BBMPNU processed_train_data
# File:  IP6ZRIGH processed_train_data
# File:  IPTLCCCU processed_train_data
# File:  IYZYF533 processed_train_data
# File:  IZF82AX9 processed_train_data
# File:  J9EJV2S3 processed_train_data
# File:  JA4L7KWX processed_train_data
# File:  JN0T2O5I processed_train_data
# File:  JZ22O0DD processed_train_data
# File:  JZLRN9PL processed_train_data
# File:  K2VEUQT0 processed_train_data
# File:  K3X3L22Y processed_train_data
# File:  K71YYDXO processed_train_data
# File:  KOQM4YU9 processed_train_data
# File:  LV5N8XDB processed_train_data
# File:  MANO2PKR processed_train_data
# File:  MSCT8MJD processed_train_data
# File:  MZ0BI8NN processed_train_data
# File:  N6QAC84T processed_train_data
# File:  NDSTZH1I processed_train_data
# File:  NV4GY44T processed_train_data
# File:  NYFX4M8T processed_train_data
# File:  O0BECB72 processed_train_data
# File:  O0UJJVBR processed_train_data
# File:  OD9USH5H processed_train_data
# File:  OHGI1JNY processed_train_data
# File:  OIDIXPNZ processed_train_data
# File:  OKW6UUW5 processed_train_data
# File:  ORPKCFRL processed_train_data
# File:  OZYCQ769 processed_train_data
# File:  P86ZJFXK processed_train_data
# File:  P8B3IAOY processed_train_data
# File:  PWNRGOJ5 processed_train_data
# File:  PZXDACJ9 processed_train_data
# File:  QIW5EC2H processed_train_data
# File:  QNP7O8L5 processed_train_data
# File:  QOAVEFGY processed_train_data
# File:  QOL4ZIHL processed_train_data
# File:  QPFX5Z8J processed_train_data
# File:  QW492LGU processed_train_data
# File:  RYTFLT5K processed_train_data
# File:  S7DQFOD4 processed_train_data
# File:  S8UOQYBG processed_train_data
# File:  SFGT3EDA processed_train_data
# File:  SNUO09BH processed_train_data
# File:  SPPNJXB2 processed_train_data
# File:  SRVLBA90 processed_train_data
# File:  T7RPWH6N processed_train_data
# File:  TNI3UKH2 processed_train_data
# File:  TW1HGRFI processed_train_data
# File:  U1FDHL7N processed_train_data
# File:  U5L6L4Q4 processed_train_data
# File:  UURPYBGQ processed_train_data
# File:  VGUZX5R3 processed_train_data
# File:  VKWTT7F7 processed_train_data
# File:  WH6JINCM processed_train_data
# File:  WI5LYQ0H processed_train_data
# File:  WRGS0WCX processed_train_data
# File:  WRPAQPNC processed_train_data
# File:  WWBIR8H6 processed_train_data
# File:  WZL61XYS processed_train_data
# File:  X1LRVWSR processed_train_data
# File:  X23TMJ3R processed_train_data
# File:  X3RACWMT processed_train_data
# File:  XBHX2VRT processed_train_data
# File:  Y85GTOSS processed_train_data
# File:  YCOUS57M processed_train_data
# File:  Z4M8AT89 processed_train_data
# File:  ZZNW93IV processed_train_data
# File:  a407fa84d55d4072945ac61346150d03 processed_train_data
# File:  b0edc48006d5454dae3ca3e41f33e280 processed_train_data
# File:  b785d9ed72b347ae9cb0997df17258d8 processed_train_data
# File:  bd00b752eba94953882023490ade0978 processed_train_data
# File:  c36f7f977dd8442681ace9541e0177c8 processed_train_data
# File:  cb1601379dca4472b6df915185124990 processed_train_data
# File:  dffeec8c3593402bafa69b50f5920fa5 processed_train_data
# File:  f99ab21885664e20bd25d1cf848f4c5e processed_train_data
# File:  file101640_0_cols1_rows31 processed_train_data
# File:  file107572_0_cols1_rows62 processed_train_data
# File:  file110008_0_cols1_rows66 processed_train_data
# File:  file110816_0_cols1_rows40 processed_train_data
# File:  file114403_0_cols1_rows82 processed_train_data
# File:  file117573_0_cols1_rows23 processed_train_data
# File:  file119797_0_cols1_rows39 processed_train_data
# File:  file123945_0_cols1_rows17 processed_train_data
# File:  file132514_0_cols1_rows17 processed_train_data
# File:  file135940_0_cols1_rows35 processed_train_data
# File:  file137293_0_cols1_rows6 processed_train_data
# File:  file138978_0_cols1_rows83 processed_train_data
# File:  file139009_10_cols1_rows25 processed_train_data
# File:  file139009_11_cols1_rows25 processed_train_data
# File:  file139009_8_cols1_rows21 processed_train_data
# File:  file139009_9_cols1_rows21 processed_train_data
# File:  file13997_0_cols1_rows20 processed_train_data
# File:  file143181_0_cols1_rows56 processed_train_data
# File:  file145174_1_cols1_rows37 processed_train_data
# File:  file152457_0_cols1_rows7 processed_train_data
# File:  file167874_0_cols1_rows11 processed_train_data
# File:  file169346_0_cols1_rows7 processed_train_data
# File:  file171157_0_cols1_rows21 processed_train_data
# File:  file177766_0_cols1_rows83 processed_train_data
# File:  file178948_0_cols1_rows14 processed_train_data
# File:  file180087_0_cols1_rows12 processed_train_data
# File:  file181303_0_cols1_rows31 processed_train_data
# File:  file183712_0_cols1_rows19 processed_train_data
# File:  file183833_0_cols1_rows21 processed_train_data
# File:  file184323_0_cols1_rows67 processed_train_data
# File:  file187184_0_cols1_rows84 processed_train_data
# File:  file191426_0_cols1_rows31 processed_train_data
# File:  file191712_10_cols1_rows25 processed_train_data
# File:  file191712_11_cols1_rows25 processed_train_data
# File:  file191712_8_cols1_rows20 processed_train_data
# File:  file191712_9_cols1_rows20 processed_train_data
# File:  file191825_0_cols1_rows15 processed_train_data
# File:  file192085_0_cols1_rows31 processed_train_data
# File:  file195533_0_cols1_rows18 processed_train_data
# File:  file198804_0_cols1_rows39 processed_train_data
# File:  file202151_0_cols1_rows31 processed_train_data
# File:  file205708_0_cols1_rows20 processed_train_data
# File:  file208153_0_cols1_rows17 processed_train_data
# File:  file21126_1_cols1_rows86 processed_train_data
# File:  file211429_0_cols1_rows92 processed_train_data
# File:  file214477_0_cols1_rows45 processed_train_data
# File:  file215105_0_cols1_rows23 processed_train_data
# File:  file219474_11_cols1_rows22 processed_train_data
# File:  file219474_12_cols1_rows17 processed_train_data
# File:  file220036_5_cols1_rows15 processed_train_data
# File:  file221797_1_cols1_rows39 processed_train_data
# File:  file222751_0_cols1_rows13 processed_train_data
# File:  file224977_0_cols1_rows66 processed_train_data
# File:  file226691_0_cols1_rows20 processed_train_data
# File:  file228670_0_cols1_rows20 processed_train_data
# File:  file229323_0_cols1_rows7 processed_train_data
# File:  file231281_1_cols1_rows39 processed_train_data
# File:  file233008_0_cols1_rows39 processed_train_data
# File:  file234296_0_cols1_rows14 processed_train_data
# File:  file234482_0_cols1_rows68 processed_train_data
# File:  file234558_0_cols1_rows39 processed_train_data
# File:  file236160_0_cols1_rows28 processed_train_data
# File:  file239528_0_cols1_rows39 processed_train_data
# File:  file240410_0_cols1_rows60 processed_train_data
# File:  file244317_0_cols1_rows39 processed_train_data
# File:  file251103_0_cols1_rows19 processed_train_data
# File:  file256909_0_cols1_rows39 processed_train_data
# File:  file257923_0_cols1_rows84 processed_train_data
# File:  file258799_0_cols1_rows40 processed_train_data
# File:  file263556_0_cols1_rows45 processed_train_data
# File:  file265665_0_cols1_rows15 processed_train_data
# File:  file267184_0_cols1_rows22 processed_train_data
# File:  file267997_0_cols1_rows69 processed_train_data
# File:  file268478_10_cols1_rows25 processed_train_data
# File:  file268478_11_cols1_rows25 processed_train_data
# File:  file268478_8_cols1_rows20 processed_train_data
# File:  file268478_9_cols1_rows20 processed_train_data
# File:  file269877_0_cols1_rows39 processed_train_data
# File:  file270041_0_cols1_rows23 processed_train_data
# File:  file270540_4_cols1_rows17 processed_train_data
# File:  file27532_0_cols1_rows82 processed_train_data
# File:  file27532_1_cols1_rows53 processed_train_data
# File:  file277057_2_cols1_rows31 processed_train_data
# File:  file279754_0_cols1_rows19 processed_train_data
# File:  file282772_0_cols1_rows45 processed_train_data
# File:  file284898_0_cols1_rows31 processed_train_data
# File:  file285010_0_cols1_rows31 processed_train_data
# File:  file286121_14_cols1_rows65 processed_train_data
# File:  file288111_0_cols1_rows34 processed_train_data
# File:  file288293_0_cols1_rows14 processed_train_data
# File:  file288989_0_cols1_rows68 processed_train_data
# File:  file289661_0_cols1_rows6 processed_train_data
# File:  file290427_0_cols1_rows14 processed_train_data
# File:  file294473_0_cols1_rows17 processed_train_data
# File:  file304250_0_cols1_rows14 processed_train_data
# File:  file313602_0_cols1_rows78 processed_train_data
# File:  file322685_0_cols1_rows29 processed_train_data
# File:  file331278_0_cols1_rows23 processed_train_data
# File:  file334380_0_cols1_rows21 processed_train_data
# File:  file337276_0_cols1_rows31 processed_train_data
# File:  file338151_0_cols1_rows6 processed_train_data
# File:  file339783_0_cols1_rows11 processed_train_data
# File:  file344029_0_cols1_rows34 processed_train_data
# File:  file34615_2_cols1_rows24 processed_train_data
# File:  file358104_14_cols1_rows65 processed_train_data
# File:  file363812_1_cols1_rows21 processed_train_data
# File:  file365069_0_cols1_rows66 processed_train_data
# File:  file365726_0_cols1_rows13 processed_train_data
# File:  file366288_0_cols1_rows29 processed_train_data
# File:  file37584_0_cols1_rows56 processed_train_data
# File:  file37584_2_cols1_rows28 processed_train_data
# File:  file376591_0_cols1_rows19 processed_train_data
# File:  file377321_1_cols1_rows24 processed_train_data
# File:  file381801_0_cols1_rows6 processed_train_data
# File:  file383362_0_cols1_rows21 processed_train_data
# File:  file386878_0_cols1_rows23 processed_train_data
# File:  file388743_6_cols1_rows28 processed_train_data
# File:  file389632_0_cols1_rows31 processed_train_data
# File:  file391510_0_cols1_rows19 processed_train_data
# File:  file394725_0_cols1_rows24 processed_train_data
# File:  file398415_0_cols1_rows58 processed_train_data
# File:  file404549_0_cols1_rows20 processed_train_data
# File:  file405599_0_cols1_rows23 processed_train_data
# File:  file409049_0_cols1_rows46 processed_train_data
# File:  file409309_0_cols1_rows60 processed_train_data
# File:  file409727_0_cols1_rows20 processed_train_data
# File:  file411836_0_cols1_rows83 processed_train_data
# File:  file416640_0_cols1_rows6 processed_train_data
# File:  file426195_0_cols1_rows21 processed_train_data
# File:  file431384_13_cols1_rows65 processed_train_data
# File:  file431641_0_cols1_rows78 processed_train_data
# File:  file431641_1_cols1_rows62 processed_train_data
# File:  file434605_0_cols1_rows15 processed_train_data
# File:  file437154_0_cols1_rows31 processed_train_data
# File:  file439313_0_cols1_rows68 processed_train_data
# File:  file440470_0_cols1_rows26 processed_train_data
# File:  file451761_0_cols1_rows19 processed_train_data
# File:  file455767_0_cols1_rows44 processed_train_data
# File:  file456872_2_cols1_rows15 processed_train_data
# File:  file461483_0_cols1_rows39 processed_train_data
# File:  file467640_0_cols1_rows20 processed_train_data
# File:  file489155_0_cols1_rows17 processed_train_data
# File:  file489984_0_cols1_rows86 processed_train_data
# File:  file492921_0_cols1_rows39 processed_train_data
# File:  file493618_0_cols1_rows39 processed_train_data
# File:  file493682_0_cols1_rows31 processed_train_data
# File:  file494624_0_cols1_rows35 processed_train_data
# File:  file496605_1_cols1_rows39 processed_train_data
# File:  file499596_0_cols1_rows39 processed_train_data
# File:  file501300_8_cols1_rows35 processed_train_data
# File:  file503004_0_cols1_rows20 processed_train_data
# File:  file505202_0_cols1_rows6 processed_train_data
# File:  file505656_0_cols1_rows20 processed_train_data
# File:  file506769_0_cols1_rows24 processed_train_data
# File:  file51375_4_cols1_rows88 processed_train_data
# File:  file51833_0_cols1_rows68 processed_train_data
# File:  file521391_0_cols1_rows6 processed_train_data
# File:  file525125_0_cols1_rows39 processed_train_data
# File:  file531575_0_cols1_rows31 processed_train_data
# File:  file533779_0_cols1_rows7 processed_train_data
# File:  file535849_0_cols1_rows20 processed_train_data
# File:  file550665_0_cols1_rows20 processed_train_data
# File:  file558362_0_cols1_rows20 processed_train_data
# File:  file568285_0_cols1_rows15 processed_train_data
# File:  file569522_0_cols1_rows21 processed_train_data
# File:  file57149_0_cols1_rows12 processed_train_data
# File:  file60228_9_cols1_rows37 processed_train_data
# File:  file6170_0_cols1_rows24 processed_train_data
# File:  file63247_13_cols1_rows65 processed_train_data
# File:  file63591_4_cols1_rows58 processed_train_data
# File:  file64479_0_cols1_rows12 processed_train_data
# File:  file65785_1_cols1_rows57 processed_train_data
# File:  file65862_24_cols1_rows58 processed_train_data
# File:  file68383_1_cols1_rows60 processed_train_data
# File:  file69673_0_cols1_rows58 processed_train_data
# File:  file73526_0_cols1_rows46 processed_train_data
# File:  file75651_0_cols1_rows14 processed_train_data
# File:  file77529_0_cols1_rows20 processed_train_data
# File:  file812_0_cols1_rows20 processed_train_data
# File:  file82769_0_cols1_rows83 processed_train_data
# File:  file8429_0_cols1_rows83 processed_train_data
# File:  file85468_0_cols1_rows80 processed_train_data
# File:  file88377_0_cols1_rows13 processed_train_data
# File:  file95757_0_cols1_rows19 processed_train_data
# File:  file98470_1_cols1_rows55 processed_train_data
# File:  file98594_5_cols1_rows22 processed_train_data
# File:  file98594_6_cols1_rows25 processed_train_data
# File:  file99290_0_cols1_rows79 processed_train_data
# File:  file99290_1_cols1_rows63 processed_train_data
# 40235 32
# 40235 32
# 40235 32
# 40235 32

# %%
#load scaler and saved pos and neg pairs
scaler = pickle.load(open(min_max_scaler_path, 'rb'))
pos, neg = generate_dataloader(pos_output, neg_output)
# Out:
# [array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ]), array([0.76      , 1.        , 0.76      , 0.5       , 0.76      ,
#        1.        , 0.        , 0.94852424, 1.        , 0.89424682,
#        1.        ])]

# %%
## Functions to train model
class T2DV2Dataset(Dataset):
    def __init__(self, pos_features, neg_features):
        self.pos_features = pos_features
        self.neg_features = neg_features

    def __len__(self):
        return len(self.pos_features)

    def __getitem__(self, idx):
        return self.pos_features[idx], self.neg_features[idx]
    
class PairwiseNetwork(nn.Module):
    def __init__(self, hidden_size):
        super().__init__()
        # original 12x24, 24x12, 12x12, 12x1
        self.fc1 = nn.Linear(hidden_size, 2*hidden_size)
        
        self.fc2 = nn.Linear(2*hidden_size, hidden_size)
        #self.fc_x = nn.Linear(2*hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, hidden_size)
        self.fc4 = nn.Linear(hidden_size, 1)

    def forward(self, pos_features, neg_features):
        # Positive pass
        x = F.relu(self.fc1(pos_features))
        x = F.relu(self.fc2(x))
        #x = F.relu(self.fc_x(x))
        x = F.relu(self.fc3(x))
        pos_out = torch.sigmoid(self.fc4(x))

        # Negative Pass
        x = F.relu(self.fc1(neg_features))
        x = F.relu(self.fc2(x))
        #x = F.relu(self.fc_x(x))
        x = F.relu(self.fc3(x))
        neg_out = torch.sigmoid(self.fc4(x))

        return pos_out, neg_out

    def predict(self, test_feat):
        x = F.relu(self.fc1(test_feat))
        x = F.relu(self.fc2(x))
        #x = F.relu(self.fc_x(x))
        x = F.relu(self.fc3(x))
        test_out = torch.sigmoid(self.fc4(x))
        return test_out


# Pairwise Loss
class PairwiseLoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.m = 0

    def forward(self, pos_out, neg_out):
        distance = (1 - pos_out) + neg_out
        loss = torch.mean(torch.max(torch.tensor(0), distance))
        return loss
    
def infer_scores(min_max_scaler_path, input_table_path, output_table_path, model, test = 0):
    #scaler = pickle.loads(s3_1.Bucket("table-linker-datasets").Object(min_max_scaler_path).get()['Body'].read())
    #pca = pickle.load(open('pca_var_500.pkl', 'rb'))
    normalize_features = features
    sfeatures = copy.deepcopy(features)
    print(features)
    number_of_cells_top_1 = 0
    number_of_cells_total = 0
    for file in input_table_path:
        file_name = file.split('/')[-1]
        try:
            d_sample = pd.read_csv(file)
        except pd.errors.EmptyDataError:
            continue
        if not isinstance(d_sample, pd.DataFrame):
            continue
        #print(d_sample.columns)
        d_sample[normalize_features] = scaler.transform(d_sample[normalize_features])
        sorted_df = d_sample
        new_features = sfeatures
        sorted_df_features = sorted_df[sfeatures]
        arr = sorted_df_features.to_numpy()
        #test_inp = convert_to_matrix_vector(arr, list(all), pca)
        #print(arr)
        test_tensor = torch.tensor(arr).float()
        scores = model.predict(test_tensor)
        scores_list = torch.squeeze(scores).tolist()
        test_df = d_sample
        test_df[final_score_column] = scores_list
        test_df['table_id'] = file_name
        test_df['dataset_id'] = " "
        #df_input_table.append(test_df)
        num_of_cells_with_correct_top_1, num_of_cells = parse_eval_files_stats(test_df, 'siamese_prediction')
        number_of_cells_top_1 += num_of_cells_with_correct_top_1
        number_of_cells_total += num_of_cells
        if test:
            test_df.to_csv(test_predictions + file_name, index=False)
    # print(number_of_cells_top_1, number_of_cells_total, input_table_path)
    return number_of_cells_top_1 / number_of_cells_total

def train(args):
    if torch.cuda.is_available():
        device = torch.device('cuda')

    else:
        device = torch.device('cpu')
    device = torch.device('cpu')
    train_dataset = T2DV2Dataset(pos, neg)
    train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE)
    criterion = PairwiseLoss()
    EPOCHS = args.num_epochs
    model = PairwiseNetwork(len(pos[0])).to(device=device)
    optimizer = Adam(model.parameters(), lr=args.lr)
    # scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.01)
    top1_max_prec = 0
    for epoch in range(EPOCHS):
        train_epoch_loss = 0
        avg_loss = 0
        model.train()
        for bid_1, batch_1 in tqdm(enumerate(train_dataloader), position=0, leave=True):
            # print("--------------")
            positive_feat = torch.tensor(batch_1[0].float())
            negative_feat = torch.tensor(batch_1[1].float())
            optimizer.zero_grad()
            # print(positive_feat.is_cuda, negative_feat.is_cuda)
            pos_out, neg_out = model(positive_feat, negative_feat)
            ##print(pos_out.is_cuda, neg_out.is_cuda, model.is_cuda)
            loss = criterion(pos_out, neg_out)
            # print(loss.is_cuda)
            loss.backward()
            optimizer.step()
            train_epoch_loss += loss
        avg_loss = train_epoch_loss / bid_1
        # scheduler.step()
        # Evaluation
        model.eval()
        print("Running on dev files")
        top1_precision = infer_scores(args.min_max_scaler_path, args.dev_path, args.dev_output, model)
        # eval_data = merge_eval_files(args.dev_output)
        # res, candidate_eval_data = parse_eval_files_stats(eval_data, final_score_column)
        # top1_precision = res['num_tasks_with_model_score_top_one_accurate'] / res['num_tasks_with_gt']
        if top1_precision > top1_max_prec:
            #copy_files(args.dev_output, dev_predictions)
            top1_max_prec = top1_precision
            model_save_name = 'top1_{}_epoch_{}_loss_{}_batch_size_{}_learning_rate_{}.pth'.format(top1_max_prec, epoch,
                                                                                                   avg_loss, BATCH_SIZE,
                                                                                                   LEARNING_RATE)
            best_model_path = args.model_save_path + model_save_name
            torch.save(model.state_dict(), best_model_path)
            print("Running on test files")
            print("Test Dataset", infer_scores(args.min_max_scaler_path, preprocessed_test_files, args.dev_output, model, test = 1))
        #s3_1.Bucket('table-linker-datasets').upload_file('/tmp/'+model_save_name, best_model_path)

        print("Epoch {}, Avg Loss is {}, epoch top1 {}, max top1 {}".format(epoch, avg_loss, top1_precision,
                                                                            top1_max_prec))
    return best_model_path, model
def parse_eval_files_stats(eval_data, method):
    res = {}
    candidate_eval_data = eval_data.groupby(['table_id', 'column', 'row'])['table_id'].count().reset_index(name="count")
    res['num_tasks_with_gt'] = len(eval_data[pd.notna(eval_data['GT_kg_id'])].groupby(['table_id', 'column', 'row']))
    num_tasks_with_model_score_top_one_accurate = []
    num_tasks_with_model_score_top_five_accurate = []
    num_tasks_with_model_score_top_ten_accurate = []
    has_gt_list = []
    has_gt_in_candidate = []
    for i, row in candidate_eval_data.iterrows():
        table_id, row_idx, col_idx = row['table_id'], row['row'], row['column']
        c_e_data = eval_data[
            (eval_data['table_id'] == table_id) & (eval_data['row'] == row_idx) & (eval_data['column'] == col_idx)]
        assert len(c_e_data) > 0
        if np.nan not in set(c_e_data['GT_kg_id']):
            has_gt_list.append(1)
        else:
            has_gt_list.append(0)
        if 1 in set(c_e_data['evaluation_label']):
            has_gt_in_candidate.append(1)
        else:
            has_gt_in_candidate.append(0)

        # rank on model score
        s_data = c_e_data.sort_values(by=[method], ascending=False)
        if s_data.iloc[0]['evaluation_label'] == 1:
            num_tasks_with_model_score_top_one_accurate.append(1)
        else:
            num_tasks_with_model_score_top_one_accurate.append(0)

    res['num_tasks_with_model_score_top_one_accurate'] = sum(num_tasks_with_model_score_top_one_accurate)
    # print(sum(num_tasks_with_model_score_top_one_accurate))
    return res['num_tasks_with_model_score_top_one_accurate'], res['num_tasks_with_gt']

# %%
train_dataset = T2DV2Dataset(pos, neg)
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE)

# %%
LEARNING_RATE = 0.00001
training_args = Namespace(num_epochs=12, lr=LEARNING_RATE, positive_feat_path=pos_output, negative_feat_path=neg_output,
                         dev_path=preprocessed_dev_files, dev_output=dev_predictions,
                         model_save_path=model_save_path, min_max_scaler_path=min_max_scaler_path)
best_model_path, model = train(training_args)
# Out:
# 0it [00:00, ?it/s]<ipython-input-26-76f007b20d24>:122: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-26-76f007b20d24>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 40223it [01:17, 519.92it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Running on test files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.9350158982511924
# Epoch 0, Avg Loss is 0.4894122779369354, epoch top1 0.7346238199675789, max top1 0.7346238199675789
# 0it [00:00, ?it/s]<ipython-input-26-76f007b20d24>:122: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-26-76f007b20d24>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 40223it [01:15, 530.72it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Running on test files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.9436936936936937
# Epoch 1, Avg Loss is 0.1882401406764984, epoch top1 0.7459712024411176, max top1 0.7459712024411176
# 0it [00:00, ?it/s]<ipython-input-26-76f007b20d24>:122: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-26-76f007b20d24>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 40223it [01:17, 520.34it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Running on test files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.9446873343932167
# Epoch 2, Avg Loss is 0.17436616122722626, epoch top1 0.7496900924954706, max top1 0.7496900924954706
# 0it [00:00, ?it/s]<ipython-input-26-76f007b20d24>:122: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-26-76f007b20d24>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 40223it [01:21, 495.32it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Running on test files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.9448198198198198
# Epoch 3, Avg Loss is 0.1686679720878601, epoch top1 0.7508343663583484, max top1 0.7508343663583484
# 0it [00:00, ?it/s]<ipython-input-26-76f007b20d24>:122: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-26-76f007b20d24>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 40223it [01:26, 466.86it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Running on test files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.9455484896661367
# Epoch 4, Avg Loss is 0.16560165584087372, epoch top1 0.7521693525317059, max top1 0.7521693525317059
# 0it [00:00, ?it/s]<ipython-input-26-76f007b20d24>:122: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-26-76f007b20d24>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 40223it [01:19, 503.71it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Running on test files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.9453497615262321
# Epoch 5, Avg Loss is 0.16368302702903748, epoch top1 0.7524554209974254, max top1 0.7524554209974254
# 0it [00:00, ?it/s]<ipython-input-26-76f007b20d24>:122: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-26-76f007b20d24>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 40223it [01:20, 501.89it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 0it [00:00, ?it/s]<ipython-input-26-76f007b20d24>:122: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-26-76f007b20d24>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 46it [00:00, 454.76it/s]
# Epoch 6, Avg Loss is 0.16233503818511963, epoch top1 0.7523600648421855, max top1 0.7524554209974254
# 40223it [01:17, 518.80it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Running on test files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.9426338102808691
# Epoch 7, Avg Loss is 0.16134411096572876, epoch top1 0.752646133307905, max top1 0.752646133307905
# 0it [00:00, ?it/s]<ipython-input-26-76f007b20d24>:122: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-26-76f007b20d24>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 40223it [01:17, 520.88it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Running on test files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Test Dataset 0.9421701112877583
# Epoch 8, Avg Loss is 0.16051961481571198, epoch top1 0.7540764756365024, max top1 0.7540764756365024
# 0it [00:00, ?it/s]<ipython-input-26-76f007b20d24>:122: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-26-76f007b20d24>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 40223it [01:15, 529.97it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (29,30,31,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Epoch 9, Avg Loss is 0.15971888601779938, epoch top1 0.7525507771526652, max top1 0.7540764756365024
# 0it [00:00, ?it/s]<ipython-input-26-76f007b20d24>:122: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch_1[0].float())
# <ipython-input-26-76f007b20d24>:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch_1[1].float())
# 40223it [01:17, 521.08it/s]
# Running on dev files
# ['monge_elkan', 'monge_elkan_aliases', 'jaro_winkler', 'levenshtein', 'prefix_monge_elkan_similarity', 'singleton', 'context_score_3', 'pgt_centroid_score', 'pgt_class_count_tf_idf_score', 'pgt_property_count_tf_idf_score', 'num_occurences']
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (27,28,29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-c2c2b5a06e70> in <module>
#       3                          dev_path=preprocessed_dev_files, dev_output=dev_predictions,
#       4                          model_save_path=model_save_path, min_max_scaler_path=min_max_scaler_path)
# ----> 5 best_model_path, model = train(training_args)
#
# <ipython-input-26-76f007b20d24> in train(args)
#     136         model.eval()
#     137         print("Running on dev files")
# --> 138         top1_precision = infer_scores(args.min_max_scaler_path, args.dev_path, args.dev_output, model)
#     139         # eval_data = merge_eval_files(args.dev_output)
#     140         # res, candidate_eval_data = parse_eval_files_stats(eval_data, final_score_column)
#
# <ipython-input-26-76f007b20d24> in infer_scores(min_max_scaler_path, input_table_path, output_table_path, model, test)
#      91         test_df['dataset_id'] = " "
#      92         #df_input_table.append(test_df)
# ---> 93         num_of_cells_with_correct_top_1, num_of_cells = parse_eval_files_stats(test_df, 'siamese_prediction')
#      94         number_of_cells_top_1 += num_of_cells_with_correct_top_1
#      95         number_of_cells_total += num_of_cells
#
# <ipython-input-26-76f007b20d24> in parse_eval_files_stats(eval_data, method)
#     180         # rank on model score
#     181         s_data = c_e_data.sort_values(by=[method], ascending=False)
# --> 182         if s_data.iloc[0]['evaluation_label'] == 1:
#     183             num_tasks_with_model_score_top_one_accurate.append(1)
#     184         else:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     892
#     893             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 894             return self._getitem_axis(maybe_callable, axis=axis)
#     895
#     896     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1500             self._validate_integer(key, axis)
#    1501
# -> 1502             return self.obj._ixs(key, axis=axis)
#    1503
#    1504     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    2952                 new_values,
#    2953                 index=self.columns,
# -> 2954                 name=self.index[i],
#    2955                 dtype=new_values.dtype,
#    2956             )
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4291         # not overloaded intentionally.
#    4292         getitem = self._data.__getitem__
# -> 4293         promote = self._shallow_copy
#    4294
#    4295         if is_scalar(key):
#
# KeyboardInterrupt:

# %%
def dev_prediction(dev_feature_path, dev_predictions_top_k, saved_model, output_column, min_max_scaler_path, k, dev_predictions_metrics):
    print(dev_feature_path)
    df_list = []
    for file in glob.glob(dev_feature_path + '/*.csv'):
        #print(file)
        filename = file.split("/")[-1]
        if filename == '13BLTPJD.csv':
            continue
        #print(filename)
        dev_output = f"{dev_predictions_top_k}/{filename}"

        df = pd.read_csv(file)
        df = df[df['evaluation_label'] != '[]']
        df.to_csv(file, index=False)
        feature_str =  ",".join(features)
        if os.path.getsize(file) == 0:
            continue

        
        # location where the output generated by the predictions wil be stored.
        
        #print(dev_output)
        #print(os.path.exists(dev_predictions_top_k))
        #print(file, output_column, feature_str, saved_model, min_max_scaler_path, final_score_column, k, dev-output)
        k = '5'
        #print(output_column, k, dev_output, file)
        if not os.path.exists(dev_output):
            # !tl predict-using-model $file -o $output_column \
                --features $feature_str \
                --ranking-model $saved_model \
                --normalization-factor $min_max_scaler_path \
                / get-kg-links -c $output_column -k $k --k-rows \
                > $dev_output
        filename = file.split("/")[-1]
        #print(filename)
        if os.path.getsize(file) == 0:
                    continue
        k_2 = '1'
        score_column = output_column
        dev_metrics_file = f"{dev_predictions_metrics}/{filename}"
        #print("__________", dev_metrics_file)
        if not os.path.exists(dev_metrics_file):
            # !tl metrics $dev_output -k $k_2 -c $score_column --tag $filename> $dev_metrics_file
        df_list.append(pd.read_csv(dev_metrics_file))

    return df_list
        
def add_color(dev_predictions_top_k, dev_colorized_path, score_column, k=5):
    for file in glob.glob(dev_predictions_top_k + '/*.csv'):
        filename = file.split("/")[-1]
        print(filename)
        if os.path.getsize(file) == 0:
                    continue
                
        dev_color_file = f"{dev_colorized_path}/{filename[:-4]}.xlsx"
        # !tl add-color $file -c "$score_column,evaluation_label" -k $k --output $dev_color_file
def metrics(column, file_path=None, df=None, k: int = 1, tag=""):
    """
    computes the precision, recall and f1 score for the tl pipeline.
    Args:
        column: column with ranking score
        file_path: input file path
        df: or input dataframe
        k: calculate recall at top k candidates
        tag: a tag to use in the output file to identify the results of running the given pipeline
    Returns:
    """
    if file_path is None and df is None:
        raise RequiredInputParameterMissingException(
            'One of the input parameters is required: {} or {}'.format('file_path', 'df'))

    if file_path:
        df = read_csv(file_path, dtype=object)

    # remove duplicate candidates if exist
    df = normalize_scores.drop_duplicate("kg_id", [column], df=df)

    # replace na to 0.0
    df[column] = df[column].astype(float).fillna(0.0)
    df['max_score'] = df.groupby(by=['column', 'row'])[column].transform(max)

    # relevant df
    rdf = df[df['evaluation_label'].astype(float) != 0.0]

    col_grouped = rdf.groupby(by=['column'])
    results = []
    for col, cgdf in col_grouped:
        # true positive for precision at 1
        tp_ps = []

        # true positive for recall at k
        tp_rs = defaultdict(list)
        grouped = cgdf.groupby(by=['row'])
        n = len(grouped)
        for key, gdf in grouped:
            gdf = gdf.sort_values(by=[column, 'kg_id'], ascending=[False, True]).reset_index()

            for i, row in gdf.iterrows():
                if float(row['evaluation_label']) == 1 and row[column] == row['max_score']:
                    tp_ps.append(key)

                # this df is sorted by score, so highest ranked candidate is rank 1 and so on...
                rank = i + 1
                if rank <= k and (row['evaluation_label'] == '1' or row['evaluation_label'] == 1.0):
                    tp_rs[k].append(key)

        precision = float(len(tp_ps)) / float(n)
        recall = {k: float(len(each_tp_rs)) / float(n) for k, each_tp_rs in tp_rs.items()}
        # sort as k value increasing
        recall = {k: v for k, v in sorted(recall.items(), key=lambda x: x[0])}

        for _k, each_recall in recall.items():
            if precision == 0 and each_recall == 0:
                f1_score = 0.0
            else:
                f1_score = (2 * precision * each_recall) / (precision + each_recall)
            results.append({"k": _k,
                            'f1': f1_score,
                            'precision': precision,
                            'recall': each_recall,
                            'column': col,
                            'tag': tag})

    output_df = pd.DataFrame(results)
    return output_df
def compute_metrics(dev_predictions_top_k, dev_predictions_metrics, score_column, k=1):
    df_list = []
    for file in glob.glob(dev_predictions_top_k + '/*.csv'):
        #print(file)
        #print(df)

        filename = file.split("/")[-1]
        print(filename)
        if os.path.getsize(file) == 0:
                    continue
                
        dev_metrics_file = f"{dev_predictions_metrics}/{filename}"
        # !tl metrics $file -k $k -c $score_column --tag $filename> $dev_metrics_file
        df_list.append(pd.read_csv(dev_metrics_file))
    return pd.concat(df_list)

# %%
best_model_path = f"{model_save_path}/top1_0.7398684085057691_epoch_9_loss_0.27942124009132385_batch_size_32_learning_rate_1e-06.pth"

# %%
# Getting the testing metrics
df_list = dev_prediction(preprocessed_test_files_path, result_predictions_location, best_model_path, 'siamese_prediction', min_max_scaler_path, 5, result_metrics_location)
#dev_prediction(main_dataset_location+test_dataset+dataset_folder_location, result_predictions_location, model_path, "siamese_prediction", min_max_scaler_path, k=5)
# Out:
# Experiment/Experiment_test_semtab_feature_addition/processed_test_data/
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//03XJOJ15.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//06ZS1QBE.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//080HU8A5.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//090EELY2.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//06UFHM3B.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0DVQGVUW.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0HFY1TOW.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0U3WMR09.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0CHQAATH.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0KL64BZL.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0LGYY0Y7.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//15S9J1SE.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0UJRG5XA.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0QWF60VG.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0WBTX8LY.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1A51CWBN.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//15Z7HD0M.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//18PQGWE2.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//15ULGJXA.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1FIFDPBT.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1FPJTMCX.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1JGP7FA0.csv
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (29,30,31,36,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1DT331RM.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1JV6896P.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1I3AJ8QT.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1JMXOUP0.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//243JI1XC.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1H6S7TGO.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1XPHI0P2.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//25KTY2D9.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2J3MZCRD.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1T2D8C5C.csv
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1ZFRQBQS.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//25EPRHUJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//253OSZNL.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//23NFMDP0.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//27V1TQHW.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2CPISXSF.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//29AXQS5A.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2BATTV6X.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2I24Y64Q.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2LC2LBG1.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2ZYEX9U9.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2FXR6BX7.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2QM0QJW9.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2TG5KMPI.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2S72D3R9.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//39DC3Z7N.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2RTA5JIB.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2YCSL7OH.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2Z7W9245.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2ZCUZYY9.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//328N1USF.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3L4TR8X5.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//340JKVHO.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3KX6UPPG.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3K0JGMP1.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3O0C4D3O.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3NCTWO03.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//471ODBDH.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3WXFYEAX.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3R0OGDXK.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3S4OOVHT.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3TKOQZJ7.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3QZT9O12.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4FXN1RZ3.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//42CSV98Q.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//471N0AUD.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4722C9EQ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4ENVC6F0.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4ANNOIVH.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4O1BS5W9.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4E99I3P7.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//49XGWHEN.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4N6X42PJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4UUFDEP4.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4FG1UN8O.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4I7A5GID.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//59CFTDPL.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4LFJR3YN.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4WN91IQN.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4Q6FAT24.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4L16JP9T.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4YBOUF9V.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//519M624G.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//50ULP1KH.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//50NWQJ1T.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//568P9F4E.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5BD6VKB3.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5BVL4YJS.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5MMHOLUI.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5VD9H3AD.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5BEY9DAJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5GS30C2C.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5NTTT408.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5S8PITYQ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5TJI4XTK.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0JSF530F.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//00YF468U.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2BLFNACC.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3CJEDV9F.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3C74M7HU.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//30KYZ3HO.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//51BN46AU.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3OAZEVOY.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0VTG406B.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//53OUTCE4.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//06BZ6E4W.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4XIXYJZJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3FRIAFQG.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//44NDHWR1.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0Z7HR2PY.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//19VR20Q8.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0XWQ7DA6.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0G9YPQC0.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2OJXQ9F3.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4I995NNQ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1TRSZPVI.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3AK02Q9B.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1GOKLC0K.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1K47VLGF.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//09Z268Z7.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//21P58N2X.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1O72GQD8.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3540Y3D5.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1XK9O8CF.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3DRSAGO5.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//36KH7GH7.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2FHCJAMA.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3UP2SR30.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//59JNC864.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4QTU5MYM.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0D1JRXQD.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//239AZL33.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5739HKRB.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//28D7RBJT.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0HZG8QGJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1SEMN3SZ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5QDDFGBJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//42WEUQ95.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0P8H49LQ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1NS33P8C.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//12MLK2A7.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//19NE0FCU.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3S6WON79.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//085QNFGZ.csv
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0VC79Y6X.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5D3I2S1N.csv
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (42,43,44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1JCXMKCK.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//00UQHNO3.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4C37XZHJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1J4YRLOY.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3IBPLURT.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5CG871YQ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3T93HF0D.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0VDX10IJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4SOL8H0M.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0BY9CFLK.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3HLRFWSX.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//48PAQE6M.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2XEP26CX.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//59W76Q0Y.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1GUVMENF.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//24OGNVVP.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1T9NKN9B.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2ZLDMP9R.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0LZ0M8W4.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4DC5O5I4.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3290T9NG.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5894JWA5.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0MYK9SQC.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4MGX23BZ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1YPLVLS9.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2PKG4E2V.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3M5QXPWN.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//14DACNEL.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//58E7A5WL.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1ZX2DCW7.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4VAYQOG0.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//45D6VIRT.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2WRDGDBJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4DPRZWVL.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3FQ85RUH.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4IJHCIR9.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//42BKS5LP.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1FXQQ1RM.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1XIWQBSF.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2P4BZPW1.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1375IHBW.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5KZVO2UP.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3HZEPYNC.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2OYAB7YM.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5PJ0EF0X.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5N8AUSXE.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5PKTGQ6Q.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5TWQ98LE.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5TXLGRXA.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5W6MRY0W.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//11VNNTDS.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0ADP8WGU.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0P4Y07PN.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//302H92MV.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//174Q7GKD.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2P3KJ1P0.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//26CIDK81.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//08XTIUJQ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//17DA0MJ4.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3RC46CRC.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//03Q5JG9I.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1STAURLW.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0ZXPJXH4.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0M7R2JUU.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//20PYU63R.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//15CM535P.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1D0TLL3P.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0B8EGHVB.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//15HDRE87.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0LF7RI6N.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0KWK2FSC.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3IALBWVT.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0CETTKTA.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0RWHW0S0.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//29D1VZHF.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0L4YDT86.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2BRG4KEL.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0ZZFENJS.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1T91CHXV.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3J5ABW9E.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//24VU5BR7.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//24VD82I7.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//24HLK9BD.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1XV2X3XE.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//32DWSB26.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1PTL0CX1.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1LI468T0.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//289YGN9G.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//10WA15QW.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3EL4J49W.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//16F08KC4.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1AXBOBYJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0TQXSY28.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3CSAH6ZY.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//32GFE6D8.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0A4KYJH5.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1QGWWYAF.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//18T4PJWW.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2E6QBLCA.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0JSE9VIO.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2QFYH2N9.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0DHFD9QY.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0EH4XC4H.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2IQQE9DB.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//27BGOKZ7.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1SWM4IDV.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0DS28PUJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1UBAHGEU.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//19WCLMKZ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3CUK6D56.csv
# /nas/home/hrathod/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (44,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0Z8LKW3C.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//042AKDN1.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//09DZVIPV.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0UX45YZS.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1E1WKZOC.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0VGKU21T.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//01E31BCQ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//00ECUL14.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//18TCX9AJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1FF0TRWQ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//28Y667AR.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//263P426L.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//258AFYQJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1JY71MSY.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2AQ0VUOP.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3B54GZSX.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1FP8LYOS.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//39W7XXTI.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2JN1R1VW.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2QS5IM8T.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1DQVRVUL.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0BM19RVO.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3CLS11K2.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2OQR5KK1.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//39HQAJDE.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//04A3K0PO.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2FSRG0OI.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3TZ2D9V5.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2VWPPCQM.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1CS2NQUR.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//36LCWPLR.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0IUSS6UH.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1TQSKB2E.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//20ISN4OJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2TUG0XHN.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//1U6PF4FY.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2ZLGXNTV.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//0FQOOJPU.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2XDZM14F.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//2TGNKH1P.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//19FQNTBF.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3IB64ASX.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3JNFST2K.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3PSDVWZR.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3T54D76A.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3PZX8I05.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//40DGQ0R6.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3MFTI3Y1.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3MKMD5TW.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3OCW1LDZ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//43NKPCQ8.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3SQ9UAK1.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//41UF0D20.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//46HT6F8E.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//3WIJWVTF.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4KDMZHXJ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4G8G7N8W.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4DM4KN9O.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//479O847V.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//49K301SA.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//48BAS22X.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4NVYEVEQ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4IB27COT.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4PKEEJU4.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4RB6CKKQ.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4VL4BFPM.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4V4O0CTS.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4P9QJEV9.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//56CDHMVN.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5BGVRHI5.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5FMSUKCH.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4UZA5UWB.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//54SEC9F3.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5ECFP78V.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//4ZZG4HMD.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5G4M4L5W.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5IXA0RAI.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5J25NATF.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5E9CSACP.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5Q5RASS8.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5IKCI9Z4.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5P2SOXGW.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5T891IJ9.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5SB78VPX.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5NMYKF77.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5WFYRRY7.csv
# __________ Experiment/Experiment_test_semtab_feature_addition/results//test_predictions_metrics//5WA7NENC.csv

# %%
metrics_df  = pd.concat(df_list)
metrics_df
# Out:
#     k    f1  precision  recall  column  num_cells           tag
# 0   1  1.00       1.00    1.00       0         20  03XJOJ15.csv
# 1   1  1.00       1.00    1.00       1         20  03XJOJ15.csv
# 0   1  0.60       0.60    0.60       0         20  06ZS1QBE.csv
# 0   1  1.00       1.00    1.00       0         20  080HU8A5.csv
# 0   1  1.00       1.00    1.00       0         20  090EELY2.csv
# .. ..   ...        ...     ...     ...        ...           ...
# 2   1  1.00       1.00    1.00       2         20  5NMYKF77.csv
# 3   1  1.00       1.00    1.00       3         20  5NMYKF77.csv
# 0   1  1.00       1.00    1.00       0         20  5WFYRRY7.csv
# 0   1  0.95       0.95    0.95       0         20  5WA7NENC.csv
# 1   1  0.80       0.80    0.80       2         20  5WA7NENC.csv
#
# [718 rows x 7 columns]

# %%
# Column Metrics
metrics_df['precision'].mean(), metrics_df['recall'].mean(), metrics_df['f1'].mean()
# Out:
# (0.9518227758230172, 0.9518227758230172, 0.9518227758230172)

# %%
# Cell Metrics
sum(metrics_df['precision']*metrics_df['num_cells']) / sum(metrics_df['num_cells']), sum(metrics_df['recall']*metrics_df['num_cells']) / sum(metrics_df['num_cells']), 2*(sum(metrics_df['precision']*metrics_df['num_cells']) / sum(metrics_df['num_cells']))*(sum(metrics_df['recall']*metrics_df['num_cells']) / sum(metrics_df['num_cells']))/(sum(metrics_df['precision']*metrics_df['num_cells']) / sum(metrics_df['num_cells']) + sum(metrics_df['recall']*metrics_df['num_cells']) / sum(metrics_df['num_cells']))
# Out:
# (0.94822328294882, 0.94822328294882, 0.94822328294882)
