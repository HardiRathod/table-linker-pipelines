# %% [markdown]
# !$kypher -i author -i nih_author -i inv -i item -i coor -i label -i project\
# --match 'author: (cluster)-[]->(qnode), nih_author:(qnihauthor)-[]->(qnode), inv:(project)-[]->(qnihauthor), \
#         item:(qnode)-[:P108]->(org_node), label:(org_node)-[]->(org_name),label:(qnode)-[]->(author_name), \
#         coor:(org_node)-[:P625]->(organization_coor)'\
# --opt 'project: (project)-[:PNIHcost]->(cost)' \
# --return 'cluster, author_name, org_name,project, organization_coor,cost' \
# --limit 50# Generating Useful Wikidata Files
#
# This notebook generates files that contain derived data that is useful in many applications. The input to the notebook is the full Wikidata or a subset of Wikidata. It also works for arbutrary KGs as long as they follow the representation requirements of Wikidata:
#
# - the *instance of* relation is represented using the `P31` property
# - the *subclass of* relation is represented using the `P279` property
# - all properties declare a datatype, and the data types must be one of the datatypes in Wikidata.
#
# Inputs:
#
# - `claims_file`: contains all statements, which consist of edges `node1/label/node2` where `label` is a property in Wikidata (e.g., sitelinks, labels, aliases and description are not in the claims file.
# - `item_file`: the subset of the `claims_file` consistin of edges for property of data type `wikibase-item`
# - `label_file`, `alias_file` and `description_file` containing labels, aliases and descriptions. It is assume that these files contain the labels, aliases and descriptions of all nodes appearing in the claims file. Users may provide these files for specific languages only.
#
# Outputs:
#
# - **Instance of (P31):** `derived.P31.tsv.gz` contains all the `instance of (P31)` edges present in the claims file.
# - **Subclass of (P279):** `derived.P279.tsv.gz` contains all the `subclass of (P279)` edges present in the claims file.
# - **Is A (isa):** `derived.isa.tsv.gz` contains edges `node`isa/node2` where either `node1/P31/node2` or `node1/P279/node2`
# - **Closure of subclass of (P279star):** `derived.P279star.tsv.gz` contains edges `node1/P279star/node2` where `node2` is reachable from `node1` via zero or more hops using the `P279` property. Note that for example, `Q44/P279star/Q44`. An example when this file is useful is when you want to find all the instance of a class, including instances of subclasses of the given class.
# - **In/out degrees:** `metadata.out_degree.tsv.gz` contains the out degree of every node, and `metadata.in_degree.tsv.gz` contains the in degree of every node.
# - **Pagerank:** outputs page rank on the directed graph in `metadata.pagerank.directed.tsv.gz` and page rank of the directed graph in `metadata.pagerank.undirected.tsv.gz`.

# %% [markdown]
# ### Batch Invocation
# Example batch command. The second argument is a notebook where the output will be stored. You can load it to see progress.
#
# ```
# papermill Wikidata\ Useful\ Files.ipynb useful-files.out.ipynb \
# -p claims_file /Volumes/GoogleDrive/Shared\ drives/KGTK-public-graphs/wikidata-20200803-v4/all.tsv.gz \
# -p label_file /Volumes/GoogleDrive/Shared\ drives/KGTK-public-graphs/wikidata-20200803-v4/part.label.en.tsv.gz \
# -p item_file /Volumes/GoogleDrive/Shared\ drives/KGTK-public-graphs/wikidata-20200803-v4/part.wikibase-item.tsv.gz \
# -p property_item_file = /Volumes/GoogleDrive/Shared\ drives/KGTK-public-graphs/wikidata-20200803-v4/part.property.wikibase-item.tsv.gz \
# -p output_path <local folder> \
# -p output_folder useful_files_v4 \
# -p temp_folder temp.useful_files_v4 \
# -p delete_database no
# -p languages es,ru,zh-cn
# ```

# %% [markdown]
# Setup environment

# %%
# !kgtk
# Out:
# usage: kgtk [options] command [ / command]*

# %%
# Parameters

# Folder on local machine where to create the output and temporary folders
output_path = "/Users/grantxie/Downloads/NIH"

# The names of the output and temporary folders
output_folder = "useful_wikidata_files"
temp_folder = "temp.useful_wikidata_files"

# The location of input files
wiki_root_folder = "/Users/grantxie/Downloads/NIH/"
claims_file = "claims.tsv.gz"
label_file = "labels.en.tsv.gz"
alias_file = "aliases.en.tsv.gz"
description_file = "descriptions.en.tsv.gz"
item_file = "claims.wikibase-item.tsv.gz"

label_all = "labels.tsv.gz"
alias_all = "aliases.tsv.gz"
description_all = "descriptions.tsv.gz"

# Location of the cache database for kypher
cache_path = "/Users/grantxie/Downloads/NIH/temp.useful_wikidata_files"

# Whether to delete the cache database
delete_database = False

# Whether to compute pagerank as it may not run on the laptop
compute_pagerank = True
languages = 'ru,es,zh-cn,de,it,nl,pl,fr,pt,sv'

# %%
languages = languages.split(',')

# %%
import io
import os
import subprocess
import sys

import numpy as np
import pandas as pd

import altair as alt

# %% [markdown]
# ## Set up environment and folders to store the files
#
# - `OUT` folder where the output files go
# - `TEMP` folder to keep temporary files , including the database
# - `kgtk` shortcut to invoke the kgtk software
# - `kypher` shortcut to invoke `kgtk query with the cache database
# - `CLAIMS` the `all.tsv` file of wikidata that contains all edges except label/alias/description
# - `LABELS` the file with the English labels
# - `ITEMS` the wikibase-item file (currently does not include node1 that are properties so for now we need the net file
# - `STORE` location of the cache file

# %%
if cache_path:
    os.environ['STORE'] = "{}/wikidata.sqlite3.db".format(cache_path)
else:
    os.environ['STORE'] = "{}/{}/wikidata.sqlite3.db".format(output_path, temp_folder)
os.environ['OUT'] = "{}/{}".format(output_path, output_folder)
os.environ['TEMP'] = "{}/{}".format(output_path, temp_folder)
os.environ['kgtk'] = "kgtk"
os.environ['kgtk'] = "kgtk --debug"
os.environ['kypher'] = "kgtk --debug query --graph-cache " + os.environ['STORE']
os.environ['CLAIMS'] = wiki_root_folder + claims_file
os.environ['LABELS'] = wiki_root_folder + label_file
os.environ['ALIASES'] = wiki_root_folder + alias_file
os.environ['DESCRIPTIONS'] = wiki_root_folder + description_file
os.environ['ITEMS'] = wiki_root_folder + item_file

# %% [markdown]
# Echo the variables to see if they are all set correctly

# %%
# !echo $OUT
# !echo $TEMP
# !echo $kgtk
# !echo $kypher
# !echo $CLAIMS
# !echo $LABELS
# !echo $ALIASES
# !echo $LABELS
# !echo $DESCRIPTIONSa
# !echo $STORE
# !alias col="column -t -s $'\t' "
# Out:
# /Users/grantxie/Downloads/NIH/useful_wikidata_files
# /Users/grantxie/Downloads/NIH/temp.useful_wikidata_files
# kgtk --debug
# kgtk --debug query --graph-cache /Users/grantxie/Downloads/NIH/temp.useful_wikidata_files/wikidata.sqlite3.db
# /Users/grantxie/Downloads/NIH/claims.tsv.gz
# /Users/grantxie/Downloads/NIH/labels.en.tsv.gz
# /Users/grantxie/Downloads/NIH/aliases.en.tsv.gz
# /Users/grantxie/Downloads/NIH/labels.en.tsv.gz
#
# /Users/grantxie/Downloads/NIH/temp.useful_wikidata_files/wikidata.sqlite3.db

# %% [markdown]
# Go to the output directory and create the subfolders for the output files and the temporary files

# %%
cd $output_path
# Out:
# /Users/grantxie/Downloads/NIH

# %%
# !mkdir -p $OUT
# !mkdir -p $TEMP

# %% [markdown]
# Clean up the output and temp folders before we start

# %%
# !rm $OUT/*.tsv $OUT/*.tsv.gz
# !rm $TEMP/*.tsv $TEMP/*.tsv.gz

# %%
if delete_database:
    print("Deleteddatabase") 
    # !rm $STORE

# %%
# !ls -l $OUT
# !ls $TEMP
# !ls -l "$CLAIMS"
# !ls -l "$LABELS"
# !ls -l "$ALIASES"
# !ls -l "$LABELS"
# !ls -l "$DESCRIPTIONS"
# !ls $STORE
# Out:
# total 240088
# -rw-r--r--  1 grantxie  staff      9025 Jul 10 14:52 Untitled.ipynb
# -rw-r--r--@ 1 grantxie  staff   4125423 Jul  9 11:27 coinvestigators 2.tsv
# -rw-r--r--@ 1 grantxie  staff   4125423 Jul  9 11:56 coinvestigators 3.tsv
# -rw-r--r--@ 1 grantxie  staff   4125423 Jul  9 11:58 coinvestigators 4.tsv
# -rw-r--r--@ 1 grantxie  staff   2511815 Jul  9 12:26 coinvestigators.compact 2.tsv
# -rw-r--r--@ 1 grantxie  staff   2511815 Jul  9 11:23 coinvestigators.compact.tsv
# -rw-r--r--@ 1 grantxie  staff    780738 Jul  9 12:25 coinvestigators.compact.tsv.gz
# -rw-r--r--@ 1 grantxie  staff   4125423 Jul  9 11:24 coinvestigators.tsv
# -rw-r--r--@ 1 grantxie  staff        63 Sep 23 08:21 coinvestigators.tsv.gz
# -rw-r--r--  1 grantxie  staff      4378 Jul  8 20:46 coinvestigators11.tsv.gz
# -rw-r--r--@ 1 grantxie  staff     92690 Jul  8 21:51 nih_investigators_for_tl 2.tsv
# -rw-r--r--@ 1 grantxie  staff     92690 Jul  8 21:51 nih_investigators_for_tl 3.tsv
# -rw-r--r--@ 1 grantxie  staff     27653 Jul  8 20:45 nih_investigators_for_tl.tsv
# -rw-r--r--@ 1 grantxie  staff     10861 Jul  8 21:51 nih_investigators_for_tl.tsv.gz
# -rw-r--r--@ 1 grantxie  staff     38766 Jul  9 11:22 nih_investigators_for_tl3 10.tsv
# -rw-r--r--@ 1 grantxie  staff     27653 Jul  8 20:48 nih_investigators_for_tl3 2.tsv
# -rw-r--r--@ 1 grantxie  staff     92690 Jul  8 20:58 nih_investigators_for_tl3 3.tsv
# -rw-r--r--@ 1 grantxie  staff     92690 Jul  8 21:09 nih_investigators_for_tl3 4.tsv
# -rw-r--r--@ 1 grantxie  staff     27653 Jul  8 21:20 nih_investigators_for_tl3 5.tsv
# -rw-r--r--@ 1 grantxie  staff     27653 Jul  8 21:25 nih_investigators_for_tl3 6.tsv
# -rw-r--r--@ 1 grantxie  staff     27653 Jul  8 21:26 nih_investigators_for_tl3 7.tsv
# -rw-r--r--@ 1 grantxie  staff  32600976 Jul  9 11:21 nih_investigators_for_tl3 8.tsv
# -rw-r--r--@ 1 grantxie  staff  32600976 Jul  9 11:21 nih_investigators_for_tl3 9.tsv
# -rw-r--r--@ 1 grantxie  staff     27653 Jul  8 20:45 nih_investigators_for_tl3.tsv
# -rw-r--r--@ 1 grantxie  staff      9270 Jul  9 11:22 nih_investigators_for_tl3.tsv.gz
# -rw-r--r--  1 grantxie  staff      7660 Jul  8 21:07 nih_investigators_for_tl3_sort.tsv.gz
# -rw-r--r--@ 1 grantxie  staff    109758 Jul  8 21:28 nih_investigators_for_tl4 2.tsv
# -rw-r--r--@ 1 grantxie  staff    115718 Jul  8 21:37 nih_investigators_for_tl4 3.tsv
# -rw-r--r--@ 1 grantxie  staff     29143 Jul  8 21:42 nih_investigators_for_tl4 4.tsv
# -rw-r--r--@ 1 grantxie  staff   5875902 Jul  8 21:47 nih_investigators_for_tl4 5.tsv
# -rw-r--r--@ 1 grantxie  staff     92690 Jul  8 21:27 nih_investigators_for_tl4.tsv
# -rw-r--r--@ 1 grantxie  staff        55 Jul  8 21:48 nih_investigators_for_tl4.tsv.gz
# -rw-r--r--@ 1 grantxie  staff     92690 Jul  9 08:48 nih_investigators_for_tl_2.tsv
# -rw-r--r--@ 1 grantxie  staff     12121 Jul  8 20:48 nih_investigators_for_tl_2.tsv.gz
# -rw-r--r--@ 1 grantxie  staff     27653 Jul  8 21:55 nih_investigators_for_tl_new 2.tsv
# -rw-r--r--@ 1 grantxie  staff     27653 Jul  9 08:48 nih_investigators_for_tl_new 3.tsv
# -rw-r--r--@ 1 grantxie  staff     27653 Jul  9 12:02 nih_investigators_for_tl_new 4.tsv
# -rw-r--r--@ 1 grantxie  staff     27653 Jul  8 21:52 nih_investigators_for_tl_new.tsv
# -rw-r--r--@ 1 grantxie  staff      6931 Jul  8 21:51 nih_investigators_for_tl_new.tsv.gz
# -rw-r--r--@ 1 grantxie  staff     38766 Jul  9 12:02 nih_investigators_for_tl_no_error.tsv
# -rw-r--r--@ 1 grantxie  staff      9278 Jul  9 12:02 nih_investigators_for_tl_no_error.tsv.gz
# -rw-r--r--@ 1 grantxie  staff     38766 Jul  9 12:28 nih_investigators_for_tl_no_error_1225 2.tsv
# -rw-r--r--@ 1 grantxie  staff     38766 Jul  9 12:29 nih_investigators_for_tl_no_error_1225 3.tsv
# -rw-r--r--@ 1 grantxie  staff   6459815 Jul  9 12:32 nih_investigators_for_tl_no_error_1225 4.tsv
# -rw-r--r--@ 1 grantxie  staff   6459815 Jul  9 12:36 nih_investigators_for_tl_no_error_1225 5.tsv
# -rw-r--r--@ 1 grantxie  staff   6459815 Jul  9 13:03 nih_investigators_for_tl_no_error_1225 6.tsv
# -rw-r--r--@ 1 grantxie  staff     38766 Jul  9 12:26 nih_investigators_for_tl_no_error_1225.tsv
# -rw-r--r--@ 1 grantxie  staff   1587292 Jul  9 12:31 nih_investigators_for_tl_no_error_1225.tsv.gz
# -rw-r--r--@ 1 grantxie  staff   6459815 Jul  9 16:40 nih_investigators_for_tl_no_error_1225_7.tsv
# -rw-r--r--@ 1 grantxie  staff     92690 Jul  8 21:53 nih_investigators_for_tl_original.tsv
# -rw-r--r--@ 1 grantxie  staff     12128 Jul  8 21:52 nih_investigators_for_tl_original.tsv.gz
# -rw-r--r--  1 grantxie  staff        33 Jul 13 12:00 org.tsv.gz
# -rw-r--r--  1 grantxie  staff        57 Sep 23 08:21 test_nih.tsv.gz
# wikidata.sqlite3.db
# -rw-r--r--@ 1 grantxie  staff  3827281 Jul 26 09:40 /Users/grantxie/Downloads/NIH/claims.tsv.gz
# -rw-r--r--@ 1 grantxie  staff  2247582427 Jul 26 16:13 /Users/grantxie/Downloads/NIH/labels.en.tsv.gz
# ls: /Users/grantxie/Downloads/NIH/aliases.en.tsv.gz: No such file or directory
# -rw-r--r--@ 1 grantxie  staff  2247582427 Jul 26 16:13 /Users/grantxie/Downloads/NIH/labels.en.tsv.gz
# ls: /Users/grantxie/Downloads/NIH/descriptions.en.tsv.gz: No such file or directory
# /Users/grantxie/Downloads/NIH/temp.useful_wikidata_files/wikidata.sqlite3.db

# %% [markdown]
# ## Concatenate and load KGTK NIH Reporter files

# %%
# !$kypher \
-i "nih_person_2021_002.id.tsv" --as person \
--limit 10
# Out:
# [2021-07-08 20:43:41 sqlstore]: DROP graph data table graph_7 from person
# [2021-07-08 20:43:41 sqlstore]: IMPORT graph directly into table graph_14 from /Users/grantxie/Downloads/NIH/nih_person_2021_002.id.tsv ...
# [2021-07-08 20:43:41 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_14 AS graph_14_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2
# QNIHPER1860172-label-60f77b	QNIHPER1860172	label	"BOUCHER, RICHARD CHARLES"
# QNIHPER1860172-PNIHID-894faa	QNIHPER1860172	PNIHID	"1860172"
# QNIHPER1860172-P108-QNIHORG578206	QNIHPER1860172	P108	QNIHORG578206
# QNIHORG578206-PNIHID-a061ee	QNIHORG578206	PNIHID	578206
# QNIHPER9569267-label-f089d6	QNIHPER9569267	label	"CULLY, JEFFREY ALEXANDER"
# QNIHPER9569267-PNIHID-718775	QNIHPER9569267	PNIHID	"9569267"
# QNIHPER9569267-P108-QNIHORG481087	QNIHPER9569267	P108	QNIHORG481087
# QNIHORG481087-PNIHID-809d11	QNIHORG481087	PNIHID	481087
# QNIHPER10426588-label-dc7443	QNIHPER10426588	label	"FLETCHER, TERRI LYNN"
# QNIHPER10426588-PNIHID-fef028	QNIHPER10426588	PNIHID	"10426588"

# %%
# !$kypher \
-i "nih_investigator_2021_002.id.tsv" --as investigator \
--limit 10
# Out:
# [2021-07-08 20:43:44 sqlstore]: DROP graph data table graph_8 from investigator
# [2021-07-08 20:43:44 sqlstore]: IMPORT graph directly into table graph_15 from /Users/grantxie/Downloads/NIH/nih_investigator_2021_002.id.tsv ...
# [2021-07-08 20:43:44 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_15 AS graph_15_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2
# QNIHPRO9983961-P8329-QNIHPER1860172	QNIHPRO9983961	P8329	QNIHPER1860172
# QNIHPRO9950743-P8329-QNIHPER9569267	QNIHPRO9950743	P8329	QNIHPER9569267
# QNIHPRO9950743-P8329-QNIHPER10426588	QNIHPRO9950743	P8329	QNIHPER10426588
# QNIHPRO10121452-P8329-QNIHPER6081502	QNIHPRO10121452	P8329	QNIHPER6081502
# QNIHPRO10121452-P8329-QNIHPER16339995	QNIHPRO10121452	P8329	QNIHPER16339995
# QNIHPRO9993026-P8329-QNIHPER15644446	QNIHPRO9993026	P8329	QNIHPER15644446
# QNIHPRO10069157-P8329-QNIHPER6690859	QNIHPRO10069157	P8329	QNIHPER6690859
# QNIHPRO10140852-P8329-QNIHPER15644249	QNIHPRO10140852	P8329	QNIHPER15644249
# QNIHPRO9993926-P8329-QNIHPER9097221	QNIHPRO9993926	P8329	QNIHPER9097221
# QNIHPRO10123330-P8329-QNIHPER16386398	QNIHPRO10123330	P8329	QNIHPER16386398

# %%
# !$kypher \
-i "nih_organization_2021_002.id.tsv" --as organization \
--limit 10
# Out:
# [2021-07-08 20:43:47 sqlstore]: DROP graph data table graph_10 from organization
# [2021-07-08 20:43:47 sqlstore]: IMPORT graph directly into table graph_10 from /Users/grantxie/Downloads/NIH/nih_organization_2021_002.id.tsv ...
# [2021-07-08 20:43:47 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_10 AS graph_10_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2
# QNIHORG578206-label-49dca4	QNIHORG578206	label	"UNIV OF NORTH CAROLINA CHAPEL HILL"
# QNIHORG578206-P159string-3b31cc	QNIHORG578206	P159string	"CHAPEL HILL"
# QNIHORG578206-PNIHstate-ad9d45	QNIHORG578206	PNIHstate	"NC"
# QNIHORG578206-P17string-aeae66	QNIHORG578206	P17string	"UNITED STATES"
# QNIHORG481087-label-681560	QNIHORG481087	label	"MICHAEL E DEBAKEY VA MEDICAL CENTER"
# QNIHORG481087-P159string-db2679	QNIHORG481087	P159string	"HOUSTON"
# QNIHORG481087-PNIHstate-58dd50	QNIHORG481087	PNIHstate	"TX"
# QNIHORG481087-P17string-aeae66	QNIHORG481087	P17string	"UNITED STATES"
# QNIHORG8246001-label-69ae51	QNIHORG8246001	label	"TENNESSEE STATE DEPARTMENT OF HEALTH"
# QNIHORG8246001-P159string-d87ead	QNIHORG8246001	P159string	"NASHVILLE"

# %% [markdown]
# ## Setup coinvestigators and output tl files

# %%
# !$kypher -i investigator -i person \
--match '\
    investigator: (project)-[]->(person1), \
    investigator: (project)-[]->(person2), \
    person: (person2)-[:label]->(person2_name)' \
--where 'person1 != person2' \
--return 'distinct person1 as node1, "Pcoinvestigator_names" as label, person2_name as `node2`' \
--order-by 'person1' \
-o "$OUT"/coinvestigators.tsv.gz
# Out:
# [2021-11-14 00:24:06 query]: SQL Translation:
# ---------------------------------------------
#   SELECT DISTINCT graph_26_c1."node2" "_aLias.node1", ? "_aLias.label", graph_58_c3."node2" "_aLias.node2"
#      FROM graph_26 AS graph_26_c1, graph_26 AS graph_26_c2, graph_58 AS graph_58_c3
#      WHERE graph_58_c3."label"=?
#      AND graph_26_c1."node1"=graph_26_c2."node1"
#      AND graph_26_c2."node2"=graph_58_c3."node1"
#      AND (graph_26_c1."node2" != graph_26_c2."node2")
#      ORDER BY graph_26_c1."node2" ASC
#   PARAS: ['Pcoinvestigator_names', 'label']
# ---------------------------------------------

# %%
# !$kgtk sort --columns node1 -i "$OUT"/coinvestigators.tsv.gz \
/ compact --mode=NONE --columns node1 label --presorted True \
-o "$OUT"/coinvestigators.compact.tsv.gz

# %%
# !$kypher -i "$OUT"/coinvestigators.compact.tsv.gz -i organization -i person \
--match ' \
    coinvestigators: (person)-[]->(coinvestigator_names), \
    person: (person)-[:P108]->(organization), \
    person: (person)-[:label]->(person_name), \
    organization: (organization)-[]->(organization_name)' \
--return ' \
    person as person, \
    person_name as person_name, \
    organization as organization, \
    organization_name as organization_name, \
coinvestigator_names as coinvestigator_names' \
-o "$OUT"/nih_investigators_for_tl_original.tsv.gz
# Out:
# [2021-11-14 00:24:22 sqlstore]: DROP graph data table graph_11 from /Users/grantxie/Downloads/NIH/useful_wikidata_files/coinvestigators.compact.tsv.gz
# [2021-11-14 00:24:22 sqlstore]: IMPORT graph directly into table graph_60 from /Users/grantxie/Downloads/NIH/useful_wikidata_files/coinvestigators.compact.tsv.gz ...
# [2021-11-14 00:24:22 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_60_c1."node1" "_aLias.person", graph_58_c3."node2" "_aLias.person_name", graph_25_c4."node1" "_aLias.organization", graph_25_c4."node2" "_aLias.organization_name", graph_60_c1."node2" "_aLias.coinvestigator_names"
#      FROM graph_25 AS graph_25_c4, graph_58 AS graph_58_c2, graph_58 AS graph_58_c3, graph_60 AS graph_60_c1
#      WHERE graph_58_c2."label"=?
#      AND graph_58_c3."label"=?
#      AND graph_25_c4."node1"=graph_58_c2."node2"
#      AND graph_58_c2."node1"=graph_58_c3."node1"
#      AND graph_58_c2."node1"=graph_60_c1."node1"
#   PARAS: ['P108', 'label']
# ---------------------------------------------
# [2021-11-14 00:24:22 sqlstore]: CREATE INDEX on table graph_60 column node1 ...
# [2021-11-14 00:24:22 sqlstore]: ANALYZE INDEX on table graph_60 column node1 ...
# [2021-11-14 00:24:22 sqlstore]: CREATE INDEX on table graph_58 column node2 ...
# [2021-11-14 00:24:22 sqlstore]: ANALYZE INDEX on table graph_58 column node2 ...

# %%
# !$kypher -i "coinvestigators.compact.tsv" -i organization -i person \
--match ' \
    organization: (organization)-[:label]->(organization_name),\
    coinvestigators: (person)-[]->(coinvestigator_names), \
    person: (person)-[:P108]->(organization), \
    person: (person)-[:label]->(person_name)'\
--return ' \
    person as person, \
    person_name as person_name, \
    organization as organization, \
    organization_name as organization_name, \
    coinvestigator_names as coinvestigator_names' \
-o "$OUT"/nih_investigators_for_tl3.tsv.gz
# Out:
# [2021-11-14 00:25:14 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_13_c2."node1" "_aLias.person", graph_58_c4."node2" "_aLias.person_name", graph_58_c3."node2" "_aLias.organization", graph_25_c1."node2" "_aLias.organization_name", graph_13_c2."node2" "_aLias.coinvestigator_names"
#      FROM graph_13 AS graph_13_c2, graph_25 AS graph_25_c1, graph_58 AS graph_58_c3, graph_58 AS graph_58_c4
#      WHERE graph_25_c1."label"=?
#      AND graph_58_c3."label"=?
#      AND graph_58_c4."label"=?
#      AND graph_13_c2."node1"=graph_58_c3."node1"
#      AND graph_25_c1."node1"=graph_58_c3."node2"
#      AND graph_58_c3."node1"=graph_58_c4."node1"
#   PARAS: ['label', 'P108', 'label']
# ---------------------------------------------

# %%
# !$kypher \
-i "$CLAIMS" --as claim \
--limit 10
# Out:
# [2021-08-16 20:14:08 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_17 AS graph_17_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2	node2;wikidatatype
# P10-P1628-32b85d-7927ece6-0	P10	P1628	"http://www.w3.org/2006/vcard/ns#Video"
# P10-P1628-acf60d-b8950832-0	P10	P1628	"https://schema.org/video"
# P10-P1629-Q34508-bcc39400-0	P10	P1629	Q34508
# P10-P1659-P1651-c4068028-0	P10	P1659	P1651
# P10-P1659-P18-5e4b9c4f-0	P10	P1659	P18
# P10-P1659-P4238-d21d1ac0-0	P10	P1659	P4238
# P10-P1659-P51-86aca4c5-0	P10	P1659	P51
# P10-P1855-Q15075950-7eff6d65-0	P10	P1855	Q15075950	wikibase-item
# P10-P1855-Q69063653-c8cdb04c-0	P10	P1855	Q69063653	wikibase-item
# P10-P1855-Q7378-555592a4-0	P10	P1855	Q7378	wikibase-item

# %%
# !$kypher \
-i "$LABELS" --as label \
--limit 10
# Out:
# [2021-08-16 20:14:13 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_18 AS graph_18_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2
# P10-label-en	P10	label	'video'@en
# P1000-label-en	P1000	label	'record held'@en
# P1001-label-en	P1001	label	'applies to jurisdiction'@en
# P1002-label-en	P1002	label	'engine configuration'@en
# P1003-label-en	P1003	label	'National Library of Romania ID'@en
# P1004-label-en	P1004	label	'MusicBrainz place ID'@en
# P1005-label-en	P1005	label	'Portuguese National Library ID'@en
# P1006-label-en	P1006	label	'Nationale Thesaurus voor Auteurs ID'@en
# P1007-label-en	P1007	label	'Lattes Platform number'@en
# P101-label-en	P101	label	'field of work'@en

# %%
# !$kypher \
-i "$ITEMS" --as item \
--limit 10
# Out:
# [2021-08-16 20:14:16 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_21 AS graph_21_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2	rank	node2;wikidatatype
# P10-P1629-Q34508-bcc39400-0	P10	P1629	Q34508	normal	wikibase-item
# P10-P1855-Q15075950-7eff6d65-0	P10	P1855	Q15075950	normal	wikibase-item
# P10-P1855-Q4504-a69d2c73-0	P10	P1855	Q4504	normal	wikibase-item
# P10-P1855-Q69063653-c8cdb04c-0	P10	P1855	Q69063653	normal	wikibase-item
# P10-P1855-Q7378-555592a4-0	P10	P1855	Q7378	normal	wikibase-item
# P10-P2302-Q21502404-d012aef4-0	P10	P2302	Q21502404	normal	wikibase-item
# P10-P2302-Q21510851-5224fe0b-0	P10	P2302	Q21510851	normal	wikibase-item
# P10-P2302-Q21510852-dde2f0ce-0	P10	P2302	Q21510852	normal	wikibase-item
# P10-P2302-Q52004125-d0288d06-0	P10	P2302	Q52004125	normal	wikibase-item
# P10-P2302-Q53869507-974ce3b1-0	P10	P2302	Q53869507	normal	wikibase-item

# %%
# !$kypher \
-i "/Users/grantxie/Downloads/claims.external-id.tsv.gz" --as exid\
--limit 10
# Out:
# [2021-09-07 01:21:31 sqlstore]: IMPORT graph directly into table graph_52 from /Users/grantxie/Downloads/claims.external-id.tsv.gz ...
# [2021-09-07 01:38:39 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_52 AS graph_52_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2	rank	node2;wikidatatype
# P1005-P2264-155572-b048c795-0	P1005	P2264	"4031"	normal	external-id
# P1005-P2264-3ae570-ebd28455-0	P1005	P2264	"4032"	normal	external-id
# P1014-P2264-a23718-8fffd32b-0	P1014	P2264	"48"	normal	external-id
# P1015-P2264-134fad-a7e86696-0	P1015	P2264	"1617"	normal	external-id
# P1015-P2264-7e9c1a-b2f829b5-0	P1015	P2264	"564"	normal	external-id
# P1021-P2264-340fcd-59428d77-0	P1021	P2264	"88"	normal	external-id
# P1043-P2264-797922-58a7ad5f-0	P1043	P2264	"248"	normal	external-id
# P1045-P2264-d509ce-e51b9649-0	P1045	P2264	"46"	normal	external-id
# P1047-P2264-63c077-2c42ccf1-0	P1047	P2264	"962"	normal	external-id
# P1047-P2264-c393fd-099f19d6-0	P1047	P2264	"43"	normal	external-id

# %% [markdown]
# ## Output files for Tableau

# %%
# !$kypher -i item -i author \
--match 'item: (c)-[:P31]->(:Q16917)' \
-o hospital.tsv
# Out:
# [2021-11-14 00:26:54 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_21 AS graph_21_c1
#      WHERE graph_21_c1."label"=?
#      AND graph_21_c1."node2"=?
#   PARAS: ['P31', 'Q16917']
# ---------------------------------------------

# %%
# !$kypher \
-i "/Users/grantxie/Downloads/claims.globe-coordinate.tsv" --as coor \
--limit 10
# Out:
# [2021-11-14 00:27:06 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_22 AS graph_22_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2	rank	node2;wikidatatype
# Q100-P625-2e35d9-cdfcaf0e-0	Q100	P625	@42.358333333333/-71.0625	normal	globe-coordinate
# Q1000-P1332-b48e3a-0ed57897-0	Q1000	P1332	@2.32/11.7	normal	globe-coordinate
# Q1000-P1333-3c3826-e820db87-0	Q1000	P1333	@-3.96005/11.15322	normal	globe-coordinate
# Q1000-P1334-44067c-eebd06bd-0	Q1000	P1334	@-0.61746/14.5266	normal	globe-coordinate
# Q1000-P1335-a8c32c-37c5bb67-0	Q1000	P1335	@-0.62444444/8.70805556	normal	globe-coordinate
# Q1000-P625-fa52c4-ce6c2e1f-0	Q1000	P625	@-0.68333055555556/11.5	normal	globe-coordinate
# Q100000-P625-58c345-14fbc9fe-0	Q100000	P625	@50.8283/5.7678	normal	globe-coordinate
# Q100000001-P625-acd0bb-fb89d825-0	Q100000001	P625	@-35.19629722222222/149.14484166666668	normal	globe-coordinate
# Q100000034-P625-e952d9-aea04e31-0	Q100000034	P625	@43.84324/13.01446	normal	globe-coordinate
# Q100000050-P625-46b12b-d84c11b4-0	Q100000050	P625	@37.1954/128.8702	normal	globe-coordinate

# %%
# !$kypher -i item -i coor -i label\
--match 'item: (c)-[]->(:Q16917), coor:(c)-[:P625]->(d), label:(c)-[]->(e)'\
--return 'c, d, e' \
-o name1.tsv
# Out:
# [2021-11-14 00:27:22 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_22_c2."node1", graph_22_c2."node2", graph_18_c3."node2"
#      FROM graph_18 AS graph_18_c3, graph_21 AS graph_21_c1, graph_22 AS graph_22_c2
#      WHERE graph_21_c1."node2"=?
#      AND graph_22_c2."label"=?
#      AND graph_18_c3."node1"=graph_21_c1."node1"
#      AND graph_21_c1."node1"=graph_22_c2."node1"
#   PARAS: ['Q16917', 'P625']
# ---------------------------------------------

# %%
ls = []
for i in range(0,50):
    ls.append('/Users/grantxie/Downloads/with_nils_author/split_' +str(i) +".csv")

# %%
df = pd.read_csv('/Users/grantxie/Downloads/with_nils_author/split_0.csv')
df.head()
# Out:
#    column  row                       label  \
# 0       0    0              LINDLEY BARBEE
# 1       0    1  CHRISTINE MITRA KHOSROPOUR
# 2       0    2              MICHAEL J GALE
# 3       0    3            DANIEL M. RATNER
# 4       0    4           SHAWN J. SKERRETT
#
#                                              context  \
# 0  UNIVERSITY OF WASHINGTON|CHRISTINE MITRA KHOSR...
# 1            UNIVERSITY OF WASHINGTON|LINDLEY BARBEE
# 2  UNIVERSITY OF WASHINGTON|CAROLYN B COYNE;HUGO ...
# 3  UNIVERSITY OF WASHINGTON|PATRICK S. STAYTON;SH...
# 4  UNIVERSITY OF WASHINGTON|COURTNEY CRANE;DANIEL...
#
#                                    filename  \
# 0  tl_person_coinvestigator_with_qnihid.tsv
# 1  tl_person_coinvestigator_with_qnihid.tsv
# 2  tl_person_coinvestigator_with_qnihid.tsv
# 3  tl_person_coinvestigator_with_qnihid.tsv
# 4  tl_person_coinvestigator_with_qnihid.tsv
#
#                                     column-id                 label_clean  \
# 0  tl_person_coinvestigator_with_qnihid.tsv-0              LINDLEY BARBEE
# 1  tl_person_coinvestigator_with_qnihid.tsv-0  CHRISTINE MITRA KHOSROPOUR
# 2  tl_person_coinvestigator_with_qnihid.tsv-0              MICHAEL J GALE
# 3  tl_person_coinvestigator_with_qnihid.tsv-0            DANIEL M. RATNER
# 4  tl_person_coinvestigator_with_qnihid.tsv-0           SHAWN J. SKERRETT
#
#       kg_id                    kg_labels  \
# 0       NIL                          NaN
# 1       NIL                          NaN
# 2  Q6831539  Michael Gale|Michael J Gale
# 3       NIL                          NaN
# 4       NIL                          NaN
#
#                                           kg_aliases  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2  M. J Gale|Michael J. Gale|M. J. Gale|Gale, M. J.   ...
# 3                                                NaN  ...
# 4                                                NaN  ...
#
#   lof_class_count_tf_idf_score  \
# 0                          NaN
# 1                          NaN
# 2                      0.51241
# 3                          NaN
# 4                          NaN
#
#                                     top5_class_count  \
# 0                                                NaN
# 1                                                NaN
# 2  Q36180:0.031|Q482980:0.030|Q2500638:0.030|Q702...
# 3                                                NaN
# 4                                                NaN
#
#    lof_property_count_tf_idf_score  \
# 0                              NaN
# 1                              NaN
# 2                         0.111416
# 3                              NaN
# 4                              NaN
#
#                                  top5_property_count  context_property  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2  P106:0.034|P735:0.028|P21:0.023|P27:0.009|P646...    P108|Pcoauthor
# 3                                                NaN               NaN
# 4                                                NaN               NaN
#
#    context_similarity  context_property_similarity_q_node  context_score  \
# 0                 NaN                                 NaN         0.0000
# 1                 NaN                                 NaN         0.0000
# 2     0.4506$$|0.45$$      P108/0.4506$$|Pcoauthor/0.45$$         0.3632
# 3                 NaN                                 NaN         0.0000
# 4                 NaN                                 NaN         0.0000
#
#    siamese_prediction  rank
# 0                 0.0   NaN
# 1                 0.0   NaN
# 2                 1.0   1.0
# 3                 0.0   NaN
# 4                 0.0   NaN
#
# [5 rows x 39 columns]

# %%
original = pd.read_csv('/Users/grantxie/Downloads/tl_person_coinvestigator_with_qnihid.tsv', sep='\t')

# %%
original.head()
# Out:
#                   person_name         organization_name  \
# 0              LINDLEY BARBEE  UNIVERSITY OF WASHINGTON
# 1  CHRISTINE MITRA KHOSROPOUR  UNIVERSITY OF WASHINGTON
# 2              MICHAEL J GALE  UNIVERSITY OF WASHINGTON
# 3            DANIEL M. RATNER  UNIVERSITY OF WASHINGTON
# 4           SHAWN J. SKERRETT  UNIVERSITY OF WASHINGTON
#
#                                 coinvestigator_names    person_qnihid
# 0                         CHRISTINE MITRA KHOSROPOUR  QNIHPER11081386
# 1                                     LINDLEY BARBEE  QNIHPER12074317
# 2  CAROLYN B COYNE;HUGO RAMON ROSEN;JOAN M GOVERM...   QNIHPER1940486
# 3  PATRICK S. STAYTON;SHAWN J. SKERRETT;TIMOTHY E...   QNIHPER6623689
# 4  COURTNEY CRANE;DANIEL M. RATNER;KATHIE ANNE WA...   QNIHPER1898012

# %%
arr = []
id_t = []
qid = []
label = []
kg = []
mem = []
graph = []
for file in ls:
    print(file)
    df = pd.read_csv(file)
    for i in range(0, len(df)):
        if df['row'][i] in arr:
            continue
        arr.append(df['row'][i])
        label.append(df.label[i])
        kg.append(df['kg_id'][i])
        id_t.append('')
        mem.append('label')
        graph.append('author')
        qid.append(original['person_qnihid'][int(df['row'][i])])
# Out:
# /Users/grantxie/Downloads/with_nils_author/split_0.csv
# /Users/grantxie/Downloads/with_nils_author/split_1.csv
# /Users/grantxie/Downloads/with_nils_author/split_2.csv
# /Users/grantxie/Downloads/with_nils_author/split_3.csv
# /Users/grantxie/Downloads/with_nils_author/split_4.csv
# /Users/grantxie/Downloads/with_nils_author/split_5.csv
# /Users/grantxie/Downloads/with_nils_author/split_6.csv
# /Users/grantxie/Downloads/with_nils_author/split_7.csv
# /Users/grantxie/Downloads/with_nils_author/split_8.csv
# /Users/grantxie/Downloads/with_nils_author/split_9.csv
# /Users/grantxie/Downloads/with_nils_author/split_10.csv
# /Users/grantxie/Downloads/with_nils_author/split_11.csv
# /Users/grantxie/Downloads/with_nils_author/split_12.csv
# /Users/grantxie/Downloads/with_nils_author/split_13.csv
# /Users/grantxie/Downloads/with_nils_author/split_14.csv
# /Users/grantxie/Downloads/with_nils_author/split_15.csv
# /Users/grantxie/Downloads/with_nils_author/split_16.csv
# /Users/grantxie/Downloads/with_nils_author/split_17.csv
# /Users/grantxie/Downloads/with_nils_author/split_18.csv
# /Users/grantxie/Downloads/with_nils_author/split_19.csv
# /Users/grantxie/Downloads/with_nils_author/split_20.csv
# /Users/grantxie/Downloads/with_nils_author/split_21.csv
# /Users/grantxie/Downloads/with_nils_author/split_22.csv
# /Users/grantxie/Downloads/with_nils_author/split_23.csv
# /Users/grantxie/Downloads/with_nils_author/split_24.csv
# /Users/grantxie/Downloads/with_nils_author/split_25.csv
# /Users/grantxie/Downloads/with_nils_author/split_26.csv
# /Users/grantxie/Downloads/with_nils_author/split_27.csv
# /Users/grantxie/Downloads/with_nils_author/split_28.csv
# /Users/grantxie/Downloads/with_nils_author/split_29.csv
# /Users/grantxie/Downloads/with_nils_author/split_30.csv
# /Users/grantxie/Downloads/with_nils_author/split_31.csv
# /Users/grantxie/Downloads/with_nils_author/split_32.csv
# /Users/grantxie/Downloads/with_nils_author/split_33.csv
# /Users/grantxie/Downloads/with_nils_author/split_34.csv
# /Users/grantxie/Downloads/with_nils_author/split_35.csv
# /Users/grantxie/Downloads/with_nils_author/split_36.csv
# /Users/grantxie/Downloads/with_nils_author/split_37.csv
# /Users/grantxie/Downloads/with_nils_author/split_38.csv
# /Users/grantxie/Downloads/with_nils_author/split_39.csv
# /Users/grantxie/Downloads/with_nils_author/split_40.csv
# /Users/grantxie/Downloads/with_nils_author/split_41.csv
# /Users/grantxie/Downloads/with_nils_author/split_42.csv
# /Users/grantxie/Downloads/with_nils_author/split_43.csv
# /Users/grantxie/Downloads/with_nils_author/split_44.csv
# /Users/grantxie/Downloads/with_nils_author/split_45.csv
# /Users/grantxie/Downloads/with_nils_author/split_46.csv
# /Users/grantxie/Downloads/with_nils_author/split_47.csv
# /Users/grantxie/Downloads/with_nils_author/split_48.csv
# /Users/grantxie/Downloads/with_nils_author/split_49.csv

# %%
new = pd.DataFrame(list(zip(id_t,qid,mem,kg,arr, label,graph)), columns = ['id', 'node1', 'label', 'node2', 'row', 'node2;label','graph'])

# %%
new
# Out:
#       id            node1  label     node2    row                 node2;label  \
# 0         QNIHPER11081386  label       NIL      0              LINDLEY BARBEE
# 1         QNIHPER12074317  label       NIL      1  CHRISTINE MITRA KHOSROPOUR
# 2          QNIHPER1940486  label  Q6831539      2              MICHAEL J GALE
# 3          QNIHPER6623689  label       NIL      3            DANIEL M. RATNER
# 4          QNIHPER1898012  label       NIL      4           SHAWN J. SKERRETT
# ...   ..              ...    ...       ...    ...                         ...
# 51563      QNIHPER8107460  label       NIL  51564          RAINA N. FICHOROVA
# 51564      QNIHPER2272576  label       NIL  51565     DOROTHEA DENISE JENKINS
# 51565     QNIHPER16431128  label       NIL  51566         JACQUELINE GENOVESI
# 51566     QNIHPER16505596  label       NIL  51567          JENNIFER JOVANOVIC
# 51567     QNIHPER16505541  label       NIL  51568          TONI A. SONDERGELD
#
#         graph
# 0      author
# 1      author
# 2      author
# 3      author
# 4      author
# ...       ...
# 51563  author
# 51564  author
# 51565  author
# 51566  author
# 51567  author
#
# [51568 rows x 7 columns]

# %%
new = new[new['node2'] != 'NIL']

# %%
new = new.reset_index(drop = True)

# %%
new
# Out:
#       id            node1  label      node2    row            node2;label  \
# 0          QNIHPER1940486  label   Q6831539      2         MICHAEL J GALE
# 1          QNIHPER2414340  label  Q87796696      5     PATRICK S. STAYTON
# 2         QNIHPER11537130  label  Q89958961      8          KENNETH NGURE
# 3          QNIHPER8820221  label  Q61467477     10       ANITHA PASUPATHY
# 4          QNIHPER8491201  label  Q46001993     11  STEPHANIE M FULLERTON
# ...   ..              ...    ...        ...    ...                    ...
# 21905      QNIHPER1865473  label  Q88874640  51553      THERESA L WALUNAS
# 21906     QNIHPER77800199  label  Q17232943  51555           HEATHER RYAN
# 21907     QNIHPER16138148  label  Q59751913  51557             TAD SIMONS
# 21908      QNIHPER6983267  label  Q88663895  51558       VERA P KRYMSKAYA
# 21909      QNIHPER1889098  label  Q91381841  51562     SCOTT C STEFFENSEN
#
#         graph
# 0      author
# 1      author
# 2      author
# 3      author
# 4      author
# ...       ...
# 21905  author
# 21906  author
# 21907  author
# 21908  author
# 21909  author
#
# [21910 rows x 7 columns]

# %%
for i in range(0, len(new)):
    new['id'][i] = 'author' + str(i)
# Out:
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new.to_csv('nih_author_kgtk.tsv', index = False, sep = '\t')

# %%
new.to_csv('/Users/grantxie/Downloads/nig_kgtk.tsv', index = False, sep = '\t')

# %% [markdown]
# Output files

# %%
# !$kypher \
-i "/Users/grantxie/Downloads/kgtk-master/use-cases/nig_kgtk.tsv" --as nih \
--limit 10
# Out:
# [2021-11-14 00:31:07 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_23 AS graph_23_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2	row	graph
# qnode0	Q219563	label	UNIVERSITY OF WASHINGTON	0	qnode
# qnode1	Q5081831	label	CHARLES R. DREW UNIVERSITY OF MEDICAL & SCIENCE	1	qnode
# qnode2	Q622664	label	UNIVERSITY OF CALIFORNIA, SAN DIEGO	2	qnode
# qnode3	Q812573	label	BAYLOR UNIVERSITY	4	qnode
# qnode4	Q49118	label	BOSTON COLLEGE	5	qnode
# qnode5	Q6806451	label	MEDICAL UNIVERSITY OF SOUTH CAROLINA	6	qnode
# qnode6	Q457281	label	UNIVERSITY OF ILLINOIS AT URBANA-CHAMPAIGN	7	qnode
# qnode7	Q168751	label	DUKE UNIVERSITY	9	qnode
# qnode8	Q349055	label	WAYNE STATE UNIVERSITY	10	qnode
# qnode9	Q104480607	label	NORTHAMPTON VA MEDICAL CENTER	11	qnode

# %%
# !$kypher \
-i "/Users/grantxie/Downloads/nih_projects/nih_project_new.id.tsv" --as project \
--limit 5
# Out:
# [2021-11-14 00:31:15 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_31 AS graph_31_c1
#      LIMIT ?
#   PARAS: [5]
# ---------------------------------------------
# id	node1	label	node2
# QNIHPRO10286324-PNIHtitle-cfa7f1	QNIHPRO10286324	PNIHtitle	"CD38-TARGETED IMMUNOPET OF MYELOMA: PHASE 2 TRIAL OF CLINICAL APPLICATIONS"
# QNIHPRO10286324-PNIHorg-17451a	QNIHPRO10286324	PNIHorg	"HOAG MEMORIAL HOSPITAL PRESBYTERIAN"
# QNIHPRO10286324-PNIHcost-452920	QNIHPRO10286324	PNIHcost	598926
# QNIHPRO10286324-PNIHsub-730793	QNIHPRO10286324	PNIHsub	"Antibodies; base; Biopsy; blind; Blood Tests; Bone marrow biopsy; burden of illness; cancer imaging; Cells; Clinical; clinical application; clinical care; Clinical Trials; clinically significant; Combined Modality Therapy; design; Detection; Detection of Minimal Residual Disease; Disease; dosimetry; early phase trial; experience; first-in-human; fluorodeoxyglucose positron emission tomography; Funding Opportunities; Future; Goals; Histologic; Human; human imaging; Image; imaging agent; imaging modality; Immunoglobulins; ImmunoPET; individual patient; innovation; Investigation; Laboratories; Measurement; Measures; Membrane Proteins; Memorial Sloan-Kettering Cancer Center; Methods; Monitor; Monoclonal Antibodies; Multiple Myeloma; multiple myeloma M Protein; novel; outcome forecast; Patient Care; Patient imaging; Patient Monitoring; Patients; PET/CT scan; Phase; Phase I Clinical Trials; phase I trial; Phase II Clinical Trials; phase II trial; Plasma Cell Neoplasm; Plasma Cells; Positron-Emission Tomography; preclinical imaging; predicting response; Prognostic Marker; Proteins; Radiochemistry; Radioimmunotherapy; Radiolabeled; Research Personnel; Residual Tumors; response; Safety; Selection for Treatments; Serum; Site; Surface; targeted imaging; theranostics; Therapeutic Agents; Tracer; Translations; treatment response; tumor; Tumor Burden; United States; uptake; virtual; Visualization; Work;"
# QNIHPRO10258167-PNIHtitle-90b590	QNIHPRO10258167	PNIHtitle	"Mechanism of selective packaging of primer tRNALys3 by HIV-1"

# %%
# !$kypher \
-i "/Users/grantxie/Downloads/kgtk-files-nih-V3.0_new/nih_investigator.id.tsv" --as inv \
--limit 5
# Out:
# [2021-11-14 00:31:21 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_32 AS graph_32_c1
#      LIMIT ?
#   PARAS: [5]
# ---------------------------------------------
# id	node1	label	node2
# QNIHPRO9983961-P8329-QNIHPER1860172	QNIHPRO9983961	P8329	QNIHPER1860172
# QNIHPRO9950743-P8329-QNIHPER9569267	QNIHPRO9950743	P8329	QNIHPER9569267
# QNIHPRO9950743-P8329-QNIHPER10426588	QNIHPRO9950743	P8329	QNIHPER10426588
# QNIHPRO10121452-P8329-QNIHPER6081502	QNIHPRO10121452	P8329	QNIHPER6081502
# QNIHPRO10121452-P8329-QNIHPER16339995	QNIHPRO10121452	P8329	QNIHPER16339995

# %%
# !$kypher \
-i "/Users/grantxie/Downloads/kgtk-files-nih-V3.0_new/nih_person.id.tsv" --as  per\
--limit 5
# Out:
# [2021-11-14 00:31:25 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_33 AS graph_33_c1
#      LIMIT ?
#   PARAS: [5]
# ---------------------------------------------
# id	node1	label	node2
# QNIHPER1904041-label-1b2172	QNIHPER1904041	label	ROBERT STERLING TURNER
# QNIHPER1904041-PNIHID-475a43	QNIHPER1904041	PNIHID	1904041
# QNIHPER1904041-P108-QNIHORG2059802	QNIHPER1904041	P108	QNIHORG2059802
# QNIHORG2059802-PNIHID-d70604	QNIHORG2059802	PNIHID	2059802
# QNIHPER6240796-label-d0a9cc	QNIHPER6240796	label	RUTH OTTMAN

# %%
# !$kypher \
-i "coinvestigators.compact.tsv" --as coinvestigator \
--limit 5
# Out:
# [2021-11-14 00:31:28 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_27 AS graph_27_c1
#      LIMIT ?
#   PARAS: [5]
# ---------------------------------------------
# node1	label	node2
# QNIHPER10001049	Pcoinvestigator_names	BARBARA ANN CHURCH|EDUARDO MERCADO|JONATHAN D. RODGERS
# QNIHPER10001128	Pcoinvestigator_names	MARK A. MC NIVEN
# QNIHPER10001819	Pcoinvestigator_names	ABRAHAM NA SHAKED|BRIAN DONALD PIENING|JUHI KUMAR|KRZYSZTOF KIRYLUK|MALEK KAMOUN|MARIO C. DENG|MICHAEL P. SNYDER|SANDRA AMARAL
# QNIHPER10003131	Pcoinvestigator_names	AARON PAUL BATISTA|BYRON M. YU
# QNIHPER10003688	Pcoinvestigator_names	BOB WONG|JANICE MARGARET MORSE

# %%
# !$kypher \
-i "author_hospital.id.tsv" --as hosp \
--limit 5
# Out:
# [2021-11-14 00:31:33 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_37 AS graph_37_c1
#      LIMIT ?
#   PARAS: [5]
# ---------------------------------------------
# id	node1	label	node2
# QNIHPER10003954-member-Q39050124	QNIHPER10003954	member	Q39050124
# QNIHPER10428590-member-Q625321	QNIHPER10428590	member	Q625321
# QNIHPER10004092-member-Q5582923	QNIHPER10004092	member	Q5582923
# QNIHPER12571233-member-Q28035413	QNIHPER12571233	member	Q28035413
# QNIHPER2098890-member-Q50036737	QNIHPER2098890	member	Q50036737

# %%
# !$kypher -i author -i nih_author -i inv -i item -i coor -i label -i project\
--optional 'project: (project)-[]->(cost)' \
--limit 10
# Out:
# usage: kgtk [options] command [ / command]*
# kgtk: error: unrecognized arguments: --optional project: (project)-[]->(cost)

# %%
# !$kypher -i author -i nih_author -i inv -i item -i coor -i label -i project\
--match 'author: (cluster)-[]->(qnode), nih_author:(qnihauthor)-[]->(qnode), inv:(project)-[]->(qnihauthor), \
        item:(qnode)-[:P108]->(org_node), label:(org_node)-[]->(org_name),label:(qnode)-[]->(author_name), \
        coor:(org_node)-[:P625]->(organization_coor)'\
--opt 'project: (project)-[:PNIHcost]->(cost)' \
--opt 'project: (project)-[:PNIHtitle]->(project_title)' \
--opt 'project: (project)-[:PNIHsub]->(project_subjects)' \
--return 'cluster as cluster_id, author_name as author_name, \
            org_name as org_name, project_title as project_title, project_subjects as project_subjects,\
            kgtk_geo_coords_lat(organization_coor) as lat, kgtk_geo_coords_long(organization_coor) as long, sum(cost)' \
-o nih_summary.tsv
# Out:
# usage: kgtk [options] command [ / command]*
# kgtk: error: unrecognized arguments: --opt project: (project)-[:PNIHcost]->(cost) --opt project: (project)-[:PNIHtitle]->(project_title) --opt project: (project)-[:PNIHsub]->(project_subjects)

# %%
# !$kypher -i author -i nih_author -i inv -i item -i coor -i label -i project\
--match 'project: (:QNIHPRO10168561)-[]->(qnode)'
# Out:
# [2021-11-14 00:32:19 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_31 AS graph_31_c1
#      WHERE graph_31_c1."node1"=?
#   PARAS: ['QNIHPRO10168561']
# ---------------------------------------------
# id	node1	label	node2
# QNIHPRO10168561-PNIHtitle-0acc1e	QNIHPRO10168561	PNIHtitle	"Mechano-molecular regulation of kinetochore function"
# QNIHPRO10168561-PNIHorg-9ddda8	QNIHPRO10168561	PNIHorg	"UNIVERSITY OF MASSACHUSETTS AMHERST"
# QNIHPRO10168561-PNIHcost-97c49b	QNIHPRO10168561	PNIHcost	313116
# QNIHPRO10168561-PNIHsub-757264	QNIHPRO10168561	PNIHsub	"Adult; Affinity; Amino Acids; Anaphase; Aneuploidy; base; Binding; Biochemical; Biological Assay; Biophysics; cancer diagnosis; Cell division; Cell Division Process; Cell physiology; Cells; Centromere; Chromatin; chromosome missegregation; chromosome movement; chromosome number abnormality; Chromosomes; Complex; Congenital Abnormality; Disease; Drosophila genus; Elements; Embryonic Development; Ensure; experimental study; First Pregnancy Trimester; force sensor; Funding; Generations; Genome; Goals; Homologous Gene; Human; human tissue; improved; In Vitro; innovation; interest; Kinetochores; Knowledge; Lead; Link; Maintenance; Mechanics; mechanotransduction; Microtubules; Mitotic Chromosome; Modeling; Molecular; Molecular Conformation; molecular mass; Names; Nature; Neoplasm Metastasis; novel; Pathologic; pointed protein; Polymers; Population; Positioning Attribute; Prevention; Proliferation Marker; Property; protein complex; protein folding; Proteins; receptor; recruit; Regulation; Regulatory Pathway; Reproducibility; Research; Role; sensor; Signal Transduction; single molecule; Sister Chromatid; Spontaneous abortion; stem; Stretching; Structure; Surface; targeted treatment; Testing; Therapeutic; Time; tissue/cell culture; Tissues; Transducers; Translating; transmission process; tumorigenesis; Work;"

# %%
# !$kypher -i author -i nih_author -i inv -i item -i coor -i label -i project -i hosp -i time -i quantities\
--match 'author: (cluster)-[]->(qnode), nih_author:(qnihauthor)-[]->(qnode), inv:(project)-[]->(qnihauthor), \
        item:(qnode)-[:P108]->(org_node), label:(org_node)-[]->(org_name),label:(qnode)-[]->(author_name), \
        coor:(org_node)-[:P625]->(organization_coor), hosp:(qnihauthor)-[]->(hosp_node),\
        label:(hosp_node)-[]->(hosp_name), coor:(hosp_node)-[:P625]->(hosp_coor)'\
--opt 'time: (hosp_node)-[:P571]->(hosp_inc)' \
--opt 'time: (org_node)-[:P571]->(org_inc)' \
--opt 'quantities: (hosp_node)-[:P6801]->(count_beds)' \
--opt 'project: (project)-[:PNIHcost]->(cost)' \
--return 'cluster as cluster_id, org_name as org_name, sum(cost) as organization_award, \
        kgtk_geo_coords_lat(organization_coor) as org_lat, kgtk_geo_coords_long(organization_coor) as org_long,\
        kgtk_date_year(org_inc) as org_inc, \
        hosp_name as hosp_name, kgtk_geo_coords_lat(hosp_coor) as hosp_lat, kgtk_geo_coords_long(hosp_coor) as hosp_long,\
        kgtk_date_year(hosp_inc) as hosp_inc, count_beds as count_beds' \
-o bed_inception_1.tsv
# Out:
# usage: kgtk [options] command [ / command]*
# kgtk: error: unrecognized arguments: --opt time: (hosp_node)-[:P571]->(hosp_inc) --opt time: (org_node)-[:P571]->(org_inc) --opt quantities: (hosp_node)-[:P6801]->(count_beds) --opt project: (project)-[:PNIHcost]->(cost)

# %%
pwd
# Out:
# '/Users/grantxie/Downloads/NIH'

# %%
df = pd.read_csv('bed_inception_1.tsv',  sep = '\t')
df['count_beds'].fillna(value=df['count_beds'].mean(), inplace=True)
df.to_csv('bed_incepition_imputed.tsv', index = False, sep = '\t')

# %%
df
# Out:
#                             cluster_id  \
# 0           cluster_0_0_0_0_0_0_0_6_93
# 1           cluster_0_0_0_0_0_0_0_6_93
# 2       cluster_0_0_0_0_0_0_39_106_193
# 3       cluster_0_0_0_0_0_14_19_25_126
# 4      cluster_0_0_0_0_0_14_66_154_718
# ..                                 ...
# 294  cluster_0_1_4_7_9_16_129_368_1416
# 295  cluster_0_1_4_7_9_16_129_368_1416
# 296   cluster_0_1_4_7_9_16_21_144_1142
# 297   cluster_0_1_4_7_9_16_21_144_1142
# 298   cluster_0_1_4_7_9_16_21_144_1144
#
#                                        org_name  organization_award  \
# 0    'Massachusetts Institute of Technology'@en           4658658.0
# 1                      'Whitehead Institute'@en           4658658.0
# 2                    'Vanderbilt University'@en           2175747.0
# 3      'University of California, San Diego'@en                 NaN
# 4                      'Stanford University'@en                 NaN
# ..                                          ...                 ...
# 294     'University of California, Berkeley'@en           8727072.0
# 295               'University of Washington'@en           8727072.0
# 296     'California Institute of Technology'@en                 NaN
# 297                    'Stanford University'@en                 NaN
# 298     'Oregon Health & Science University'@en            629276.0
#
#        org_lat    org_long  org_inc  \
# 0    42.359820  -71.092110   1861.0
# 1    42.363132  -71.089476   1982.0
# 2    36.148649  -86.804972   1873.0
# 3    32.881000 -117.238000   1960.0
# 4    37.428229 -122.168858   1891.0
# ..         ...         ...      ...
# 294  37.870000 -122.259000   1868.0
# 295  47.654167 -122.308056   1861.0
# 296  34.137500 -118.125000   1891.0
# 297  37.428229 -122.168858   1891.0
# 298  45.498917 -122.688750   1974.0
#
#                                           hosp_name   hosp_lat   hosp_long  \
# 0                    'Cambridge Health Alliance'@en  42.374800  -71.104800
# 1                    'Cambridge Health Alliance'@en  42.374800  -71.104800
# 2    'Children’s Hospital at TriStar Centennial'@en  36.153508  -86.807237
# 3                        'Jacobs Medical Center'@en  32.877703 -117.226499
# 4           'Stanford University Medical Center'@en  37.434000 -122.175000
# ..                                              ...        ...         ...
# 294               'Children\'s Hospital Oakland'@en  37.837500 -122.267000
# 295               'Children\'s Hospital Oakland'@en  37.837500 -122.267000
# 296                        'Huntington Hospital'@en  34.134500 -118.153000
# 297                        'Huntington Hospital'@en  34.134500 -118.153000
# 298           'Doernbecher Children\'s Hospital'@en  45.499800 -122.688000
#
#      hosp_inc  count_beds
# 0      1996.0  617.830986
# 1      1996.0  617.830986
# 2         NaN  617.830986
# 3      2016.0  364.000000
# 4      1959.0  613.000000
# ..        ...         ...
# 294    1912.0  191.000000
# 295    1912.0  191.000000
# 296    1892.0  625.000000
# 297    1892.0  625.000000
# 298    1926.0  617.830986
#
# [299 rows x 11 columns]

# %%
df.to_excel('bed_incepition_imputed_1.xlsx', index = False)

# %%
df = pd.read_csv('nih_sum_cost.tsv', sep = '\t')
df['total_cost'].fillna(value=df['total_cost'].mean(), inplace=True)

# %%
df.to_excel('/Users/grantxie/Downloads/nih_sum_cost_by_org.xlsx', index = False)

# %%
# !$kypher \
-i "/Users/grantxie/Downloads/claims.quantity.tsv.gz" --as quantities\
--limit 10
# Out:
# [2021-08-17 05:03:06 sqlstore]: IMPORT graph directly into table graph_38 from /Users/grantxie/Downloads/claims.quantity.tsv.gz ...
# [2021-08-17 05:12:08 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_38 AS graph_38_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2	rank	node2;wikidatatype
# P1004-P4876-b5e617-af81a4c5-0	P1004	P4876	+37427	normal	quantity
# P1014-P4876-605b34-fbb0b790-0	P1014	P4876	+53249	preferred	quantity
# P1014-P4876-62c45c-db5d6620-0	P1014	P4876	+50825	normal	quantity
# P1014-P4876-732e1a-9ea8b31a-0	P1014	P4876	+47267	normal	quantity
# P1014-P4876-f7a212-293bd556-0	P1014	P4876	+46591	normal	quantity
# P1022-P4876-fa0ca8-40e422f8-0	P1022	P4876	+541	normal	quantity
# P1024-P4876-8fb399-9696d4ac-0	P1024	P4876	+857	normal	quantity
# P1025-P4876-f0dc63-acd0fe33-0	P1025	P4876	+13000000	normal	quantity
# P1042-P1114-27b781-00b6c31d-0	P1042	P1114	+1952404	normal	quantity
# P1044-P4876-d72e5b-569d2ef4-0	P1044	P4876	+54300000	normal	quantity

# %%
# !$kypher -i item -i coor -i label\
--match 'item: (c)-[]->(:Q16917), coor:(c)-[:P625]->(d), label:(c)-[]->(e)'\
--force \
--return 'c, d, e' \
-o name1.tsv

# %%
# !$kypher \
-i "/Users/grantxie/Downloads/nih_match_hospital.tsv" --as hospital\
--limit 10
# Out:
# [2021-08-17 04:22:37 sqlstore]: IMPORT graph directly into table graph_36 from /Users/grantxie/Downloads/nih_match_hospital.tsv ...
# [2021-08-17 04:22:37 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_36 AS graph_36_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# node1	node2	coordinates	nearest_label	nearest_coordinates	distance
# Q219563	UNIVERSITY OF WASHINGTON	@47.65416666666667/-122.30805555555555	'University of Washington Medical Center'@en	@47.6489232/-122.3065945	2.9628626020887572e-05
# Q5081831	CHARLES R. DREW UNIVERSITY OF MEDICAL & SCIENCE	@33.925634/-118.242594	'Martin Luther King, Jr. Multi-Service Ambulatory Care Center'@en	@33.9238/-118.242	3.7163919999995717e-06
# Q622664	UNIVERSITY OF CALIFORNIA, SAN DIEGO	@32.881/-117.238	'Jacobs Medical Center'@en	@32.877703/-117.226499	0.00014314320999992013
# Q812573	BAYLOR UNIVERSITY	@31.5472/-97.1139	'Scott & White Memorial Hospital'@en	@31.07753/-97.36383	0.28305491379999664
# Q49118	BOSTON COLLEGE	@42.335083333333/-71.170361111111	'Floating Hospital for Children'@en	@42.353267/-71.173681	0.00034166739569182304
# Q6806451	MEDICAL UNIVERSITY OF SOUTH CAROLINA	@32.784166666667/-79.950833333333	'Roper Hospital'@en	@32.7826/-79.949593	3.992871222429877e-06
# Q457281	UNIVERSITY OF ILLINOIS AT URBANA-CHAMPAIGN	@40.110538888889/-88.228411111111	'OSF Heart of Mary Medical Center'@en	@40.11792/-88.22746	5.538541357833092e-05
# Q168751	DUKE UNIVERSITY	@36.001111111111/-78.938888888889	'Duke Cancer Institute'@en	@36.00496/-78.93689	1.8809502470368104e-05
# Q349055	WAYNE STATE UNIVERSITY	@42.357344444444/-83.070105555556	'Dunbar Hospital'@en	@42.361667/-83.058889	0.00014449560507558061
# Q104480607	NORTHAMPTON VA MEDICAL CENTER	@35.588877/-82.484897	'Clarence Barker Memorial Hospital'@en	@35.565/-82.5411	0.0037288883379995442

# %%
# !$kypher \
-i "/Users/grantxie/Downloads/kgtk-master/use-cases/nih_author_kgtk.tsv" --as nih_author \
--limit 10
# Out:
# [2021-08-16 20:30:03 sqlstore]: IMPORT graph directly into table graph_30 from /Users/grantxie/Downloads/kgtk-master/use-cases/nih_author_kgtk.tsv ...
# [2021-08-16 20:30:03 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_30 AS graph_30_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2	row	node2;label	graph
# author0	QNIHPER1940486	label	Q6831539	2	MICHAEL J GALE	author
# author1	QNIHPER2414340	label	Q87796696	5	PATRICK S. STAYTON	author
# author2	QNIHPER11537130	label	Q89958961	8	KENNETH NGURE	author
# author3	QNIHPER8820221	label	Q61467477	10	ANITHA PASUPATHY	author
# author4	QNIHPER8491201	label	Q46001993	11	STEPHANIE M FULLERTON	author
# author5	QNIHPER7882742	label	Q89866816	13	MARION PEPPER	author
# author6	QNIHPER8146532	label	Q89937644	14	HORACIO O DE LA IGLESIA	author
# author7	QNIHPER10499986	label	Q56809498	17	KEVIN HYBISKE	author
# author8	QNIHPER2315018	label	Q87887672	18	KARIN E. BORNFELDT	author
# author9	QNIHPER3065493	label	Q90437737	21	RAYMOND SCOTT MCCLELLAND	author

# %%
# %cd /Users/grantxie/Downloads/NIH
# Out:
# /Users/grantxie/Downloads/NIH

# %%
# !$kypher -i item -i coor -i nih\
--match 'nih:(c)-[]->(d), coor:(c)-[:P625]->(e)'\
--return 'c, d, e' \
-o name_nih_new.tsv
# Out:
# [2021-08-09 19:46:06 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_23_c1."node1", graph_23_c1."node2", graph_22_c2."node2"
#      FROM graph_22 AS graph_22_c2
#      INNER JOIN graph_23 AS graph_23_c1
#      ON graph_23_c1."node1" = graph_22_c2."node1"
#         AND graph_22_c2."label" = ?
#   PARAS: ['P625']
# ---------------------------------------------

# %% [markdown]
# ## Calculating closest hospital for organizations (using kdtree)

# %%
df = pd.read_csv('name1.tsv', sep = '\t')

# %%
x = []
y = []

for i in range(0, len(df)):
    x.append(df.node2[i][1:].split('/')[0])
    y.append(df.node2[i][1:].split('/')[1])

# %%
x_c = []
y_c = []

for i in range(0, len(df)):
    x_c.append(float(x[i]))
    y_c.append(float(y[i]))

# %%
import kdtree

# %%
emptyTree = kdtree.create(dimensions=2)

# %%
arr = []
for i in range(0, len(df)):
    arr.append((x_c[i], y_c[i]))

# %%
tree = kdtree.create(arr)

# %%
nih = pd.read_csv('/Users/grantxie/Downloads/cluster_coor.tsv', sep = '\t')

# %%
nih
# Out:
#       id                       node1   label            node2  \
# 0    NaN  cluster_0_0_2_2_14_112_322  member  QNIHPER10003954
# 1    NaN  cluster_0_0_2_2_14_112_322  member  QNIHPER10428590
# 2    NaN  cluster_0_0_3_6_21_40_1800  member  QNIHPER10004092
# 3    NaN  cluster_0_0_3_6_21_40_1238  member  QNIHPER12571233
# 4    NaN  cluster_0_0_3_6_21_40_1238  member   QNIHPER2098890
# ...   ..                         ...     ...              ...
# 2377 NaN    cluster_0_0_2_2_14_8_259  member   QNIHPER9634058
# 2378 NaN     cluster_0_0_3_6_7_2_843  member   QNIHPER9728962
# 2379 NaN    cluster_0_0_3_6_7_2_2378  member   QNIHPER9883306
# 2380 NaN  cluster_0_0_3_6_21_77_1289  member   QNIHPER9807979
# 2381 NaN  cluster_0_0_3_6_21_77_1289  member   QNIHPER9859180
#
#                              node2;coor  \
# 0                       @41.504/-81.608
# 1                      @37.5625/126.945
# 2                @44.564588/-123.275705
# 3     @42.447222222222/-76.483055555556
# 4                @46.343224/-119.276333
# ...                                 ...
# 2377  @35.908611111111/-79.049166666667
# 2378  @38.907222222222/-77.072777777778
# 2379                    @38.912/-77.077
# 2380                     @40.73/-73.995
# 2381                     @40.73/-73.995
#
#                                            node2;label
# 0                 'Case Western Reserve University'@en
# 1                          'Ewha Womans University'@en
# 2                         'Oregon State University'@en
# 3                              'Cornell University'@en
# 4           'Pacific Northwest National Laboratory'@en
# ...                                                ...
# 2377  'University of North Carolina at Chapel Hill'@en
# 2378                        'Georgetown University'@en
# 2379         'Georgetown University Medical Center'@en
# 2380                          'New York University'@en
# 2381                          'New York University'@en
#
# [2382 rows x 6 columns]

# %%
nih_vec = []
x = []
y = []
for i in range(0, len(nih)):
    x.append(nih['node2;coor'][i][1:].split('/')[0])
    y.append(nih['node2;coor'][i][1:].split('/')[1])

# %%
results = []
for i in range(0, len(nih)):
    results.append(tree.search_nn((float(x[i]), float(y[i]))))

# %%
results[1][0].data
# Out:
# (37.5624, 126.941)

# %%
total = []
for i in range(0, len(x_c)):
    total.append((x_c[i], y_c[i]))

# %%
tree.data[0]
# Out:
# 38.248967

# %%
total.index(results[0][0].data)
# Out:
# 7451

# %%
index = []
for i in range(0, len(results)):
    index.append(total.index(results[i][0].data))

# %%
nih['nearest_node'] = ''
nih['nearest_label'] = ''
nih['nearest_coordinates'] = ''

# %%
for i in range(0, len(nih)):
    nih['nearest_node'][i] = df['node1'][index[i]]
    nih['nearest_label'][i] = df['node2.1'][index[i]]
    nih['nearest_coordinates'][i] = df['node2'][index[i]]
# Out:
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
nih['distance'] = -1.1

# %%
for i in range(0, len(nih)):
    nih['distance'][i] = results[i][1]
# Out:
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
nih.head()
# Out:
#    id                       node1   label            node2  \
# 0 NaN  cluster_0_0_2_2_14_112_322  member  QNIHPER10003954
# 1 NaN  cluster_0_0_2_2_14_112_322  member  QNIHPER10428590
# 2 NaN  cluster_0_0_3_6_21_40_1800  member  QNIHPER10004092
# 3 NaN  cluster_0_0_3_6_21_40_1238  member  QNIHPER12571233
# 4 NaN  cluster_0_0_3_6_21_40_1238  member   QNIHPER2098890
#
#                           node2;coor  \
# 0                    @41.504/-81.608
# 1                   @37.5625/126.945
# 2             @44.564588/-123.275705
# 3  @42.447222222222/-76.483055555556
# 4             @46.343224/-119.276333
#
#                                   node2;label nearest_node  \
# 0        'Case Western Reserve University'@en    Q39050124
# 1                 'Ewha Womans University'@en      Q625321
# 2                'Oregon State University'@en     Q5582923
# 3                     'Cornell University'@en    Q28035413
# 4  'Pacific Northwest National Laboratory'@en    Q50036737
#
#                                  nearest_label    nearest_coordinates  \
# 0        'Case Comprehensive Cancer Center'@en        @41.504/-81.608
# 1                      'Severance Hospital'@en       @37.5624/126.941
# 2  'Good Samaritan Regional Medical Center'@en      @44.6022/-123.252
# 3                   'Cayuga Medical Center'@en   @42.469273/-76.53727
# 4                           'Kadlec Clinic'@en  @46.28146/-119.281346
#
#    distance
# 0  0.000000
# 1  0.000016
# 2  0.001977
# 3  0.003425
# 4  0.003840

# %%
output = pd.DataFrame(list(zip(nih['id'], nih.node2, nih.label, nih.nearest_node)) ,columns = ['id', 'node1', 'label', 'node2'])

# %%
output.to_csv('author_hospital.tsv', index = False, sep = '\t')

# %%
# !$kgtk add-id --id-style wikidata \
-i "author_hospital.tsv" -o author_hospital.id.tsv

# %%
output
# Out:
#       id            node1   label      node2
# 0    NaN  QNIHPER10003954  member  Q39050124
# 1    NaN  QNIHPER10428590  member    Q625321
# 2    NaN  QNIHPER10004092  member   Q5582923
# 3    NaN  QNIHPER12571233  member  Q28035413
# 4    NaN   QNIHPER2098890  member  Q50036737
# ...   ..              ...     ...        ...
# 2377 NaN   QNIHPER9634058  member  Q30288421
# 2378 NaN   QNIHPER9728962  member   Q5547057
# 2379 NaN   QNIHPER9883306  member   Q5547057
# 2380 NaN   QNIHPER9807979  member  Q22061077
# 2381 NaN   QNIHPER9859180  member  Q22061077
#
# [2382 rows x 4 columns]

# %%
group = nih.groupby('node1')

# %%
def get_cluster_dist(cluster):
    
    group = nih.groupby('node1')
    df = group.get_group(cluster)
    l = df.nearest_label.unique()
    org = df.groupby('nearest_label')

    c1 = []
    c2 = []
    for i in range(0, len(l)):
        c1.append(l[i][1:len(l[i])-4])
        c2.append(org.get_group(l[i]).count()[1])
        
    df = pd.DataFrame(list(zip(c1,c2)), columns = ['org', 'count'])
    return df.sort_values(by='count', ascending=False).reset_index(drop = True)

# %%
get_cluster_dist('cluster_0_0_2_2_14_112_322')
# Out:
#                                                   org  count
# 0                Washington University Medical Center      7
# 1                       Brigham and Women\'s Hospital      5
# 2          VA Center for Clinical Management Research      5
# 3   Center for Emergency Medicine of Western Penns...      4
# 4                          NYU Langone Medical Center      4
# ..                                                ...    ...
# 57                               The Peak Mark Clinic      1
# 58                     St. John\'s Episcopal Hospital      1
# 59                         Bloomingdale Insane Asylum      1
# 60                Morgan Stanley Children\'s Hospital      1
# 61                Shands at the University of Florida      1
#
# [62 rows x 2 columns]

# %%
import math
def get_cluster_mean(cluster):
    df_temp = pd.read_csv('name1.tsv', sep = '\t')
    group = nih.groupby('node1')
    df = group.get_group(cluster).reset_index(drop = True)

    df_vec = []
    x = []
    y = []
    for i in range(0, len(df)):
        x.append(float(df['node2;coor'][i][1:].split('/')[0]))
        y.append(float(df['node2;coor'][i][1:].split('/')[1]))
        
    x1 = float(sum(x))/float(len(x))
    y1 = float(sum(y))/float(len(y))
    #print(x1 ,y1)
    res = tree.search_nn([x1, y1])
    #print(df_temp['node2.1'][total.index(results[i][0].data)][1: len(df_temp['node2.1'][total.index(results[i][0].data)])-4])
    #print(res[0])
    
    tot = 0.0
    
    for i in range(0, len(x)):
        tot = tot + 111 * math.sqrt( (res[0].data[0]-x[i])**2 + (res[0].data[1]-y[i])**2 )
    #print(tot/len(x))
    
    return (df_temp['node2.1'][total.index(results[i][0].data)][1: len(df_temp['node2.1'][total.index(results[i][0].data)])-4], tot/len(x))

# %%
get_cluster_mean('cluster_0_0_2_2_14_112_322')
# Out:
# ('Penn Medicine Princeton Medical Center', 1901.3523863405317)

# %%
name = []
dist = []
cl = []
count = []
cluster = nih.node1.unique()
label = []

for i in range(0, len(cluster)):
    group = nih.groupby('node1')
    cl.append(cluster[i])
    count.append(len(group.get_group(cluster[i])))
    temp = get_cluster_mean(cluster[i])
    name.append(temp[0])
    dist.append(temp[1])
    label.append('Near')

# %%
output = pd.DataFrame(list(zip(cl,name, label, dist,count,)), columns = ['node1', 'label', 'node2', 'node2;dist', 'node1;count'])

# %%
output.sort_values(by='node2;dist', ascending=True).reset_index(drop = True)
# Out:
#                            node1                                       label  \
# 0      cluster_0_0_3_5_15_45_215            Case Comprehensive Cancer Center
# 1      cluster_0_0_3_5_30_39_104                       Cayuga Medical Center
# 2    cluster_0_0_2_2_14_146_1984                       Cayuga Medical Center
# 3     cluster_0_0_3_5_15_45_1068                          Severance Hospital
# 4     cluster_0_0_2_3_23_60_1880                          Severance Hospital
# ..                           ...                                         ...
# 144    cluster_0_0_3_6_21_40_623                          Spaulding Hospital
# 145    cluster_0_0_2_2_9_93_2350  James Whitcomb Riley Hospital for Children
# 146   cluster_0_0_3_6_11_61_1689                               Kadlec Clinic
# 147   cluster_0_0_3_5_30_82_1616                  Baylor College of Medicine
# 148   cluster_0_0_3_6_11_61_1642                  Baylor College of Medicine
#
#     node2   node2;dist  node1;count
# 0    Near     0.357465            1
# 1    Near     1.564715            4
# 2    Near    19.162157            4
# 3    Near    46.704682            2
# 4    Near   170.079363            2
# ..    ...          ...          ...
# 144  Near  4858.154756            9
# 145  Near  5135.594781           18
# 146  Near  5234.390724            5
# 147  Near  6702.576310           10
# 148  Near  8357.909891           10
#
# [149 rows x 5 columns]

# %%
output.sort_values(by='node2;dist', ascending=True).reset_index(drop = True).to_csv('hospital_mean_distance.tsv', index = False, sep = '\t')

# %%
pwd
# Out:
# '/Users/grantxie/Downloads/NIH'

# %%
# Out:
#                            node1                                   label  \
# 0     cluster_0_0_2_2_14_112_322  Penn Medicine Princeton Medical Center
# 1     cluster_0_0_3_6_21_40_1800                Norman Regional Hospital
# 2     cluster_0_0_3_6_21_40_1238              Baylor College of Medicine
# 3     cluster_0_0_2_3_22_129_391       University of New Mexico Hospital
# 4     cluster_0_0_3_5_30_15_1005              NYU Langone Medical Center
# ..                           ...                                     ...
# 144    cluster_0_0_2_3_23_85_782                   Cayuga Medical Center
# 145  cluster_0_0_2_3_24_103_2290  Good Samaritan Regional Medical Center
# 146  cluster_0_0_2_3_24_103_1216                   Cayuga Medical Center
# 147    cluster_0_0_3_5_30_39_620         Stony Brook University Hospital
# 148    cluster_0_0_3_5_28_70_495                      Severance Hospital
#
#     node2   node2;dist  node1;count
# 0    Near  1901.352386          111
# 1    Near  3734.246675            6
# 2    Near  1504.803572           10
# 3    Near   891.357219           16
# 4    Near  1670.367667           13
# ..    ...          ...          ...
# 144  Near  1034.161456            4
# 145  Near  1764.546490            3
# 146  Near  4119.954933            4
# 147  Near  3813.832220            7
# 148  Near   430.439936            2
#
# [149 rows x 5 columns]

# %%
nih
# Out:
#       id                       node1   label            node2  \
# 0    NaN  cluster_0_0_2_2_14_112_322  member  QNIHPER10003954
# 1    NaN  cluster_0_0_2_2_14_112_322  member  QNIHPER10428590
# 2    NaN  cluster_0_0_3_6_21_40_1800  member  QNIHPER10004092
# 3    NaN  cluster_0_0_3_6_21_40_1238  member  QNIHPER12571233
# 4    NaN  cluster_0_0_3_6_21_40_1238  member   QNIHPER2098890
# ...   ..                         ...     ...              ...
# 2377 NaN    cluster_0_0_2_2_14_8_259  member   QNIHPER9634058
# 2378 NaN     cluster_0_0_3_6_7_2_843  member   QNIHPER9728962
# 2379 NaN    cluster_0_0_3_6_7_2_2378  member   QNIHPER9883306
# 2380 NaN  cluster_0_0_3_6_21_77_1289  member   QNIHPER9807979
# 2381 NaN  cluster_0_0_3_6_21_77_1289  member   QNIHPER9859180
#
#                              node2;coor  \
# 0                       @41.504/-81.608
# 1                      @37.5625/126.945
# 2                @44.564588/-123.275705
# 3     @42.447222222222/-76.483055555556
# 4                @46.343224/-119.276333
# ...                                 ...
# 2377  @35.908611111111/-79.049166666667
# 2378  @38.907222222222/-77.072777777778
# 2379                    @38.912/-77.077
# 2380                     @40.73/-73.995
# 2381                     @40.73/-73.995
#
#                                            node2;label  \
# 0                 'Case Western Reserve University'@en
# 1                          'Ewha Womans University'@en
# 2                         'Oregon State University'@en
# 3                              'Cornell University'@en
# 4           'Pacific Northwest National Laboratory'@en
# ...                                                ...
# 2377  'University of North Carolina at Chapel Hill'@en
# 2378                        'Georgetown University'@en
# 2379         'Georgetown University Medical Center'@en
# 2380                          'New York University'@en
# 2381                          'New York University'@en
#
#                                     nearest_label    nearest_coordinates  \
# 0           'Case Comprehensive Cancer Center'@en        @41.504/-81.608
# 1                         'Severance Hospital'@en       @37.5624/126.941
# 2     'Good Samaritan Regional Medical Center'@en      @44.6022/-123.252
# 3                      'Cayuga Medical Center'@en   @42.469273/-76.53727
# 4                              'Kadlec Clinic'@en  @46.28146/-119.281346
# ...                                           ...                    ...
# 2377  'University of North Carolina Hospitals'@en   @35.90515/-79.050011
# 2378    'Georgetown University Medical Center'@en        @38.912/-77.077
# 2379    'Georgetown University Medical Center'@en        @38.912/-77.077
# 2380          'St. John\'s Episcopal Hospital'@en  @40.725656/-73.991794
# 2381          'St. John\'s Episcopal Hospital'@en  @40.725656/-73.991794
#
#       distance
# 0     0.000000
# 1     0.000016
# 2     0.001977
# 3     0.003425
# 4     0.003840
# ...        ...
# 2377  0.000013
# 2378  0.000041
# 2379  0.000000
# 2380  0.000029
# 2381  0.000029
#
# [2382 rows x 9 columns]

# %%
nih['lat'] = -1.1
nih['long'] = -1.1

# %%
for i in range(0, len(nih)):
    nih.lat[i] = float(nih['node2;coor'][i][1:].split('/')[0])
    nih.long[i] = float(nih['node2;coor'][i][1:].split('/')[1])
# Out:
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
nih.to_excel('nih.xlsx', index = False)

# %% [markdown]
# ## Output Tableau files to show main topics (subjects) of papers for each organization

# %%
# !$kgtk add-id --id-style wikidata -i "/Users/grantxie/Downloads/NIH/nih_sub_sep.tsv" -o nih_sub_sep.id.tsv

# %%
# !$kypher \
-i "nih_sub_sep.id.tsv" --as subjects_new\
--limit 10
# Out:
# [2021-08-19 00:19:24 sqlstore]: IMPORT graph directly into table graph_40 from /Users/grantxie/Downloads/NIH/nih_sub_sep.id.tsv ...
# [2021-08-19 00:19:43 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_40 AS graph_40_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2
# QNIHPRO10286324-PNIHsub-fc3d31	QNIHPRO10286324	PNIHsub	antibodies
# QNIHPRO10286324-PNIHsub-cae662	QNIHPRO10286324	PNIHsub	base
# QNIHPRO10286324-PNIHsub-9621fb	QNIHPRO10286324	PNIHsub	biopsy
# QNIHPRO10286324-PNIHsub-e5b84c	QNIHPRO10286324	PNIHsub	blind
# QNIHPRO10286324-PNIHsub-505b64	QNIHPRO10286324	PNIHsub	blood tests
# QNIHPRO10286324-PNIHsub-d361d3	QNIHPRO10286324	PNIHsub	bone marrow biopsy
# QNIHPRO10286324-PNIHsub-c933a4	QNIHPRO10286324	PNIHsub	burden of illness
# QNIHPRO10286324-PNIHsub-81ad91	QNIHPRO10286324	PNIHsub	cancer imaging
# QNIHPRO10286324-PNIHsub-57104c	QNIHPRO10286324	PNIHsub	cells
# QNIHPRO10286324-PNIHsub-98569e	QNIHPRO10286324	PNIHsub	clinical

# %%
# !$kypher -i author -i nih_author -i inv -i item -i coor -i label -i project -i hosp -i time -i quantities\
--match 'author: (cluster)-[]->(qnode), nih_author:(qnihauthor)-[]->(qnode), inv:(project)-[]->(qnihauthor), \
        item:(qnode)-[:P108]->(org_node), label:(org_node)-[]->(org_name),label:(qnode)-[]->(author_name), \
        coor:(org_node)-[:P625]->(organization_coor), hosp:(qnihauthor)-[]->(hosp_node),\
        label:(hosp_node)-[]->(hosp_name), coor:(hosp_node)-[:P625]->(hosp_coor),item:(paper)-[:P50]->(qnode),item:(paper)-[:P921]->(mai)'\
--opt 'time: (hosp_node)-[:P571]->(hosp_inc)' \
--opt 'time: (org_node)-[:P571]->(org_inc)' \
--opt 'quantities: (hosp_node)-[:P6801]->(count_beds)' \
--opt 'project: (project)-[:PNIHcost]->(cost)' \
--return 'cluster as cluster_id, org_name as org_name, sum(cost) as organization_award, \
        kgtk_geo_coords_lat(organization_coor) as org_lat, kgtk_geo_coords_long(organization_coor) as org_long,\
        kgtk_date_year(org_inc) as org_inc, \
        hosp_name as hosp_name, kgtk_geo_coords_lat(hosp_coor) as hosp_lat, kgtk_geo_coords_long(hosp_coor) as hosp_long,\
        kgtk_date_year(hosp_inc) as hosp_inc, count_beds as count_beds' \
-o bed_inception_1.tsv

# %%
# !$kypher -i author_test_new -i nih_author -i inv -i item -i coor -i label -i project -i hosp -i time -i quantities -i subjects_new\
--match 'author: (cluster)-[]->(qnode), nih_author:(qnihauthor)-[]->(qnode), inv:(project)-[]->(qnihauthor), \
        item:(qnode)-[:P108]->(org_node), label:(org_node)-[]->(org_name),label:(qnode)-[]->(author_name), \
        coor:(org_node)-[:P625]->(organization_coor), subjects_new:(project)-[]->(subject), hosp:(qnihauthor)-[]->(hosp_node),\
        label:(hosp_node)-[]->(hosp_name), coor:(hosp_node)-[:P625]->(hosp_coor)'\
--opt 'project: (project)-[:PNIHcost]->(cost)' \
--opt 'project: (project)-[:PNIHtitle]->(project_title)' \
--opt 'project: (project)-[:PNIHsub]->(project_subjects)' \
--return 'subject as subject, \
            count(subject) as subject_count, sum(cost) as cost' \
--order-by "subject_count desc"\
-o subjects_total.tsv
# Out:
# [2021-08-20 04:48:16 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_40_c8."node2" "_aLias.subject", count("_aLias.subject") "_aLias.subject_count", sum(graph_31_c12."node2") "_aLias.cost"
#      FROM graph_18 AS graph_18_c10
#      INNER JOIN graph_18 AS graph_18_c5, graph_18 AS graph_18_c6, graph_19 AS graph_19_c1, graph_21 AS graph_21_c4, graph_22 AS graph_22_c11, graph_22 AS graph_22_c7, graph_30 AS graph_30_c2, graph_32 AS graph_32_c3, graph_37 AS graph_37_c9, graph_40 AS graph_40_c8
#      ON graph_19_c1."node2" = graph_18_c6."node1"
#         AND graph_19_c1."node2" = graph_21_c4."node1"
#         AND graph_19_c1."node2" = graph_30_c2."node2"
#         AND graph_21_c4."node2" = graph_18_c5."node1"
#         AND graph_21_c4."node2" = graph_22_c7."node1"
#         AND graph_30_c2."node1" = graph_32_c3."node2"
#         AND graph_30_c2."node1" = graph_37_c9."node1"
#         AND graph_32_c3."node1" = graph_40_c8."node1"
#         AND graph_37_c9."node2" = graph_18_c10."node1"
#         AND graph_37_c9."node2" = graph_22_c11."node1"
#         AND graph_21_c4."label" = ?
#         AND graph_22_c11."label" = ?
#         AND graph_22_c7."label" = ?
#      LEFT JOIN graph_31 AS graph_31_c12
#      ON graph_32_c3."node1" = graph_31_c12."node1"
#         AND graph_31_c12."label" = ?
#      LEFT JOIN graph_31 AS graph_31_c13
#      ON graph_32_c3."node1" = graph_31_c13."node1"
#         AND graph_31_c13."label" = ?
#      LEFT JOIN graph_31 AS graph_31_c14
#      ON graph_32_c3."node1" = graph_31_c14."node1"
#         AND graph_31_c14."label" = ?
#      GROUP BY "_aLias.subject"
#      ORDER BY "_aLias.subject_count" DESC
#   PARAS: ['P108', 'P625', 'P625', 'PNIHcost', 'PNIHtitle', 'PNIHsub']
# ---------------------------------------------

# %%
df = pd.read_csv('file.tsv', sep = '\t')

# %%
df['count_beds'].fillna(value=df['count_beds'].mean(), inplace=True)

# %%
df.to_excel('nih_0824.xlsx', index = False)

# %%
cluster = []
org_name = []
org_node = []
org_lat = []
org_long = []
hosp_name = []
hosp_node = []
hosp_lat =[]
hosp_long= []

subject1 = []
subject2 = []
subject3 = []
subject4 = []
subject5 = []

subject1_count = []
subject2_count = []
subject3_count = []
subject4_count = []
subject5_count = []

subject1_cost  = []
subject2_cost  = []
subject3_cost  = []
subject4_cost  = []
subject5_cost  = []

org_inc = []
hosp_inc = []

hosp_bed = []

last_cluster = ''
last_org = ''

for i in range(0, len(df)):
    
    if df.cluster_id[i] == last_cluster and df['org_name'][i] == last_org:
        continue
    else:
        last_cluster = df.cluster_id[i]
        last_org = df['org_name'][i]
        last_cluster = df.cluster_id[i]
        last_org = df['org_name'][i]
        cluster.append(df['cluster_id'][i])
        org_name.append(df['org_name'][i])
        #org_node.append(df['org_node'][i])
        org_lat.append(df['org_lat'][i])
        org_long.append(df['org_long'][i])
        hosp_name.append(df['hosp_name'][i])
        #hosp_node.append(df['hosp_node'][i])
        hosp_lat.append(df['hosp_lat'][i])
        hosp_long.append(df['hosp_long'][i])
        
        
        subject1.append(df.ms_name[i])
        subject2.append(df.ms_name[i+1])
        subject3.append(df.ms_name[i+2])
        subject4.append(df.ms_name[i+3])
        subject5.append(df.ms_name[i+4])
        
        subject1_count.append(df.subject_count[i])
        subject2_count.append(df.subject_count[i+1])
        subject3_count.append(df.subject_count[i+2])
        subject4_count.append(df.subject_count[i+3])
        subject5_count.append(df.subject_count[i+4])
        
        
        #subject1_cost.append(df.cost[i])
        #subject2_cost.append(df.cost[i+1])
        #subject3_cost.append(df.cost[i+2])
        #subject4_cost.append(df.cost[i+3])
        #subject5_cost.append(df.cost[i+4])
        
        org_inc.append(df.org_inc[i])
        hosp_inc.append(df.hosp_inc[i])
        hosp_bed.append(df.count_beds[i])

# %%
output = pd.DataFrame(list(zip(cluster, org_name,  org_lat, org_long, org_inc, hosp_name,  hosp_lat, hosp_long, hosp_inc, hosp_bed, subject1, \
subject2, subject3, subject4, subject5, subject1_count,subject2_count,subject3_count,subject4_count,subject5_count)), columns = ['cluster', 'org_name', 'org_lat', 'org_long', 'org_inc', 'hosp_name',  'hosp_lat', 'hosp_long', 'hosp_inc', 'hosp_bed', 'subject1', \
'subject2', 'subject3', 'subject4', 'subject5', 'count1', 'count2','count3','count4','count5'])

# %%
output['hosp_bed'].fillna(value=output['hosp_bed'].mean(), inplace=True)

# %%
output
# Out:
#                                  cluster  \
# 0     cluster_0_0_0_5_34_82_165_315_1172
# 1        cluster_0_0_0_3_12_19_26_39_990
# 2      cluster_0_1_1_12_27_47_75_129_446
# 3     cluster_0_0_0_3_12_20_131_236_1292
# 4      cluster_0_1_1_12_27_47_75_129_446
# ...                                  ...
# 1015    cluster_0_0_0_3_12_20_27_233_494
# 1016  cluster_0_1_1_12_29_57_94_232_1261
# 1017  cluster_0_1_1_12_27_75_124_219_527
# 1018    cluster_0_0_0_3_12_20_27_233_494
# 1019  cluster_0_1_1_12_27_75_124_219_527
#
#                                       org_name    org_lat   org_long  org_inc  \
# 0                         'Yale University'@en  41.311111 -72.926667   1701.0
# 1                         'Yale University'@en  41.311111 -72.926667   1701.0
# 2                         'Yale University'@en  41.311111 -72.926667   1701.0
# 3                         'Yale University'@en  41.311111 -72.926667   1701.0
# 4                         'Yale University'@en  41.311111 -72.926667   1701.0
# ...                                        ...        ...        ...      ...
# 1015  'Albert Einstein College of Medicine'@en  40.850852 -73.844949   1955.0
# 1016  'Albert Einstein College of Medicine'@en  40.850852 -73.844949   1955.0
# 1017  'Albert Einstein College of Medicine'@en  40.850852 -73.844949   1955.0
# 1018  'Albert Einstein College of Medicine'@en  40.850852 -73.844949   1955.0
# 1019  'Albert Einstein College of Medicine'@en  40.850852 -73.844949   1955.0
#
#                          hosp_name   hosp_lat   hosp_long  hosp_inc  \
# 0      'Smilow Cancer Hospital'@en  41.304278  -72.935676    2009.0
# 1         'UCSF Medical Center'@en  37.763200 -122.458000    1907.0
# 2      'Smilow Cancer Hospital'@en  41.304278  -72.935676    2009.0
# 3      'Smilow Cancer Hospital'@en  41.304278  -72.935676    2009.0
# 4      'Smilow Cancer Hospital'@en  41.304278  -72.935676    2009.0
# ...                            ...        ...         ...       ...
# 1015  'Calvary Hospital, Bronx'@en  40.847986  -73.843853    1899.0
# 1016  'Calvary Hospital, Bronx'@en  40.847986  -73.843853    1899.0
# 1017  'Calvary Hospital, Bronx'@en  40.847986  -73.843853    1899.0
# 1018  'Calvary Hospital, Bronx'@en  40.847986  -73.843853    1899.0
# 1019  'Calvary Hospital, Bronx'@en  40.847986  -73.843853    1899.0
#
#         hosp_bed                                   subject1  \
# 0     632.616279                       'phosphorylation'@en
# 1     796.000000                                'CRISPR'@en
# 2     632.616279                        'RNA sequencing'@en
# 3     632.616279                    'Toll-like receptor'@en
# 4     632.616279                            'statistics'@en
# ...          ...                                        ...
# 1015  225.000000  'Human Induced Pluripotent Stem Cells'@en
# 1016  225.000000  'BH3 interacting domain death agonist'@en
# 1017  225.000000                        'ovarian cancer'@en
# 1018  225.000000              'ATRX chromatin remodeler'@en
# 1019  225.000000                             'cell line'@en
#
#                             subject2  \
# 0                        'CRISPR'@en
# 1                'RNA sequencing'@en
# 2                      'database'@en
# 3                    'statistics'@en
# 4        'Caenorhabditis elegans'@en
# ...                              ...
# 1015                     'autism'@en
# 1016                     'Bcl-xL'@en
# 1017   'ATRX chromatin remodeler'@en
# 1018  'ATRX, chromatin remodeler'@en
# 1019             'adenocarcinoma'@en
#
#                                                subject3  \
# 0                                   'RNA sequencing'@en
# 1                                         'database'@en
# 2                               'Toll-like receptor'@en
# 3                           'Caenorhabditis elegans'@en
# 4                                    'transcriptome'@en
# ...                                                 ...
# 1015                                 'transcriptome'@en
# 1016  'Chemical modulation of chaperone-mediated aut...
# 1017                     'ATRX, chromatin remodeler'@en
# 1018                        'Caenorhabditis elegans'@en
# 1019                                      'antibody'@en
#
#                          subject4  \
# 0                   'database'@en
# 1         'Toll-like receptor'@en
# 2                 'statistics'@en
# 3              'transcriptome'@en
# 4              'macromolecule'@en
# ...                           ...
# 1015                  'CRISPR'@en
# 1016        'Fanconi syndrome'@en
# 1017  'Caenorhabditis elegans'@en
# 1018         'DNA methylation'@en
# 1019               'biomarker'@en
#
#                                                subject5  count1  count2  \
# 0                               'Toll-like receptor'@en    3570    3330
# 1                                       'statistics'@en    3330    2028
# 2                           'Caenorhabditis elegans'@en    2028    2028
# 3                                    'macromolecule'@en    1620    1404
# 4                                         'ribozyme'@en    1404    1248
# ...                                                 ...     ...     ...
# 1015                                  'cell biology'@en      66      66
# 1016                                'autoinhibition'@en      42      42
# 1017                               'DNA methylation'@en      30      22
# 1018  'DNA-binding E3 ubiquitin-protein ligase SNT2 ...      22      22
# 1019                                  'chemotherapy'@en      20      10
#
#       count3  count4  count5
# 0       2028    2028    1620
# 1       2028    1620    1404
# 2       1620    1404    1248
# 3       1248    1248    1092
# 4       1248    1092     945
# ...      ...     ...     ...
# 1015      66      44      44
# 1016      42      42      42
# 1017      22      22      22
# 1018      22      22      22
# 1019      10      10      10
#
# [1020 rows x 20 columns]

# %%
output.to_excel('top5_subject_0820.xlsx', index = False)

# %%
# !$kypher -i item -i nih_author -i item -i label\
--match 'item:(paper)-[:P921]->(ms),\
        item:(paper)-[:P50]->(qnode),item:(paper)-[:P921]->(ms_node),\
        label:(ms_node)-[]->(ms_name)'\
--return 'paper,ms, ms_name'\
--limit 100

# %%
# !$kypher -i item -i nih_author -i item -i label -i author\
--match 'author: ()-[]->(qnode),item:(paper)-[:P50]->(qnode)'\
--return 'distinct "" as id, qnode as node1, "P50" as label, paper as node2'\
-o paper.tsv
# Out:
# [2021-08-20 10:29:24 query]: SQL Translation:
# ---------------------------------------------
#   SELECT DISTINCT ? "_aLias.id", graph_30_c1."node2" "_aLias.node1", ? "_aLias.label", graph_21_c2."node1" "_aLias.node2"
#      FROM graph_21 AS graph_21_c2
#      INNER JOIN graph_30 AS graph_30_c1
#      ON graph_30_c1."node2" = graph_21_c2."node2"
#         AND graph_21_c2."label" = ?
#   PARAS: ['', 'P50', 'P50']
# ---------------------------------------------

# %%
# !$kgtk add-id --id-style wikidata -i "/Users/grantxie/Downloads/NIH/paper.tsv" -o paper.id.tsv

# %%
# !$kypher \
-i "paper.id.tsv" --as paper_test_new\
--limit 10
# Out:
# [2021-08-20 10:31:34 sqlstore]: IMPORT graph directly into table graph_44 from /Users/grantxie/Downloads/NIH/paper.id.tsv ...
# [2021-08-20 10:31:35 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_44 AS graph_44_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2
# Q100287043-P50-Q27316717	Q100287043	P50	Q27316717
# Q100287043-P50-Q28728777	Q100287043	P50	Q28728777
# Q100287043-P50-Q33579346	Q100287043	P50	Q33579346
# Q100287043-P50-Q34769869	Q100287043	P50	Q34769869
# Q100287043-P50-Q36126966	Q100287043	P50	Q36126966
# Q100287043-P50-Q36950067	Q100287043	P50	Q36950067
# Q100287043-P50-Q38741540	Q100287043	P50	Q38741540
# Q100287043-P50-Q38751767	Q100287043	P50	Q38751767
# Q100287043-P50-Q44000882	Q100287043	P50	Q44000882
# Q100287043-P50-Q54264722	Q100287043	P50	Q54264722

# %%
# !$kypher -i item -i nih_author -i item -i label -i test -i paper_test\
--match 'paper_test:()-[]->(:Q27316717)'\
# Out:
# [2021-08-20 10:35:22 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_43 AS graph_43_c1
#      WHERE graph_43_c1."node2" = ?
#   PARAS: ['Q27316717']
# ---------------------------------------------
# id	node1	label	node2

# %%
# !$kypher -i item -i nih_author -i item -i label -i test -i paper_test_new -i author_test_new\
--match 'author_test_new: ()-[]->(qnode), paper_test_new:(qnode)-[:P50]->(paper),item:(paper)-[:P921]->(ms_node),\
        label:(ms_node)-[]->(ms_name), label:(qnode)-[]->(name)'\
--return 'distinct name, ms_name, count(ms_node)'\
--order 'count(ms_node) desc'\
-o test4.tsv
# Out:
# [2021-08-20 10:50:28 query]: SQL Translation:
# ---------------------------------------------
#   SELECT DISTINCT graph_18_c5."node2", graph_18_c4."node2", count(graph_21_c3."node2")
#      FROM graph_18 AS graph_18_c4
#      INNER JOIN graph_18 AS graph_18_c5, graph_21 AS graph_21_c3, graph_44 AS graph_44_c2, graph_45 AS graph_45_c1
#      ON graph_21_c3."node2" = graph_18_c4."node1"
#         AND graph_44_c2."node2" = graph_21_c3."node1"
#         AND graph_45_c1."node2" = graph_18_c5."node1"
#         AND graph_45_c1."node2" = graph_44_c2."node1"
#         AND graph_21_c3."label" = ?
#         AND graph_44_c2."label" = ?
#      GROUP BY graph_18_c5."node2", graph_18_c4."node2"
#      ORDER BY count(graph_21_c3."node2") DESC
#   PARAS: ['P921', 'P50']
# ---------------------------------------------
# [2021-08-20 10:50:28 sqlstore]: CREATE INDEX on table graph_45 column node2 ...
# [2021-08-20 10:50:28 sqlstore]: ANALYZE INDEX on table graph_45 column node2 ...

# %%
# !$kypher -i item -i nih_author -i item -i label -i paper_test_new\
--match 'author: (a)-[]->(b)'\
--return 'distinct "" as id, a as node1, "same" as label, b as node2'\
-o author_kgtk_distinct.tsv
# Out:
# [2021-08-20 10:47:18 query]: SQL Translation:
# ---------------------------------------------
#   SELECT DISTINCT ? "_aLias.id", graph_30_c1."node1" "_aLias.node1", ? "_aLias.label", graph_30_c1."node2" "_aLias.node2"
#      FROM graph_30 AS graph_30_c1
#   PARAS: ['', 'same']
# ---------------------------------------------

# %%
# !$kgtk add-id --id-style wikidata -i "/Users/grantxie/Downloads/NIH/author_kgtk_distinct.tsv" -o author_kgtk_distinct.id.tsv

# %%
# !$kypher \
-i "author_kgtk_distinct.id.tsv" --as author_test_new\
--limit 10
# Out:
# [2021-08-20 10:48:48 sqlstore]: DROP graph data table graph_45 from author_test_new
# [2021-08-20 10:48:48 sqlstore]: IMPORT graph directly into table graph_45 from /Users/grantxie/Downloads/NIH/author_kgtk_distinct.id.tsv ...
# [2021-08-20 10:48:48 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_45 AS graph_45_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2
# QNIHPER1940486-same-Q6831539	QNIHPER1940486	same	Q6831539
# QNIHPER2414340-same-Q87796696	QNIHPER2414340	same	Q87796696
# QNIHPER11537130-same-Q89958961	QNIHPER11537130	same	Q89958961
# QNIHPER8820221-same-Q61467477	QNIHPER8820221	same	Q61467477
# QNIHPER8491201-same-Q46001993	QNIHPER8491201	same	Q46001993
# QNIHPER7882742-same-Q89866816	QNIHPER7882742	same	Q89866816
# QNIHPER8146532-same-Q89937644	QNIHPER8146532	same	Q89937644
# QNIHPER10499986-same-Q56809498	QNIHPER10499986	same	Q56809498
# QNIHPER2315018-same-Q87887672	QNIHPER2315018	same	Q87887672
# QNIHPER3065493-same-Q90437737	QNIHPER3065493	same	Q90437737

# %%
# !$kypher \
-i "/Users/grantxie/test_kgtk.tsv" --as test\
--limit 10
# Out:
# [2021-08-20 05:55:27 sqlstore]: IMPORT graph via csv.reader into table graph_41 from /Users/grantxie/test_kgtk.tsv ...
# [2021-08-20 05:55:27 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_41 AS graph_41_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2	row	node2;label	graph
# author0	QNIHPER1940486	label	Q6831539	2	MICHAEL J GALE	author
# author1	QNIHPER2414340	label	Q87796696	5	PATRICK S. STAYTON	author
# author2	QNIHPER11537130	label	Q89958961	8	KENNETH NGURE	author
# author3	QNIHPER8820221	label	Q61467477	10	ANITHA PASUPATHY	author

# %%
# !$kypher -i item -i nih_author -i item -i label -i test\
--match 'test: ()-[]->(qnode),item:(paper)-[:P50]->(qnode),item:(paper)-[:P921]->(ms_node),\
        label:(ms_node)-[]->(ms_name), label:(qnode)-[]->(name)'\
--return 'distinct name, ms_name, count(ms_node)'\
--order 'count(ms_node) desc'\
-o test1.tsv
# Out:
# [2021-08-20 05:55:52 query]: SQL Translation:
# ---------------------------------------------
#   SELECT DISTINCT graph_18_c5."node2", graph_18_c4."node2", count(graph_21_c3."node2")
#      FROM graph_18 AS graph_18_c4
#      INNER JOIN graph_18 AS graph_18_c5, graph_21 AS graph_21_c2, graph_21 AS graph_21_c3, graph_41 AS graph_41_c1
#      ON graph_21_c2."node1" = graph_21_c3."node1"
#         AND graph_21_c3."node2" = graph_18_c4."node1"
#         AND graph_41_c1."node2" = graph_18_c5."node1"
#         AND graph_41_c1."node2" = graph_21_c2."node2"
#         AND graph_21_c2."label" = ?
#         AND graph_21_c3."label" = ?
#      GROUP BY graph_18_c5."node2", graph_18_c4."node2"
#      ORDER BY count(graph_21_c3."node2") DESC
#   PARAS: ['P50', 'P921']
# ---------------------------------------------
# [2021-08-20 05:55:52 sqlstore]: CREATE INDEX on table graph_41 column node2 ...
# [2021-08-20 05:55:52 sqlstore]: ANALYZE INDEX on table graph_41 column node2 ...

# %% [markdown]
# ## file for tableau display

# %%
# !$kypher -i author -i nih_author -i inv -i item -i coor -i label -i project -i hosp -i time -i quantities -i author_test_new -i paper_test_new -i nih0825_new\
--match 'author: (cluster)-[]->(qnode), nih_author:(qnihauthor)-[]->(qnode), inv:(project)-[]->(qnihauthor), \
        item:(qnode)-[:P108]->(org_node), label:(org_node)-[]->(org_name),label:(qnode)-[]->(author_name), \
        coor:(org_node)-[:P625]->(organization_coor), hosp:(qnihauthor)-[]->(hosp_node),\
        label:(hosp_node)-[]->(hosp_name), coor:(hosp_node)-[:P625]->(hosp_coor),author_test_new: ()-[]->(qnode), paper_test_new:(qnode)-[:P50]->(paper),item:(paper)-[:P921]->(ms_node),\
        label:(ms_node)-[]->(ms_name), label:(qnode)-[]->(name), nih0825_new:(project)-[:PNIHstart]->(start1)'\
--opt 'time: (hosp_node)-[:P571]->(hosp_inc)' \
--opt 'time: (org_node)-[:P571]->(org_inc)' \
--opt 'quantities: (hosp_node)-[:P6801]->(count_beds)' \
--opt 'nih0825_new: (project)-[:PNIHcost]->(cost)' \
--return 'cluster as cluster_id, org_name as org_name, \
        kgtk_geo_coords_lat(organization_coor) as org_lat, kgtk_geo_coords_long(organization_coor) as org_long,\
        kgtk_date_year(org_inc) as org_inc, \
        hosp_name as hosp_name, kgtk_geo_coords_lat(hosp_coor) as hosp_lat, kgtk_geo_coords_long(hosp_coor) as hosp_long,\
        kgtk_date_year(hosp_inc) as hosp_inc, count_beds as count_beds, ms_name as ms_name, count(ms_node) as subject_count, sum(cost) as cost, start1 as start' \
--order 'org_name desc, subject_count desc'\
-o final.tsv
# Out:
# [2021-08-26 03:00:17 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_19_c1."node1" "_aLias.cluster_id", graph_18_c5."node2" "_aLias.org_name", kgtk_geo_coords_lat(graph_22_c7."node2") "_aLias.org_lat", kgtk_geo_coords_long(graph_22_c7."node2") "_aLias.org_long", kgtk_date_year(graph_35_c18."node2") "_aLias.org_inc", graph_18_c9."node2" "_aLias.hosp_name", kgtk_geo_coords_lat(graph_22_c10."node2") "_aLias.hosp_lat", kgtk_geo_coords_long(graph_22_c10."node2") "_aLias.hosp_long", kgtk_date_year(graph_35_c17."node2") "_aLias.hosp_inc", graph_38_c19."node2" "_aLias.count_beds", graph_18_c14."node2" "_aLias.ms_name", count(graph_21_c13."node2") "_aLias.subject_count", sum(graph_49_c20."node2") "_aLias.cost", graph_49_c16."node2" "_aLias.start"
#      FROM graph_18 AS graph_18_c14
#      INNER JOIN graph_18 AS graph_18_c15, graph_18 AS graph_18_c5, graph_18 AS graph_18_c6, graph_18 AS graph_18_c9, graph_19 AS graph_19_c1, graph_21 AS graph_21_c13, graph_21 AS graph_21_c4, graph_22 AS graph_22_c10, graph_22 AS graph_22_c7, graph_30 AS graph_30_c2, graph_32 AS graph_32_c3, graph_37 AS graph_37_c8, graph_44 AS graph_44_c12, graph_45 AS graph_45_c11, graph_49 AS graph_49_c16
#      ON graph_19_c1."node2" = graph_18_c15."node1"
#         AND graph_19_c1."node2" = graph_18_c6."node1"
#         AND graph_19_c1."node2" = graph_21_c4."node1"
#         AND graph_19_c1."node2" = graph_30_c2."node2"
#         AND graph_19_c1."node2" = graph_44_c12."node1"
#         AND graph_19_c1."node2" = graph_45_c11."node2"
#         AND graph_21_c13."node2" = graph_18_c14."node1"
#         AND graph_21_c4."node2" = graph_18_c5."node1"
#         AND graph_21_c4."node2" = graph_22_c7."node1"
#         AND graph_30_c2."node1" = graph_32_c3."node2"
#         AND graph_30_c2."node1" = graph_37_c8."node1"
#         AND graph_32_c3."node1" = graph_49_c16."node1"
#         AND graph_37_c8."node2" = graph_18_c9."node1"
#         AND graph_37_c8."node2" = graph_22_c10."node1"
#         AND graph_44_c12."node2" = graph_21_c13."node1"
#         AND graph_21_c13."label" = ?
#         AND graph_21_c4."label" = ?
#         AND graph_22_c10."label" = ?
#         AND graph_22_c7."label" = ?
#         AND graph_44_c12."label" = ?
#         AND graph_49_c16."label" = ?
#      LEFT JOIN graph_35 AS graph_35_c17
#      ON graph_37_c8."node2" = graph_35_c17."node1"
#         AND graph_35_c17."label" = ?
#      LEFT JOIN graph_35 AS graph_35_c18
#      ON graph_21_c4."node2" = graph_35_c18."node1"
#         AND graph_35_c18."label" = ?
#      LEFT JOIN graph_38 AS graph_38_c19
#      ON graph_37_c8."node2" = graph_38_c19."node1"
#         AND graph_38_c19."label" = ?
#      LEFT JOIN graph_49 AS graph_49_c20
#      ON graph_32_c3."node1" = graph_49_c20."node1"
#         AND graph_49_c20."label" = ?
#      GROUP BY "_aLias.cluster_id", "_aLias.org_name", "_aLias.org_lat", "_aLias.org_long", "_aLias.org_inc", "_aLias.hosp_name", "_aLias.hosp_lat", "_aLias.hosp_long", "_aLias.hosp_inc", "_aLias.count_beds", "_aLias.ms_name"
#      ORDER BY "_aLias.org_name" DESC, "_aLias.subject_count" DESC
#   PARAS: ['P921', 'P108', 'P625', 'P625', 'P50', 'PNIHstart', 'P571', 'P571', 'P6801', 'PNIHcost']
# ---------------------------------------------
# [2021-08-26 03:00:17 sqlstore]: CREATE INDEX on table graph_49 column node1 ...
# [2021-08-26 03:00:19 sqlstore]: ANALYZE INDEX on table graph_49 column node1 ...
# [2021-08-26 03:00:19 sqlstore]: CREATE INDEX on table graph_49 column label ...
# [2021-08-26 03:00:20 sqlstore]: ANALYZE INDEX on table graph_49 column label ...

# %%
# !$kypher \
-i "/Users/grantxie/Downloads/kgtk-files-nih-V5.0/nih_project_0825.id.tsv" --as nih0825_new\
--limit 10
# Out:
# [2021-08-26 02:59:59 sqlstore]: IMPORT graph directly into table graph_49 from /Users/grantxie/Downloads/kgtk-files-nih-V5.0/nih_project_0825.id.tsv ...
# [2021-08-26 03:00:11 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_49 AS graph_49_c1
#      LIMIT ?
#   PARAS: [10]
# ---------------------------------------------
# id	node1	label	node2
# QNIHPRO10286324-PNIHtitle-cfa7f1	QNIHPRO10286324	PNIHtitle	"CD38-TARGETED IMMUNOPET OF MYELOMA: PHASE 2 TRIAL OF CLINICAL APPLICATIONS"
# QNIHPRO10286324-PNIHstart-f85450	QNIHPRO10286324	PNIHstart	"02/01/2021"
# QNIHPRO10286324-PNIHorg-QNIHORG205901	QNIHPRO10286324	PNIHorg	QNIHORG205901
# QNIHPRO10286324-PNIHcost-452920	QNIHPRO10286324	PNIHcost	598926
# QNIHPRO10286324-PNIHsub-730793	QNIHPRO10286324	PNIHsub	"Antibodies; base; Biopsy; blind; Blood Tests; Bone marrow biopsy; burden of illness; cancer imaging; Cells; Clinical; clinical application; clinical care; Clinical Trials; clinically significant; Combined Modality Therapy; design; Detection; Detection of Minimal Residual Disease; Disease; dosimetry; early phase trial; experience; first-in-human; fluorodeoxyglucose positron emission tomography; Funding Opportunities; Future; Goals; Histologic; Human; human imaging; Image; imaging agent; imaging modality; Immunoglobulins; ImmunoPET; individual patient; innovation; Investigation; Laboratories; Measurement; Measures; Membrane Proteins; Memorial Sloan-Kettering Cancer Center; Methods; Monitor; Monoclonal Antibodies; Multiple Myeloma; multiple myeloma M Protein; novel; outcome forecast; Patient Care; Patient imaging; Patient Monitoring; Patients; PET/CT scan; Phase; Phase I Clinical Trials; phase I trial; Phase II Clinical Trials; phase II trial; Plasma Cell Neoplasm; Plasma Cells; Positron-Emission Tomography; preclinical imaging; predicting response; Prognostic Marker; Proteins; Radiochemistry; Radioimmunotherapy; Radiolabeled; Research Personnel; Residual Tumors; response; Safety; Selection for Treatments; Serum; Site; Surface; targeted imaging; theranostics; Therapeutic Agents; Tracer; Translations; treatment response; tumor; Tumor Burden; United States; uptake; virtual; Visualization; Work;"
# QNIHPRO10258167-PNIHtitle-90b590	QNIHPRO10258167	PNIHtitle	"Mechanism of selective packaging of primer tRNALys3 by HIV-1"
# QNIHPRO10258167-PNIHstart-f6f53e	QNIHPRO10258167	PNIHstart	"03/22/2021"
# QNIHPRO10258167-PNIHorg-QNIHORG9420201	QNIHPRO10258167	PNIHorg	QNIHORG9420201
# QNIHPRO10258167-PNIHcost-686611	QNIHPRO10258167	PNIHcost	217898
# QNIHPRO10258167-PNIHsub-dfb3bb	QNIHPRO10258167	PNIHsub	"Acquired Immunodeficiency Syndrome; Address; Affinity; Amino Acyl-tRNA Synthetases; Aminoacylation; Anisotropy; Anti-Retroviral Agents; base; Binding; Biochemical; Biological Assay; Biology; biophysical techniques; C-terminal; Calorimetry; Capsid Proteins; Catalytic Domain; Cells; Charge; Chemicals; comparative; Complex; Coupled; crosslink; Cryoelectron Microscopy; Crystallization; Data; Dependence; design; Development; Dissection; drug development; Drug resistance; Electron Microscopy; Electrophoretic Mobility Shift Assay; EMSA; Enzymes; Event; experimental study; flexibility; Fluorescence; Fluorescence Anisotropy; Goals; HIV; HIV-1; Individual; Infection; insight; Kinetics; Knowledge; Life Cycle Stages; light scattering; Lysine-Specific tRNA; Lysine-tRNA Ligase; Measures; Modeling; Molecular; Molecular Sieve Chromatography; mutant; Negative Staining; new therapeutic target; Non-Small-Cell Lung Carcinoma; novel; pandemic disease; particle; Pharmaceutical Preparations; Phosphorylation; Play; pol Gene Products; Process; Public Health; Recording of previous events; recruit; Reporting; Research; resistance mutation; Resolution; Reverse Transcription; Role; screening; SP1 gene; Structure; success; Testing; therapeutic development; Titrations; Transcriptional Regulation; Transfer RNA; Vaccines; Validation; Viral Genome; Viral Reverse Transcription; Virion; Work; X-Ray Crystallography;"

# %%
test = pd.read_csv('final.tsv', sep ='\t')

# %%
test
# Out:
#                                cluster_id  \
# 0      cluster_0_0_0_5_34_82_165_315_1172
# 1         cluster_0_0_0_3_12_19_26_39_990
# 2       cluster_0_1_1_12_27_47_75_129_446
# 3       cluster_0_1_1_12_27_47_75_129_446
# 4       cluster_0_1_1_12_27_47_75_129_446
# ...                                   ...
# 15238  cluster_0_1_1_12_27_75_124_219_527
# 15239  cluster_0_1_1_12_27_75_124_219_527
# 15240  cluster_0_1_1_12_27_75_124_219_527
# 15241  cluster_0_1_1_12_27_75_124_219_527
# 15242  cluster_0_1_1_12_27_75_124_219_527
#
#                                        org_name    org_lat   org_long  \
# 0                          'Yale University'@en  41.311111 -72.926667
# 1                          'Yale University'@en  41.311111 -72.926667
# 2                          'Yale University'@en  41.311111 -72.926667
# 3                          'Yale University'@en  41.311111 -72.926667
# 4                          'Yale University'@en  41.311111 -72.926667
# ...                                         ...        ...        ...
# 15238  'Albert Einstein College of Medicine'@en  40.850852 -73.844949
# 15239  'Albert Einstein College of Medicine'@en  40.850852 -73.844949
# 15240  'Albert Einstein College of Medicine'@en  40.850852 -73.844949
# 15241  'Albert Einstein College of Medicine'@en  40.850852 -73.844949
# 15242  'Albert Einstein College of Medicine'@en  40.850852 -73.844949
#
#        org_inc                     hosp_name   hosp_lat   hosp_long  hosp_inc  \
# 0       1701.0   'Smilow Cancer Hospital'@en  41.304278  -72.935676    2009.0
# 1       1701.0      'UCSF Medical Center'@en  37.763200 -122.458000    1907.0
# 2       1701.0   'Smilow Cancer Hospital'@en  41.304278  -72.935676    2009.0
# 3       1701.0   'Smilow Cancer Hospital'@en  41.304278  -72.935676    2009.0
# 4       1701.0   'Smilow Cancer Hospital'@en  41.304278  -72.935676    2009.0
# ...        ...                           ...        ...         ...       ...
# 15238   1955.0  'Calvary Hospital, Bronx'@en  40.847986  -73.843853    1899.0
# 15239   1955.0  'Calvary Hospital, Bronx'@en  40.847986  -73.843853    1899.0
# 15240   1955.0  'Calvary Hospital, Bronx'@en  40.847986  -73.843853    1899.0
# 15241   1955.0  'Calvary Hospital, Bronx'@en  40.847986  -73.843853    1899.0
# 15242   1955.0  'Calvary Hospital, Bronx'@en  40.847986  -73.843853    1899.0
#
#        count_beds                        ms_name  subject_count        cost  \
# 0             NaN           'phosphorylation'@en           5100  3583893760
# 1           796.0                    'CRISPR'@en           4662  3295411734
# 2             NaN            'RNA sequencing'@en           3198  3663737922
# 3             NaN                  'database'@en           3198  3663737922
# 4             NaN                'statistics'@en           2214  2536433946
# ...           ...                            ...            ...         ...
# 15238       225.0  'multiple drug resistance'@en             16     5784638
# 15239       225.0           'phosphorylation'@en             16     5784638
# 15240       225.0      'substance dependence'@en             16     5784638
# 15241       225.0              'team science'@en             16     5784638
# 15242       225.0                 'xenograft'@en             16     5784638
#
#             start
# 0      06/01/2021
# 1      06/01/2021
# 2      04/01/2021
# 3      04/01/2021
# 4      04/01/2021
# ...           ...
# 15238  07/01/2017
# 15239  07/01/2017
# 15240  07/01/2017
# 15241  07/01/2017
# 15242  07/01/2017
#
# [15243 rows x 14 columns]

# %%
for i in range(0, len(df)):
    df.start[i] = df.start[i][len(df.start[i])-4:]
# Out:
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['count_beds'].fillna(value=df['count_beds'].mean(), inplace=True)

# %%
df.to_excel('nih_0826_new2.xlsx', index = False)

# %%
for i in range(0, len(df)):
    df.start[i] = df.start[i][len(df.start[i])-4:]
# Out:
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head()
# Out:
#                            cluster_id              org_name    org_lat  \
# 0  cluster_0_0_0_5_34_82_165_315_1172  'Yale University'@en  41.311111
# 1  cluster_0_0_0_3_12_20_131_236_1292  'Yale University'@en  41.311111
# 2     cluster_0_0_0_3_12_19_26_39_990  'Yale University'@en  41.311111
# 3  cluster_0_0_0_5_34_82_165_315_1172  'Yale University'@en  41.311111
# 4  cluster_0_0_0_5_34_82_165_315_1172  'Yale University'@en  41.311111
#
#     org_long  org_inc                    hosp_name   hosp_lat   hosp_long  \
# 0 -72.926667   1701.0  'Smilow Cancer Hospital'@en  41.304278  -72.935676
# 1 -72.926667   1701.0  'Smilow Cancer Hospital'@en  41.304278  -72.935676
# 2 -72.926667   1701.0     'UCSF Medical Center'@en  37.763200 -122.458000
# 3 -72.926667   1701.0  'Smilow Cancer Hospital'@en  41.304278  -72.935676
# 4 -72.926667   1701.0  'Smilow Cancer Hospital'@en  41.304278  -72.935676
#
#    hosp_inc  count_beds                  ms_name  subject_count         cost  \
# 0    2009.0         NaN     'phosphorylation'@en            850  554722240.0
# 1    2009.0         NaN  'Toll-like receptor'@en            360  121399080.0
# 2    1907.0       796.0              'CRISPR'@en            222  460578516.0
# 3    2009.0         NaN     'corpus striatum'@en            180  117470592.0
# 4    2009.0         NaN            'dopamine'@en            160  104418304.0
#
#   start
# 0  2021
# 1  2021
# 2  2021
# 3  2021
# 4  2021

# %%
df['count_beds'].fillna(value=df['count_beds'].mean(), inplace=True)

# %%
df.to_excel('nih_0825.xlsx', index = False)

# %% [markdown]
# ## Adding internet coverage by county to map background

# %%
import pandas as pd
df = pd.read_csv('countycode.tsv', sep = '\t')
df.to_excel('FIPS.xlsx')

# %%
df['FIPS'] = ''

# %%
cov = pd.read_csv('/Users/grantxie/Downloads/broadband_data_2020October.csv')

# %%
cov = cov[18:]

# %%
cov = cov.reset_index(drop = True)

# %%
cov.head()
# Out:
#   Data is to be used only for analysis purposes related to broadband mapping  \
# 0                                                 AL
# 1                                                 AL
# 2                                                 AL
# 3                                                 AL
# 4                                                 AL
#
#   Unnamed: 1      Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0       1001  Autauga County     0.8057      0.391
# 1       1003  Baldwin County     0.8362      0.452
# 2       1005  Barbour County     0.6891      0.324
# 3       1007     Bibb County     0.3368      0.136
# 4       1009   Blount County      0.758      0.199

# %%
cov
# Out:
#      Data is to be used only for analysis purposes related to broadband mapping  \
# 0                                                    AL
# 1                                                    AL
# 2                                                    AL
# 3                                                    AL
# 4                                                    AL
# ...                                                 ...
# 3137                                                 WY
# 3138                                                 WY
# 3139                                                 WY
# 3140                                                 WY
# 3141                                                 WY
#
#      Unnamed: 1         Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0          1001     Autauga County     0.8057      0.391
# 1          1003     Baldwin County     0.8362      0.452
# 2          1005     Barbour County     0.6891      0.324
# 3          1007        Bibb County     0.3368      0.136
# 4          1009      Blount County      0.758      0.199
# ...         ...                ...        ...        ...
# 3137      56037  Sweetwater County     0.9422        0.4
# 3138      56039       Teton County     0.9508      0.623
# 3139      56041       Uinta County     0.9963      0.431
# 3140      56043    Washakie County     0.8903      0.571
# 3141      56045      Weston County     0.8937      0.152
#
# [3142 rows x 5 columns]

# %%
for i in range(0, len(cov)):
    if len(cov['Unnamed: 1'][i]) == 4:
        cov['Unnamed: 1'][i] = '0' + str(cov['Unnamed: 1'][i])

# %%
for i in range(0, len(df)):
    df['n1'][i] = cov['Unnamed: 3'][i]
    df['n2'][i] = cov['Unnamed: 4'][i]
# Out:
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/kgtk-env/lib/python3.7/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df
# Out:
#                  county    qnode   code   FIPS      n1     n2
# 0        Autauga County  Q156168   1001  01001  0.8057  0.391
# 1        Baldwin County  Q156163   1003  01003  0.8362  0.452
# 2        Barbour County  Q109437   1005  01005  0.6891  0.324
# 3           Bibb County  Q461204   1007  01007  0.3368  0.136
# 4         Blount County  Q111250   1009  01009   0.758  0.199
# ...                 ...      ...    ...    ...     ...    ...
# 3124  Sweetwater County  Q484194  56037  56037  0.8503   0.21
# 3125       Teton County  Q488912  56039  56039  0.7941  0.373
# 3126       Uinta County  Q483973  56041  56041  0.9972  0.198
# 3127    Washakie County  Q112846  56043  56043  0.8722  0.381
# 3128      Weston County  Q115413  56045  56045  0.9217  0.456
#
# [3129 rows x 6 columns]

# %%
out
# Out:
#                                 cluster  \
# 0    cluster_0_0_0_5_34_82_165_315_1172
# 1    cluster_0_0_0_3_12_20_131_236_1292
# 2       cluster_0_0_0_3_12_19_26_39_990
# 3    cluster_0_0_0_5_34_82_165_315_1172
# 4     cluster_0_1_1_12_27_47_75_129_446
# ..                                  ...
# 617    cluster_0_0_0_3_12_20_27_233_494
# 618  cluster_0_1_1_12_29_57_94_232_1261
# 619    cluster_0_0_0_3_12_20_27_233_494
# 620  cluster_0_1_1_12_29_57_94_232_1261
# 621    cluster_0_0_0_3_12_20_27_233_494
#
#                                      org_name  org_node    org_lat   org_long  \
# 0                        'Yale University'@en    Q49112  41.311111 -72.926667
# 1                        'Yale University'@en    Q49112  41.311111 -72.926667
# 2                        'Yale University'@en    Q49112  41.311111 -72.926667
# 3                        'Yale University'@en    Q49112  41.311111 -72.926667
# 4                        'Yale University'@en    Q49112  41.311111 -72.926667
# ..                                        ...       ...        ...        ...
# 617  'Albert Einstein College of Medicine'@en  Q2030894  40.850852 -73.844949
# 618  'Albert Einstein College of Medicine'@en  Q2030894  40.850852 -73.844949
# 619  'Albert Einstein College of Medicine'@en  Q2030894  40.850852 -73.844949
# 620  'Albert Einstein College of Medicine'@en  Q2030894  40.850852 -73.844949
# 621  'Albert Einstein College of Medicine'@en  Q2030894  40.850852 -73.844949
#
#      org_inc                     hosp_name  hosp_node   hosp_lat   hosp_long  \
# 0     1701.0   'Smilow Cancer Hospital'@en  Q50037095  41.304278  -72.935676
# 1     1701.0   'Smilow Cancer Hospital'@en  Q50037095  41.304278  -72.935676
# 2     1701.0      'UCSF Medical Center'@en   Q7864122  37.763200 -122.458000
# 3     1701.0   'Smilow Cancer Hospital'@en  Q50037095  41.304278  -72.935676
# 4     1701.0   'Smilow Cancer Hospital'@en  Q50037095  41.304278  -72.935676
# ..       ...                           ...        ...        ...         ...
# 617   1955.0  'Calvary Hospital, Bronx'@en   Q5024190  40.847986  -73.843853
# 618   1955.0  'Calvary Hospital, Bronx'@en   Q5024190  40.847986  -73.843853
# 619   1955.0  'Calvary Hospital, Bronx'@en   Q5024190  40.847986  -73.843853
# 620   1955.0  'Calvary Hospital, Bronx'@en   Q5024190  40.847986  -73.843853
# 621   1955.0  'Calvary Hospital, Bronx'@en   Q5024190  40.847986  -73.843853
#
#      hosp_inc    hosp_bed                                   subject1  \
# 0      2009.0  657.884393                       'phosphorylation'@en
# 1      2009.0  657.884393                    'Toll-like receptor'@en
# 2      1907.0  796.000000                                'CRISPR'@en
# 3      2009.0  657.884393                       'corpus striatum'@en
# 4      2009.0  657.884393                        'RNA sequencing'@en
# ..        ...         ...                                        ...
# 617    1899.0  225.000000                        'RNA sequencing'@en
# 618    1899.0  225.000000                     'apoptotic process'@en
# 619    1899.0  225.000000                         'schizophrenia'@en
# 620    1899.0  225.000000  'BH3 interacting domain death agonist'@en
# 621    1899.0  225.000000  'Human Induced Pluripotent Stem Cells'@en
#
#                                       subject2  \
# 0                      'Toll-like receptor'@en
# 1                                  'CRISPR'@en
# 2                         'corpus striatum'@en
# 3                                'dopamine'@en
# 4                                'database'@en
# ..                                         ...
# 617                     'apoptotic process'@en
# 618                  'molecular chaperones'@en
# 619  'BH3 interacting domain death agonist'@en
# 620                                'Bcl-xL'@en
# 621                                'autism'@en
#
#                                               subject3  \
# 0                                          'CRISPR'@en
# 1                                 'corpus striatum'@en
# 2                                        'dopamine'@en
# 3                                  'RNA sequencing'@en
# 4                            'Alzheimer\'s disease'@en
# ..                                                 ...
# 617                          'molecular chaperones'@en
# 618                                 'schizophrenia'@en
# 619                                        'Bcl-xL'@en
# 620  'Chemical modulation of chaperone-mediated aut...
# 621                                 'transcriptome'@en
#
#                                               subject4  \
# 0                                 'corpus striatum'@en
# 1                                        'dopamine'@en
# 2                                  'RNA sequencing'@en
# 3                                        'database'@en
# 4                                      'statistics'@en
# ..                                                 ...
# 617                                 'schizophrenia'@en
# 618          'BH3 interacting domain death agonist'@en
# 619  'Chemical modulation of chaperone-mediated aut...
# 620                              'Fanconi syndrome'@en
# 621                                        'CRISPR'@en
#
#                                       subject5   FIPS      n1     n2
# 0                                'dopamine'@en  01001  0.8057  0.391
# 1                          'RNA sequencing'@en  01003  0.8362  0.452
# 2                                'database'@en  01005  0.6891  0.324
# 3                    'Alzheimer\'s disease'@en  01007  0.3368  0.136
# 4                            'inflammation'@en  01009   0.758  0.199
# ..                                         ...    ...     ...    ...
# 617  'BH3 interacting domain death agonist'@en  17045  0.9221  0.173
# 618                                'Bcl-xL'@en  17047  0.7801  0.188
# 619                      'Fanconi syndrome'@en  17049  0.9528  0.586
# 620                        'autoinhibition'@en  17051  0.5575  0.198
# 621                          'cell biology'@en  17053  0.8982  0.349
#
# [622 rows x 20 columns]

# %%
row = pd.DataFrame([[np.nan] * len(out.columns)], columns=out.columns)
out = out.append(row, ignore_index=True)

# %%
for i in range(0, 3000):
    out = out.append(row, ignore_index=True)

# %%
out = pd.read_excel('/Users/grantxie/Downloads/NIH/top5_subject.xlsx')

# %%
out['FIPS'] = ''
out['n1'] = 0.0
out['n2'] = 0.0

# %%
out['county'] = ''

# %%
out.append(pd.Series(), ignore_index=True)
out
# Out:
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.
#                                  cluster  \
# 0    cluster_0_1_3_11_25_80_153_279_1164
# 1    cluster_0_1_3_11_25_80_153_279_1164
# 2         cluster_0_0_2_2_11_1_15_90_574
# 3    cluster_0_1_1_12_27_75_144_358_1672
# 4        cluster_0_1_4_7_21_36_48_78_451
# ..                                   ...
# 617     cluster_0_1_3_9_28_49_65_104_870
# 618  cluster_0_1_3_11_25_81_158_385_1488
# 619  cluster_0_1_3_11_25_81_158_385_1488
# 620    cluster_0_0_2_1_19_31_45_398_1684
# 621      cluster_0_0_0_8_10_15_20_26_511
#
#                                               org_name  org_node    org_lat  \
# 0           'University of California, Los Angeles'@en   Q174710  34.072222
# 1                              'Harvard University'@en    Q13371  42.374444
# 2    'University of Texas MD Anderson Cancer Center...  Q1525831  29.707800
# 3                              'Harvard University'@en    Q13371  42.374444
# 4    'University of Pittsburgh Graduate School of P...  Q7896126  40.442600
# ..                                                 ...       ...        ...
# 617                      'University of Washington'@en   Q219563  47.654167
# 618                            'Harvard University'@en    Q13371  42.374444
# 619       'University of California, San Francisco'@en  Q1061104  37.763319
# 620           'University of California, San Diego'@en   Q622664  32.881000
# 621                           'Stanford University'@en    Q41506  37.428229
#
#        org_long  org_inc                                          hosp_name  \
# 0   -118.444167   1919.0                            'Spaulding Hospital'@en
# 1    -71.116944   1636.0                            'Spaulding Hospital'@en
# 2    -95.397500   1941.0  'University of Texas MD Anderson Cancer Center...
# 3    -71.116944   1636.0                            'Spaulding Hospital'@en
# 4    -79.958200   1948.0  'Center for Emergency Medicine of Western Penn...
# ..          ...      ...                                                ...
# 617 -122.308056   1861.0       'University of Washington Medical Center'@en
# 618  -71.116944   1636.0                           'UCSF Medical Center'@en
# 619 -122.458539   1873.0                           'UCSF Medical Center'@en
# 620 -117.238000   1960.0                         'Jacobs Medical Center'@en
# 621 -122.168858   1891.0            'Stanford University Medical Center'@en
#
#      hosp_node   hosp_lat   hosp_long  ...  subject5_count  subject1_cost  \
# 0    Q30270420  42.375748  -71.107052  ...           24200   1.938386e+11
# 1    Q30270420  42.375748  -71.107052  ...           66024   1.938386e+11
# 2     Q1525831  29.707800  -95.397500  ...           28998   1.482875e+11
# 3    Q30270420  42.375748  -71.107052  ...           44016   1.803773e+12
# 4     Q5059612  40.439200  -79.958900  ...           64240   6.762670e+10
# ..         ...        ...         ...  ...             ...            ...
# 617   Q7896576  47.648923 -122.306595  ...              90   3.228399e+07
# 618   Q7864122  37.763200 -122.458000  ...              65   5.368876e+07
# 619   Q7864122  37.763200 -122.458000  ...              65   5.368876e+07
# 620  Q38250501  32.877703 -117.226499  ...          314600   8.909118e+06
# 621   Q7598810  37.434000 -122.175000  ...              59   5.428472e+06
#
#     subject2_cost subject3_cost subject4_cost subject5_cost FIPS   n1   n2  \
# 0    1.057301e+11  8.268639e+10  1.626617e+10  1.491066e+10       0.0  0.0
# 1    1.057301e+11  1.803773e+12  8.268639e+10  7.284469e+11       0.0  0.0
# 2    7.544451e+10  7.544451e+10  6.763990e+10  2.341381e+10       0.0  0.0
# 3    8.268639e+10  7.284469e+11  5.203192e+11  4.856313e+11       0.0  0.0
# 4    4.830478e+10  3.355911e+10  2.898287e+10  2.796593e+10       0.0  0.0
# ..            ...           ...           ...           ...  ...  ...  ...
# 617  3.228399e+07  3.228399e+07  3.228399e+07  3.228399e+07       0.0  0.0
# 618  5.368876e+07  5.368876e+07  5.368876e+07  5.368876e+07       0.0  0.0
# 619  5.368876e+07  5.368876e+07  5.368876e+07  5.368876e+07       0.0  0.0
# 620  8.909118e+06  8.909118e+06  8.909118e+06  1.938386e+11       0.0  0.0
# 621  5.428472e+06  5.428472e+06  5.428472e+06  5.428472e+06       0.0  0.0
#
#      county
# 0
# 1
# 2
# 3
# 4
# ..      ...
# 617
# 618
# 619
# 620
# 621
#
# [622 rows x 31 columns]

# %%
for i in range(0, len(df)):
    out['FIPS'][i] = df['FIPS'][i]
    out['n1'][i] =df['n1'][i]
    out['n2'][i] = df['n2'][i]
    out['county'][i] = df['county'][i]
# Out:
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
out
# Out:
#                                  cluster              org_name org_node  \
# 0     cluster_0_0_0_5_34_82_165_315_1172  'Yale University'@en   Q49112
# 1     cluster_0_0_0_3_12_20_131_236_1292  'Yale University'@en   Q49112
# 2        cluster_0_0_0_3_12_19_26_39_990  'Yale University'@en   Q49112
# 3     cluster_0_0_0_5_34_82_165_315_1172  'Yale University'@en   Q49112
# 4      cluster_0_1_1_12_27_47_75_129_446  'Yale University'@en   Q49112
# ...                                  ...                   ...      ...
# 3618                                 NaN                   NaN      NaN
# 3619                                 NaN                   NaN      NaN
# 3620                                 NaN                   NaN      NaN
# 3621                                 NaN                   NaN      NaN
# 3622                                 NaN                   NaN      NaN
#
#         org_lat   org_long  org_inc                    hosp_name  hosp_node  \
# 0     41.311111 -72.926667   1701.0  'Smilow Cancer Hospital'@en  Q50037095
# 1     41.311111 -72.926667   1701.0  'Smilow Cancer Hospital'@en  Q50037095
# 2     41.311111 -72.926667   1701.0     'UCSF Medical Center'@en   Q7864122
# 3     41.311111 -72.926667   1701.0  'Smilow Cancer Hospital'@en  Q50037095
# 4     41.311111 -72.926667   1701.0  'Smilow Cancer Hospital'@en  Q50037095
# ...         ...        ...      ...                          ...        ...
# 3618        NaN        NaN      NaN                          NaN        NaN
# 3619        NaN        NaN      NaN                          NaN        NaN
# 3620        NaN        NaN      NaN                          NaN        NaN
# 3621        NaN        NaN      NaN                          NaN        NaN
# 3622        NaN        NaN      NaN                          NaN        NaN
#
#        hosp_lat   hosp_long  hosp_inc    hosp_bed                 subject1  \
# 0     41.304278  -72.935676    2009.0  657.884393     'phosphorylation'@en
# 1     41.304278  -72.935676    2009.0  657.884393  'Toll-like receptor'@en
# 2     37.763200 -122.458000    1907.0  796.000000              'CRISPR'@en
# 3     41.304278  -72.935676    2009.0  657.884393     'corpus striatum'@en
# 4     41.304278  -72.935676    2009.0  657.884393      'RNA sequencing'@en
# ...         ...         ...       ...         ...                      ...
# 3618        NaN         NaN       NaN         NaN                      NaN
# 3619        NaN         NaN       NaN         NaN                      NaN
# 3620        NaN         NaN       NaN         NaN                      NaN
# 3621        NaN         NaN       NaN         NaN                      NaN
# 3622        NaN         NaN       NaN         NaN                      NaN
#
#                      subject2                   subject3  \
# 0     'Toll-like receptor'@en                'CRISPR'@en
# 1                 'CRISPR'@en       'corpus striatum'@en
# 2        'corpus striatum'@en              'dopamine'@en
# 3               'dopamine'@en        'RNA sequencing'@en
# 4               'database'@en  'Alzheimer\'s disease'@en
# ...                       ...                        ...
# 3618                      NaN                        NaN
# 3619                      NaN                        NaN
# 3620                      NaN                        NaN
# 3621                      NaN                        NaN
# 3622                      NaN                        NaN
#
#                   subject4                   subject5   FIPS      n1     n2
# 0     'corpus striatum'@en              'dopamine'@en  01001  0.8057  0.391
# 1            'dopamine'@en        'RNA sequencing'@en  01003  0.8362  0.452
# 2      'RNA sequencing'@en              'database'@en  01005  0.6891  0.324
# 3            'database'@en  'Alzheimer\'s disease'@en  01007  0.3368  0.136
# 4          'statistics'@en          'inflammation'@en  01009   0.758  0.199
# ...                    ...                        ...    ...     ...    ...
# 3618                   NaN                        NaN    NaN     NaN    NaN
# 3619                   NaN                        NaN    NaN     NaN    NaN
# 3620                   NaN                        NaN    NaN     NaN    NaN
# 3621                   NaN                        NaN    NaN     NaN    NaN
# 3622                   NaN                        NaN    NaN     NaN    NaN
#
# [3623 rows x 20 columns]

# %%
for i in range(0, len(cov)):
    out.FIPS[i] = cov['Unnamed: 1'][i]
# Out:
# /Users/grantxie/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
out[out['FIPS'] != '']
# Out:
#                                 cluster  \
# 0    cluster_0_0_0_5_34_82_165_315_1172
# 1    cluster_0_0_0_3_12_20_131_236_1292
# 2       cluster_0_0_0_3_12_19_26_39_990
# 3    cluster_0_0_0_5_34_82_165_315_1172
# 4     cluster_0_1_1_12_27_47_75_129_446
# ..                                  ...
# 617    cluster_0_0_0_3_12_20_27_233_494
# 618  cluster_0_1_1_12_29_57_94_232_1261
# 619    cluster_0_0_0_3_12_20_27_233_494
# 620  cluster_0_1_1_12_29_57_94_232_1261
# 621    cluster_0_0_0_3_12_20_27_233_494
#
#                                      org_name  org_node    org_lat   org_long  \
# 0                        'Yale University'@en    Q49112  41.311111 -72.926667
# 1                        'Yale University'@en    Q49112  41.311111 -72.926667
# 2                        'Yale University'@en    Q49112  41.311111 -72.926667
# 3                        'Yale University'@en    Q49112  41.311111 -72.926667
# 4                        'Yale University'@en    Q49112  41.311111 -72.926667
# ..                                        ...       ...        ...        ...
# 617  'Albert Einstein College of Medicine'@en  Q2030894  40.850852 -73.844949
# 618  'Albert Einstein College of Medicine'@en  Q2030894  40.850852 -73.844949
# 619  'Albert Einstein College of Medicine'@en  Q2030894  40.850852 -73.844949
# 620  'Albert Einstein College of Medicine'@en  Q2030894  40.850852 -73.844949
# 621  'Albert Einstein College of Medicine'@en  Q2030894  40.850852 -73.844949
#
#      org_inc                     hosp_name  hosp_node   hosp_lat   hosp_long  \
# 0     1701.0   'Smilow Cancer Hospital'@en  Q50037095  41.304278  -72.935676
# 1     1701.0   'Smilow Cancer Hospital'@en  Q50037095  41.304278  -72.935676
# 2     1701.0      'UCSF Medical Center'@en   Q7864122  37.763200 -122.458000
# 3     1701.0   'Smilow Cancer Hospital'@en  Q50037095  41.304278  -72.935676
# 4     1701.0   'Smilow Cancer Hospital'@en  Q50037095  41.304278  -72.935676
# ..       ...                           ...        ...        ...         ...
# 617   1955.0  'Calvary Hospital, Bronx'@en   Q5024190  40.847986  -73.843853
# 618   1955.0  'Calvary Hospital, Bronx'@en   Q5024190  40.847986  -73.843853
# 619   1955.0  'Calvary Hospital, Bronx'@en   Q5024190  40.847986  -73.843853
# 620   1955.0  'Calvary Hospital, Bronx'@en   Q5024190  40.847986  -73.843853
# 621   1955.0  'Calvary Hospital, Bronx'@en   Q5024190  40.847986  -73.843853
#
#      hosp_inc    hosp_bed                                   subject1  \
# 0      2009.0  657.884393                       'phosphorylation'@en
# 1      2009.0  657.884393                    'Toll-like receptor'@en
# 2      1907.0  796.000000                                'CRISPR'@en
# 3      2009.0  657.884393                       'corpus striatum'@en
# 4      2009.0  657.884393                        'RNA sequencing'@en
# ..        ...         ...                                        ...
# 617    1899.0  225.000000                        'RNA sequencing'@en
# 618    1899.0  225.000000                     'apoptotic process'@en
# 619    1899.0  225.000000                         'schizophrenia'@en
# 620    1899.0  225.000000  'BH3 interacting domain death agonist'@en
# 621    1899.0  225.000000  'Human Induced Pluripotent Stem Cells'@en
#
#                                       subject2  \
# 0                      'Toll-like receptor'@en
# 1                                  'CRISPR'@en
# 2                         'corpus striatum'@en
# 3                                'dopamine'@en
# 4                                'database'@en
# ..                                         ...
# 617                     'apoptotic process'@en
# 618                  'molecular chaperones'@en
# 619  'BH3 interacting domain death agonist'@en
# 620                                'Bcl-xL'@en
# 621                                'autism'@en
#
#                                               subject3  \
# 0                                          'CRISPR'@en
# 1                                 'corpus striatum'@en
# 2                                        'dopamine'@en
# 3                                  'RNA sequencing'@en
# 4                            'Alzheimer\'s disease'@en
# ..                                                 ...
# 617                          'molecular chaperones'@en
# 618                                 'schizophrenia'@en
# 619                                        'Bcl-xL'@en
# 620  'Chemical modulation of chaperone-mediated aut...
# 621                                 'transcriptome'@en
#
#                                               subject4  \
# 0                                 'corpus striatum'@en
# 1                                        'dopamine'@en
# 2                                  'RNA sequencing'@en
# 3                                        'database'@en
# 4                                      'statistics'@en
# ..                                                 ...
# 617                                 'schizophrenia'@en
# 618          'BH3 interacting domain death agonist'@en
# 619  'Chemical modulation of chaperone-mediated aut...
# 620                              'Fanconi syndrome'@en
# 621                                        'CRISPR'@en
#
#                                       subject5   FIPS      n1     n2
# 0                                'dopamine'@en  01001  0.8057  0.391
# 1                          'RNA sequencing'@en  01003  0.8362  0.452
# 2                                'database'@en  01005  0.6891  0.324
# 3                    'Alzheimer\'s disease'@en  01007  0.3368  0.136
# 4                            'inflammation'@en  01009   0.758  0.199
# ..                                         ...    ...     ...    ...
# 617  'BH3 interacting domain death agonist'@en  17045  0.9221  0.173
# 618                                'Bcl-xL'@en  17047  0.7801  0.188
# 619                      'Fanconi syndrome'@en  17049  0.9528  0.586
# 620                        'autoinhibition'@en  17051  0.5575  0.198
# 621                          'cell biology'@en  17053  0.8982  0.349
#
# [622 rows x 20 columns]

# %%
out.to_excel('/Users/grantxie/Downloads/NIH/nih_0909_new3.xlsx')
